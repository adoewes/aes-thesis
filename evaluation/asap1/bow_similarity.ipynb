# %%
import numpy as np
import joblib
from sklearn.metrics.pairwise import cosine_similarity

# %%
ease = joblib.load("essay_ease_spelling_unique_416_paraphrase_withprompt")

# %%
x_ease = ease[:-1]
prompt = ease[-1]

# %%
x_ease.shape
# Out:
# (1783, 416)

# %%
prompt = prompt.reshape(1,-1)
prompt.shape
# Out:
# (1, 416)

# %%
x = x_ease[:, 12:-2]
x.shape
# Out:
# (1783, 402)

# %%
prompt = prompt[:, 12:-2]
prompt.shape
# Out:
# (1, 402)

# %%
essays = x
essays.shape
# Out:
# (1783, 402)

# %%
text1 = essays[0]
cosine_similarity(text1.reshape(1,-1), prompt.reshape(1,-1))
# Out:
# array([[0.42121986]])

# %%
similarity_list = []

for i in range(len(essays)):
    similarity_list.append(cosine_similarity(essays[i].reshape(1,-1), prompt.reshape(1,-1))[0][0])

# %%
len(similarity_list)
# Out:
# 1783

# %%
similarity_list = np.array(similarity_list).reshape(-1,1)
similarity_list.shape
# Out:
# (1783, 1)

# %%
joblib.dump(similarity_list, "bow_similarity_asap1_paraphrase")
# Out:
# ['bow_similarity_asap1_paraphrase']

# %%
import joblib

# %%
a = joblib.load('bow_similarity_asap1')

# %%
a[:10]
# Out:
# array([[0.56599141],
#        [0.50290705],
#        [0.52658035],
#        [0.27101786],
#        [0.40826039],
#        [0.51741336],
#        [0.52548716],
#        [0.39385924],
#        [0.40424991],
#        [0.55788863]])
