# %%
import joblib
import pandas as pd
from quadratic_weighted_kappa import quadratic_weighted_kappa
from scipy.stats import pearsonr
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
scores = pd.read_excel("asap6_summary.xlsx")
y =  joblib.load('score_asap6')
model_score = joblib.load('score_model_normalized')
x = joblib.load('essay_ease10_sbert768_simbow_langerr_780_normalized_asap6')

# %%
x_12 = x[:, :12]
x_12.shape
# Out:
# (1800, 12)

# %%
scores
# Out:
#       Unnamed: 0  rater1_domain1  rater2_domain1  model_score  y  diff_r1r2  \
# 0              0               2               2            3  2          0
# 1              1               3               3            4  3          0
# 2              2               3               4            4  4          1
# 3              3               1               1            2  1          0
# 4              4               3               3            3  3          0
# ...          ...             ...             ...          ... ..        ...
# 1795        1795               2               0            2  0          2
# 1796        1796               1               2            2  2          1
# 1797        1797               2               3            3  3          1
# 1798        1798               2               1            2  2          1
# 1799        1799               2               2            2  2          0
#
#       diff_model_y
# 0                1
# ...

# %%
scores_2diff = scores[scores["diff_r1r2"] > 1]
scores_2diff
# Out:
#       Unnamed: 0  rater1_domain1  rater2_domain1  model_score  y  diff_r1r2  \
# 25            25               2               4            3  2          2
# 65            65               0               2            2  1          2
# 151          151               0               2            1  0          2
# 188          188               2               4            3  3          2
# 226          226               4               2            3  3          2
# 230          230               3               1            2  2          2
# 248          248               4               1            2  1          3
# 359          359               2               0            1  1          2
# 401          401               3               1            3  2          2
# 428          428               1               3            2  1          2
# 608          608               2               4            3  2          2
# ...

# %%
index_2diff = scores_2diff.index
len(index_2diff)
# Out:
# 27

# %%
x_12_2diff = x_12[index_2diff]
x_12_2diff.shape
# Out:
# (27, 12)

# %%
x_axis = np.arange(1800)

# %%
y_axis = x_12_2diff[:,0]

# %%
plt.plot(y_axis)
plt.show()

# %%
plt.plot(x_12[:,0])
plt.plot(y_axis)
plt.show()
