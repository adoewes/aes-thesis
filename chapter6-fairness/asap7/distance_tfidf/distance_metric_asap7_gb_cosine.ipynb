# %%
import pandas as pd
import numpy as np
import time
import joblib

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

from quadratic_weighted_kappa import quadratic_weighted_kappa

from scipy.spatial.distance import pdist,squareform

from collections import Counter

# %%
x = joblib.load('essay_tfidf_asap7')
#y = joblib.load('score_asap7')
pred = joblib.load('score_model_gb_normalized_float_tfidf')
x_normed = x / x.max(axis=0)

# %%
traits = joblib.load('df_essay7_traits_sum')

# %%
x.shape
# Out:
# (1569, 14974)

# %% [markdown]
# ## 1569 essays

# %%
dist_euclid = pdist(x, metric='cosine')

# %%
outcome_euclid = pdist(pred.reshape(-1,1), metric='euclidean')

# %%
dist = dist_euclid
outcome = outcome_euclid

# %% [markdown]
# ### Min-Max Normalization

# %%
dist_minmax = (dist-min(dist))/(max(dist)-min(dist))
outcome = (outcome-min(outcome))/(max(outcome)-min(outcome))

# %% [markdown]
# ### Max Normalization

# %%
dist_max = dist / dist.max()
outcome = outcome / outcome.max()

# %%
joblib.dump(dist_minmax, "distance_tfidf")
joblib.dump(outcome, "outcome_tfidf")
# Out:
# ['outcome_tfidf']

# %% [markdown]
# ### Plot

# %%
plt.hist(outcome, bins=100, label='outcome')
plt.hist(dist_minmax, bins=100, label='distance')
plt.legend()
plt.show()

# %%
plt.hist(outcome, bins=100, label='outcome')
plt.hist(dist_max, bins=100, label='distance')
plt.legend()
plt.show()

# %%
dist = squareform(dist_max)
outcome = squareform(outcome)

# %% [markdown]
# ## Evaluate whether pairs of essay satisfy the equation
#
# \begin{equation}
#     D(Mx, My) \leq d(x,y)
# \end{equation}

# %%
IF = outcome <= dist
IF
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
(np.count_nonzero(IF) - 1569) / 2
# Out:
# 1230095.0

# %% [markdown]
# ## Number of True pairs (MinMax)

# %% [markdown]
# Number of pairs (excluding with selves): 1.230.096 pairs
# x 1230024 : 99.9%

# %% [markdown]
# ## Number of True pairs (Max)

# %% [markdown]
# Number of pairs (excluding with selves): 1.230.096 pairs
# x 1230095 : 99.99%
