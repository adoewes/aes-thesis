# %%
import joblib
import numpy as np
import pandas as pd

# %%
iterdist_sorted = joblib.load('iterdist_sorted_laser')
score_gb = joblib.load('score_model_gb_normalized_float_laser_whole')
score_rf = joblib.load('score_model_rf_normalized_float_laser_whole')
score_rr = joblib.load('score_model_rr_normalized_float_laser_whole')

# %%
def compute_score_difference(pairs):
    score_diff_gb = []
    score_diff_rf = []
    score_diff_rr = []
    
    for pair in pairs:

        idx1 = pair[0]
        idx2 = pair[1]

        diff = abs(score_gb[idx1] - score_gb[idx2])
        score_diff_gb.append(diff)
        
        diff = abs(score_rf[idx1] - score_rf[idx2])
        score_diff_rf.append(diff)
        
        diff = abs(score_rr[idx1] - score_rr[idx2])
        score_diff_rr.append(diff)
    
    return score_diff_gb, score_diff_rf, score_diff_rr

# %%
len(iterdist_sorted)
# Out:
# 1230096

# %% [markdown]
# ### 1/5 pairs (nearest)

# %%
pairs_iter_1_5 = iterdist_sorted[:10000]

pairs_1_5 = [i[0] for i in pairs_iter_1_5]

# %% [markdown]
# ### 2/5 pairs

# %%
pairs_iter_2_5 = iterdist_sorted[302524:312524]

pairs_2_5 = [i[0] for i in pairs_iter_2_5]

# %% [markdown]
# ### 3/5 pairs (medium)

# %%
pairs_iter_3_5 = iterdist_sorted[610048:620048]

pairs_3_5 = [i[0] for i in pairs_iter_3_5]

# %% [markdown]
# ### 4/5 pairs

# %%
pairs_iter_4_5 = iterdist_sorted[917572:927572]

pairs_4_5 = [i[0] for i in pairs_iter_4_5]

# %% [markdown]
# ### 5/5 pairs (farthest)

# %%
pairs_iter_5_5 = iterdist_sorted[-10000:]

pairs_5_5 = [i[0] for i in pairs_iter_5_5]

# %%
a, b, c = compute_score_difference(pairs_1_5)

a = np.array(a)
a = np.mean(a, axis=0)
b = np.array(b)
b = np.mean(b, axis=0)
c = np.array(c)
c = np.mean(c, axis=0)

score_diff_1_5 = [a,b,c]

a, b, c = compute_score_difference(pairs_2_5)

a = np.array(a)
a = np.mean(a, axis=0)
b = np.array(b)
b = np.mean(b, axis=0)
c = np.array(c)
c = np.mean(c, axis=0)

score_diff_2_5 = [a,b,c]

a, b, c = compute_score_difference(pairs_3_5)

a = np.array(a)
a = np.mean(a, axis=0)
b = np.array(b)
b = np.mean(b, axis=0)
c = np.array(c)
c = np.mean(c, axis=0)

score_diff_3_5 = [a,b,c]

a, b, c = compute_score_difference(pairs_4_5)

a = np.array(a)
a = np.mean(a, axis=0)
b = np.array(b)
b = np.mean(b, axis=0)
c = np.array(c)
c = np.mean(c, axis=0)

score_diff_4_5 = [a,b,c]

a, b, c = compute_score_difference(pairs_5_5)

a = np.array(a)
a = np.mean(a, axis=0)
b = np.array(b)
b = np.mean(b, axis=0)
c = np.array(c)
c = np.mean(c, axis=0)

score_diff_5_5 = [a,b,c]

# %%
score_diff_1_5
# Out:
# [1.6280247269630432, 1.1984199999999998, 2.0758834917068483]

# %%
score_diff_2_5
# Out:
# [3.0710515145301818, 2.65325, 3.1341370196819307]

# %%
score_diff_3_5
# Out:
# [3.796663084459305, 3.366911, 3.891957914543152]

# %%
score_diff_4_5
# Out:
# [4.571354709863662, 4.10337, 4.894843807601928]

# %%
score_diff_5_5
# Out:
# [6.8290079678535465, 5.602182000000001, 9.290301133167743]

# %%
joblib.dump(score_diff_1_5, 'score_diff_1_5_laser')
joblib.dump(score_diff_2_5, 'score_diff_2_5_laser')
joblib.dump(score_diff_3_5, 'score_diff_3_5_laser')
joblib.dump(score_diff_4_5, 'score_diff_4_5_laser')
joblib.dump(score_diff_5_5, 'score_diff_5_5_laser')
# Out:
# ['score_diff_5_5_laser']
