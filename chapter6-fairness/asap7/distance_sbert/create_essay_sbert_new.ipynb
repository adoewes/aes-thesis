# %%
import joblib
import pandas as pd
import numpy as np

# %%
x = joblib.load('s-bert_asap7_prompt_mean_paragraph_new')
x = np.array(x)
x = x[:-1,:]
x.shape
# Out:
# (1569, 768)

# %%
joblib.dump(x, 'essay_sbert_asap7_new')
# Out:
# ['essay_sbert_asap7_new']

# %%
x_asap7 = joblib.load('essay_ease10_sbert768_simbow_langerr_780_normalized_asap7')
x_asap7.shape
# Out:
# (1569, 780)

# %%
x_asap7_12 = x_asap7[:,:12]
x_asap7_12.shape
# Out:
# (1569, 12)

# %%
x_new = np.concatenate((x_asap7_12, x), axis=1)
x_new.shape
# Out:
# (1569, 780)

# %%
joblib.dump(x_new, 'essay_ease10_sbert768_simbow_langerr_780_normalized_asap7_new')
# Out:
# ['essay_ease10_sbert768_simbow_langerr_780_normalized_asap7_new']
