# %%
import pandas as pd
import joblib

# %%
asap = pd.read_csv('../training_set_rel3.tsv', sep='\t', encoding = "ISO-8859-1")
asap = asap[asap['essay_set'] == 4]
asap = asap[['essay','domain1_score']]
asap
# Out:
#                                                   essay  domain1_score
# 5309  The author concludes the story with this becau...              0
# 5310  The narrater has that in with Paragraph becuse...              0
# 5311  The author concludes the story with that passa...              3
# 5312  The author ended the story with this paragraph...              2
# 5313  The author concludes the story with this parag...              2
# ...                                                 ...            ...
# 7076  To me it seam like the whoever was saying that...              0
# 7077  The author concludes the story with this becau...              2
# 7078  The author uses this conclusion for a reason. ...              1
# 7079  The author concludes the story with this parag...              0
# 7080  There was a specific reason as to why the auth...              2
#
# [1772 rows x 2 columns]

# %%
asap = asap.reset_index()
asap
# Out:
#       index                                              essay  domain1_score
# 0      5309  The author concludes the story with this becau...              0
# 1      5310  The narrater has that in with Paragraph becuse...              0
# 2      5311  The author concludes the story with that passa...              3
# 3      5312  The author ended the story with this paragraph...              2
# 4      5313  The author concludes the story with this parag...              2
# ...     ...                                                ...            ...
# 1767   7076  To me it seam like the whoever was saying that...              0
# 1768   7077  The author concludes the story with this becau...              2
# 1769   7078  The author uses this conclusion for a reason. ...              1
# 1770   7079  The author concludes the story with this parag...              0
# 1771   7080  There was a specific reason as to why the auth...              2
#
# [1772 rows x 3 columns]

# %%
with open('asap4_paraphrased.txt') as f:
    s = f.readlines()

len(s)
# Out:
# 1773

# %% [markdown]
# ### concat paraphrase result to dataset

# %%
asap['essay_paraphrase'] = s[1:]
asap = asap[['essay', 'essay_paraphrase', 'domain1_score']]
asap
# Out:
#                                                   essay  \
# 0     The author concludes the story with this becau...
# 1     The narrater has that in with Paragraph becuse...
# 2     The author concludes the story with that passa...
# 3     The author ended the story with this paragraph...
# 4     The author concludes the story with this parag...
# ...                                                 ...
# 1767  To me it seam like the whoever was saying that...
# 1768  The author concludes the story with this becau...
# 1769  The author uses this conclusion for a reason. ...
# 1770  The author concludes the story with this parag...
# 1771  There was a specific reason as to why the auth...
#
#                                        essay_paraphrase  domain1_score
# 0     The creator closes the story with this since g...              0
# 1     The narrater has that in with Paragraph becuse...              0
# 2     The creator closes the story with that section...              3
# 3     The creator finished the story with this passa...              2
# 4     The creator closes the story with this section...              2
# ...                                                 ...            ...
# 1767  "To me it crease like the whoever was saying t...              0
# 1768  The creator closes the story with this since i...              2
# 1769  The creator utilizes this determination on pur...              1
# 1770  The creator closes the story with this passage...              0
# 1771  There was a particular explanation regarding w...              2
#
# [1772 rows x 3 columns]

# %% [markdown]
# ### save

# %%
import joblib
joblib.dump(asap, 'asap4_paraphrase')
# Out:
# ['asap4_paraphrase']
