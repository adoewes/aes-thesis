# %%
import joblib
import numpy as np
import pandas as pd

# %%
np_gib = joblib.load('gibberish_200text_780')
np_gib.shape
# Out:
# (200, 780)

# %% [markdown]
# ### Create asap6 780-dim feature, including the gibberish (in total 2005 essays)

# %%
x = joblib.load('essay_ease10_sbert768_simbow_langerr_780_normalized_asap5')
y = joblib.load("score_asap5")

# %%
feats = np.concatenate((x, np_gib), axis=0)
feats.shape
# Out:
# (2005, 780)

# %%
joblib.dump(feats, 'essay_asap5_780_with200gibberish')
# Out:
# ['essay_asap5_780_with200gibberish']

# %% [markdown]
# ### Create asap6 score, with 0 (zero) scores for 200 gibberish (total 2005 esay scores)

# %%
zeros = np.zeros(200)
print(zeros.shape)
y = np.concatenate((y, zeros), axis=0)
print(y.shape)
# Out:
# (200,)
# (2005,)

# %%
joblib.dump(y, 'score_asap5_with200gibberish')
# Out:
# ['score_asap5_with200gibberish']
