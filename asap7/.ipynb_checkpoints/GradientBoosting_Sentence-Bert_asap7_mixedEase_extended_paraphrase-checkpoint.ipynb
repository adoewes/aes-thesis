# %%
import xgboost
import joblib
import numpy as np
from sklearn.metrics import accuracy_score
from quadratic_weighted_kappa import quadratic_weighted_kappa
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#x = joblib.load('essay_ease10_sbert768_simbow_langerr_780')
x = joblib.load('essay_ease10_sbert768_simbow_langerr_780_normalized_asap7')
x_par = joblib.load('essay_ease10_sbert768_simbow_langerr_780_paraphrase_normalized_asap7')
y = joblib.load("score_asap7")

# %%
x.shape
# Out:
# (1569, 780)

# %%
def get_feature_names_extended():
    ease_feats = ['Answer Length', 'Word Counts', 'Average Word Length', 'Good n-gram', 'Prompt Overlap',
              'Prompt Overlap (synonyms)', 'Punctuation Counts', 'Spelling Error', 'Unique Words', 'Prompt Similarity SBert']

    sbert_feats = []
    sbert_dim = 768

    for i in range(0, sbert_dim):
    	fname = "sbert_" + str(i) 
    	sbert_feats.append(fname)
    
    prompt_similarity_bow = ["Prompt Similarity BOW"]
    lang_error = ["Language Error"]
    
    feature_names = ease_feats + prompt_similarity_bow + lang_error + sbert_feats 

    print("len feature names: ", len(feature_names))
    
    return feature_names

feature_names = get_feature_names_extended()[:12]
# Out:
# len feature names:  780

# %%
feature_names = get_feature_names_extended()
# Out:
# len feature names:  780

# %% [markdown]
# ### create model

# %%
indices = np.arange(1800)
X_train, X_test, Y_train, Y_test, idx1, idx2 = train_test_split(x, y, indices, test_size=0.2, random_state=42)
X_train.shape
# Out:
# (1440, 780)

# %%
d_train = xgboost.DMatrix(X_train, label=Y_train, feature_names=feature_names)
d_test = xgboost.DMatrix(X_test, label=Y_test, feature_names=feature_names)

# %%
model = xgboost.train({"learning_rate": 0.05, "max_depth":3}, d_train, 200, evals = [(d_test, "test")], early_stopping_rounds=20)
# Out:
# [0]	test-rmse:2.30035
# Will train until test-rmse hasn't improved in 20 rounds.
# [1]	test-rmse:2.19388
# [2]	test-rmse:2.09097
# [3]	test-rmse:1.99648
# [4]	test-rmse:1.90653
# [5]	test-rmse:1.82066
# [6]	test-rmse:1.73829
# [7]	test-rmse:1.66124
# [8]	test-rmse:1.58844
# [9]	test-rmse:1.51933
# [10]	test-rmse:1.45390
# [11]	test-rmse:1.39255
# [12]	test-rmse:1.33493
# [13]	test-rmse:1.27968
# [14]	test-rmse:1.22821
# [15]	test-rmse:1.17958
# [16]	test-rmse:1.13228
# [17]	test-rmse:1.08909
# [18]	test-rmse:1.04884
# [19]	test-rmse:1.01011
# [20]	test-rmse:0.97415
# [21]	test-rmse:0.94110
# [22]	test-rmse:0.91000
# [23]	test-rmse:0.88061
# [24]	test-rmse:0.85217
# [25]	test-rmse:0.82629
# [26]	test-rmse:0.80264
# [27]	test-rmse:0.77939
# [28]	test-rmse:0.75911
# [29]	test-rmse:0.73957
# [30]	test-rmse:0.72091
# [31]	test-rmse:0.70416
# [32]	test-rmse:0.68817
# [33]	test-rmse:0.67364
# [34]	test-rmse:0.65978
# [35]	test-rmse:0.64668
# [36]	test-rmse:0.63553
# [37]	test-rmse:0.62461
# [38]	test-rmse:0.61422
# [39]	test-rmse:0.60461
# [40]	test-rmse:0.59608
# [41]	test-rmse:0.58899
# [42]	test-rmse:0.58113
# [43]	test-rmse:0.57439
# [44]	test-rmse:0.56807
# [45]	test-rmse:0.56234
# [46]	test-rmse:0.55663
# [47]	test-rmse:0.55112
# [48]	test-rmse:0.54628
# [49]	test-rmse:0.54267
# [50]	test-rmse:0.53855
# [51]	test-rmse:0.53417
# [52]	test-rmse:0.53057
# [53]	test-rmse:0.52763
# [54]	test-rmse:0.52463
# [55]	test-rmse:0.52172
# [56]	test-rmse:0.51889
# [57]	test-rmse:0.51711
# [58]	test-rmse:0.51483
# [59]	test-rmse:0.51240
# [60]	test-rmse:0.51027
# [61]	test-rmse:0.50850
# [62]	test-rmse:0.50635
# [63]	test-rmse:0.50480
# [64]	test-rmse:0.50332
# [65]	test-rmse:0.50182
# [66]	test-rmse:0.50051
# [67]	test-rmse:0.49912
# [68]	test-rmse:0.49758
# [69]	test-rmse:0.49616
# [70]	test-rmse:0.49512
# [71]	test-rmse:0.49393
# [72]	test-rmse:0.49321
# [73]	test-rmse:0.49294
# [74]	test-rmse:0.49210
# [75]	test-rmse:0.49139
# [76]	test-rmse:0.49075
# [77]	test-rmse:0.49008
# [78]	test-rmse:0.48998
# [79]	test-rmse:0.48935
# [80]	test-rmse:0.48850
# [81]	test-rmse:0.48796
# [82]	test-rmse:0.48727
# [83]	test-rmse:0.48701
# [84]	test-rmse:0.48665
# [85]	test-rmse:0.48614
# [86]	test-rmse:0.48589
# [87]	test-rmse:0.48594
# [88]	test-rmse:0.48539
# [89]	test-rmse:0.48492
# [90]	test-rmse:0.48441
# [91]	test-rmse:0.48417
# [92]	test-rmse:0.48402
# [93]	test-rmse:0.48394
# [94]	test-rmse:0.48355
# [95]	test-rmse:0.48330
# [96]	test-rmse:0.48342
# [97]	test-rmse:0.48294
# [98]	test-rmse:0.48323
# [99]	test-rmse:0.48341
# [100]	test-rmse:0.48353
# [101]	test-rmse:0.48315
# [102]	test-rmse:0.48320
# [103]	test-rmse:0.48293
# [104]	test-rmse:0.48274
# [105]	test-rmse:0.48243
# [106]	test-rmse:0.48190
# [107]	test-rmse:0.48175
# [108]	test-rmse:0.48149
# [109]	test-rmse:0.48119
# [110]	test-rmse:0.48072
# [111]	test-rmse:0.48120
# [112]	test-rmse:0.48121
# [113]	test-rmse:0.48072
# [114]	test-rmse:0.48069
# [115]	test-rmse:0.48054
# [116]	test-rmse:0.48052
# [117]	test-rmse:0.48041
# [118]	test-rmse:0.48032
# [119]	test-rmse:0.48025
# [120]	test-rmse:0.48006
# [121]	test-rmse:0.48012
# [122]	test-rmse:0.48055
# [123]	test-rmse:0.48022
# [124]	test-rmse:0.48021
# [125]	test-rmse:0.48003
# [126]	test-rmse:0.47987
# [127]	test-rmse:0.47959
# [128]	test-rmse:0.47943
# [129]	test-rmse:0.47889
# [130]	test-rmse:0.47901
# [131]	test-rmse:0.47891
# [132]	test-rmse:0.47871
# [133]	test-rmse:0.47861
# [134]	test-rmse:0.47862
# [135]	test-rmse:0.47871
# [136]	test-rmse:0.47857
# [137]	test-rmse:0.47858
# [138]	test-rmse:0.47865
# [139]	test-rmse:0.47866
# [140]	test-rmse:0.47856
# [141]	test-rmse:0.47844
# [142]	test-rmse:0.47836
# [143]	test-rmse:0.47835
# [144]	test-rmse:0.47874
# [145]	test-rmse:0.47845
# [146]	test-rmse:0.47852
# [147]	test-rmse:0.47852
# [148]	test-rmse:0.47849
# [149]	test-rmse:0.47823
# [150]	test-rmse:0.47836
# [151]	test-rmse:0.47829
# [152]	test-rmse:0.47822
# [153]	test-rmse:0.47841
# [154]	test-rmse:0.47860
# [155]	test-rmse:0.47844
# [156]	test-rmse:0.47867
# [157]	test-rmse:0.47866
# [158]	test-rmse:0.47880
# [159]	test-rmse:0.47890
# [160]	test-rmse:0.47892
# [161]	test-rmse:0.47866
# [162]	test-rmse:0.47847
# [163]	test-rmse:0.47877
# [164]	test-rmse:0.47851
# [165]	test-rmse:0.47815
# [166]	test-rmse:0.47813
# [167]	test-rmse:0.47819
# [168]	test-rmse:0.47802
# [169]	test-rmse:0.47818
# [170]	test-rmse:0.47825
# [171]	test-rmse:0.47821
# [172]	test-rmse:0.47803
# [173]	test-rmse:0.47785
# [174]	test-rmse:0.47805
# [175]	test-rmse:0.47806
# [176]	test-rmse:0.47805
# [177]	test-rmse:0.47822
# [178]	test-rmse:0.47830
# [179]	test-rmse:0.47798
# [180]	test-rmse:0.47772
# [181]	test-rmse:0.47738
# [182]	test-rmse:0.47758
# [183]	test-rmse:0.47755
# [184]	test-rmse:0.47739
# [185]	test-rmse:0.47769
# [186]	test-rmse:0.47787
# [187]	test-rmse:0.47792
# [188]	test-rmse:0.47817
# [189]	test-rmse:0.47800
# [190]	test-rmse:0.47811
# [191]	test-rmse:0.47822
# [192]	test-rmse:0.47821
# [193]	test-rmse:0.47819
# [194]	test-rmse:0.47802
# [195]	test-rmse:0.47764
# [196]	test-rmse:0.47774
# [197]	test-rmse:0.47767
# [198]	test-rmse:0.47778
# [199]	test-rmse:0.47787

# %%
yxgb_pred = model.predict(d_test)
yxgb_pred = np.round(yxgb_pred)
print("accuracy: ", accuracy_score(yxgb_pred, Y_test))
print("qwk: ", quadratic_weighted_kappa(yxgb_pred, Y_test))
# Out:
# accuracy:  0.7138888888888889
# qwk:  0.8244318181818182

# %%
joblib.dump(model, "model_asap6_extended_780")
# Out:
# ['model_asap6_extended_780']

# %% [markdown]
# ### create model 5-fold

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

kf = KFold(n_splits=5, shuffle=True, random_state=42)
#kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
#kf.get_n_splits(x, y)
print(kf)
# Out:
# KFold(n_splits=5, random_state=42, shuffle=True)

# %%
model2 = xgboost.XGBRegressor(objective ='reg:squarederror',
                colsample_bytree=0.4,
                 gamma=0,                 
                 learning_rate=0.03,
                 max_depth=3,
                 min_child_weight=1.5,
                 n_estimators=1000,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=42)

# %% [markdown]
# ### training using original essays --> predict paraphrased essays

# %%
qwk_scores = []
qwk_scores_par = []
qwk_between_predictions = []

test_indices = []
pred_labels = []
pred_labels_par = []

for train_index, test_index in kf.split(x, y):
    
    X_train, X_test, Y_train, Y_test = x[train_index], x[test_index], y[train_index], y[test_index]
         
    model2.fit(X_train, Y_train)
    
    predict = model2.predict(X_test)
    predict = np.round(predict)
    
    pred_labels.extend(predict)
    test_indices.extend(test_index)
    
    result = quadratic_weighted_kappa(Y_test, predict)
    print("Qwk : ", result)
    qwk_scores.append(result)
    
    
    # PREDICT FOR PARAPHRASED ESSAY
    x_par_test = x_par[test_index]
    predict_par = model2.predict(x_par_test)
    predict_par = np.round(predict_par)
    
    pred_labels_par.extend(predict_par)
    
    result_par = quadratic_weighted_kappa(Y_test, predict_par)
    print("Qwk par : ", result_par)
    qwk_scores_par.append(result_par)
    
    result_between_preds = quadratic_weighted_kappa(predict, predict_par)
    qwk_between_predictions.append(result_between_preds)
    print("qwk between prediction: ", result_between_preds)
    
print("\nMean QWK : ", np.mean(qwk_scores))
print("Mean QWK paraphrase : ", np.mean(qwk_scores_par))
print("Mean QWK between predictions : ", np.mean(qwk_between_predictions))
# Out:
# Qwk :  0.7931416123535302
# Qwk par :  0.7507640471279386
# qwk between prediction:  0.9371686076612256
# Qwk :  0.7780216629342351
# Qwk par :  0.7536063746630657
# qwk between prediction:  0.9467015940110897
# Qwk :  0.8062406348636821
# Qwk par :  0.7770702309677103
# qwk between prediction:  0.9362983193442185
# Qwk :  0.7932437700883994
# Qwk par :  0.7716967352407381
# qwk between prediction:  0.9442204557975333
# Qwk :  0.7149977236239904
# Qwk par :  0.6935643704343726
# qwk between prediction:  0.9409173177266839
#
# Mean QWK :  0.7771290807727675
# Mean QWK paraphrase :  0.7493403516867649
# Mean QWK between predictions :  0.9410612589081502

# %% [markdown]
# ### Training using paraphrased essays --> predict original essays

# %%
qwk_scores = []
qwk_scores_ori = []
qwk_between_predictions = []

test_indices = []
pred_labels = []
pred_labels_ori = []

print("Training using paraphrase")
print("=========================")

for train_index, test_index in kf.split(x, y):
    
    X_train, X_test, Y_train, Y_test = x_par[train_index], x_par[test_index], y[train_index], y[test_index]
         
    model2.fit(X_train, Y_train)
    
    predict = model2.predict(X_test)
    predict = np.round(predict)
    
    pred_labels.extend(predict)
    test_indices.extend(test_index)
    
    result = quadratic_weighted_kappa(Y_test, predict)
    print("Qwk : ", result)
    qwk_scores.append(result)
    
    
    # PREDICT FOR ORIGINAL ESSAY
    x_ori_test = x[test_index]
    predict_ori = model2.predict(x_ori_test)
    predict_ori = np.round(predict_ori)
    
    pred_labels_ori.extend(predict_ori)
    
    result_ori = quadratic_weighted_kappa(Y_test, predict_ori)
    print("Qwk ori : ", result_ori)
    qwk_scores_ori.append(result_ori)
    
    result_between_preds = quadratic_weighted_kappa(predict, predict_ori)
    qwk_between_predictions.append(result_between_preds)
    print("qwk between prediction: ", result_between_preds)
        

print("\nMean QWK Paraphrase: ", np.mean(qwk_scores))
print("Mean QWK ori : ", np.mean(qwk_scores_ori))
print("Mean QWK between predictions : ", np.mean(qwk_between_predictions))
# Out:
# Training using paraphrase
# =========================
# Qwk :  0.7495871818669596
# Qwk ori :  0.7436839818817574
# qwk between prediction:  0.9309406727594804
# Qwk :  0.7593691932920748
# Qwk ori :  0.7478047719615969
# qwk between prediction:  0.9433637083277607
# Qwk :  0.7880904895141232
# Qwk ori :  0.773415097293711
# qwk between prediction:  0.9306897367541713
# Qwk :  0.752253229380665
# Qwk ori :  0.7549836463004311
# qwk between prediction:  0.9357875341487271
# Qwk :  0.6870787376457799
# Qwk ori :  0.6955959540141431
# qwk between prediction:  0.9272909584043569
#
# Mean QWK Paraphrase:  0.7472757663399205
# Mean QWK ori :  0.7430966902903279
# Mean QWK between predictions :  0.9336145220788993

# %%
print(len(pred_labels))
print(len(test_indices))
# Out:
# 1569
# 1569

# %%
pred_labels_int = list(map(int, pred_labels))
print(pred_labels)
print(pred_labels_int)
# Out:
# [17.0, 15.0, 15.0, 19.0, 18.0, 10.0, 18.0, 20.0, 16.0, 19.0, 23.0, 12.0, 10.0, 21.0, 20.0, 13.0, 9.0, 20.0, 12.0, 18.0, 19.0, 19.0, 23.0, 15.0, 12.0, 16.0, 11.0, 14.0, 20.0, 19.0, 19.0, 12.0, 12.0, 16.0, 13.0, 10.0, 24.0, 15.0, 19.0, 19.0, 17.0, 15.0, 21.0, 20.0, 13.0, 15.0, 10.0, 18.0, 17.0, 13.0, 21.0, 16.0, 12.0, 13.0, 14.0, 20.0, 19.0, 18.0, 13.0, 16.0, 17.0, 14.0, 20.0, 17.0, 14.0, 16.0, 13.0, 18.0, 18.0, 19.0, 19.0, 12.0, 15.0, 18.0, 17.0, 15.0, 12.0, 16.0, 20.0, 16.0, 12.0, 16.0, 18.0, 14.0, 17.0, 15.0, 11.0, 16.0, 15.0, 11.0, 22.0, 20.0, 10.0, 24.0, 17.0, 15.0, 22.0, 11.0, 20.0, 12.0, 19.0, 19.0, 22.0, 17.0, 15.0, 15.0, 14.0, 15.0, 12.0, 16.0, 16.0, 14.0, 19.0, 19.0, 9.0, 13.0, 16.0, 20.0, 14.0, 21.0, 14.0, 15.0, 6.0, 17.0, 12.0, 13.0, 16.0, 19.0, 17.0, 23.0, 22.0, 11.0, 12.0, 8.0, 23.0, 21.0, 15.0, 15.0, 10.0, 14.0, 20.0, 16.0, 19.0, 13.0, 17.0, 14.0, 15.0, 13.0, 15.0, 15.0, 17.0, 24.0, 17.0, 18.0, 21.0, 11.0, 19.0, 22.0, 22.0, 13.0, 22.0, 14.0, 23.0, 14.0, 10.0, 16.0, 11.0, 18.0, 19.0, 8.0, 20.0, 15.0, 22.0, 17.0, 20.0, 19.0, 19.0, 17.0, 24.0, 18.0, 12.0, 23.0, 23.0, 14.0, 7.0, 17.0, 20.0, 8.0, 15.0, 14.0, 24.0, 17.0, 16.0, 16.0, 21.0, 17.0, 13.0, 17.0, 21.0, 15.0, 10.0, 20.0, 21.0, 21.0, 16.0, 11.0, 9.0, 16.
 15, 12, 18, 9, 14, 22, 15, 15, 22, 14, 18, 17, 16, 19, 20, 19, 19, 17, 13, 17, 16, 20, 20, 12, 10, 16, 16, 15, 11, 14, 13, 16, 16, 21, 18, 13, 16, 21, 17, 11, 14, 14, 15, 15, 17, 18, 16, 19, 15, 15, 14, 17, 20, 19, 22, 18, 17, 19, 21, 17, 10, 11, 20, 22, 17, 16, 23, 20, 13, 18, 16, 20, 18, 13, 20, 16, 20, 18, 22, 16, 12, 15, 19, 10, 21, 7, 14, 14, 19, 12, 15, 11, 19, 11, 16, 20, 15, 20, 20, 7, 12, 18, 19, 21, 19, 17, 17, 15, 20, 12, 21, 12, 12, 18, 18, 12, 21, 21, 14, 15, 17, 22, 17, 18, 17, 22, 13, 10, 17, 20, 19, 16, 17, 21, 10, 20, 20, 21, 14, 16, 21, 20, 16, 19, 18, 15, 14, 12, 18, 21, 21, 16, 23, 9, 18, 14, 21, 13, 11, 18, 18, 13, 19, 17, 12, 20, 12, 12, 17, 21, 12, 18, 13, 22, 15, 16, 9, 15, 21, 20, 14, 11, 21, 13, 18, 16, 17, 18, 16, 21, 21, 15, 21, 21, 19, 14, 19, 17, 16, 21, 18, 15, 17, 12, 14, 12, 13, 22, 12, 17, 19, 14, 20, 19, 16, 14, 17, 14, 19, 16, 18, 15, 20, 21, 19, 16, 14, 9, 16, 16, 10, 19, 12, 23, 17, 14, 22, 17, 20, 20, 18, 12, 16, 13, 20, 13, 17, 21, 21, 14, 11, 14, 17, 21, 20, 18, 16, 21, 14, 21, 17, 21, 21, 18, 12, 13, 14, 17, 13, 13, 19, 13, 19, 13, 18, 12, 15, 10, 18, 14, 14, 19, 11, 21, 23, 9, 17, 15, 10, 15, 17, 22, 15, 17, 19, 22, 12, 11, 9, 22, 15, 20, 17, 23, 19, 11, 15, 16, 20, 22, 11, 18, 19, 19, 15, 17, 20, 20, 20, 17, 20, 12, 11, 19, 14, 21, 12, 13, 15, 17, 12, 16, 15, 20, 14, 19, 10, 20, 13, 22, 22, 14, 21, 17, 17, 17, 18, 21, 21, 21, 16, 18, 17, 18, 19, 8, 18, 15, 18, 10, 16, 20, 9, 13, 21, 14, 19, 11, 18, 22, 20, 23, 21, 21 ...

# %%
new_score = np.zeros(1569)
new_score_par = np.zeros(1569)
new_score
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
new_score[test_indices] = pred_labels_int
new_score_par[test_indices] = pred_labels_par_int

# %%
new_score
# Out:
# array([11., 12., 14., ..., 16., 21., 16.])

# %%
new_score_par
# Out:
# array([11., 14., 15., ..., 18., 22., 18.])

# %%
new_score[60]
# Out:
# 14.0

# %%
joblib.dump(new_score, 'model_score_normalized')
# Out:
# ['model_score_normalized']

# %%
joblib.dump(new_score, 'model_score_paraphrase_normalized')
# Out:
# ['model_score_paraphrase_normalized']

# %% [markdown]
# ## Model performance to predict paraphrased essays

# %%
# Accuracy
accuracy_score(new_score, new_score_par)
# Out:
# 0.30720203951561503

# %%
# QWK
quadratic_weighted_kappa(new_score, new_score_par)
# Out:
# 0.9413613534712769
