# %%
import pandas as pd
import joblib

# %%
asap = pd.read_csv('../training_set_rel3.tsv', sep='\t', encoding = "ISO-8859-1")
asap = asap[asap['essay_set'] == 7]
asap = asap[['essay','domain1_score']]
asap
# Out:
#                                                    essay  domain1_score
# 10686  Patience is when your waiting .I was patience ...             15
# 10687  I am not a patience person, like I canÆt sit i...             13
# 10688  One day I was at basketball practice and I was...             15
# 10689  I going to write about a time when I went to t...             17
# 10690  It can be very hard for somebody to be patient...             13
# ...                                                  ...            ...
# 12250  One time I was getting a cool @CAPS1 game it w...             12
# 12251  A patent person in my life is my mom. Aicason ...             16
# 12252  A time when someone else I know was patient wa...             19
# 12253  I hate weddings. I love when people get marrie...             22
# 12254  A few weeks ago, we had a garage sale and a mo...             15
#
# [1569 rows x 2 columns]

# %%
asap = asap.reset_index()
asap
# Out:
#       index                                              essay  domain1_score
# 0     10686  Patience is when your waiting .I was patience ...             15
# 1     10687  I am not a patience person, like I canÆt sit i...             13
# 2     10688  One day I was at basketball practice and I was...             15
# 3     10689  I going to write about a time when I went to t...             17
# 4     10690  It can be very hard for somebody to be patient...             13
# ...     ...                                                ...            ...
# 1564  12250  One time I was getting a cool @CAPS1 game it w...             12
# 1565  12251  A patent person in my life is my mom. Aicason ...             16
# 1566  12252  A time when someone else I know was patient wa...             19
# 1567  12253  I hate weddings. I love when people get marrie...             22
# 1568  12254  A few weeks ago, we had a garage sale and a mo...             15
#
# [1569 rows x 3 columns]

# %%
with open('asap7_paraphrased.txt') as f:
    s = f.readlines()

len(s)
# Out:
# 1570

# %% [markdown]
# ### concat paraphrase result to dataset

# %%
asap['essay_paraphrase'] = s[1:]
asap = asap[['essay', 'essay_paraphrase', 'domain1_score']]
asap
# Out:
#                                                   essay  \
# 0     Patience is when your waiting .I was patience ...
# 1     I am not a patience person, like I canÆt sit i...
# 2     One day I was at basketball practice and I was...
# 3     I going to write about a time when I went to t...
# 4     It can be very hard for somebody to be patient...
# ...                                                 ...
# 1564  One time I was getting a cool @CAPS1 game it w...
# 1565  A patent person in my life is my mom. Aicason ...
# 1566  A time when someone else I know was patient wa...
# 1567  I hate weddings. I love when people get marrie...
# 1568  A few weeks ago, we had a garage sale and a mo...
#
#                                        essay_paraphrase  domain1_score
# 0     Tolerance is the point at which your pausing ....             15
# 1     I'm not a tolerance individual, similar to I c...             13
# 2     One day I was at b-ball practice and I was run...             15
# 3     I going to expound on when I went to the @ORGA...             17
# 4     It very well may be exceptionally difficult fo...             13
# ...                                                 ...            ...
# 1564  Once I was getting a cool @CAPS1 game it was s...             12
# 1565  A patent individual in my life is my mother. A...             16
# 1566  At the point when another person I know showed...             19
# 1567  I disdain weddings. I love when individuals ge...             22
# 1568  Half a month prior, we had a carport deal and ...             15
#
# [1569 rows x 3 columns]

# %% [markdown]
# ### save

# %%
import joblib
joblib.dump(asap, 'asap7_paraphrase')
# Out:
# ['asap7_paraphrase']
