# %%
import joblib
import pandas as pd
import nltk
import re
import itertools
import numpy as np
import random

# %%
data = pd.read_csv('ASAP7 Test Set.tsv', sep='\t')
data_100 = data[:100]
data_100.head()
# Out:
#    essay_id                                              essay  domain1_score
# 0     19392  My at saying your patient is. Your patient whe...             12
# 1     18926  Once upon a time there was a young girl named ...             18
# 2     18318  Patience is hard. You always @CAPS1 it now not...             14
# 3     18904  Patience, @CAPS6 essential part of our world. ...             14
# 4     19131  One time I was pacient was when my mum said th...              8

# %%
corrections = joblib.load('files/json_responses_test_100')
corrections
# Out:
# [[{'original': 'at saying',
#    'correction': 'way of saying',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'patience',
#    'correction': 'patient',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'queiter',
#    'correction': 'quarter',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'had patience',
#    'correction': 'have patience',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'patient',
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'the yell',
#    'correction': 'to yell',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'their',
#    'correction': "they're",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': "wern't",
#    'correction': "weren't",
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'patient',
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'Am not',
#    'correction': 'I am not',
#    'type': 'Grammatical',
#    'sentence': 6}],
#  [{'original': 'exited',
#    'correction': 'excited',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'here luckey',
#    'correction': 'her lucky',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'sience',
#    'correction': 'since',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'there cows',
#    'correction': 'their cows',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'stuburn',
#    'correction': 'stubborn',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': '@CAPS1',
#    'correction': 'want',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'pieceful',
#    'correction': 'peaceful',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'whating',
#    'correction': 'waiting',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'theres',
#    'correction': "there's",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'what',
#    'correction': 'wait',
#    'type': 'Word Choice',
#    'sentence': 6},
#   {'original': 'whats',
#    'correction': "what's",
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'one a gift',
#    'correction': 'is a gift',
#    'type': 'Grammatical',
#    'sentence': 7}],
#  [{'original': 'deffeniatly',
#    'correction': 'definitely',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'some thing',
#    'correction': 'something',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'but not',
#    'correction': 'But not',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'a low',
#    'correction': 'allow',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'good have',
#    'correction': "you'd have",
#    'type': 'Grammatical',
#    'sentence': 9}],
#  [{'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'wated',
#    'correction': 'waited',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'mum',
#    'correction': 'mom',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'through hard times',
#    'correction': 'through a hard time',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'is because',
#    'correction': 'is that',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'dozent',
#    'correction': "doesn't",
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'ask',
#    'correction': 'asks',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'is because',
#    'correction': 'is that',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'a lot of',
#    'correction': 'a lot of',
#    'type': 'Word Choice',
#    'sentence': 4}],
#  [{'original': 'launch',
#    'correction': 'lunch',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'Especialy',
#    'correction': 'Especially',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'patienty',
#    'correction': 'patiently',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'thats',
#    'correction': "that's",
#    'type': 'Grammatical',
#    'sentence': 6}],
#  [{'original': 'conly',
#    'correction': 'conference',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'o my friend',
#    'correction': 'of my friends',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'be hind',
#    'correction': 'behind',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'thru',
#    'correction': 'through',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'wich',
#    'correction': 'which',
#    'type': 'Spelling',
#    'sentence': 3}],
#  [{'original': 'side walk',
#    'correction': 'sidewalk',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'flowed',
#    'correction': 'followed',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'sales',
#    'correction': 'says',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'saies',
#    'correction': 'says',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'looseing',
#    'correction': 'losing',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'tell',
#    'correction': 'tells',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'the in',
#    'correction': 'them',
#    'type': 'Word Choice',
#    'sentence': 4}],
#  [{'original': 'probly',
#    'correction': 'probably',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'Every body',
#    'correction': 'Everybody',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'Its',
#    'correction': "It's",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'peperoni',
#    'correction': 'pepperoni',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'practicly',
#    'correction': 'practically',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'ogf', 'correction': 'of', 'type': 'Spelling', 'sentence': 8},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'to much',
#    'correction': 'too much',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'brouse',
#    'correction': 'louder',
#    'type': 'Word Choice',
#    'sentence': 23},
#   {'original': 'nocking',
#    'correction': 'mocking',
#    'type': 'Spelling',
#    'sentence': 24},
#   {'original': 'bare',
#    'correction': 'bear',
#    'type': 'Word Choice',
#    'sentence': 24},
#   {'original': 'am about',
#    'correction': "I'm about",
#    'type': 'Grammatical',
#    'sentence': 25},
#   {'original': 'finaly',
#    'correction': 'finally',
#    'type': 'Spelling',
#    'sentence': 33},
#   {'original': 'of signaling',
#    'correction': 'off signaling',
#    'type': 'Grammatical',
#    'sentence': 33}],
#  [{'original': 'patience',
#    'correction': 'patient',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'wen', 'correction': 'when', 'type': 'Spelling', 'sentence': 1},
#   {'original': 'hod', 'correction': 'had', 'type': 'Spelling', 'sentence': 1},
#   {'original': 'to my',
#    'correction': 'for my',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'and school',
#    'correction': 'at school',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'In some',
#    'correction': 'At some',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'in a line need',
#    'correction': 'in a line, you need',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'to waiting',
#    'correction': 'to wait',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'as wait',
#    'correction': 'also wait',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'ran',
#    'correction': 'run',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'git', 'correction': 'get', 'type': 'Spelling', 'sentence': 5},
#   {'original': 'brithbay',
#    'correction': 'birthday',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'no wait',
#    'correction': 'not wait',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'crismase',
#    'correction': 'Christmas',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'almose',
#    'correction': 'almost',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'thing',
#    'correction': 'things',
#    'type': 'Grammatical',
#    'sentence': 7}],
#  [{'original': 'deaffening',
#    'correction': 'deafening',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'T he',
#    'correction': 'The',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'eery',
#    'correction': 'eerie',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'concidered',
#    'correction': 'considered',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'triddes',
#    'correction': 'trickles',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'Ambulences',
#    'correction': "Ambulances'",
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'someways',
#    'correction': 'some ways',
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'constently',
#    'correction': 'constantly',
#    'type': 'Spelling',
#    'sentence': 26},
#   {'original': 'we we',
#    'correction': 'we were',
#    'type': 'Grammatical',
#    'sentence': 28},
#   {'original': 'farther',
#    'correction': 'further',
#    'type': 'Word Choice',
#    'sentence': 36},
#   {'original': 'hunny',
#    'correction': 'honey',
#    'type': 'Spelling',
#    'sentence': 38},
#   {'original': 'overtime',
#    'correction': 'over time',
#    'type': 'Grammatical',
#    'sentence': 45},
#   {'original': 'unhesitantly',
#    'correction': 'unhesitatingly',
#    'type': 'Word Choice',
#    'sentence': 48},
#   {'original': 'definately',
#    'correction': 'definitely',
#    'type': 'Spelling',
#    'sentence': 50}],
#  [{'original': 'brother name',
#    'correction': "brother's name",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': '@CAPS2 waiting',
#    'correction': '@CAPS2 waited',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'lead',
#    'correction': 'led',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'a hour',
#    'correction': 'an hour',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'amnesia',
#    'correction': 'anesthesia',
#    'type': 'Word Choice',
#    'sentence': 15}],
#  [{'original': 'Is when',
#    'correction': 'is when',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'to @CAPS1',
#    'correction': 'to be',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'too @CAPS1',
#    'correction': 'to be',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'doctors office',
#    'correction': "doctor's office",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'many way',
#    'correction': 'many ways',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'be careful',
#    'correction': 'should be careful',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'I ever be',
#    'correction': 'I am',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'absouletly',
#    'correction': 'absolutely',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'Theirs',
#    'correction': 'There are',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'pass in',
#    'correction': 'past',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'at leat',
#    'correction': 'at least',
#    'type': 'Spelling',
#    'sentence': 7}],
#  [{'original': 'to took',
#    'correction': 'took',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'minight',
#    'correction': 'midnight',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'wonce',
#    'correction': 'once',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'stright',
#    'correction': 'straight',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'cuzins',
#    'correction': 'cousins',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'suppose',
#    'correction': 'supposed',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'ment',
#    'correction': 'meant',
#    'type': 'Spelling',
#    'sentence': 33},
#   {'original': 'know', 'correction': 'no', 'type': 'Spelling', 'sentence': 38},
#   {'original': 'hug',
#    'correction': 'hugged',
#    'type': 'Grammatical',
#    'sentence': 43},
#   {'original': 'live',
#    'correction': 'lives',
#    'type': 'Grammatical',
#    'sentence': 44}],
#  [{'original': 'the cedar point',
#    'correction': 'Cedar Point',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'cedar point',
#    'correction': 'Cedar Point',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'a nother',
#    'correction': 'another',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'wait @CAPS1 long',
#    'correction': 'wait too long',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'more people in line @CAPS1',
#    'correction': 'more people in line, so',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'It hard',
#    'correction': 'It was hard',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'will',
#    'correction': 'would',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'Her and her brother',
#    'correction': 'She and her brother',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'fro', 'correction': 'for', 'type': 'Spelling', 'sentence': 7},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Word Choice',
#    'sentence': 8},
#   {'original': 'til',
#    'correction': 'till',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'new',
#    'correction': 'knew',
#    'type': 'Spelling',
#    'sentence': 11}],
#  [{'original': 'rember',
#    'correction': 'remember',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'octhndontist',
#    'correction': 'orthodontist',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'fourty-five',
#    'correction': 'forty-five',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'oppointment',
#    'correction': 'appointment',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'lifteen',
#    'correction': 'fifteen',
#    'type': 'Spelling',
#    'sentence': 4}],
#  [{'original': 'cause',
#    'correction': 'because',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'there a lot',
#    'correction': 'there were a lot',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'docters',
#    'correction': 'doctors',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'scar',
#    'correction': 'scared',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'if hurts',
#    'correction': 'it would hurt',
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'like my birthday for instance,',
#    'correction': 'like, for instance, my birthday,',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'I only have @NUM1 birthday',
#    'correction': 'I only have one birthday',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'My father on the other hand',
#    'correction': 'My father, on the other hand,',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'I know he will tell me to clean the car @DATE1 I told him',
#    'correction': 'I know he will tell me to clean the car, but I told him',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'I didnt do it yet',
#    'correction': 'I haven’t done it yet',
#    'type': 'Grammatical',
#    'sentence': 7}],
#  [{'original': 'happy that',
#    'correction': 'happily that',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'breake',
#    'correction': 'break',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'rall', 'correction': 'ran', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'he little',
#    'correction': 'her little',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'un-patiently',
#    'correction': 'impatiently',
#    'type': 'Word Choice',
#    'sentence': 2}],
#  [{'original': 'sedar',
#    'correction': 'Cedar',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'there it',
#    'correction': 'there, there',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'guies',
#    'correction': 'guys',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'rid', 'correction': 'ride', 'type': 'Spelling', 'sentence': 5},
#   {'original': 'seen',
#    'correction': 'saw',
#    'type': 'Grammatical',
#    'sentence': 5}],
#  [{'original': 'slove',
#    'correction': 'store',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'marsh mellows',
#    'correction': 'marshmallows',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'bye', 'correction': 'buy', 'type': 'Spelling', 'sentence': 4},
#   {'original': 'in the line',
#    'correction': 'into the line',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'mash mellows',
#    'correction': 'marshmallows',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'jorney',
#    'correction': 'journey',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'california',
#    'correction': 'California',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'line for',
#    'correction': 'lines for',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'plain',
#    'correction': 'plane',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'finaly',
#    'correction': 'finally',
#    'type': 'Spelling',
#    'sentence': 3}],
#  [{'original': 'on a bridge',
#    'correction': 'in a line',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'night more',
#    'correction': 'nightmare',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'compliments',
#    'correction': 'complain',
#    'type': 'Word Choice',
#    'sentence': 6},
#   {'original': 'companing',
#    'correction': 'complaining',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'fum',
#    'correction': 'fun',
#    'type': 'Spelling',
#    'sentence': 26}],
#  [{'original': 'oven',
#    'correction': 'open',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'goat', 'correction': 'got', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'three day',
#    'correction': 'three-day',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'out of state',
#    'correction': 'out-of-state',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'so when',
#    'correction': 'so that when',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'half way',
#    'correction': 'halfway',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'the passport were',
#    'correction': 'the passports were',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'a lot whining',
#    'correction': 'a lot of whining',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'for @LOCATION3 citizens',
#    'correction': 'for the citizens of @LOCATION3',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'we were coming',
#    'correction': 'we were returning',
#    'type': 'Word Choice',
#    'sentence': 2}],
#  [{'original': 'me and my mom dad',
#    'correction': 'my mom, dad, and I',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'unversual',
#    'correction': 'Universal',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'he asking',
#    'correction': 'he is asking',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'rollor coastor',
#    'correction': 'roller coaster',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'lets go',
#    'correction': "let's go",
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'fanominall',
#    'correction': 'phenomenal',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'I never gone',
#    'correction': 'I had never gone',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'disiported',
#    'correction': 'disappointed',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'I orderd',
#    'correction': 'I ordered',
#    'type': 'Spelling',
#    'sentence': 12}],
#  [{'original': 'all the like',
#    'correction': 'like all the',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'are house',
#    'correction': 'our house',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'o the phone',
#    'correction': 'on the phone',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'the some thing',
#    'correction': 'the same thing',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'took at the trash',
#    'correction': 'took the trash',
#    'type': 'Grammatical',
#    'sentence': 9}],
#  [{'original': "patient's",
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'ther',
#    'correction': 'there',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'where',
#    'correction': 'were',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': "pant's",
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'a sleep',
#    'correction': 'asleep',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': "patient's",
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'trow',
#    'correction': 'through',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'sowe', 'correction': 'so', 'type': 'Spelling', 'sentence': 4}],
#  [{'original': 'patience ?',
#    'correction': 'patient?',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'patience .I',
#    'correction': 'patient. I',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'weall',
#    'correction': 'we all',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'futher',
#    'correction': 'future',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'your teaching',
#    'correction': "you're teaching",
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'a @CAPS1 tree',
#    'correction': 'a @CAPS1 tree',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'presents-each one',
#    'correction': 'presents—each one',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'suppose to',
#    'correction': 'supposed to',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'boarders',
#    'correction': 'borders',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': '@CAPS7 only have',
#    'correction': 'Not only have',
#    'type': 'Grammatical',
#    'sentence': 23}],
#  [{'original': 'meap',
#    'correction': 'MEAP',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'didnt',
#    'correction': "didn't",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'new', 'correction': 'knew', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'every one',
#    'correction': 'everyone',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'noone',
#    'correction': 'no one',
#    'type': 'Spelling',
#    'sentence': 3}],
#  [{'original': 'An warrior',
#    'correction': 'A warrior',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'every one',
#    'correction': 'everyone',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'as swords',
#    'correction': 'swords',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'patiently to get',
#    'correction': 'patiently waiting to get',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'they to a',
#    'correction': 'they did to a',
#    'type': 'Grammatical',
#    'sentence': 9}],
#  [{'original': 'I patience',
#    'correction': 'Patience',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'ran out to',
#    'correction': 'ran out of',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'divulged into',
#    'correction': 'delved into',
#    'type': 'Word Choice',
#    'sentence': 9},
#   {'original': 'friend poured',
#    'correction': 'friends poured',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'principle',
#    'correction': 'principal',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': "hadn't of cared",
#    'correction': "hadn't cared",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'shuttered',
#    'correction': 'shuddered',
#    'type': 'Spelling',
#    'sentence': 25}],
#  [{'original': 'time',
#    'correction': 'times',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'I patient',
#    'correction': 'I was patient',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'waiting the man',
#    'correction': 'waiting, the man',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'back there',
#    'correction': 'back',
#    'type': 'Word Choice',
#    'sentence': 8},
#   {'original': 'like a half',
#    'correction': 'about half',
#    'type': 'Word Choice',
#    'sentence': 8}],
#  [{'original': 'I waiting',
#    'correction': 'I was waiting',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'scud',
#    'correction': 'said',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'My mom, brother, cousins, uncle',
#    'correction': 'My mom, brother, cousins, and uncle',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'can',
#    'correction': 'could',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'In conclusion I',
#    'correction': 'In conclusion, I',
#    'type': 'Grammatical',
#    'sentence': 12}],
#  [{'original': 'magnum',
#    'correction': 'Magnum',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'after a little',
#    'correction': 'after a little while,',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'Although, not',
#    'correction': 'Although not',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'every thing',
#    'correction': 'everything',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'intil',
#    'correction': 'until',
#    'type': 'Spelling',
#    'sentence': 10}],
#  [{'original': 'Patient',
#    'correction': 'Patience',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'resturaunts',
#    'correction': 'restaurants',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'board',
#    'correction': 'bored',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'easially',
#    'correction': 'easily',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'On time',
#    'correction': 'One time',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'waiting in',
#    'correction': 'waited in',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'patient',
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 10}],
#  [{'original': 'has had job',
#    'correction': 'has had a job',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'san',
#    'correction': 'San',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'trys',
#    'correction': 'tries',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'patientence',
#    'correction': 'patience',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'his as',
#    'correction': 'is as',
#    'type': 'Grammatical',
#    'sentence': 12}],
#  [{'original': 'lets',
#    'correction': "let's",
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'to long',
#    'correction': 'too long',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'replyed',
#    'correction': 'replied',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'yraes',
#    'correction': 'years',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'paitients',
#    'correction': 'patience',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'put of',
#    'correction': 'out of',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'know patience',
#    'correction': 'knew patience',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'snaped is',
#    'correction': 'snapped his',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'There faces',
#    'correction': 'Their faces',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'paitience',
#    'correction': 'patience',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'emmbarased',
#    'correction': 'embarrassed',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'wernt',
#    'correction': "weren't",
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'thier',
#    'correction': 'their',
#    'type': 'Spelling',
#    'sentence': 13}],
#  [{'original': 'patiEnt',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'break fast',
#    'correction': 'breakfast',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'catchs',
#    'correction': 'catches',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'wat', 'correction': 'what', 'type': 'Spelling', 'sentence': 5},
#   {'original': 'take',
#    'correction': 'takes',
#    'type': 'Grammatical',
#    'sentence': 7}],
#  [{'original': 'is are',
#    'correction': 'is our',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'half',
#    'correction': 'have',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'wall in',
#    'correction': 'well then',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'unit',
#    'correction': 'wait',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'all ways',
#    'correction': 'always',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'step',
#    'correction': 'steps',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'step dad',
#    'correction': 'stepdad',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'could',
#    'correction': 'cold',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'shead',
#    'correction': 'shed',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'doer',
#    'correction': 'deer',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'of', 'correction': 'off', 'type': 'Spelling', 'sentence': 16},
#   {'original': 'Purted',
#    'correction': 'Perfect',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'trial',
#    'correction': 'trail',
#    'type': 'Spelling',
#    'sentence': 18},
#   {'original': 'wroth',
#    'correction': 'worth',
#    'type': 'Spelling',
#    'sentence': 19},
#   {'original': 'shuting',
#    'correction': 'shutting',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'wining',
#    'correction': 'whining',
#    'type': 'Spelling',
#    'sentence': 20}],
#  [{'original': 'whey',
#    'correction': 'they',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'staning',
#    'correction': 'standing',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'paient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'wan', 'correction': 'when', 'type': 'Spelling', 'sentence': 1},
#   {'original': 'watet',
#    'correction': "wasn't",
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'savere',
#    'correction': 'severe',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'say nothing',
#    'correction': 'say anything',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'im',
#    'correction': "I'm",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'twords',
#    'correction': 'towards',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'to much',
#    'correction': 'too much',
#    'type': 'Grammatical',
#    'sentence': 12}],
#  [{'original': 'Ok', 'correction': 'Okay', 'type': 'Spelling', 'sentence': 1},
#   {'original': 'band new',
#    'correction': 'brand new',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'if I nid',
#    'correction': 'if I did',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'dertmind',
#    'correction': 'determined',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'Im',
#    'correction': "I'm",
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'there',
#    'correction': 'they',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'are',
#    'correction': 'our',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'a early',
#    'correction': 'an early',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'rember',
#    'correction': 'remember',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'sense',
#    'correction': 'since',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'use',
#    'correction': 'used',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'crine',
#    'correction': 'come',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'ask',
#    'correction': 'asked',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'spend',
#    'correction': 'spent',
#    'type': 'Grammatical',
#    'sentence': 8}],
#  [{'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'At @PERSON2 high',
#    'correction': "At @PERSON2's high",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'frield',
#    'correction': 'tried',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'fo', 'correction': 'to', 'type': 'Spelling', 'sentence': 8}],
#  [{'original': 'anniversery',
#    'correction': 'anniversary',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'parent are',
#    'correction': 'parents are',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'a hour',
#    'correction': 'an hour',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'She said, I dont know. And',
#    'correction': 'She said, I dont know, and',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'to @CAPS7 house',
#    'correction': "to @CAPS7's house",
#    'type': 'Grammatical',
#    'sentence': 18}],
#  [{'original': 'exsact',
#    'correction': 'exact',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'for.',
#    'correction': 'for it.',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'calenders',
#    'correction': 'calendars',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'thirty two',
#    'correction': 'thirty-two',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'callop duty',
#    'correction': 'Call of Duty',
#    'type': 'Spelling',
#    'sentence': 9}],
#  [{'original': 'on things',
#    'correction': 'for things',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'my audience what',
#    'correction': 'my audience: what',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'Well in',
#    'correction': 'Well, in',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'wash & dty',
#    'correction': 'wash & dry',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'wont',
#    'correction': "won't",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'in very negative',
#    'correction': 'in a very negative',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'pros and cons',
#    'correction': 'pros and cons',
#    'type': 'Grammatical',
#    'sentence': 12}],
#  [{'original': '@CAPS1',
#    'correction': 'When',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'exept',
#    'correction': 'except',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': '@CAPS1',
#    'correction': 'After',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'wook',
#    'correction': 'woke',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': '@CAPS1',
#    'correction': 'When',
#    'type': 'Grammatical',
#    'sentence': 11}],
#  [{'original': 'has been',
#    'correction': 'have been',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'intrest',
#    'correction': 'interest',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'Finaly',
#    'correction': 'Finally',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'biggest lines',
#    'correction': 'biggest line',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'every thing',
#    'correction': 'everything',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'has been',
#    'correction': 'had been',
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'mum',
#    'correction': 'mom',
#    'type': 'Word Choice',
#    'sentence': 19},
#   {'original': 'then',
#    'correction': 'than',
#    'type': 'Grammatical',
#    'sentence': 24},
#   {'original': 'dans',
#    'correction': 'dang',
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'patcience',
#    'correction': 'patience',
#    'type': 'Spelling',
#    'sentence': 26}],
#  [{'original': '@NUM1',
#    'correction': 'two',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'to no avail',
#    'correction': 'but to no avail',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': '@CAPS1 out',
#    'correction': 'took out',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'live happy',
#    'correction': 'live happily',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'beutiful',
#    'correction': 'beautiful',
#    'type': 'Spelling',
#    'sentence': 13}],
#  [{'original': 'vaction',
#    'correction': 'vacation',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'dicided',
#    'correction': 'decided',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'After another hour the',
#    'correction': 'After another hour, the',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'waiting @NUM1 and a half hours @ORGANIZATION1 it',
#    'correction': 'waiting @NUM1 and a half hours for it',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'worth waiting @NUM1 and a half hours',
#    'correction': 'worth waiting @NUM1 and a half hours for',
#    'type': 'Grammatical',
#    'sentence': 10}],
#  [{'original': 'everyday',
#    'correction': 'every day',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'cant want',
#    'correction': "can't wait",
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'cause',
#    'correction': 'because',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'No ,he',
#    'correction': 'No, he',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'andto',
#    'correction': 'and to',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'me, my brother, and my mom',
#    'correction': 'my brother, my mom, and I',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'writing',
#    'correction': 'waiting',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'areand',
#    'correction': 'around',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'barly',
#    'correction': 'barely',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'put school supplies',
#    'correction': 'buy school supplies',
#    'type': 'Word Choice',
#    'sentence': 1}],
#  [{'original': 'One time',
#    'correction': 'One time,',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'them I',
#    'correction': 'them, I',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'was  on',
#    'correction': 'was on',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'get me',
#    'correction': 'get one',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'your patient',
#    'correction': "you're patient",
#    'type': 'Grammatical',
#    'sentence': 8}],
#  [{'original': 'top', 'correction': 'trip', 'type': 'Spelling', 'sentence': 1},
#   {'original': 'when we got',
#    'correction': 'when we would get',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'can I go',
#    'correction': 'if I could go',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'as long as',
#    'correction': 'as long as I',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'couldt',
#    'correction': "couldn't",
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'was the often',
#    'correction': 'was often the',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'I had went',
#    'correction': 'I had gone',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'we on was',
#    'correction': 'we went on was',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'because how the',
#    'correction': 'because of how the',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'we stared rolling',
#    'correction': 'we started rolling',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'rollar coaster',
#    'correction': 'roller coaster',
#    'type': 'Spelling',
#    'sentence': 4}],
#  [{'original': 'doctor appointment',
#    'correction': "doctor's appointment",
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'tell',
#    'correction': 'until',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'regiester',
#    'correction': 'register',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'want',
#    'correction': "wasn't",
#    'type': 'Grammatical',
#    'sentence': 7}],
#  [{'original': 'upon',
#    'correction': 'up on',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'my self',
#    'correction': 'myself',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'out side',
#    'correction': 'outside',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'didnt have nothing',
#    'correction': "didn't have anything",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'wait, then',
#    'correction': 'wait, and then',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'didnt had',
#    'correction': "didn't have",
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'for ever',
#    'correction': 'forever',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'know',
#    'correction': 'now',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'real dont',
#    'correction': "really don't",
#    'type': 'Grammatical',
#    'sentence': 12}],
#  [{'original': 'gonna',
#    'correction': 'going to',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'gooing',
#    'correction': 'going',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'exited',
#    'correction': 'excited',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 5},
#   {'original': 'gonning',
#    'correction': 'going',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'untill',
#    'correction': 'until',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'are',
#    'correction': 'ate',
#    'type': 'Word Choice',
#    'sentence': 8},
#   {'original': 'nights',
#    'correction': "night's",
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'herd',
#    'correction': 'heard',
#    'type': 'Spelling',
#    'sentence': 13}],
#  [{'original': 'patiences',
#    'correction': 'patience',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'patiences',
#    'correction': 'patience',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'moth',
#    'correction': 'math',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'luch',
#    'correction': 'lunch',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'wich',
#    'correction': 'which',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'If not your',
#    'correction': "If not, you're",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'I f',
#    'correction': 'If',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'our would would',
#    'correction': 'our world would',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'fasier',
#    'correction': 'easier',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'instint',
#    'correction': 'instant',
#    'type': 'Spelling',
#    'sentence': 7}],
#  [{'original': 'me, my dad',
#    'correction': 'my dad and I',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'millenum',
#    'correction': 'millennium',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'waiting in line',
#    'correction': 'waited in line',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'difficuties',
#    'correction': 'difficulties',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'tarn',
#    'correction': 'turned',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'virture',
#    'correction': 'virtue',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'boring',
#    'correction': 'bored',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'on ipod',
#    'correction': 'an iPod',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'omazon',
#    'correction': 'Amazon',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'yet', 'correction': 'get', 'type': 'Spelling', 'sentence': 10},
#   {'original': 'Unfortunetly',
#    'correction': 'Unfortunately',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'come',
#    'correction': 'came',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'rite',
#    'correction': 'right',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'bin',
#    'correction': 'been',
#    'type': 'Spelling',
#    'sentence': 16}],
#  [{'original': 'of when',
#    'correction': 'when',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'alow',
#    'correction': 'allow',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'parent',
#    'correction': 'parents',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'bring',
#    'correction': 'bringing',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'over joyed',
#    'correction': 'overjoyed',
#    'type': 'Spelling',
#    'sentence': 13}],
#  [{'original': 'had took',
#    'correction': 'had taken',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'at two',
#    'correction': 'out two',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'patentance',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'there',
#    'correction': 'their',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'every thing',
#    'correction': 'everything',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'went thorugh',
#    'correction': 'gone through',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'panke',
#    'correction': 'pain',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'realitives',
#    'correction': 'relatives',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'drive',
#    'correction': 'drove',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'strafoam',
#    'correction': 'styrofoam',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'chessy',
#    'correction': 'cheesy',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'orginal',
#    'correction': 'original',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'escelators',
#    'correction': 'escalators',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'deylayed',
#    'correction': 'delayed',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'Luckly',
#    'correction': 'Luckily',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'extotic',
#    'correction': 'exotic',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'restraunt',
#    'correction': 'restaurant',
#    'type': 'Spelling',
#    'sentence': 16}],
#  [{'original': 'mchother',
#    'correction': 'each other',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'be', 'correction': 'bee', 'type': 'Spelling', 'sentence': 6},
#   {'original': 'yers',
#    'correction': 'years',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'rah', 'correction': 'ran', 'type': 'Spelling', 'sentence': 7},
#   {'original': 'org', 'correction': 'cry', 'type': 'Spelling', 'sentence': 8}],
#  [{'original': 'an waiting',
#    'correction': 'and waiting',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'heal',
#    'correction': 'head',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'I being',
#    'correction': 'I was being',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'because I wanted',
#    'correction': 'but I wanted',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'couldnt',
#    'correction': "couldn't",
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'queitly',
#    'correction': 'quietly',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'acident',
#    'correction': 'accident',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'new', 'correction': 'knew', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'the had',
#    'correction': 'the day had',
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'patient',
#    'correction': 'waiting',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'gender',
#    'correction': 'Cedar',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'have way',
#    'correction': 'halfway',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'stad',
#    'correction': 'stayed',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'exited',
#    'correction': 'excited',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'baby sat',
#    'correction': 'babysat',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'immeadiently',
#    'correction': 'immediately',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'Im',
#    'correction': "I'm",
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'Ill',
#    'correction': "I'll",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'Her @CAPS5 is',
#    'correction': 'Her @CAPS5 was',
#    'type': 'Grammatical',
#    'sentence': 6}],
#  [{'original': 'at.', 'correction': '.', 'type': 'Grammatical', 'sentence': 1},
#   {'original': 'buddies.',
#    'correction': 'Buddies.',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'pepsie.',
#    'correction': 'Pepsi.',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'mountain dew.',
#    'correction': 'Mountain Dew.',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'cherry pepsie.',
#    'correction': 'Cherry Pepsi.',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'will take',
#    'correction': 'would take',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'resturaunt',
#    'correction': 'restaurant',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'minutes.',
#    'correction': 'minute.',
#    'type': 'Grammatical',
#    'sentence': 22}],
#  [{'original': 'interapt',
#    'correction': 'interrupt',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'an', 'correction': 'and', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'got to',
#    'correction': 'have to',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'firedrill',
#    'correction': 'fire drill',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'what they got',
#    'correction': 'what they have',
#    'type': 'Word Choice',
#    'sentence': 4}],
#  [{'original': 'evelope',
#    'correction': 'envelope',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'spanted',
#    'correction': 'sprinted',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'an envelopes',
#    'correction': 'an envelope',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'congroduclotions',
#    'correction': 'congratulations',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'this boys head',
#    'correction': "this boy's head",
#    'type': 'Grammatical',
#    'sentence': 11}],
#  [{'original': 'patients',
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'strait',
#    'correction': 'straight',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'a half a',
#    'correction': 'half a',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'Me my mom',
#    'correction': 'My mom and I',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'los',
#    'correction': 'Los',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'hawk bay',
#    'correction': 'Hawk Bay',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'patients',
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 13},
#   {'original': 'coarse',
#    'correction': 'course',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'patients',
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 15},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 15}],
#  [{'original': 'gets',
#    'correction': 'gets',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'For example if',
#    'correction': 'For example, if',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'youll',
#    'correction': "you'll",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'drastically.so',
#    'correction': 'drastically. So',
#    'type': 'Grammatical',
#    'sentence': 11}],
#  [{'original': 'cedar point',
#    'correction': 'Cedar Point',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'wake',
#    'correction': 'woke',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'we was',
#    'correction': 'we were',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'we a',
#    'correction': 'myself a',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'start',
#    'correction': 'started',
#    'type': 'Grammatical',
#    'sentence': 7}],
#  [{'original': 'whene',
#    'correction': 'when',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'if', 'correction': 'of', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'a award',
#    'correction': 'an award',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'didnt',
#    'correction': "didn't",
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'Then after',
#    'correction': 'Then, after',
#    'type': 'Grammatical',
#    'sentence': 8}],
#  [{'original': 'ceder',
#    'correction': 'Cedar',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'grabed',
#    'correction': 'grabbed',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'in to',
#    'correction': 'into',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Word Choice',
#    'sentence': 16},
#   {'original': 'I playing',
#    'correction': 'I played',
#    'type': 'Grammatical',
#    'sentence': 16}],
#  [{'original': 'pationt',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'two', 'correction': 'to', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'too shels',
#    'correction': 'to help',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'tack',
#    'correction': 'take',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'are examples',
#    'correction': 'is an example',
#    'type': 'Grammatical',
#    'sentence': 9}],
#  [{'original': 'doctors  office',
#    'correction': "doctor's office",
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'belive',
#    'correction': 'believe',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'becouse',
#    'correction': 'because',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'sprins',
#    'correction': 'sprained',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'knc',
#    'correction': 'knee',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'cedar point',
#    'correction': 'Cedar Point',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'bas', 'correction': 'bus', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'in', 'correction': 'to', 'type': 'Grammatical', 'sentence': 3},
#   {'original': 'hilerious',
#    'correction': 'hilarious',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'it the',
#    'correction': 'is the',
#    'type': 'Grammatical',
#    'sentence': 11}],
#  [{'original': 'out weigh',
#    'correction': 'outweigh',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'rollar',
#    'correction': 'roller',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'However many',
#    'correction': 'However, many',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'be @CAPS1 a trile',
#    'correction': 'be a trial',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'as patient as monks',
#    'correction': 'as patient as a monk',
#    'type': 'Word Choice',
#    'sentence': 4}],
#  [{'original': 'atime',
#    'correction': 'a time',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'we can',
#    'correction': 'so we could',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'and;',
#    'correction': 'and I',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'at the middle',
#    'correction': 'in the middle',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'to the beach.This',
#    'correction': 'to go to the beach. This',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'volley ball',
#    'correction': 'volleyball',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'lasts',
#    'correction': 'lasted',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'there',
#    'correction': 'at',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'the worst time',
#    'correction': 'at the worst time',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'When there are',
#    'correction': 'When they are',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'good the',
#    'correction': 'good for',
#    'type': 'Grammatical',
#    'sentence': 9}],
#  [{'original': 'unlik',
#    'correction': 'unlike',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'sibling',
#    'correction': 'siblings',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'me had',
#    'correction': 'I had',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'are proggress',
#    'correction': 'our progress',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'trys',
#    'correction': 'tries',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'fit live',
#    'correction': 'felt like',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'complane',
#    'correction': 'complain',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'musem',
#    'correction': 'museum',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'histry',
#    'correction': 'history',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'Untill',
#    'correction': 'Until',
#    'type': 'Spelling',
#    'sentence': 10}],
#  [{'original': 'O my go',
#    'correction': 'Oh my god',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'butt hort',
#    'correction': 'butt hurt',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'packing spots',
#    'correction': 'parking spots',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'theres',
#    'correction': "there's",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'burgers fries',
#    'correction': 'burger, fries',
#    'type': 'Grammatical',
#    'sentence': 6}],
#  [{'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'wiil',
#    'correction': 'will',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 2},
#   {'original': 'are',
#    'correction': 'our',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'sense',
#    'correction': 'since',
#    'type': 'Word Choice',
#    'sentence': 2}],
#  [{'original': 'is seem',
#    'correction': 'seems',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'to the in',
#    'correction': 'to the end',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'advice',
#    'correction': 'advise',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'new', 'correction': 'knew', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'patience mean',
#    'correction': 'patience means',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'no', 'correction': 'know', 'type': 'Spelling', 'sentence': 3}]]

# %%
# Function to sample 5 dictionaries from each inner list
def sample_five_from_each(inner_lists):
    return [random.sample(inner_list, min(len(inner_list), 5)) for inner_list in inner_lists]

# Sample 5 dictionaries from each inner list
sampled_corrections = sample_five_from_each(corrections)

#print(np.array(sampled_corrections).shape)

# Print the results
for idx, sampled_list in enumerate(sampled_corrections):
    print(f"Sampled data for list {idx + 1}:")
    for item in sampled_list:
        print(item)
    print()
# Out:
# Sampled data for list 1:
# {'original': 'the yell', 'correction': 'to yell', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'patient', 'correction': 'patience', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'Am not', 'correction': 'I am not', 'type': 'Grammatical', 'sentence': 6}
# {'original': "wern't", 'correction': "weren't", 'type': 'Spelling', 'sentence': 5}
# {'original': 'their', 'correction': "they're", 'type': 'Grammatical', 'sentence': 5}
#
# Sampled data for list 2:
# {'original': 'sience', 'correction': 'since', 'type': 'Spelling', 'sentence': 4}
# {'original': 'there cows', 'correction': 'their cows', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'exited', 'correction': 'excited', 'type': 'Spelling', 'sentence': 3}
# {'original': 'stuburn', 'correction': 'stubborn', 'type': 'Spelling', 'sentence': 6}
# {'original': 'here luckey', 'correction': 'her lucky', 'type': 'Spelling', 'sentence': 4}
#
# Sampled data for list 3:
# {'original': 'theres', 'correction': "there's", 'type': 'Grammatical', 'sentence': 5}
# {'original': 'one a gift', 'correction': 'is a gift', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'what', 'correction': 'wait', 'type': 'Word Choice', 'sentence': 6}
# {'original': 'pieceful', 'correction': 'peaceful', 'type': 'Spelling', 'sentence': 3}
# {'original': 'whats', 'correction': "what's", 'type': 'Grammatical', 'sentence': 6}
#
# Sampled data for list 4:
# {'original': 'good have', 'correction': "you'd have", 'type': 'Grammatical', 'sentence': 9}
# {'original': 'a low', 'correction': 'allow', 'type': 'Spelling', 'sentence': 8}
# {'original': 'deffeniatly', 'correction': 'definitely', 'type': 'Spelling', 'sentence': 2}
# {'original': 'some thing', 'correction': 'something', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'but not', 'correction': 'But not', 'type': 'Grammatical', 'sentence': 3}
#
# Sampled data for list 5:
# {'original': 'wated', 'correction': 'waited', 'type': 'Spelling', 'sentence': 1}
# {'original': 'pacient', 'correction': 'patient', 'type': 'Spelling', 'sentence': 1}
# {'original': 'through hard times', 'correction': 'through a hard time', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'pacient', 'correction': 'patient', 'type': 'Spelling', 'sentence': 1}
# {'original': 'mum', 'correction': 'mom', 'type': 'Word Choice', 'sentence': 1}
#
# Sampled data for list 6:
# {'original': 'ask', 'correction': 'asks', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'is because', 'correction': 'is that', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'a lot of', 'correction': 'a lot of', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'is because', 'correction': 'is that', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'dozent', 'correction': "doesn't", 'type': 'Spelling', 'sentence': 3}
#
# Sampled data for list 7:
# {'original': 'patienty', 'correction': 'patiently', 'type': 'Spelling', 'sentence': 5}
# {'original': 'your', 'correction': "you're", 'type': 'Grammatical', 'sentence': 3}
# {'original': 'launch', 'correction': 'lunch', 'type': 'Spelling', 'sentence': 1}
# {'original': 'thats', 'correction': "that's", 'type': 'Grammatical', 'sentence': 6}
# {'original': 'Especialy', 'correction': 'Especially', 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 8:
# {'original': 'o my friend', 'correction': 'of my friends', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'thru', 'correction': 'through', 'type': 'Spelling', 'sentence': 3}
# {'original': 'wich', 'correction': 'which', 'type': 'Spelling', 'sentence': 3}
# {'original': 'be hind', 'correction': 'behind', 'type': 'Spelling', 'sentence': 2}
# {'original': 'conly', 'correction': 'conference', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 9:
# {'original': 'the in', 'correction': 'them', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'flowed', 'correction': 'followed', 'type': 'Spelling', 'sentence': 2}
# {'original': 'side walk', 'correction': 'sidewalk', 'type': 'Spelling', 'sentence': 1}
# {'original': 'tell', 'correction': 'tells', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'looseing', 'correction': 'losing', 'type': 'Spelling', 'sentence': 3}
#
# Sampled data for list 10:
# {'original': 'probly', 'correction': 'probably', 'type': 'Spelling', 'sentence': 1}
# {'original': 'practicly', 'correction': 'practically', 'type': 'Spelling', 'sentence': 4}
# {'original': 'finaly', 'correction': 'finally', 'type': 'Spelling', 'sentence': 33}
# {'original': 'peperoni', 'correction': 'pepperoni', 'type': 'Spelling', 'sentence': 4}
# {'original': 'Its', 'correction': "It's", 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 11:
# {'original': 'and school', 'correction': 'at school', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'hod', 'correction': 'had', 'type': 'Spelling', 'sentence': 1}
# {'original': 'wen', 'correction': 'when', 'type': 'Spelling', 'sentence': 1}
# {'original': 'to my', 'correction': 'for my', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'patience', 'correction': 'patient', 'type': 'Word Choice', 'sentence': 1}
#
# Sampled data for list 12:
# {'original': 'git', 'correction': 'get', 'type': 'Spelling', 'sentence': 5}
# {'original': 'In some', 'correction': 'At some', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'ran', 'correction': 'run', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'no wait', 'correction': 'not wait', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'crismase', 'correction': 'Christmas', 'type': 'Spelling', 'sentence': 6}
#
# Sampled data for list 13:
# {'original': 'unhesitantly', 'correction': 'unhesitatingly', 'type': 'Word Choice', 'sentence': 48}
# {'original': 'eery', 'correction': 'eerie', 'type': 'Spelling', 'sentence': 6}
# {'original': 'hunny', 'correction': 'honey', 'type': 'Spelling', 'sentence': 38}
# {'original': 'triddes', 'correction': 'trickles', 'type': 'Spelling', 'sentence': 14}
# {'original': 'Ambulences', 'correction': "Ambulances'", 'type': 'Spelling', 'sentence': 16}
#
# Sampled data for list 14:
# {'original': 'amnesia', 'correction': 'anesthesia', 'type': 'Word Choice', 'sentence': 15}
# {'original': 'lead', 'correction': 'led', 'type': 'Spelling', 'sentence': 10}
# {'original': 'brother name', 'correction': "brother's name", 'type': 'Grammatical', 'sentence': 2}
# {'original': '@CAPS2 waiting', 'correction': '@CAPS2 waited', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'a hour', 'correction': 'an hour', 'type': 'Grammatical', 'sentence': 14}
#
# Sampled data for list 15:
# {'original': 'doctors office', 'correction': "doctor's office", 'type': 'Grammatical', 'sentence': 4}
# {'original': 'many way', 'correction': 'many ways', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'to @CAPS1', 'correction': 'to be', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'too @CAPS1', 'correction': 'to be', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'Is when', 'correction': 'is when', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 16:
# {'original': 'pass in', 'correction': 'past', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'I ever be', 'correction': 'I am', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 3}
# {'original': 'absouletly', 'correction': 'absolutely', 'type': 'Spelling', 'sentence': 4}
# {'original': 'be careful', 'correction': 'should be careful', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 17:
# {'original': 'to took', 'correction': 'took', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'minight', 'correction': 'midnight', 'type': 'Spelling', 'sentence': 5}
# {'original': 'cuzins', 'correction': 'cousins', 'type': 'Spelling', 'sentence': 6}
# {'original': 'stright', 'correction': 'straight', 'type': 'Spelling', 'sentence': 5}
# {'original': 'wonce', 'correction': 'once', 'type': 'Spelling', 'sentence': 5}
#
# Sampled data for list 18:
# {'original': 'ment', 'correction': 'meant', 'type': 'Spelling', 'sentence': 33}
# {'original': 'suppose', 'correction': 'supposed', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'live', 'correction': 'lives', 'type': 'Grammatical', 'sentence': 44}
# {'original': 'hug', 'correction': 'hugged', 'type': 'Grammatical', 'sentence': 43}
# {'original': 'know', 'correction': 'no', 'type': 'Spelling', 'sentence': 38}
#
# Sampled data for list 19:
# {'original': 'a nother', 'correction': 'another', 'type': 'Spelling', 'sentence': 3}
# {'original': 'more people in line @CAPS1', 'correction': 'more people in line, so', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'wait @CAPS1 long', 'correction': 'wait too long', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'the cedar point', 'correction': 'Cedar Point', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'cedar point', 'correction': 'Cedar Point', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 20:
# {'original': 'pacient', 'correction': 'patient', 'type': 'Spelling', 'sentence': 1}
# {'original': 'will', 'correction': 'would', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'pacient', 'correction': 'patient', 'type': 'Spelling', 'sentence': 3}
# {'original': 'It hard', 'correction': 'It was hard', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'pacient', 'correction': 'patient', 'type': 'Spelling', 'sentence': 5}
#
# Sampled data for list 21:
# {'original': 'Her and her brother', 'correction': 'She and her brother', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'new', 'correction': 'knew', 'type': 'Spelling', 'sentence': 11}
# {'original': 'fro', 'correction': 'for', 'type': 'Spelling', 'sentence': 7}
# {'original': 'their', 'correction': 'there', 'type': 'Word Choice', 'sentence': 8}
# {'original': 'til', 'correction': 'till', 'type': 'Spelling', 'sentence': 10}
#
# Sampled data for list 22:
# {'original': 'fourty-five', 'correction': 'forty-five', 'type': 'Spelling', 'sentence': 2}
# {'original': 'octhndontist', 'correction': 'orthodontist', 'type': 'Spelling', 'sentence': 1}
# {'original': 'rember', 'correction': 'remember', 'type': 'Spelling', 'sentence': 1}
# {'original': 'oppointment', 'correction': 'appointment', 'type': 'Spelling', 'sentence': 3}
# {'original': 'lifteen', 'correction': 'fifteen', 'type': 'Spelling', 'sentence': 4}
#
# Sampled data for list 23:
# {'original': 'docters', 'correction': 'doctors', 'type': 'Spelling', 'sentence': 2}
# {'original': 'cause', 'correction': 'because', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'there a lot', 'correction': 'there were a lot', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'scar', 'correction': 'scared', 'type': 'Spelling', 'sentence': 3}
# {'original': 'if hurts', 'correction': 'it would hurt', 'type': 'Grammatical', 'sentence': 3}
#
# Sampled data for list 24:
# {'original': 'I know he will tell me to clean the car @DATE1 I told him', 'correction': 'I know he will tell me to clean the car, but I told him', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'I didnt do it yet', 'correction': 'I haven’t done it yet', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'My father on the other hand', 'correction': 'My father, on the other hand,', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'I only have @NUM1 birthday', 'correction': 'I only have one birthday', 'type': 'Word Choice', 'sentence': 3}
# {'original': 'like my birthday for instance,', 'correction': 'like, for instance, my birthday,', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 25:
# {'original': 'he little', 'correction': 'her little', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'breake', 'correction': 'break', 'type': 'Spelling', 'sentence': 1}
# {'original': 'rall', 'correction': 'ran', 'type': 'Spelling', 'sentence': 2}
# {'original': 'un-patiently', 'correction': 'impatiently', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'happy that', 'correction': 'happily that', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 26:
# {'original': 'seen', 'correction': 'saw', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'there it', 'correction': 'there, there', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'guies', 'correction': 'guys', 'type': 'Spelling', 'sentence': 4}
# {'original': 'rid', 'correction': 'ride', 'type': 'Spelling', 'sentence': 5}
# {'original': 'sedar', 'correction': 'Cedar', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 27:
# {'original': 'bye', 'correction': 'buy', 'type': 'Spelling', 'sentence': 4}
# {'original': 'mash mellows', 'correction': 'marshmallows', 'type': 'Spelling', 'sentence': 6}
# {'original': 'marsh mellows', 'correction': 'marshmallows', 'type': 'Spelling', 'sentence': 2}
# {'original': 'in the line', 'correction': 'into the line', 'type': 'Word Choice', 'sentence': 5}
# {'original': 'slove', 'correction': 'store', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 28:
# {'original': 'jorney', 'correction': 'journey', 'type': 'Spelling', 'sentence': 2}
# {'original': 'california', 'correction': 'California', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'line for', 'correction': 'lines for', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'plain', 'correction': 'plane', 'type': 'Spelling', 'sentence': 3}
# {'original': 'finaly', 'correction': 'finally', 'type': 'Spelling', 'sentence': 3}
#
# Sampled data for list 29:
# {'original': 'on a bridge', 'correction': 'in a line', 'type': 'Word Choice', 'sentence': 3}
# {'original': 'companing', 'correction': 'complaining', 'type': 'Spelling', 'sentence': 12}
# {'original': 'compliments', 'correction': 'complain', 'type': 'Word Choice', 'sentence': 6}
# {'original': 'night more', 'correction': 'nightmare', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'fum', 'correction': 'fun', 'type': 'Spelling', 'sentence': 26}
#
# Sampled data for list 30:
# {'original': 'out of state', 'correction': 'out-of-state', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'oven', 'correction': 'open', 'type': 'Spelling', 'sentence': 2}
# {'original': 'three day', 'correction': 'three-day', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'goat', 'correction': 'got', 'type': 'Spelling', 'sentence': 2}
# {'original': 'so when', 'correction': 'so that when', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 31:
# {'original': 'a lot whining', 'correction': 'a lot of whining', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'the passport were', 'correction': 'the passports were', 'type': 'Grammatical', 'sentence': 8}
# {'original': 'half way', 'correction': 'halfway', 'type': 'Spelling', 'sentence': 6}
# {'original': 'we were coming', 'correction': 'we were returning', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'for @LOCATION3 citizens', 'correction': 'for the citizens of @LOCATION3', 'type': 'Word Choice', 'sentence': 4}
#
# Sampled data for list 32:
# {'original': 'he asking', 'correction': 'he is asking', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'lets go', 'correction': "let's go", 'type': 'Grammatical', 'sentence': 2}
# {'original': 'unversual', 'correction': 'Universal', 'type': 'Spelling', 'sentence': 1}
# {'original': 'rollor coastor', 'correction': 'roller coaster', 'type': 'Spelling', 'sentence': 2}
# {'original': 'me and my mom dad', 'correction': 'my mom, dad, and I', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 33:
# {'original': 'disiported', 'correction': 'disappointed', 'type': 'Spelling', 'sentence': 8}
# {'original': 'I orderd', 'correction': 'I ordered', 'type': 'Spelling', 'sentence': 12}
# {'original': 'fanominall', 'correction': 'phenomenal', 'type': 'Spelling', 'sentence': 1}
# {'original': 'I never gone', 'correction': 'I had never gone', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'pacient', 'correction': 'patient', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 34:
# {'original': 'are house', 'correction': 'our house', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'o the phone', 'correction': 'on the phone', 'type': 'Spelling', 'sentence': 6}
# {'original': 'took at the trash', 'correction': 'took the trash', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'the some thing', 'correction': 'the same thing', 'type': 'Spelling', 'sentence': 7}
# {'original': 'all the like', 'correction': 'like all the', 'type': 'Word Choice', 'sentence': 2}
#
# Sampled data for list 35:
# {'original': 'sowe', 'correction': 'so', 'type': 'Spelling', 'sentence': 4}
# {'original': 'trow', 'correction': 'through', 'type': 'Spelling', 'sentence': 4}
# {'original': "patient's", 'correction': 'patience', 'type': 'Word Choice', 'sentence': 1}
# {'original': "pant's", 'correction': 'patience', 'type': 'Word Choice', 'sentence': 3}
# {'original': 'where', 'correction': 'were', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 36:
# {'original': 'weall', 'correction': 'we all', 'type': 'Spelling', 'sentence': 2}
# {'original': 'your teaching', 'correction': "you're teaching", 'type': 'Grammatical', 'sentence': 2}
# {'original': 'patience ?', 'correction': 'patient?', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'patience .I', 'correction': 'patient. I', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'futher', 'correction': 'future', 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 37:
# {'original': 'presents-each one', 'correction': 'presents—each one', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'suppose to', 'correction': 'supposed to', 'type': 'Grammatical', 'sentence': 14}
# {'original': '@CAPS7 only have', 'correction': 'Not only have', 'type': 'Grammatical', 'sentence': 23}
# {'original': 'a @CAPS1 tree', 'correction': 'a @CAPS1 tree', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'boarders', 'correction': 'borders', 'type': 'Spelling', 'sentence': 22}
#
# Sampled data for list 38:
# {'original': 'noone', 'correction': 'no one', 'type': 'Spelling', 'sentence': 3}
# {'original': 'every one', 'correction': 'everyone', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'didnt', 'correction': "didn't", 'type': 'Grammatical', 'sentence': 3}
# {'original': 'new', 'correction': 'knew', 'type': 'Spelling', 'sentence': 3}
# {'original': 'meap', 'correction': 'MEAP', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 39:
# {'original': 'patiently to get', 'correction': 'patiently waiting to get', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'as swords', 'correction': 'swords', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'they to a', 'correction': 'they did to a', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'every one', 'correction': 'everyone', 'type': 'Spelling', 'sentence': 2}
# {'original': 'An warrior', 'correction': 'A warrior', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 40:
# {'original': 'divulged into', 'correction': 'delved into', 'type': 'Word Choice', 'sentence': 9}
# {'original': 'friend poured', 'correction': 'friends poured', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'ran out to', 'correction': 'ran out of', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'shuttered', 'correction': 'shuddered', 'type': 'Spelling', 'sentence': 25}
# {'original': "hadn't of cared", 'correction': "hadn't cared", 'type': 'Grammatical', 'sentence': 7}
#
# Sampled data for list 41:
# {'original': 'like a half', 'correction': 'about half', 'type': 'Word Choice', 'sentence': 8}
# {'original': 'time', 'correction': 'times', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'I patient', 'correction': 'I was patient', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'waiting the man', 'correction': 'waiting, the man', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'back there', 'correction': 'back', 'type': 'Word Choice', 'sentence': 8}
#
# Sampled data for list 42:
# {'original': 'can', 'correction': 'could', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'scud', 'correction': 'said', 'type': 'Spelling', 'sentence': 10}
# {'original': 'I waiting', 'correction': 'I was waiting', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'In conclusion I', 'correction': 'In conclusion, I', 'type': 'Grammatical', 'sentence': 12}
# {'original': 'My mom, brother, cousins, uncle', 'correction': 'My mom, brother, cousins, and uncle', 'type': 'Grammatical', 'sentence': 3}
#
# Sampled data for list 43:
# {'original': 'Although, not', 'correction': 'Although not', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'every thing', 'correction': 'everything', 'type': 'Spelling', 'sentence': 10}
# {'original': 'magnum', 'correction': 'Magnum', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'after a little', 'correction': 'after a little while,', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'intil', 'correction': 'until', 'type': 'Spelling', 'sentence': 10}
#
# Sampled data for list 44:
# {'original': 'board', 'correction': 'bored', 'type': 'Spelling', 'sentence': 2}
# {'original': 'On time', 'correction': 'One time', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'waiting in', 'correction': 'waited in', 'type': 'Grammatical', 'sentence': 8}
# {'original': 'patient', 'correction': 'patience', 'type': 'Word Choice', 'sentence': 10}
# {'original': 'easially', 'correction': 'easily', 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 45:
# {'original': 'has had job', 'correction': 'has had a job', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'his as', 'correction': 'is as', 'type': 'Grammatical', 'sentence': 12}
# {'original': 'patientence', 'correction': 'patience', 'type': 'Spelling', 'sentence': 11}
# {'original': 'san', 'correction': 'San', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'trys', 'correction': 'tries', 'type': 'Spelling', 'sentence': 10}
#
# Sampled data for list 46:
# {'original': 'dont', 'correction': "don't", 'type': 'Grammatical', 'sentence': 7}
# {'original': 'thier', 'correction': 'their', 'type': 'Spelling', 'sentence': 13}
# {'original': 'dont', 'correction': "don't", 'type': 'Grammatical', 'sentence': 4}
# {'original': 'snaped is', 'correction': 'snapped his', 'type': 'Spelling', 'sentence': 4}
# {'original': 'know patience', 'correction': 'knew patience', 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 47:
# {'original': 'break fast', 'correction': 'breakfast', 'type': 'Spelling', 'sentence': 2}
# {'original': 'catchs', 'correction': 'catches', 'type': 'Spelling', 'sentence': 5}
# {'original': 'take', 'correction': 'takes', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'patiEnt', 'correction': 'patient', 'type': 'Spelling', 'sentence': 1}
# {'original': 'wat', 'correction': 'what', 'type': 'Spelling', 'sentence': 5}
#
# Sampled data for list 48:
# {'original': 'half', 'correction': 'have', 'type': 'Spelling', 'sentence': 1}
# {'original': 'is are', 'correction': 'is our', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'wall in', 'correction': 'well then', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'all ways', 'correction': 'always', 'type': 'Spelling', 'sentence': 2}
# {'original': 'unit', 'correction': 'wait', 'type': 'Word Choice', 'sentence': 2}
#
# Sampled data for list 49:
# {'original': 'trial', 'correction': 'trail', 'type': 'Spelling', 'sentence': 18}
# {'original': 'step', 'correction': 'steps', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'shuting', 'correction': 'shutting', 'type': 'Spelling', 'sentence': 20}
# {'original': 'could', 'correction': 'cold', 'type': 'Spelling', 'sentence': 9}
# {'original': 'of', 'correction': 'off', 'type': 'Spelling', 'sentence': 16}
#
# Sampled data for list 50:
# {'original': 'paient', 'correction': 'patient', 'type': 'Spelling', 'sentence': 1}
# {'original': 'staning', 'correction': 'standing', 'type': 'Spelling', 'sentence': 1}
# {'original': 'whey', 'correction': 'they', 'type': 'Spelling', 'sentence': 1}
# {'original': 'watet', 'correction': "wasn't", 'type': 'Spelling', 'sentence': 2}
# {'original': 'wan', 'correction': 'when', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 51:
# {'original': 'im', 'correction': "I'm", 'type': 'Grammatical', 'sentence': 9}
# {'original': 'to much', 'correction': 'too much', 'type': 'Grammatical', 'sentence': 12}
# {'original': 'say nothing', 'correction': 'say anything', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'twords', 'correction': 'towards', 'type': 'Spelling', 'sentence': 12}
# {'original': 'savere', 'correction': 'severe', 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 52:
# {'original': 'if I nid', 'correction': 'if I did', 'type': 'Spelling', 'sentence': 2}
# {'original': 'dertmind', 'correction': 'determined', 'type': 'Spelling', 'sentence': 2}
# {'original': 'Im', 'correction': "I'm", 'type': 'Grammatical', 'sentence': 3}
# {'original': 'Ok', 'correction': 'Okay', 'type': 'Spelling', 'sentence': 1}
# {'original': 'band new', 'correction': 'brand new', 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 53:
# {'original': 'a early', 'correction': 'an early', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'there', 'correction': 'they', 'type': 'Word Choice', 'sentence': 3}
# {'original': 'are', 'correction': 'our', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'rember', 'correction': 'remember', 'type': 'Spelling', 'sentence': 4}
# {'original': 'pacient', 'correction': 'patient', 'type': 'Spelling', 'sentence': 6}
#
# Sampled data for list 54:
# {'original': 'crine', 'correction': 'come', 'type': 'Spelling', 'sentence': 4}
# {'original': 'ask', 'correction': 'asked', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'use', 'correction': 'used', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'sense', 'correction': 'since', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'spend', 'correction': 'spent', 'type': 'Grammatical', 'sentence': 8}
#
# Sampled data for list 55:
# {'original': 'fo', 'correction': 'to', 'type': 'Spelling', 'sentence': 8}
# {'original': 'your', 'correction': "you're", 'type': 'Grammatical', 'sentence': 2}
# {'original': 'frield', 'correction': 'tried', 'type': 'Spelling', 'sentence': 6}
# {'original': 'At @PERSON2 high', 'correction': "At @PERSON2's high", 'type': 'Grammatical', 'sentence': 5}
# {'original': 'your', 'correction': "you're", 'type': 'Grammatical', 'sentence': 3}
#
# Sampled data for list 56:
# {'original': 'a hour', 'correction': 'an hour', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'to @CAPS7 house', 'correction': "to @CAPS7's house", 'type': 'Grammatical', 'sentence': 18}
# {'original': 'She said, I dont know. And', 'correction': 'She said, I dont know, and', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'anniversery', 'correction': 'anniversary', 'type': 'Spelling', 'sentence': 2}
# {'original': 'parent are', 'correction': 'parents are', 'type': 'Grammatical', 'sentence': 7}
#
# Sampled data for list 57:
# {'original': 'callop duty', 'correction': 'Call of Duty', 'type': 'Spelling', 'sentence': 9}
# {'original': 'thirty two', 'correction': 'thirty-two', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'exsact', 'correction': 'exact', 'type': 'Spelling', 'sentence': 2}
# {'original': 'calenders', 'correction': 'calendars', 'type': 'Spelling', 'sentence': 6}
# {'original': 'for.', 'correction': 'for it.', 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 58:
# {'original': 'in very negative', 'correction': 'in a very negative', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'pros and cons', 'correction': 'pros and cons', 'type': 'Grammatical', 'sentence': 12}
# {'original': 'my audience what', 'correction': 'my audience: what', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'wont', 'correction': "won't", 'type': 'Grammatical', 'sentence': 9}
# {'original': 'Well in', 'correction': 'Well, in', 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 59:
# {'original': 'exept', 'correction': 'except', 'type': 'Spelling', 'sentence': 4}
# {'original': '@CAPS1', 'correction': 'After', 'type': 'Grammatical', 'sentence': 5}
# {'original': '@CAPS1', 'correction': 'When', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'wook', 'correction': 'woke', 'type': 'Spelling', 'sentence': 8}
# {'original': '@CAPS1', 'correction': 'When', 'type': 'Grammatical', 'sentence': 11}
#
# Sampled data for list 60:
# {'original': 'mum', 'correction': 'mom', 'type': 'Word Choice', 'sentence': 19}
# {'original': 'dans', 'correction': 'dang', 'type': 'Spelling', 'sentence': 25}
# {'original': 'every thing', 'correction': 'everything', 'type': 'Spelling', 'sentence': 7}
# {'original': 'biggest lines', 'correction': 'biggest line', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'Finaly', 'correction': 'Finally', 'type': 'Spelling', 'sentence': 3}
#
# Sampled data for list 61:
# {'original': 'beutiful', 'correction': 'beautiful', 'type': 'Spelling', 'sentence': 13}
# {'original': '@NUM1', 'correction': 'two', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'live happy', 'correction': 'live happily', 'type': 'Grammatical', 'sentence': 6}
# {'original': '@CAPS1 out', 'correction': 'took out', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'to no avail', 'correction': 'but to no avail', 'type': 'Grammatical', 'sentence': 3}
#
# Sampled data for list 62:
# {'original': 'vaction', 'correction': 'vacation', 'type': 'Spelling', 'sentence': 1}
# {'original': 'dicided', 'correction': 'decided', 'type': 'Spelling', 'sentence': 4}
# {'original': 'worth waiting @NUM1 and a half hours', 'correction': 'worth waiting @NUM1 and a half hours for', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'waiting @NUM1 and a half hours @ORGANIZATION1 it', 'correction': 'waiting @NUM1 and a half hours for it', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'After another hour the', 'correction': 'After another hour, the', 'type': 'Grammatical', 'sentence': 8}
#
# Sampled data for list 63:
# {'original': 'cant want', 'correction': "can't wait", 'type': 'Grammatical', 'sentence': 1}
# {'original': 'andto', 'correction': 'and to', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'No ,he', 'correction': 'No, he', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'everyday', 'correction': 'every day', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'cause', 'correction': 'because', 'type': 'Word Choice', 'sentence': 1}
#
# Sampled data for list 64:
# {'original': 'writing', 'correction': 'waiting', 'type': 'Spelling', 'sentence': 1}
# {'original': 'me, my brother, and my mom', 'correction': 'my brother, my mom, and I', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'put school supplies', 'correction': 'buy school supplies', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'areand', 'correction': 'around', 'type': 'Spelling', 'sentence': 5}
# {'original': 'barly', 'correction': 'barely', 'type': 'Spelling', 'sentence': 7}
#
# Sampled data for list 65:
# {'original': 'was  on', 'correction': 'was on', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'get me', 'correction': 'get one', 'type': 'Word Choice', 'sentence': 5}
# {'original': 'One time', 'correction': 'One time,', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'your patient', 'correction': "you're patient", 'type': 'Grammatical', 'sentence': 8}
# {'original': 'them I', 'correction': 'them, I', 'type': 'Grammatical', 'sentence': 3}
#
# Sampled data for list 66:
# {'original': 'couldt', 'correction': "couldn't", 'type': 'Spelling', 'sentence': 6}
# {'original': 'can I go', 'correction': 'if I could go', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'as long as', 'correction': 'as long as I', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'when we got', 'correction': 'when we would get', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'top', 'correction': 'trip', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 67:
# {'original': 'we on was', 'correction': 'we went on was', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'we stared rolling', 'correction': 'we started rolling', 'type': 'Spelling', 'sentence': 3}
# {'original': 'was the often', 'correction': 'was often the', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'because how the', 'correction': 'because of how the', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'rollar coaster', 'correction': 'roller coaster', 'type': 'Spelling', 'sentence': 4}
#
# Sampled data for list 68:
# {'original': 'their', 'correction': 'there', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'their', 'correction': 'there', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'want', 'correction': "wasn't", 'type': 'Grammatical', 'sentence': 7}
# {'original': 'tell', 'correction': 'until', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'their', 'correction': 'there', 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 69:
# {'original': 'know', 'correction': 'now', 'type': 'Spelling', 'sentence': 12}
# {'original': 'out side', 'correction': 'outside', 'type': 'Spelling', 'sentence': 7}
# {'original': 'real dont', 'correction': "really don't", 'type': 'Grammatical', 'sentence': 12}
# {'original': 'didnt have nothing', 'correction': "didn't have anything", 'type': 'Grammatical', 'sentence': 9}
# {'original': 'my self', 'correction': 'myself', 'type': 'Spelling', 'sentence': 6}
#
# Sampled data for list 70:
# {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'gooing', 'correction': 'going', 'type': 'Spelling', 'sentence': 3}
# {'original': 'their', 'correction': 'there', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'herd', 'correction': 'heard', 'type': 'Spelling', 'sentence': 13}
# {'original': 'gonning', 'correction': 'going', 'type': 'Spelling', 'sentence': 6}
#
# Sampled data for list 71:
# {'original': 'wich', 'correction': 'which', 'type': 'Spelling', 'sentence': 6}
# {'original': 'moth', 'correction': 'math', 'type': 'Spelling', 'sentence': 3}
# {'original': 'patiences', 'correction': 'patience', 'type': 'Spelling', 'sentence': 3}
# {'original': 'luch', 'correction': 'lunch', 'type': 'Spelling', 'sentence': 6}
# {'original': 'patiences', 'correction': 'patience', 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 72:
# {'original': 'instint', 'correction': 'instant', 'type': 'Spelling', 'sentence': 7}
# {'original': 'I f', 'correction': 'If', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'If not your', 'correction': "If not, you're", 'type': 'Grammatical', 'sentence': 2}
# {'original': 'fasier', 'correction': 'easier', 'type': 'Spelling', 'sentence': 6}
# {'original': 'our would would', 'correction': 'our world would', 'type': 'Spelling', 'sentence': 6}
#
# Sampled data for list 73:
# {'original': 'tarn', 'correction': 'turned', 'type': 'Spelling', 'sentence': 5}
# {'original': 'millenum', 'correction': 'millennium', 'type': 'Spelling', 'sentence': 2}
# {'original': 'difficuties', 'correction': 'difficulties', 'type': 'Spelling', 'sentence': 4}
# {'original': 'me, my dad', 'correction': 'my dad and I', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'waiting in line', 'correction': 'waited in line', 'type': 'Grammatical', 'sentence': 3}
#
# Sampled data for list 74:
# {'original': 'Unfortunetly', 'correction': 'Unfortunately', 'type': 'Spelling', 'sentence': 11}
# {'original': 'omazon', 'correction': 'Amazon', 'type': 'Spelling', 'sentence': 9}
# {'original': 'bin', 'correction': 'been', 'type': 'Spelling', 'sentence': 16}
# {'original': 'yet', 'correction': 'get', 'type': 'Spelling', 'sentence': 10}
# {'original': 'on ipod', 'correction': 'an iPod', 'type': 'Grammatical', 'sentence': 6}
#
# Sampled data for list 75:
# {'original': 'parent', 'correction': 'parents', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'of when', 'correction': 'when', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'alow', 'correction': 'allow', 'type': 'Spelling', 'sentence': 1}
# {'original': 'over joyed', 'correction': 'overjoyed', 'type': 'Spelling', 'sentence': 13}
# {'original': 'bring', 'correction': 'bringing', 'type': 'Grammatical', 'sentence': 11}
#
# Sampled data for list 76:
# {'original': 'had took', 'correction': 'had taken', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'went thorugh', 'correction': 'gone through', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'at two', 'correction': 'out two', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'there', 'correction': 'their', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'panke', 'correction': 'pain', 'type': 'Spelling', 'sentence': 5}
#
# Sampled data for list 77:
# {'original': 'Luckly', 'correction': 'Luckily', 'type': 'Spelling', 'sentence': 16}
# {'original': 'realitives', 'correction': 'relatives', 'type': 'Spelling', 'sentence': 1}
# {'original': 'chessy', 'correction': 'cheesy', 'type': 'Spelling', 'sentence': 8}
# {'original': 'orginal', 'correction': 'original', 'type': 'Spelling', 'sentence': 9}
# {'original': 'escelators', 'correction': 'escalators', 'type': 'Spelling', 'sentence': 12}
#
# Sampled data for list 78:
# {'original': 'org', 'correction': 'cry', 'type': 'Spelling', 'sentence': 8}
# {'original': 'yers', 'correction': 'years', 'type': 'Spelling', 'sentence': 6}
# {'original': 'be', 'correction': 'bee', 'type': 'Spelling', 'sentence': 6}
# {'original': 'rah', 'correction': 'ran', 'type': 'Spelling', 'sentence': 7}
# {'original': 'mchother', 'correction': 'each other', 'type': 'Grammatical', 'sentence': 5}
#
# Sampled data for list 79:
# {'original': 'queitly', 'correction': 'quietly', 'type': 'Spelling', 'sentence': 3}
# {'original': 'the had', 'correction': 'the day had', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'couldnt', 'correction': "couldn't", 'type': 'Spelling', 'sentence': 3}
# {'original': 'new', 'correction': 'knew', 'type': 'Spelling', 'sentence': 3}
# {'original': 'an waiting', 'correction': 'and waiting', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 80:
# {'original': 'stad', 'correction': 'stayed', 'type': 'Spelling', 'sentence': 1}
# {'original': 'patient', 'correction': 'waiting', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'gender', 'correction': 'Cedar', 'type': 'Spelling', 'sentence': 1}
# {'original': 'have way', 'correction': 'halfway', 'type': 'Spelling', 'sentence': 1}
# {'original': 'exited', 'correction': 'excited', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 81:
# {'original': 'baby sat', 'correction': 'babysat', 'type': 'Spelling', 'sentence': 1}
# {'original': 'Ill', 'correction': "I'll", 'type': 'Grammatical', 'sentence': 9}
# {'original': 'Her @CAPS5 is', 'correction': 'Her @CAPS5 was', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'Im', 'correction': "I'm", 'type': 'Grammatical', 'sentence': 8}
# {'original': 'immeadiently', 'correction': 'immediately', 'type': 'Spelling', 'sentence': 6}
#
# Sampled data for list 82:
# {'original': 'cherry pepsie.', 'correction': 'Cherry Pepsi.', 'type': 'Spelling', 'sentence': 10}
# {'original': 'at.', 'correction': '.', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'will take', 'correction': 'would take', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'pepsie.', 'correction': 'Pepsi.', 'type': 'Spelling', 'sentence': 6}
# {'original': 'resturaunt', 'correction': 'restaurant', 'type': 'Spelling', 'sentence': 21}
#
# Sampled data for list 83:
# {'original': 'got to', 'correction': 'have to', 'type': 'Word Choice', 'sentence': 5}
# {'original': 'an', 'correction': 'and', 'type': 'Spelling', 'sentence': 3}
# {'original': 'interapt', 'correction': 'interrupt', 'type': 'Spelling', 'sentence': 2}
# {'original': 'firedrill', 'correction': 'fire drill', 'type': 'Spelling', 'sentence': 6}
# {'original': 'what they got', 'correction': 'what they have', 'type': 'Word Choice', 'sentence': 4}
#
# Sampled data for list 84:
# {'original': 'an envelopes', 'correction': 'an envelope', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'evelope', 'correction': 'envelope', 'type': 'Spelling', 'sentence': 1}
# {'original': 'spanted', 'correction': 'sprinted', 'type': 'Spelling', 'sentence': 3}
# {'original': 'this boys head', 'correction': "this boy's head", 'type': 'Grammatical', 'sentence': 11}
# {'original': 'congroduclotions', 'correction': 'congratulations', 'type': 'Spelling', 'sentence': 5}
#
# Sampled data for list 85:
# {'original': 'Me my mom', 'correction': 'My mom and I', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'strait', 'correction': 'straight', 'type': 'Spelling', 'sentence': 1}
# {'original': 'patients', 'correction': 'patience', 'type': 'Word Choice', 'sentence': 13}
# {'original': 'coarse', 'correction': 'course', 'type': 'Spelling', 'sentence': 14}
# {'original': 'patients', 'correction': 'patience', 'type': 'Word Choice', 'sentence': 15}
#
# Sampled data for list 86:
# {'original': 'gets', 'correction': 'gets', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'youll', 'correction': "you'll", 'type': 'Grammatical', 'sentence': 5}
# {'original': 'For example if', 'correction': 'For example, if', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'cant', 'correction': "can't", 'type': 'Grammatical', 'sentence': 6}
# {'original': 'drastically.so', 'correction': 'drastically. So', 'type': 'Grammatical', 'sentence': 11}
#
# Sampled data for list 87:
# {'original': 'we a', 'correction': 'myself a', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'cedar point', 'correction': 'Cedar Point', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'wake', 'correction': 'woke', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'we was', 'correction': 'we were', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'start', 'correction': 'started', 'type': 'Grammatical', 'sentence': 7}
#
# Sampled data for list 88:
# {'original': 'Then after', 'correction': 'Then, after', 'type': 'Grammatical', 'sentence': 8}
# {'original': 'whene', 'correction': 'when', 'type': 'Spelling', 'sentence': 1}
# {'original': 'if', 'correction': 'of', 'type': 'Spelling', 'sentence': 3}
# {'original': 'a award', 'correction': 'an award', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'didnt', 'correction': "didn't", 'type': 'Grammatical', 'sentence': 6}
#
# Sampled data for list 89:
# {'original': 'grabed', 'correction': 'grabbed', 'type': 'Spelling', 'sentence': 2}
# {'original': 'in to', 'correction': 'into', 'type': 'Grammatical', 'sentence': 13}
# {'original': 'ceder', 'correction': 'Cedar', 'type': 'Spelling', 'sentence': 1}
# {'original': 'their', 'correction': 'there', 'type': 'Word Choice', 'sentence': 16}
# {'original': 'I playing', 'correction': 'I played', 'type': 'Grammatical', 'sentence': 16}
#
# Sampled data for list 90:
# {'original': 'two', 'correction': 'to', 'type': 'Spelling', 'sentence': 2}
# {'original': 'are examples', 'correction': 'is an example', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'pationt', 'correction': 'patient', 'type': 'Spelling', 'sentence': 1}
# {'original': 'too shels', 'correction': 'to help', 'type': 'Word Choice', 'sentence': 5}
# {'original': 'tack', 'correction': 'take', 'type': 'Spelling', 'sentence': 9}
#
# Sampled data for list 91:
# {'original': 'belive', 'correction': 'believe', 'type': 'Spelling', 'sentence': 1}
# {'original': 'knc', 'correction': 'knee', 'type': 'Spelling', 'sentence': 2}
# {'original': 'doctors  office', 'correction': "doctor's office", 'type': 'Grammatical', 'sentence': 1}
# {'original': 'sprins', 'correction': 'sprained', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'becouse', 'correction': 'because', 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 92:
# {'original': 'cedar point', 'correction': 'Cedar Point', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'it the', 'correction': 'is the', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'in', 'correction': 'to', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'bas', 'correction': 'bus', 'type': 'Spelling', 'sentence': 2}
# {'original': 'hilerious', 'correction': 'hilarious', 'type': 'Spelling', 'sentence': 7}
#
# Sampled data for list 93:
# {'original': 'However many', 'correction': 'However, many', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'out weigh', 'correction': 'outweigh', 'type': 'Spelling', 'sentence': 1}
# {'original': 'as patient as monks', 'correction': 'as patient as a monk', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'be @CAPS1 a trile', 'correction': 'be a trial', 'type': 'Spelling', 'sentence': 5}
# {'original': 'rollar', 'correction': 'roller', 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 94:
# {'original': 'we can', 'correction': 'so we could', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'to the beach.This', 'correction': 'to go to the beach. This', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'and;', 'correction': 'and I', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'at the middle', 'correction': 'in the middle', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'atime', 'correction': 'a time', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 95:
# {'original': 'the worst time', 'correction': 'at the worst time', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'When there are', 'correction': 'When they are', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'there', 'correction': 'at', 'type': 'Word Choice', 'sentence': 3}
# {'original': 'good the', 'correction': 'good for', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'volley ball', 'correction': 'volleyball', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 96:
# {'original': 'me had', 'correction': 'I had', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'unlik', 'correction': 'unlike', 'type': 'Spelling', 'sentence': 1}
# {'original': 'are proggress', 'correction': 'our progress', 'type': 'Spelling', 'sentence': 2}
# {'original': 'trys', 'correction': 'tries', 'type': 'Spelling', 'sentence': 5}
# {'original': 'sibling', 'correction': 'siblings', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 97:
# {'original': 'musem', 'correction': 'museum', 'type': 'Spelling', 'sentence': 7}
# {'original': 'histry', 'correction': 'history', 'type': 'Spelling', 'sentence': 7}
# {'original': 'Untill', 'correction': 'Until', 'type': 'Spelling', 'sentence': 10}
# {'original': 'complane', 'correction': 'complain', 'type': 'Spelling', 'sentence': 4}
# {'original': 'fit live', 'correction': 'felt like', 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 98:
# {'original': 'theres', 'correction': "there's", 'type': 'Grammatical', 'sentence': 7}
# {'original': 'burgers fries', 'correction': 'burger, fries', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'packing spots', 'correction': 'parking spots', 'type': 'Spelling', 'sentence': 4}
# {'original': 'O my go', 'correction': 'Oh my god', 'type': 'Spelling', 'sentence': 3}
# {'original': 'butt hort', 'correction': 'butt hurt', 'type': 'Spelling', 'sentence': 3}
#
# Sampled data for list 99:
# {'original': 'wiil', 'correction': 'will', 'type': 'Spelling', 'sentence': 1}
# {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'are', 'correction': 'our', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'your', 'correction': "you're", 'type': 'Grammatical', 'sentence': 1}
# {'original': 'sense', 'correction': 'since', 'type': 'Word Choice', 'sentence': 2}
#
# Sampled data for list 100:
# {'original': 'advice', 'correction': 'advise', 'type': 'Spelling', 'sentence': 2}
# {'original': 'patience mean', 'correction': 'patience means', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'no', 'correction': 'know', 'type': 'Spelling', 'sentence': 3}
# {'original': 'to the in', 'correction': 'to the end', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'is seem', 'correction': 'seems', 'type': 'Grammatical', 'sentence': 1}

# %%
sampled_corrections
# Out:
# [[{'original': 'the yell',
#    'correction': 'to yell',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'patient',
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'Am not',
#    'correction': 'I am not',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': "wern't",
#    'correction': "weren't",
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'their',
#    'correction': "they're",
#    'type': 'Grammatical',
#    'sentence': 5}],
#  [{'original': 'sience',
#    'correction': 'since',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'there cows',
#    'correction': 'their cows',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'exited',
#    'correction': 'excited',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'stuburn',
#    'correction': 'stubborn',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'here luckey',
#    'correction': 'her lucky',
#    'type': 'Spelling',
#    'sentence': 4}],
#  [{'original': 'theres',
#    'correction': "there's",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'one a gift',
#    'correction': 'is a gift',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'what',
#    'correction': 'wait',
#    'type': 'Word Choice',
#    'sentence': 6},
#   {'original': 'pieceful',
#    'correction': 'peaceful',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'whats',
#    'correction': "what's",
#    'type': 'Grammatical',
#    'sentence': 6}],
#  [{'original': 'good have',
#    'correction': "you'd have",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'a low',
#    'correction': 'allow',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'deffeniatly',
#    'correction': 'definitely',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'some thing',
#    'correction': 'something',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'but not',
#    'correction': 'But not',
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'wated',
#    'correction': 'waited',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'through hard times',
#    'correction': 'through a hard time',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'mum',
#    'correction': 'mom',
#    'type': 'Word Choice',
#    'sentence': 1}],
#  [{'original': 'ask',
#    'correction': 'asks',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'is because',
#    'correction': 'is that',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'a lot of',
#    'correction': 'a lot of',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'is because',
#    'correction': 'is that',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'dozent',
#    'correction': "doesn't",
#    'type': 'Spelling',
#    'sentence': 3}],
#  [{'original': 'patienty',
#    'correction': 'patiently',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'launch',
#    'correction': 'lunch',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'thats',
#    'correction': "that's",
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'Especialy',
#    'correction': 'Especially',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'o my friend',
#    'correction': 'of my friends',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'thru',
#    'correction': 'through',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'wich',
#    'correction': 'which',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'be hind',
#    'correction': 'behind',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'conly',
#    'correction': 'conference',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'the in',
#    'correction': 'them',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'flowed',
#    'correction': 'followed',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'side walk',
#    'correction': 'sidewalk',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'tell',
#    'correction': 'tells',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'looseing',
#    'correction': 'losing',
#    'type': 'Spelling',
#    'sentence': 3}],
#  [{'original': 'probly',
#    'correction': 'probably',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'practicly',
#    'correction': 'practically',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'finaly',
#    'correction': 'finally',
#    'type': 'Spelling',
#    'sentence': 33},
#   {'original': 'peperoni',
#    'correction': 'pepperoni',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'Its',
#    'correction': "It's",
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'and school',
#    'correction': 'at school',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'hod', 'correction': 'had', 'type': 'Spelling', 'sentence': 1},
#   {'original': 'wen', 'correction': 'when', 'type': 'Spelling', 'sentence': 1},
#   {'original': 'to my',
#    'correction': 'for my',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'patience',
#    'correction': 'patient',
#    'type': 'Word Choice',
#    'sentence': 1}],
#  [{'original': 'git', 'correction': 'get', 'type': 'Spelling', 'sentence': 5},
#   {'original': 'In some',
#    'correction': 'At some',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'ran',
#    'correction': 'run',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'no wait',
#    'correction': 'not wait',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'crismase',
#    'correction': 'Christmas',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'unhesitantly',
#    'correction': 'unhesitatingly',
#    'type': 'Word Choice',
#    'sentence': 48},
#   {'original': 'eery',
#    'correction': 'eerie',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'hunny',
#    'correction': 'honey',
#    'type': 'Spelling',
#    'sentence': 38},
#   {'original': 'triddes',
#    'correction': 'trickles',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'Ambulences',
#    'correction': "Ambulances'",
#    'type': 'Spelling',
#    'sentence': 16}],
#  [{'original': 'amnesia',
#    'correction': 'anesthesia',
#    'type': 'Word Choice',
#    'sentence': 15},
#   {'original': 'lead',
#    'correction': 'led',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'brother name',
#    'correction': "brother's name",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': '@CAPS2 waiting',
#    'correction': '@CAPS2 waited',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'a hour',
#    'correction': 'an hour',
#    'type': 'Grammatical',
#    'sentence': 14}],
#  [{'original': 'doctors office',
#    'correction': "doctor's office",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'many way',
#    'correction': 'many ways',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'to @CAPS1',
#    'correction': 'to be',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'too @CAPS1',
#    'correction': 'to be',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'Is when',
#    'correction': 'is when',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'pass in',
#    'correction': 'past',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'I ever be',
#    'correction': 'I am',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'absouletly',
#    'correction': 'absolutely',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'be careful',
#    'correction': 'should be careful',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'to took',
#    'correction': 'took',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'minight',
#    'correction': 'midnight',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'cuzins',
#    'correction': 'cousins',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'stright',
#    'correction': 'straight',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'wonce',
#    'correction': 'once',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'ment',
#    'correction': 'meant',
#    'type': 'Spelling',
#    'sentence': 33},
#   {'original': 'suppose',
#    'correction': 'supposed',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'live',
#    'correction': 'lives',
#    'type': 'Grammatical',
#    'sentence': 44},
#   {'original': 'hug',
#    'correction': 'hugged',
#    'type': 'Grammatical',
#    'sentence': 43},
#   {'original': 'know',
#    'correction': 'no',
#    'type': 'Spelling',
#    'sentence': 38}],
#  [{'original': 'a nother',
#    'correction': 'another',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'more people in line @CAPS1',
#    'correction': 'more people in line, so',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'wait @CAPS1 long',
#    'correction': 'wait too long',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'the cedar point',
#    'correction': 'Cedar Point',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'cedar point',
#    'correction': 'Cedar Point',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'will',
#    'correction': 'would',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'It hard',
#    'correction': 'It was hard',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'Her and her brother',
#    'correction': 'She and her brother',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'new',
#    'correction': 'knew',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'fro', 'correction': 'for', 'type': 'Spelling', 'sentence': 7},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Word Choice',
#    'sentence': 8},
#   {'original': 'til',
#    'correction': 'till',
#    'type': 'Spelling',
#    'sentence': 10}],
#  [{'original': 'fourty-five',
#    'correction': 'forty-five',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'octhndontist',
#    'correction': 'orthodontist',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'rember',
#    'correction': 'remember',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'oppointment',
#    'correction': 'appointment',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'lifteen',
#    'correction': 'fifteen',
#    'type': 'Spelling',
#    'sentence': 4}],
#  [{'original': 'docters',
#    'correction': 'doctors',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'cause',
#    'correction': 'because',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'there a lot',
#    'correction': 'there were a lot',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'scar',
#    'correction': 'scared',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'if hurts',
#    'correction': 'it would hurt',
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'I know he will tell me to clean the car @DATE1 I told him',
#    'correction': 'I know he will tell me to clean the car, but I told him',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'I didnt do it yet',
#    'correction': 'I haven’t done it yet',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'My father on the other hand',
#    'correction': 'My father, on the other hand,',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'I only have @NUM1 birthday',
#    'correction': 'I only have one birthday',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'like my birthday for instance,',
#    'correction': 'like, for instance, my birthday,',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'he little',
#    'correction': 'her little',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'breake',
#    'correction': 'break',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'rall', 'correction': 'ran', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'un-patiently',
#    'correction': 'impatiently',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'happy that',
#    'correction': 'happily that',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'seen',
#    'correction': 'saw',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'there it',
#    'correction': 'there, there',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'guies',
#    'correction': 'guys',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'rid', 'correction': 'ride', 'type': 'Spelling', 'sentence': 5},
#   {'original': 'sedar',
#    'correction': 'Cedar',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'bye', 'correction': 'buy', 'type': 'Spelling', 'sentence': 4},
#   {'original': 'mash mellows',
#    'correction': 'marshmallows',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'marsh mellows',
#    'correction': 'marshmallows',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'in the line',
#    'correction': 'into the line',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'slove',
#    'correction': 'store',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'jorney',
#    'correction': 'journey',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'california',
#    'correction': 'California',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'line for',
#    'correction': 'lines for',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'plain',
#    'correction': 'plane',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'finaly',
#    'correction': 'finally',
#    'type': 'Spelling',
#    'sentence': 3}],
#  [{'original': 'on a bridge',
#    'correction': 'in a line',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'companing',
#    'correction': 'complaining',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'compliments',
#    'correction': 'complain',
#    'type': 'Word Choice',
#    'sentence': 6},
#   {'original': 'night more',
#    'correction': 'nightmare',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'fum',
#    'correction': 'fun',
#    'type': 'Spelling',
#    'sentence': 26}],
#  [{'original': 'out of state',
#    'correction': 'out-of-state',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'oven',
#    'correction': 'open',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'three day',
#    'correction': 'three-day',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'goat', 'correction': 'got', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'so when',
#    'correction': 'so that when',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'a lot whining',
#    'correction': 'a lot of whining',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'the passport were',
#    'correction': 'the passports were',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'half way',
#    'correction': 'halfway',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'we were coming',
#    'correction': 'we were returning',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'for @LOCATION3 citizens',
#    'correction': 'for the citizens of @LOCATION3',
#    'type': 'Word Choice',
#    'sentence': 4}],
#  [{'original': 'he asking',
#    'correction': 'he is asking',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'lets go',
#    'correction': "let's go",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'unversual',
#    'correction': 'Universal',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'rollor coastor',
#    'correction': 'roller coaster',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'me and my mom dad',
#    'correction': 'my mom, dad, and I',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'disiported',
#    'correction': 'disappointed',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'I orderd',
#    'correction': 'I ordered',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'fanominall',
#    'correction': 'phenomenal',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'I never gone',
#    'correction': 'I had never gone',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'are house',
#    'correction': 'our house',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'o the phone',
#    'correction': 'on the phone',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'took at the trash',
#    'correction': 'took the trash',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'the some thing',
#    'correction': 'the same thing',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'all the like',
#    'correction': 'like all the',
#    'type': 'Word Choice',
#    'sentence': 2}],
#  [{'original': 'sowe', 'correction': 'so', 'type': 'Spelling', 'sentence': 4},
#   {'original': 'trow',
#    'correction': 'through',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': "patient's",
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': "pant's",
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'where',
#    'correction': 'were',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'weall',
#    'correction': 'we all',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'your teaching',
#    'correction': "you're teaching",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'patience ?',
#    'correction': 'patient?',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'patience .I',
#    'correction': 'patient. I',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'futher',
#    'correction': 'future',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'presents-each one',
#    'correction': 'presents—each one',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'suppose to',
#    'correction': 'supposed to',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': '@CAPS7 only have',
#    'correction': 'Not only have',
#    'type': 'Grammatical',
#    'sentence': 23},
#   {'original': 'a @CAPS1 tree',
#    'correction': 'a @CAPS1 tree',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'boarders',
#    'correction': 'borders',
#    'type': 'Spelling',
#    'sentence': 22}],
#  [{'original': 'noone',
#    'correction': 'no one',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'every one',
#    'correction': 'everyone',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'didnt',
#    'correction': "didn't",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'new', 'correction': 'knew', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'meap',
#    'correction': 'MEAP',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'patiently to get',
#    'correction': 'patiently waiting to get',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'as swords',
#    'correction': 'swords',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'they to a',
#    'correction': 'they did to a',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'every one',
#    'correction': 'everyone',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'An warrior',
#    'correction': 'A warrior',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'divulged into',
#    'correction': 'delved into',
#    'type': 'Word Choice',
#    'sentence': 9},
#   {'original': 'friend poured',
#    'correction': 'friends poured',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'ran out to',
#    'correction': 'ran out of',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'shuttered',
#    'correction': 'shuddered',
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': "hadn't of cared",
#    'correction': "hadn't cared",
#    'type': 'Grammatical',
#    'sentence': 7}],
#  [{'original': 'like a half',
#    'correction': 'about half',
#    'type': 'Word Choice',
#    'sentence': 8},
#   {'original': 'time',
#    'correction': 'times',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'I patient',
#    'correction': 'I was patient',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'waiting the man',
#    'correction': 'waiting, the man',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'back there',
#    'correction': 'back',
#    'type': 'Word Choice',
#    'sentence': 8}],
#  [{'original': 'can',
#    'correction': 'could',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'scud',
#    'correction': 'said',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'I waiting',
#    'correction': 'I was waiting',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'In conclusion I',
#    'correction': 'In conclusion, I',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'My mom, brother, cousins, uncle',
#    'correction': 'My mom, brother, cousins, and uncle',
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'Although, not',
#    'correction': 'Although not',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'every thing',
#    'correction': 'everything',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'magnum',
#    'correction': 'Magnum',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'after a little',
#    'correction': 'after a little while,',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'intil',
#    'correction': 'until',
#    'type': 'Spelling',
#    'sentence': 10}],
#  [{'original': 'board',
#    'correction': 'bored',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'On time',
#    'correction': 'One time',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'waiting in',
#    'correction': 'waited in',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'patient',
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 10},
#   {'original': 'easially',
#    'correction': 'easily',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'has had job',
#    'correction': 'has had a job',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'his as',
#    'correction': 'is as',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'patientence',
#    'correction': 'patience',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'san',
#    'correction': 'San',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'trys',
#    'correction': 'tries',
#    'type': 'Spelling',
#    'sentence': 10}],
#  [{'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'thier',
#    'correction': 'their',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'snaped is',
#    'correction': 'snapped his',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'know patience',
#    'correction': 'knew patience',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'break fast',
#    'correction': 'breakfast',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'catchs',
#    'correction': 'catches',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'take',
#    'correction': 'takes',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'patiEnt',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'wat',
#    'correction': 'what',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'half',
#    'correction': 'have',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'is are',
#    'correction': 'is our',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'wall in',
#    'correction': 'well then',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'all ways',
#    'correction': 'always',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'unit',
#    'correction': 'wait',
#    'type': 'Word Choice',
#    'sentence': 2}],
#  [{'original': 'trial',
#    'correction': 'trail',
#    'type': 'Spelling',
#    'sentence': 18},
#   {'original': 'step',
#    'correction': 'steps',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'shuting',
#    'correction': 'shutting',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'could',
#    'correction': 'cold',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'of', 'correction': 'off', 'type': 'Spelling', 'sentence': 16}],
#  [{'original': 'paient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'staning',
#    'correction': 'standing',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'whey',
#    'correction': 'they',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'watet',
#    'correction': "wasn't",
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'wan',
#    'correction': 'when',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'im',
#    'correction': "I'm",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'to much',
#    'correction': 'too much',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'say nothing',
#    'correction': 'say anything',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'twords',
#    'correction': 'towards',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'savere',
#    'correction': 'severe',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'if I nid',
#    'correction': 'if I did',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'dertmind',
#    'correction': 'determined',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'Im',
#    'correction': "I'm",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'Ok', 'correction': 'Okay', 'type': 'Spelling', 'sentence': 1},
#   {'original': 'band new',
#    'correction': 'brand new',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'a early',
#    'correction': 'an early',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'there',
#    'correction': 'they',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'are',
#    'correction': 'our',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'rember',
#    'correction': 'remember',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'pacient',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'crine',
#    'correction': 'come',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'ask',
#    'correction': 'asked',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'use',
#    'correction': 'used',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'sense',
#    'correction': 'since',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'spend',
#    'correction': 'spent',
#    'type': 'Grammatical',
#    'sentence': 8}],
#  [{'original': 'fo', 'correction': 'to', 'type': 'Spelling', 'sentence': 8},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'frield',
#    'correction': 'tried',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'At @PERSON2 high',
#    'correction': "At @PERSON2's high",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'a hour',
#    'correction': 'an hour',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'to @CAPS7 house',
#    'correction': "to @CAPS7's house",
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'She said, I dont know. And',
#    'correction': 'She said, I dont know, and',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'anniversery',
#    'correction': 'anniversary',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'parent are',
#    'correction': 'parents are',
#    'type': 'Grammatical',
#    'sentence': 7}],
#  [{'original': 'callop duty',
#    'correction': 'Call of Duty',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'thirty two',
#    'correction': 'thirty-two',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'exsact',
#    'correction': 'exact',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'calenders',
#    'correction': 'calendars',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'for.',
#    'correction': 'for it.',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'in very negative',
#    'correction': 'in a very negative',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'pros and cons',
#    'correction': 'pros and cons',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'my audience what',
#    'correction': 'my audience: what',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'wont',
#    'correction': "won't",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'Well in',
#    'correction': 'Well, in',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'exept',
#    'correction': 'except',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': '@CAPS1',
#    'correction': 'After',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': '@CAPS1',
#    'correction': 'When',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'wook',
#    'correction': 'woke',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': '@CAPS1',
#    'correction': 'When',
#    'type': 'Grammatical',
#    'sentence': 11}],
#  [{'original': 'mum',
#    'correction': 'mom',
#    'type': 'Word Choice',
#    'sentence': 19},
#   {'original': 'dans',
#    'correction': 'dang',
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'every thing',
#    'correction': 'everything',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'biggest lines',
#    'correction': 'biggest line',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'Finaly',
#    'correction': 'Finally',
#    'type': 'Spelling',
#    'sentence': 3}],
#  [{'original': 'beutiful',
#    'correction': 'beautiful',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': '@NUM1',
#    'correction': 'two',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'live happy',
#    'correction': 'live happily',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': '@CAPS1 out',
#    'correction': 'took out',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'to no avail',
#    'correction': 'but to no avail',
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'vaction',
#    'correction': 'vacation',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'dicided',
#    'correction': 'decided',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'worth waiting @NUM1 and a half hours',
#    'correction': 'worth waiting @NUM1 and a half hours for',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'waiting @NUM1 and a half hours @ORGANIZATION1 it',
#    'correction': 'waiting @NUM1 and a half hours for it',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'After another hour the',
#    'correction': 'After another hour, the',
#    'type': 'Grammatical',
#    'sentence': 8}],
#  [{'original': 'cant want',
#    'correction': "can't wait",
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'andto',
#    'correction': 'and to',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'No ,he',
#    'correction': 'No, he',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'everyday',
#    'correction': 'every day',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'cause',
#    'correction': 'because',
#    'type': 'Word Choice',
#    'sentence': 1}],
#  [{'original': 'writing',
#    'correction': 'waiting',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'me, my brother, and my mom',
#    'correction': 'my brother, my mom, and I',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'put school supplies',
#    'correction': 'buy school supplies',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'areand',
#    'correction': 'around',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'barly',
#    'correction': 'barely',
#    'type': 'Spelling',
#    'sentence': 7}],
#  [{'original': 'was  on',
#    'correction': 'was on',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'get me',
#    'correction': 'get one',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'One time',
#    'correction': 'One time,',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'your patient',
#    'correction': "you're patient",
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'them I',
#    'correction': 'them, I',
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'couldt',
#    'correction': "couldn't",
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'can I go',
#    'correction': 'if I could go',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'as long as',
#    'correction': 'as long as I',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'when we got',
#    'correction': 'when we would get',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'top',
#    'correction': 'trip',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'we on was',
#    'correction': 'we went on was',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'we stared rolling',
#    'correction': 'we started rolling',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'was the often',
#    'correction': 'was often the',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'because how the',
#    'correction': 'because of how the',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'rollar coaster',
#    'correction': 'roller coaster',
#    'type': 'Spelling',
#    'sentence': 4}],
#  [{'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'want',
#    'correction': "wasn't",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'tell',
#    'correction': 'until',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'know',
#    'correction': 'now',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'out side',
#    'correction': 'outside',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'real dont',
#    'correction': "really don't",
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'didnt have nothing',
#    'correction': "didn't have anything",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'my self',
#    'correction': 'myself',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 5},
#   {'original': 'gooing',
#    'correction': 'going',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'herd',
#    'correction': 'heard',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'gonning',
#    'correction': 'going',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'wich',
#    'correction': 'which',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'moth',
#    'correction': 'math',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'patiences',
#    'correction': 'patience',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'luch',
#    'correction': 'lunch',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'patiences',
#    'correction': 'patience',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'instint',
#    'correction': 'instant',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'I f',
#    'correction': 'If',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'If not your',
#    'correction': "If not, you're",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'fasier',
#    'correction': 'easier',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'our would would',
#    'correction': 'our world would',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'tarn',
#    'correction': 'turned',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'millenum',
#    'correction': 'millennium',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'difficuties',
#    'correction': 'difficulties',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'me, my dad',
#    'correction': 'my dad and I',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'waiting in line',
#    'correction': 'waited in line',
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'Unfortunetly',
#    'correction': 'Unfortunately',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'omazon',
#    'correction': 'Amazon',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'bin',
#    'correction': 'been',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'yet', 'correction': 'get', 'type': 'Spelling', 'sentence': 10},
#   {'original': 'on ipod',
#    'correction': 'an iPod',
#    'type': 'Grammatical',
#    'sentence': 6}],
#  [{'original': 'parent',
#    'correction': 'parents',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'of when',
#    'correction': 'when',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'alow',
#    'correction': 'allow',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'over joyed',
#    'correction': 'overjoyed',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'bring',
#    'correction': 'bringing',
#    'type': 'Grammatical',
#    'sentence': 11}],
#  [{'original': 'had took',
#    'correction': 'had taken',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'went thorugh',
#    'correction': 'gone through',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'at two',
#    'correction': 'out two',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'there',
#    'correction': 'their',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'panke',
#    'correction': 'pain',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'Luckly',
#    'correction': 'Luckily',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'realitives',
#    'correction': 'relatives',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'chessy',
#    'correction': 'cheesy',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'orginal',
#    'correction': 'original',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'escelators',
#    'correction': 'escalators',
#    'type': 'Spelling',
#    'sentence': 12}],
#  [{'original': 'org', 'correction': 'cry', 'type': 'Spelling', 'sentence': 8},
#   {'original': 'yers',
#    'correction': 'years',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'be', 'correction': 'bee', 'type': 'Spelling', 'sentence': 6},
#   {'original': 'rah', 'correction': 'ran', 'type': 'Spelling', 'sentence': 7},
#   {'original': 'mchother',
#    'correction': 'each other',
#    'type': 'Grammatical',
#    'sentence': 5}],
#  [{'original': 'queitly',
#    'correction': 'quietly',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'the had',
#    'correction': 'the day had',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'couldnt',
#    'correction': "couldn't",
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'new', 'correction': 'knew', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'an waiting',
#    'correction': 'and waiting',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'stad',
#    'correction': 'stayed',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'patient',
#    'correction': 'waiting',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'gender',
#    'correction': 'Cedar',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'have way',
#    'correction': 'halfway',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'exited',
#    'correction': 'excited',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'baby sat',
#    'correction': 'babysat',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'Ill',
#    'correction': "I'll",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'Her @CAPS5 is',
#    'correction': 'Her @CAPS5 was',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'Im',
#    'correction': "I'm",
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'immeadiently',
#    'correction': 'immediately',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'cherry pepsie.',
#    'correction': 'Cherry Pepsi.',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'at.', 'correction': '.', 'type': 'Grammatical', 'sentence': 1},
#   {'original': 'will take',
#    'correction': 'would take',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'pepsie.',
#    'correction': 'Pepsi.',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'resturaunt',
#    'correction': 'restaurant',
#    'type': 'Spelling',
#    'sentence': 21}],
#  [{'original': 'got to',
#    'correction': 'have to',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'an', 'correction': 'and', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'interapt',
#    'correction': 'interrupt',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'firedrill',
#    'correction': 'fire drill',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'what they got',
#    'correction': 'what they have',
#    'type': 'Word Choice',
#    'sentence': 4}],
#  [{'original': 'an envelopes',
#    'correction': 'an envelope',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'evelope',
#    'correction': 'envelope',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'spanted',
#    'correction': 'sprinted',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'this boys head',
#    'correction': "this boy's head",
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'congroduclotions',
#    'correction': 'congratulations',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'Me my mom',
#    'correction': 'My mom and I',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'strait',
#    'correction': 'straight',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'patients',
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 13},
#   {'original': 'coarse',
#    'correction': 'course',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'patients',
#    'correction': 'patience',
#    'type': 'Word Choice',
#    'sentence': 15}],
#  [{'original': 'gets',
#    'correction': 'gets',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'youll',
#    'correction': "you'll",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'For example if',
#    'correction': 'For example, if',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'drastically.so',
#    'correction': 'drastically. So',
#    'type': 'Grammatical',
#    'sentence': 11}],
#  [{'original': 'we a',
#    'correction': 'myself a',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'cedar point',
#    'correction': 'Cedar Point',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'wake',
#    'correction': 'woke',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'we was',
#    'correction': 'we were',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'start',
#    'correction': 'started',
#    'type': 'Grammatical',
#    'sentence': 7}],
#  [{'original': 'Then after',
#    'correction': 'Then, after',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'whene',
#    'correction': 'when',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'if', 'correction': 'of', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'a award',
#    'correction': 'an award',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'didnt',
#    'correction': "didn't",
#    'type': 'Grammatical',
#    'sentence': 6}],
#  [{'original': 'grabed',
#    'correction': 'grabbed',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'in to',
#    'correction': 'into',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'ceder',
#    'correction': 'Cedar',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Word Choice',
#    'sentence': 16},
#   {'original': 'I playing',
#    'correction': 'I played',
#    'type': 'Grammatical',
#    'sentence': 16}],
#  [{'original': 'two', 'correction': 'to', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'are examples',
#    'correction': 'is an example',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'pationt',
#    'correction': 'patient',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'too shels',
#    'correction': 'to help',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'tack',
#    'correction': 'take',
#    'type': 'Spelling',
#    'sentence': 9}],
#  [{'original': 'belive',
#    'correction': 'believe',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'knc', 'correction': 'knee', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'doctors  office',
#    'correction': "doctor's office",
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'sprins',
#    'correction': 'sprained',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'becouse',
#    'correction': 'because',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'cedar point',
#    'correction': 'Cedar Point',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'it the',
#    'correction': 'is the',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'in', 'correction': 'to', 'type': 'Grammatical', 'sentence': 3},
#   {'original': 'bas', 'correction': 'bus', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'hilerious',
#    'correction': 'hilarious',
#    'type': 'Spelling',
#    'sentence': 7}],
#  [{'original': 'However many',
#    'correction': 'However, many',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'out weigh',
#    'correction': 'outweigh',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'as patient as monks',
#    'correction': 'as patient as a monk',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'be @CAPS1 a trile',
#    'correction': 'be a trial',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'rollar',
#    'correction': 'roller',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'we can',
#    'correction': 'so we could',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'to the beach.This',
#    'correction': 'to go to the beach. This',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'and;',
#    'correction': 'and I',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'at the middle',
#    'correction': 'in the middle',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'atime',
#    'correction': 'a time',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'the worst time',
#    'correction': 'at the worst time',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'When there are',
#    'correction': 'When they are',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'there',
#    'correction': 'at',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'good the',
#    'correction': 'good for',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'volley ball',
#    'correction': 'volleyball',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'me had',
#    'correction': 'I had',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'unlik',
#    'correction': 'unlike',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'are proggress',
#    'correction': 'our progress',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'trys',
#    'correction': 'tries',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'sibling',
#    'correction': 'siblings',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'musem',
#    'correction': 'museum',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'histry',
#    'correction': 'history',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'Untill',
#    'correction': 'Until',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'complane',
#    'correction': 'complain',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'fit live',
#    'correction': 'felt like',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'theres',
#    'correction': "there's",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'burgers fries',
#    'correction': 'burger, fries',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'packing spots',
#    'correction': 'parking spots',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'O my go',
#    'correction': 'Oh my god',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'butt hort',
#    'correction': 'butt hurt',
#    'type': 'Spelling',
#    'sentence': 3}],
#  [{'original': 'wiil',
#    'correction': 'will',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 2},
#   {'original': 'are',
#    'correction': 'our',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'sense',
#    'correction': 'since',
#    'type': 'Word Choice',
#    'sentence': 2}],
#  [{'original': 'advice',
#    'correction': 'advise',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'patience mean',
#    'correction': 'patience means',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'no', 'correction': 'know', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'to the in',
#    'correction': 'to the end',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'is seem',
#    'correction': 'seems',
#    'type': 'Grammatical',
#    'sentence': 1}]]

# %%
joblib.dump(sampled_corrections, 'files/correction_test_100essay_5corr')
# Out:
# ['files/correction_test_100essay_5corr']

# %%
# Function to apply corrections to the essay
def apply_corrections_grammar(essay, corrections):
    # Tokenize the essay into sentences using NLTK
    sentences = nltk.sent_tokenize(essay)

    # Create a list to store corrected sentences
    corrected_sentences = []

    # Iterate through sentences
    for i, sentence in enumerate(sentences):
        # Apply corrections to the current sentence
        for correction in corrections:
            # Adjust the index by subtracting 1 to match the enumeration starting from 0
            if correction['sentence'] == i + 1:
                # Replace all occurrences of the incorrect text with the correction
                #sentence = sentence.replace(correction['original'], correction['correction'])
                 # Use regular expression with word boundaries to replace only whole words
                sentence = re.sub(r'\b' + re.escape(correction['original']) + r'\b', correction['correction'], sentence)
        # Add the corrected sentence to the list
        corrected_sentences.append(sentence)

    # Join the corrected sentences to form the final essay
    corrected_essay = ' '.join(corrected_sentences)
    return corrected_essay

# Function to generate all combinations of corrections and apply them
def generate_corrected_versions(essay, corrections):
    corrected_versions = []
    max_corrections = len(corrections)

    # Iterate over different numbers of corrections to apply
    for num_corrections in range(1, max_corrections + 1):
        for combination in itertools.combinations(corrections, num_corrections):
            corrected_essay = apply_corrections_grammar(essay, combination)
            corrected_versions.append(corrected_essay)
  
    return corrected_versions

# # Example usage
# essay = "This is a tess essay. The break through was amazing. The possitive effects were clear."
# corrections = [
#     {'original': 'tess', 'correction': 'test', 'type': 'Spelling', 'sentence': 1},
#     {'original': 'break through', 'correction': 'breakthrough', 'type': 'Spelling', 'sentence': 2},
#     {'original': 'possitive', 'correction': 'positive', 'type': 'Spelling', 'sentence': 3},
# ]

# # Generate corrected versions with combinations of 1, 2, and 3 corrections
# corrected_versions = generate_corrected_versions(essay, corrections)
# corrected_versions

# %%
correction_test_100essay_5corr = joblib.load('files/correction_test_100essay_5corr')

corrected_test_100data_5corr = []

for index, row in data_100.iterrows():
    try:
        corrected_essays = generate_corrected_versions(row['essay'], correction_test_100essay_5corr[index]) 
        # Append the result to the list
        corrected_test_100data_5corr.append(corrected_essays)
    except Exception as e:
        print(f"Error processing row {index}: {e}")
        corrected_test_100data_5corr.append(None)  # Append None or an empty dict if an error occurs

# %%
np.array(corrected_test_100data_5corr).shape
# Out:
# (100, 31)

# %%
joblib.dump(corrected_test_100data_5corr, 'files/corrected_test_100data_5corr')
# Out:
# ['files/corrected_test_100data_5corr']
