# %% [markdown]
# ### This is to retrain using both positive and negative counterfactuals

# %%
import xgboost
import joblib
import numpy as np
from sklearn.metrics import accuracy_score
from quadratic_weighted_kappa import quadratic_weighted_kappa
import pandas as pd
import itertools

# %%
scores_ori = np.array(joblib.load("files/scores_essay_100_train_ori")).astype(float)
scores_ori.shape
# Out:
# (100,)

# %%
scores_ori = np.repeat(scores_ori, 31)

# %%
len(scores_ori)
# Out:
# 3100

# %%
x = joblib.load('files/asap7_features_776').squeeze()
y = joblib.load("files/score_asap7")
y = y.reshape(-1,1)

feature_names = joblib.load('files/feature_names_776')
#model = joblib.load('model_asap1_778')

feats_counter_train_error = joblib.load('files/feats_counter_train_error_776').reshape(-1,776)
new_label_train_error = scores_ori.copy().reshape(3100,-1)

feats_counter_train_better = joblib.load('files/feats_counter_train_correct_776').reshape(-1,776)
new_label_train_better = scores_ori.copy().reshape(3100,-1)

# %%
new_label_train_better.shape
# Out:
# (3100, 1)

# %%
y.shape
# Out:
# (1569, 1)

# %%
print(scores_ori.dtype)
# Out:
# float64

# %%
print(new_label_train_better.dtype)
# Out:
# float64

# %%
import numpy as np
import matplotlib.pyplot as plt

n_show = 100

# Flatten and slice
ori = scores_ori[:n_show]
err = new_label_train_error[:n_show].flatten()
bet = new_label_train_better[:n_show].flatten()

# Compute and scale differences
diff_err = (err - ori) * 1000
diff_bet = (bet - ori) * 1000

# Plot
plt.figure(figsize=(12, 6))
plt.plot(diff_err, label='(Error - Original) × 1000', marker='o')
plt.plot(diff_bet, label='(Better - Original) × 1000', marker='x')
plt.axhline(0, color='gray', linestyle='--')
plt.title(f'Scaled Differences from Original Scores (First {n_show})')
plt.xlabel('Index')
plt.ylabel('Difference × 1000')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(scores_ori, bins=20, alpha=0.5, label='Original Scores')
plt.hist(new_label_train_error, bins=20, alpha=0.5, label='Error Labels')
plt.hist(new_label_train_better, bins=20, alpha=0.5, label='Better Labels')
plt.title('Score Distributions')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_counter = np.concatenate((y, new_label_train_better, new_label_train_error), axis=0).reshape(-1)
y_counter.shape
# Out:
# (7769,)

# %%
y = y_counter
y.shape
# Out:
# (7769,)

# %%
x_counter = np.concatenate((x,feats_counter_train_better, feats_counter_train_error), axis=0)
x_counter.shape
# Out:
# (7769, 776)

# %%
x = x_counter
x.shape
# Out:
# (7769, 776)

# %%
# REMOVE PROMPT OVERLAP & PROMPT OVERLAP (SYNONYM) FEATURES, AS THEY HAVE NEGATIVE CORRELATION WITH FINAL SCORE

# x_776 = np.delete(x, [5,6],axis=1)
# x_776.shape

# %%
# x = x_776
# x.shape

# %%
def get_feature_names_extended():
    inter_feats = ['Answer Length', 'Word Count', 'Average Word Length', 'Unique Word Count', 'Punctuation Density',
                  'Prompt Overlap', 'Prompt Overlap (synonyms)', 'Prompt Similarity SBert', 
                  'Spelling Error', 'Language Error']
    inter_feats = ['Answer Length', 'Word Count', 'Average Word Length', 'Unique Word Count', 'Punctuation Density',
                  'Prompt Similarity SBert', 
                  'Spelling Error', 'Language Error']
    
    sbert_feats = []
    sbert_dim = 768

    for i in range(0, sbert_dim):
    	fname = "sbert_" + str(i) 
    	sbert_feats.append(fname)
    
    feature_names = inter_feats + sbert_feats 

    print("len feature names: ", len(feature_names))
    
    return feature_names

feature_names = get_feature_names_extended()#[:12]
# Out:
# len feature names:  776

# %%
#joblib.dump(feature_names, 'feature_names_778')

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

kf = KFold(n_splits=5, shuffle=True, random_state=42)

print(kf)
# Out:
# KFold(n_splits=5, random_state=42, shuffle=True)

# %%
model = xgboost.XGBRegressor(objective ='reg:squarederror',
                colsample_bytree=0.4,
                 gamma=0,                 
                 learning_rate=0.05,
                 max_depth=4,
                 min_child_weight=1.5,
                 n_estimators=1000,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=42)

# ORI QWK :

# %%
qwk_scores = []

test_indices = []
pred_labels = []

for train_index, test_index in kf.split(x, y):
    
    X_train, X_test, Y_train, Y_test = x[train_index], x[test_index], y[train_index], y[test_index]
         
    model.fit(X_train, Y_train)
    
    predict = model.predict(X_test)
    predict = np.round(predict)
    
    pred_labels.extend(predict)
    test_indices.extend(test_index)
    
    result = quadratic_weighted_kappa(Y_test, predict)
    
    print("Qwk : ", result)
    print(X_train.shape)
    qwk_scores.append(result)
    
np.mean(qwk_scores)
# Out:
# Qwk :  0.9597151455794828
# (6215, 776)
# Qwk :  0.9607942034706825
# (6215, 776)
# Qwk :  0.9622481533975744
# (6215, 776)
# Qwk :  0.9597930784778418
# (6215, 776)
# Qwk :  0.9631121942203099
# (6216, 776)
# 0.9611325550291783

# %% [markdown]
# ##### Only evaluate the original Test Set (without augmentation), but using new Model (trained with augmentation)

# %%
qwk_scores = []

for train_index, test_index in kf.split(x, y):
    
    X_train, X_test, Y_train, Y_test = x[train_index], x[test_index], y[train_index], y[test_index]

    # Filter test indices for those less than 1783
    test_index_baru = test_index[test_index < 1783]
    print("Filtered test indices count:", len(test_index_baru))
    
    print(X_train.shape)
    print(Y_train.shape)
    model.fit(X_train, Y_train)

    # Use test_index_baru to get filtered test sets from the original arrays
    X_test_baru = X_test[test_index < 1783]  # Correct filtering
    Y_test_baru = Y_test[test_index < 1783]  # Correct filtering

    print("Filtered X_test count:", len(X_test_baru))
    print("Filtered Y_test count:", len(Y_test_baru))
    
    predict = model.predict(X_test_baru)
    predict = np.round(predict)
    
    result = quadratic_weighted_kappa(Y_test_baru, predict)
    
    print("Qwk : ", result)
    qwk_scores.append(result)

mean_qwk = np.mean(qwk_scores)
print("Mean Qwk:", mean_qwk)
# Out:
# Filtered test indices count: 379
# (6215, 776)
# (6215,)
# Filtered X_test count: 379
# Filtered Y_test count: 379
# Qwk :  0.8294789122954422
# Filtered test indices count: 361
# (6215, 776)
# (6215,)
# Filtered X_test count: 361
# Filtered Y_test count: 361
# Qwk :  0.8179921032572542
# Filtered test indices count: 346
# (6215, 776)
# (6215,)
# Filtered X_test count: 346
# Filtered Y_test count: 346
# Qwk :  0.8251878715108952
# Filtered test indices count: 375
# (6215, 776)
# (6215,)
# Filtered X_test count: 375
# Filtered Y_test count: 375
# Qwk :  0.8281035860956723
# Filtered test indices count: 322
# (6216, 776)
# (6216,)
# Filtered X_test count: 322
# Filtered Y_test count: 322
# Qwk :  0.809974023724517
# Mean Qwk: 0.8221472993767561

# %%
print(len(pred_labels))
print(len(test_indices))
# Out:
# 7769
# 7769

# %%
new_score = np.zeros(1783)
new_score
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
new_score[test_indices] = pred_labels_int
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 new_score[test_indices] = pred_labels_int
#
# NameError: name 'pred_labels_int' is not defined

# %%
new_score
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
new_score[60]
# Out:
# 0.0

# %%
#joblib.dump(new_score, 'score_model_normalized')

# %% [markdown]
# ## Create model

# %%
from sklearn.model_selection import train_test_split
indices = np.arange(len(x))
X_train, X_test, Y_train, Y_test, idx_train, idx_test = train_test_split(x, y, indices, test_size=0.2, random_state=42)

# %%
len(idx_test)
# Out:
# 1554

# %%
idx_test
# Out:
# array([1421, 2746, 3473, ...,  904, 1446, 7285])

# %%
# Filter the array for values less than 1783
new_array = idx_test[idx_test < 1783]
len(new_array)
# Out:
# 379

# %%
d_train = xgboost.DMatrix(X_train, label=Y_train, feature_names=feature_names)
d_test = xgboost.DMatrix(X_test, label=Y_test, feature_names=feature_names)

# %%
model = xgboost.train({"learning_rate": 0.05, "max_depth":4, 'alpha':0.75, 'lambda':0.45,}, d_train, 400, evals = [(d_test, "test")], early_stopping_rounds=50)
# Out:
# [0]	test-rmse:15.62889
# [1]	test-rmse:14.86418
# [2]	test-rmse:14.13701
# [3]	test-rmse:13.44681
# [4]	test-rmse:12.79086
# [5]	test-rmse:12.16881
# [6]	test-rmse:11.57936
# [7]	test-rmse:11.01893
# [8]	test-rmse:10.48676
# [9]	test-rmse:9.98339
# [10]	test-rmse:9.50084
# [11]	test-rmse:9.04630
# [12]	test-rmse:8.61541
# [13]	test-rmse:8.20809
# [14]	test-rmse:7.81666
# [15]	test-rmse:7.44693
# [16]	test-rmse:7.09718
# [17]	test-rmse:6.76361
# [18]	test-rmse:6.44797
# [19]	test-rmse:6.14946
# [20]	test-rmse:5.86663
# [21]	test-rmse:5.59747
# [22]	test-rmse:5.34254
# [23]	test-rmse:5.10204
# [24]	test-rmse:4.87414
# [25]	test-rmse:4.65623
# [26]	test-rmse:4.45159
# [27]	test-rmse:4.25725
# [28]	test-rmse:4.07370
# [29]	test-rmse:3.90179
# [30]	test-rmse:3.73749
# [31]	test-rmse:3.58205
# [32]	test-rmse:3.43509
# [33]	test-rmse:3.29778
# [34]	test-rmse:3.16974
# [35]	test-rmse:3.04856
# [36]	test-rmse:2.93352
# [37]	test-rmse:2.82552
# [38]	test-rmse:2.72463
# [39]	test-rmse:2.62895
# [40]	test-rmse:2.53827
# [41]	test-rmse:2.45499
# [42]	test-rmse:2.37647
# [43]	test-rmse:2.30243
# [44]	test-rmse:2.23363
# [45]	test-rmse:2.16868
# [46]	test-rmse:2.10786
# [47]	test-rmse:2.05225
# [48]	test-rmse:2.00159
# [49]	test-rmse:1.95366
# [50]	test-rmse:1.90840
# [51]	test-rmse:1.86928
# [52]	test-rmse:1.82851
# [53]	test-rmse:1.79375
# [54]	test-rmse:1.76109
# [55]	test-rmse:1.72955
# [56]	test-rmse:1.70079
# [57]	test-rmse:1.67606
# [58]	test-rmse:1.65087
# [59]	test-rmse:1.62874
# [60]	test-rmse:1.60746
# [61]	test-rmse:1.58828
# [62]	test-rmse:1.56879
# [63]	test-rmse:1.55031
# [64]	test-rmse:1.53513
# [65]	test-rmse:1.52140
# [66]	test-rmse:1.50665
# [67]	test-rmse:1.49510
# [68]	test-rmse:1.48429
# [69]	test-rmse:1.47357
# [70]	test-rmse:1.46326
# [71]	test-rmse:1.45440
# [72]	test-rmse:1.44487
# [73]	test-rmse:1.43792
# [74]	test-rmse:1.43110
# [75]	test-rmse:1.42513
# [76]	test-rmse:1.41801
# [77]	test-rmse:1.41253
# [78]	test-rmse:1.40715
# [79]	test-rmse:1.40370
# [80]	test-rmse:1.39865
# [81]	test-rmse:1.39268
# [82]	test-rmse:1.38899
# [83]	test-rmse:1.38449
# [84]	test-rmse:1.38182
# [85]	test-rmse:1.37748
# [86]	test-rmse:1.37357
# [87]	test-rmse:1.37176
# [88]	test-rmse:1.36930
# [89]	test-rmse:1.36575
# [90]	test-rmse:1.36414
# [91]	test-rmse:1.36096
# [92]	test-rmse:1.35882
# [93]	test-rmse:1.35759
# [94]	test-rmse:1.35643
# [95]	test-rmse:1.35337
# [96]	test-rmse:1.35111
# [97]	test-rmse:1.34920
# [98]	test-rmse:1.34663
# [99]	test-rmse:1.34606
# [100]	test-rmse:1.34465
# [101]	test-rmse:1.34339
# [102]	test-rmse:1.34266
# [103]	test-rmse:1.34193
# [104]	test-rmse:1.34072
# [105]	test-rmse:1.33931
# [106]	test-rmse:1.33812
# [107]	test-rmse:1.33788
# [108]	test-rmse:1.33775
# [109]	test-rmse:1.33732
# [110]	test-rmse:1.33629
# [111]	test-rmse:1.33568
# [112]	test-rmse:1.33494
# [113]	test-rmse:1.33387
# [114]	test-rmse:1.33342
# [115]	test-rmse:1.33295
# [116]	test-rmse:1.33270
# [117]	test-rmse:1.33139
# [118]	test-rmse:1.33089
# [119]	test-rmse:1.33030
# [120]	test-rmse:1.33021
# [121]	test-rmse:1.32841
# [122]	test-rmse:1.32763
# [123]	test-rmse:1.32664
# [124]	test-rmse:1.32626
# [125]	test-rmse:1.32553
# [126]	test-rmse:1.32489
# [127]	test-rmse:1.32407
# [128]	test-rmse:1.32290
# [129]	test-rmse:1.32265
# [130]	test-rmse:1.32271
# [131]	test-rmse:1.32202
# [132]	test-rmse:1.32113
# [133]	test-rmse:1.32122
# [134]	test-rmse:1.32147
# [135]	test-rmse:1.32082
# [136]	test-rmse:1.32066
# [137]	test-rmse:1.32010
# [138]	test-rmse:1.31969
# [139]	test-rmse:1.31908
# [140]	test-rmse:1.31896
# [141]	test-rmse:1.31875
# [142]	test-rmse:1.31860
# [143]	test-rmse:1.31811
# [144]	test-rmse:1.31684
# [145]	test-rmse:1.31706
# [146]	test-rmse:1.31649
# [147]	test-rmse:1.31612
# [148]	test-rmse:1.31575
# [149]	test-rmse:1.31615
# [150]	test-rmse:1.31550
# [151]	test-rmse:1.31498
# [152]	test-rmse:1.31456
# [153]	test-rmse:1.31528
# [154]	test-rmse:1.31486
# [155]	test-rmse:1.31431
# [156]	test-rmse:1.31468
# [157]	test-rmse:1.31429
# [158]	test-rmse:1.31400
# [159]	test-rmse:1.31410
# [160]	test-rmse:1.31393
# [161]	test-rmse:1.31356
# [162]	test-rmse:1.31297
# [163]	test-rmse:1.31346
# [164]	test-rmse:1.31222
# [165]	test-rmse:1.31164
# [166]	test-rmse:1.31166
# [167]	test-rmse:1.31136
# [168]	test-rmse:1.31117
# [169]	test-rmse:1.31120
# [170]	test-rmse:1.31101
# [171]	test-rmse:1.31094
# [172]	test-rmse:1.31026
# [173]	test-rmse:1.31019
# [174]	test-rmse:1.30957
# [175]	test-rmse:1.30924
# [176]	test-rmse:1.30874
# [177]	test-rmse:1.30877
# [178]	test-rmse:1.30897
# [179]	test-rmse:1.30893
# [180]	test-rmse:1.30828
# [181]	test-rmse:1.30814
# [182]	test-rmse:1.30815
# [183]	test-rmse:1.30738
# [184]	test-rmse:1.30757
# [185]	test-rmse:1.30738
# [186]	test-rmse:1.30619
# [187]	test-rmse:1.30624
# [188]	test-rmse:1.30623
# [189]	test-rmse:1.30604
# [190]	test-rmse:1.30627
# [191]	test-rmse:1.30567
# [192]	test-rmse:1.30495
# [193]	test-rmse:1.30437
# [194]	test-rmse:1.30390
# [195]	test-rmse:1.30323
# [196]	test-rmse:1.30296
# [197]	test-rmse:1.30277
# [198]	test-rmse:1.30243
# [199]	test-rmse:1.30157
# [200]	test-rmse:1.30102
# [201]	test-rmse:1.30082
# [202]	test-rmse:1.30061
# [203]	test-rmse:1.30061
# [204]	test-rmse:1.29972
# [205]	test-rmse:1.29906
# [206]	test-rmse:1.29879
# [207]	test-rmse:1.29863
# [208]	test-rmse:1.29801
# [209]	test-rmse:1.29818
# [210]	test-rmse:1.29788
# [211]	test-rmse:1.29779
# [212]	test-rmse:1.29741
# [213]	test-rmse:1.29720
# [214]	test-rmse:1.29749
# [215]	test-rmse:1.29730
# [216]	test-rmse:1.29676
# [217]	test-rmse:1.29623
# [218]	test-rmse:1.29635
# [219]	test-rmse:1.29561
# [220]	test-rmse:1.29531
# [221]	test-rmse:1.29513
# [222]	test-rmse:1.29482
# [223]	test-rmse:1.29526
# [224]	test-rmse:1.29525
# [225]	test-rmse:1.29502
# [226]	test-rmse:1.29465
# [227]	test-rmse:1.29401
# [228]	test-rmse:1.29298
# [229]	test-rmse:1.29298
# [230]	test-rmse:1.29341
# [231]	test-rmse:1.29355
# [232]	test-rmse:1.29297
# [233]	test-rmse:1.29298
# [234]	test-rmse:1.29276
# [235]	test-rmse:1.29280
# [236]	test-rmse:1.29303
# [237]	test-rmse:1.29258
# [238]	test-rmse:1.29250
# [239]	test-rmse:1.29229
# [240]	test-rmse:1.29206
# [241]	test-rmse:1.29178
# [242]	test-rmse:1.29124
# [243]	test-rmse:1.29091
# [244]	test-rmse:1.29069
# [245]	test-rmse:1.29049
# [246]	test-rmse:1.29029
# [247]	test-rmse:1.29041
# [248]	test-rmse:1.29025
# [249]	test-rmse:1.29030
# [250]	test-rmse:1.29043
# [251]	test-rmse:1.29073
# [252]	test-rmse:1.29081
# [253]	test-rmse:1.29115
# [254]	test-rmse:1.29083
# [255]	test-rmse:1.29056
# [256]	test-rmse:1.29012
# [257]	test-rmse:1.28979
# [258]	test-rmse:1.28940
# [259]	test-rmse:1.28910
# [260]	test-rmse:1.28924
# [261]	test-rmse:1.28919
# [262]	test-rmse:1.28968
# [263]	test-rmse:1.28927
# [264]	test-rmse:1.28987
# [265]	test-rmse:1.28974
# [266]	test-rmse:1.28950
# [267]	test-rmse:1.28943
# [268]	test-rmse:1.28946
# [269]	test-rmse:1.28932
# [270]	test-rmse:1.28940
# [271]	test-rmse:1.28964
# [272]	test-rmse:1.28880
# [273]	test-rmse:1.28894
# [274]	test-rmse:1.28885
# [275]	test-rmse:1.28879
# [276]	test-rmse:1.28804
# [277]	test-rmse:1.28797
# [278]	test-rmse:1.28818
# [279]	test-rmse:1.28795
# [280]	test-rmse:1.28796
# [281]	test-rmse:1.28732
# [282]	test-rmse:1.28769
# [283]	test-rmse:1.28751
# [284]	test-rmse:1.28732
# [285]	test-rmse:1.28687
# [286]	test-rmse:1.28675
# [287]	test-rmse:1.28643
# [288]	test-rmse:1.28635
# [289]	test-rmse:1.28614
# [290]	test-rmse:1.28591
# [291]	test-rmse:1.28577
# [292]	test-rmse:1.28572
# [293]	test-rmse:1.28604
# [294]	test-rmse:1.28597
# [295]	test-rmse:1.28537
# [296]	test-rmse:1.28521
# [297]	test-rmse:1.28490
# [298]	test-rmse:1.28556
# [299]	test-rmse:1.28522
# [300]	test-rmse:1.28486
# [301]	test-rmse:1.28479
# [302]	test-rmse:1.28479
# [303]	test-rmse:1.28463
# [304]	test-rmse:1.28517
# [305]	test-rmse:1.28499
# [306]	test-rmse:1.28524
# [307]	test-rmse:1.28544
# [308]	test-rmse:1.28552
# [309]	test-rmse:1.28568
# [310]	test-rmse:1.28548
# [311]	test-rmse:1.28586
# [312]	test-rmse:1.28586
# [313]	test-rmse:1.28634
# [314]	test-rmse:1.28663
# [315]	test-rmse:1.28659
# [316]	test-rmse:1.28638
# [317]	test-rmse:1.28642
# [318]	test-rmse:1.28646
# [319]	test-rmse:1.28616
# [320]	test-rmse:1.28637
# [321]	test-rmse:1.28638
# [322]	test-rmse:1.28568
# [323]	test-rmse:1.28479
# [324]	test-rmse:1.28520
# [325]	test-rmse:1.28505
# [326]	test-rmse:1.28536
# [327]	test-rmse:1.28502
# [328]	test-rmse:1.28473
# [329]	test-rmse:1.28526
# [330]	test-rmse:1.28549
# [331]	test-rmse:1.28531
# [332]	test-rmse:1.28541
# [333]	test-rmse:1.28517
# [334]	test-rmse:1.28544
# [335]	test-rmse:1.28553
# [336]	test-rmse:1.28505
# [337]	test-rmse:1.28456
# [338]	test-rmse:1.28444
# [339]	test-rmse:1.28443
# [340]	test-rmse:1.28450
# [341]	test-rmse:1.28477
# [342]	test-rmse:1.28419
# [343]	test-rmse:1.28386
# [344]	test-rmse:1.28355
# [345]	test-rmse:1.28347
# [346]	test-rmse:1.28294
# [347]	test-rmse:1.28272
# [348]	test-rmse:1.28267
# [349]	test-rmse:1.28194
# [350]	test-rmse:1.28138
# [351]	test-rmse:1.28145
# [352]	test-rmse:1.28138
# [353]	test-rmse:1.28140
# [354]	test-rmse:1.28101
# [355]	test-rmse:1.28109
# [356]	test-rmse:1.28094
# [357]	test-rmse:1.28054
# [358]	test-rmse:1.28050
# [359]	test-rmse:1.27960
# [360]	test-rmse:1.27995
# [361]	test-rmse:1.27977
# [362]	test-rmse:1.27986
# [363]	test-rmse:1.28000
# [364]	test-rmse:1.27989
# [365]	test-rmse:1.28021
# [366]	test-rmse:1.28017
# [367]	test-rmse:1.28014
# [368]	test-rmse:1.27932
# [369]	test-rmse:1.27911
# [370]	test-rmse:1.27884
# [371]	test-rmse:1.27898
# [372]	test-rmse:1.27888
# [373]	test-rmse:1.27896
# [374]	test-rmse:1.27904
# [375]	test-rmse:1.27922
# [376]	test-rmse:1.27924
# [377]	test-rmse:1.27941
# [378]	test-rmse:1.27909
# [379]	test-rmse:1.27896
# [380]	test-rmse:1.27916
# [381]	test-rmse:1.27890
# [382]	test-rmse:1.27877
# [383]	test-rmse:1.27835
# [384]	test-rmse:1.27840
# [385]	test-rmse:1.27809
# [386]	test-rmse:1.27815
# [387]	test-rmse:1.27781
# [388]	test-rmse:1.27761
# [389]	test-rmse:1.27689
# [390]	test-rmse:1.27697
# [391]	test-rmse:1.27714
# [392]	test-rmse:1.27739
# [393]	test-rmse:1.27732
# [394]	test-rmse:1.27741
# [395]	test-rmse:1.27716
# [396]	test-rmse:1.27725
# [397]	test-rmse:1.27736
# [398]	test-rmse:1.27738
# [399]	test-rmse:1.27696

# %%
yxgb_pred = model.predict(d_test)
yxgb_pred = np.round(yxgb_pred)

# %%
accuracy_score(yxgb_pred, np.round(Y_test))
# Out:
# 0.7992277992277992

# %%
quadratic_weighted_kappa(yxgb_pred, Y_test)
# Out:
# 0.9570563450039837

# %%
joblib.dump(model, 'files/model_asap7_776_counter_both_ori')
# Out:
# ['files/model_asap7_776_counter_both_ori']

# %% [markdown]
# ## Model interpretation

# %%
imp_vals = model.get_fscore()
#print(imp_vals)
feature_important = model.get_score(importance_type='weight')
feats_sorted = sorted(feature_important.items(), key=lambda x: x[1], reverse=True)
aa_25 = feats_sorted[:25]

# %%
x_axis = [i[0] for i in aa_25]
y_axis = [i[1] for i in aa_25]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,25))
plt.title("GB Best-25 Features", fontsize=40)
plt.bar(x_axis, y_axis, width=0.8, align='center')
plt.xticks(x_axis, fontsize=40, rotation=80)
plt.ylabel("F Score", fontsize=40)
plt.yticks(fontsize=40)
plt.tight_layout()
plt.savefig('gb_best_25.png')
plt.show()

# %% [markdown]
# ### Get Testing Data

# %%
import joblib

# %%
asap1 = joblib.load('files/asap1_essay')

# %%
len(asap1)
# Out:
# 1783

# %%
asap1
# Out:
#       essay_id                                              essay  \
# 0            1  Dear local newspaper, I think effects computer...
# 1            2  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2            3  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3            4  Dear Local Newspaper, @CAPS1 I have found that...
# 4            5  Dear @LOCATION1, I know having computers has a...
# ...        ...                                                ...
# 1778      1783  Dear @CAPS1, @CAPS2 several reasons on way I t...
# 1779      1784  Do a adults and kids spend to much time on the...
# 1780      1785  My opinion is that people should have computer...
# 1781      1786  Dear readers, I think that its good and bad to...
# 1782      1787  Dear - Local Newspaper I agree thats computers...
#
#       domain1_score
# 0                 8
# 1                 9
# 2                 7
# 3                10
# 4                 8
# ...             ...
# 1778              8
# 1779              7
# 1780              8
# 1781              2
# 1782              7
#
# [1783 rows x 3 columns]

# %%
type(asap1)
# Out:
# pandas.core.frame.DataFrame

# %%
asap1_test = asap1.iloc[idx_test]

# %%
len(asap1_test)
# Out:
# 357

# %%
#asap1_test

# %%
asap1_test.to_csv('ASAP1 Test Set.tsv', index=False, sep='\t')

# %%
df = pd.read_csv('ASAP1 Test Set.tsv', sep='\t', encoding = "ISO-8859-1")

# %% [markdown]
# ### Get Training Data

# %%
asap1_train = asap1.iloc[idx_train]

# %%
len(asap1_train)
# Out:
# 1426

# %%
asap1_train.to_csv('ASAP1 Train Set.tsv', index=False, sep='\t')

# %%
df = pd.read_csv('ASAP1 Train Set.tsv', sep='\t', encoding = "ISO-8859-1")

# %%
import itertools 

n = 4 # OPEN AI GIVES A LOT OF SUGGESTIONS
numbers = range(1, n + 1) 

ctr = 0
for length in range(1, n + 1):
    print("Combination with length: ", length)
    combinations = itertools.combinations(numbers, length)
    delta = 0.4 * length  # Adjust delta based on length
    delta = round(delta, 2)
    for combo in combinations:
        print(combo)
        ctr += 1

print("Total number: ", ctr)
# Out:
# Combination with length:  1
# (1,)
# (2,)
# (3,)
# (4,)
# Combination with length:  2
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 4)
# Combination with length:  3
# (1, 2, 3)
# (1, 2, 4)
# (1, 3, 4)
# (2, 3, 4)
# Combination with length:  4
# (1, 2, 3, 4)
# Total number:  15

# %%
FROM 1 ESSAY --> we generate 31 new better essays --> Why 31 --> 2^n - 1 --> 2 ^ 5 -1 = 31

# %%
I TOOK 100 ESSAYS RANDOMLY --> 3100 NEW BETTER ESSAYS --> WE NEED NEW LABELS FOR THOSE 3100 DATA

# %%
THEN, WE DO THE SAME FROM EXACTLY THE SAME 100 ESSAYS --> BUT NOW WORSE ESSAYS --> 3100 NEW ESSAYS

# %%
SO, IN THE END WE HAVE 6200 AUGMENTATION DATA
THE ORIGINAL ESSAYS ARE ONLY 1700 DATA

# %%
n = 5
numbers = range(1, n + 1)  # Numbers from 1 to 5
ctr = 0

for i in range(len(new_label_train_error)):
    # Generate combinations of varying lengths
    idx = 0
    for length in range(1, n + 1):
        combinations = itertools.combinations(numbers, length)
        delta = 0.3 * length  # Adjust delta based on length
        delta = round(delta, 2)
        for combo in combinations:
            new_label_train_error[i][idx] -= delta
            print(combo)
            idx += 1

# %%
import itertools
n = 4
numbers = range(1, n + 1)
ctr = 0

for length in range(1, n + 1):
    combinations = itertools.combinations(numbers, length)
    print("length: ", length)
    for combo in combinations:
        print(combo)
        ctr += 1
print("Total : ", ctr)
# Out:
# length:  1
# (1,)
# (2,)
# (3,)
# (4,)
# length:  2
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 4)
# length:  3
# (1, 2, 3)
# (1, 2, 4)
# (1, 3, 4)
# (2, 3, 4)
# length:  4
# (1, 2, 3, 4)
# Total :  15

# %%
import itertools
n = 5
numbers = range(1, n + 1)
ctr = 0

for length in range(1, n + 1):
    combinations = math.comb(len(numbers), length)
    print("length: ", length)
    for j in range(combinations):
        print(length)
        ctr += 1
print("Total : ", ctr)
# Out:
# length:  1
# 1
# 1
# 1
# 1
# 1
# length:  2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# length:  3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# length:  4
# 4
# 4
# 4
# 4
# 4
# length:  5
# 5
# Total :  31

# %%
import math

def binomial(n, k):
    return math.comb(n, k)

def cumulative_sums(n):
    S = [0]  # S(0) = 0
    for k in range(1, n + 1):
        S.append(S[k - 1] + binomial(n, k))  # Cumulative sum
    return S

def generate_k_array(n):
    S = cumulative_sums(n)  # Get cumulative sums
    print(S)
    result = []
    
    for i in range(S[-1]):  # Iterate up to the total number of combinations
        for k in range(1, n + 1):
            if S[k - 1] <= i < S[k]:
                result.append(k)  # Append the current k
                break  # Move to the next index

    return result

# Example usage
n = 4
k_array = generate_k_array(n)
print(k_array)
# Out:
# 0
# 4
# 10
# 14
# [0, 4, 10, 14, 15]
# [1, 1, 1, 1, 2, 2, 2, 2, 2, 2, 3, 3, 3, 3, 4]

# %%
binomial(4,2)
# Out:
# 6

# %%
cumulative_sums(4)
# Out:
# S[k-1] :  0
# n :  4 k :  1
# S[k-1] :  4
# n :  4 k :  2
# S[k-1] :  10
# n :  4 k :  3
# S[k-1] :  14
# n :  4 k :  4
# [0, 4, 10, 14, 15]
