# %%
import joblib
import pandas as pd
import nltk
import re
import itertools
import random
import numpy as np

# %%
data = pd.read_csv('ASAP7 Test Set.tsv', sep='\t')
data_100 = data[:100]
data_100.head()
# Out:
#    essay_id                                              essay  domain1_score
# 0     19392  My at saying your patient is. Your patient whe...             12
# 1     18926  Once upon a time there was a young girl named ...             18
# 2     18318  Patience is hard. You always @CAPS1 it now not...             14
# 3     18904  Patience, @CAPS6 essential part of our world. ...             14
# 4     19131  One time I was pacient was when my mum said th...              8

# %%
errors = joblib.load('files/error_lists_test_100')
#error_test_100essay_5err = joblib.load('error_test_100essay_5err')

# %%
# Function to sample 5 dictionaries from each inner list
def sample_five_from_each(inner_lists):
    return [random.sample(inner_list, min(len(inner_list), 5)) for inner_list in inner_lists]

# Sample 5 dictionaries from each inner list
sampled_errors = sample_five_from_each(errors)

print(np.array(sampled_errors).shape)

# Print the results
for idx, sampled_list in enumerate(sampled_errors):
    print(f"Sampled data for list {idx + 1}:")
    for item in sampled_list:
        print(item)
    print()
# Out:
# (100, 5)
# Sampled data for list 1:
# {'original': 'saying', 'error': 'saynig', 'sentence': 1}
# {'original': 'know', 'error': 'knew', 'sentence': 4}
# {'original': 'manner', 'error': 'manner', 'sentence': 4}
# {'original': 'have', 'error': 'has', 'sentence': 5}
# {'original': 'for', 'error': 'inside', 'sentence': 2}
#
# Sampled data for list 2:
# {'original': 'walked', 'error': 'walks', 'sentence': 11}
# {'original': 'almost', 'error': 'almsot', 'sentence': 3}
# {'original': 'lived', 'error': 'lvied', 'sentence': 1}
# {'original': 'number', 'error': 'nmuber', 'sentence': 4}
# {'original': 'went', 'error': 'go', 'sentence': 7}
#
# Sampled data for list 3:
# {'original': 'patience', 'error': 'patienec', 'sentence': 3}
# {'original': 'test', 'error': 'tset', 'sentence': 5}
# {'original': 'stand', 'error': 'stnad', 'sentence': 4}
# {'original': 'always', 'error': 'alawys', 'sentence': 2}
# {'original': 'like', 'error': 'past', 'sentence': 7}
#
# Sampled data for list 4:
# {'original': 'holding', 'error': 'hold', 'sentence': 15}
# {'original': 'time', 'error': 'tiem', 'sentence': 5}
# {'original': 'have', 'error': 'has', 'sentence': 5}
# {'original': 'believe', 'error': 'believed', 'sentence': 4}
# {'original': 'has', 'error': 'have', 'sentence': 3}
#
# Sampled data for list 5:
# {'original': 'time', 'error': 'tiem', 'sentence': 1}
# {'original': 'waited', 'error': 'wait', 'sentence': 2}
# {'original': 'times', 'error': 'tiems', 'sentence': 1}
# {'original': 'knew', 'error': 'know', 'sentence': 3}
# {'original': 'through', 'error': 'against', 'sentence': 3}
#
# Sampled data for list 6:
# {'original': 'of', 'error': 'under', 'sentence': 2}
# {'original': 'time', 'error': 'tmie', 'sentence': 2}
# {'original': 'reason', 'error': 'raeson', 'sentence': 3}
# {'original': 'to', 'error': 'since', 'sentence': 4}
# {'original': 'comes', 'error': 'ocmes', 'sentence': 4}
#
# Sampled data for list 7:
# {'original': 'have', 'error': 'has', 'sentence': 1}
# {'original': 'at', 'error': 'under', 'sentence': 1}
# {'original': 'food', 'error': 'food', 'sentence': 5}
# {'original': 'lunch', 'error': 'lnuch', 'sentence': 3}
# {'original': 'in', 'error': 'underneath', 'sentence': 2}
#
# Sampled data for list 8:
# {'original': 'chance', 'error': 'chanec', 'sentence': 4}
# {'original': 'stop', 'error': 'sotp', 'sentence': 3}
# {'original': 'as', 'error': 'beside', 'sentence': 2}
# {'original': 'took', 'error': 'takes', 'sentence': 1}
# {'original': 'group', 'error': 'rgoup', 'sentence': 1}
#
# Sampled data for list 9:
# {'original': 'patience', 'error': 'patiecne', 'sentence': 3}
# {'original': 'to', 'error': 'since', 'sentence': 5}
# {'original': 'yelled', 'error': 'yell', 'sentence': 2}
# {'original': 'looseing', 'error': 'looses', 'sentence': 6}
# {'original': 'to', 'error': 'around', 'sentence': 2}
#
# Sampled data for list 10:
# {'original': 'knew', 'error': 'know', 'sentence': 20}
# {'original': 'long', 'error': 'logn', 'sentence': 3}
# {'original': 'zoomed', 'error': 'zoom', 'sentence': 38}
# {'original': 'clock', 'error': 'clokc', 'sentence': 1}
# {'original': 'agony', 'error': 'gaony', 'sentence': 5}
#
# Sampled data for list 11:
# {'original': 'use', 'error': 'used', 'sentence': 6}
# {'original': 'had', 'error': 'has', 'sentence': 5}
# {'original': 'get', 'error': 'egt', 'sentence': 1}
# {'original': 'hod', 'error': 'hods', 'sentence': 3}
# {'original': 'always', 'error': 'alwasy', 'sentence': 1}
#
# Sampled data for list 12:
# {'original': 'wait', 'error': 'wiat', 'sentence': 5}
# {'original': 'patient', 'error': 'aptient', 'sentence': 2}
# {'original': 'for', 'error': 'to', 'sentence': 6}
# {'original': 'ran', 'error': 'run', 'sentence': 5}
# {'original': 'have', 'error': 'had', 'sentence': 3}
#
# Sampled data for list 13:
# {'original': 'fight', 'error': 'fights', 'sentence': 27}
# {'original': 'could', 'error': 'oculd', 'sentence': 5}
# {'original': 'keep', 'error': 'kept', 'sentence': 31}
# {'original': 'said', 'error': 'says', 'sentence': 48}
# {'original': 'way', 'error': 'wya', 'sentence': 4}
#
# Sampled data for list 14:
# {'original': 'to', 'error': 'before', 'sentence': 9}
# {'original': 'waiting', 'error': 'awiting', 'sentence': 1}
# {'original': 'day', 'error': 'ady', 'sentence': 3}
# {'original': 'went', 'error': 'goes', 'sentence': 10}
# {'original': 'sixteen', 'error': 'isxteen', 'sentence': 2}
#
# Sampled data for list 15:
# {'original': 'in', 'error': 'under', 'sentence': 4}
# {'original': 'patient', 'error': 'pateint', 'sentence': 1}
# {'original': 'on', 'error': 'beyond', 'sentence': 3}
# {'original': 'time', 'error': 'tmie', 'sentence': 1}
# {'original': 'office', 'error': 'ofifce', 'sentence': 4}
#
# Sampled data for list 16:
# {'original': 'People', 'error': 'ePople', 'sentence': 2}
# {'original': 'write', 'error': 'wirte', 'sentence': 5}
# {'original': 'easy', 'error': 'esay', 'sentence': 3}
# {'original': 'mad', 'error': 'amd', 'sentence': 1}
# {'original': 'be', 'error': 'was', 'sentence': 2}
#
# Sampled data for list 17:
# {'original': 'patient', 'error': 'pateint', 'sentence': 1}
# {'original': 'sleepy', 'error': 'lseepy', 'sentence': 5}
# {'original': 'took', 'error': 'take', 'sentence': 3}
# {'original': 'about', 'error': 'at', 'sentence': 7}
# {'original': 'got', 'error': 'get', 'sentence': 8}
#
# Sampled data for list 18:
# {'original': 'dollar', 'error': 'dollar', 'sentence': 5}
# {'original': 'to', 'error': 'toward', 'sentence': 40}
# {'original': 'miss', 'error': 'misses', 'sentence': 7}
# {'original': 'understand', 'error': 'understands', 'sentence': 18}
# {'original': 'up', 'error': 'on', 'sentence': 19}
#
# Sampled data for list 19:
# {'original': 'walked', 'error': 'walks', 'sentence': 5}
# {'original': 'came', 'error': 'cmae', 'sentence': 4}
# {'original': 'to', 'error': 'except', 'sentence': 5}
# {'original': 'patient', 'error': 'paitent', 'sentence': 1}
# {'original': 'wait', 'error': 'wati', 'sentence': 3}
#
# Sampled data for list 20:
# {'original': 'acting', 'error': 'actnig', 'sentence': 1}
# {'original': 'get', 'error': 'egt', 'sentence': 2}
# {'original': 'down', 'error': 'under', 'sentence': 4}
# {'original': 'stop', 'error': 'stpo', 'sentence': 5}
# {'original': 'down', 'error': 'over', 'sentence': 5}
#
# Sampled data for list 21:
# {'original': 'knew', 'error': 'knows', 'sentence': 14}
# {'original': 'country', 'error': 'ocuntry', 'sentence': 4}
# {'original': 'time', 'error': 'tmie', 'sentence': 5}
# {'original': 'patient', 'error': 'paitent', 'sentence': 3}
# {'original': 'born', 'error': 'bear', 'sentence': 9}
#
# Sampled data for list 22:
# {'original': 'thirty', 'error': 'thrity', 'sentence': 3}
# {'original': 'people', 'error': 'epople', 'sentence': 4}
# {'original': 'ordered', 'error': 'ordreed', 'sentence': 5}
# {'original': 'told', 'error': 'tells', 'sentence': 11}
# {'original': 'way', 'error': 'awy', 'sentence': 1}
#
# Sampled data for list 23:
# {'original': 'stay', 'error': 'stayed', 'sentence': 2}
# {'original': 'of', 'error': 'by', 'sentence': 2}
# {'original': 'lot', 'error': 'lto', 'sentence': 2}
# {'original': 'went', 'error': 'goes', 'sentence': 4}
# {'original': 'nothing', 'error': 'ntohing', 'sentence': 3}
#
# Sampled data for list 24:
# {'original': 'course', 'error': 'ocurse', 'sentence': 3}
# {'original': 'know', 'error': 'knew', 'sentence': 7}
# {'original': 'patient', 'error': 'ptaient', 'sentence': 1}
# {'original': 'told', 'error': 'tell', 'sentence': 9}
# {'original': 'force', 'error': 'forced', 'sentence': 13}
#
# Sampled data for list 25:
# {'original': 'laughed', 'error': 'laughs', 'sentence': 5}
# {'original': 'get', 'error': 'gte', 'sentence': 1}
# {'original': 'said', 'error': 'say', 'sentence': 11}
# {'original': 'have', 'error': 'had', 'sentence': 9}
# {'original': 'around', 'error': 'aruond', 'sentence': 2}
#
# Sampled data for list 26:
# {'original': 'in', 'error': 'as', 'sentence': 4}
# {'original': 'rid', 'error': 'ird', 'sentence': 5}
# {'original': 'drove', 'error': 'drvoe', 'sentence': 2}
# {'original': 'had', 'error': 'have', 'sentence': 5}
# {'original': 'patient', 'error': 'pateint', 'sentence': 4}
#
# Sampled data for list 27:
# {'original': 'smiled', 'error': 'smile', 'sentence': 8}
# {'original': 'walking', 'error': 'walks', 'sentence': 3}
# {'original': 'went', 'error': 'wetn', 'sentence': 1}
# {'original': 'marsh', 'error': 'masrh', 'sentence': 2}
# {'original': 'upon', 'error': 'uopn', 'sentence': 4}
#
# Sampled data for list 28:
# {'original': 'had', 'error': 'have', 'sentence': 4}
# {'original': 'Sadly', 'error': 'Saldy', 'sentence': 5}
# {'original': 'had', 'error': 'has', 'sentence': 3}
# {'original': 'to', 'error': 'outside', 'sentence': 5}
# {'original': 'Patience', 'error': 'Paitence', 'sentence': 1}
#
# Sampled data for list 29:
# {'original': 'looked', 'error': 'look', 'sentence': 10}
# {'original': 'went', 'error': 'ewnt', 'sentence': 1}
# {'original': 'left', 'error': 'leave', 'sentence': 28}
# {'original': 'wait', 'error': 'awit', 'sentence': 2}
# {'original': 'loved', 'error': 'loves', 'sentence': 26}
#
# Sampled data for list 30:
# {'original': 'From', 'error': 'under', 'sentence': 2}
# {'original': 'patient', 'error': 'paitent', 'sentence': 1}
# {'original': 'trip', 'error': 'trpi', 'sentence': 2}
# {'original': 'oven', 'error': 'voen', 'sentence': 2}
# {'original': 'of', 'error': 'for', 'sentence': 2}
#
# Sampled data for list 31:
# {'original': 'thanked', 'error': 'thanks', 'sentence': 8}
# {'original': 'coming', 'error': 'come', 'sentence': 2}
# {'original': 'go', 'error': 'og', 'sentence': 3}
# {'original': 'at', 'error': 'onto', 'sentence': 1}
# {'original': 'two', 'error': 'tow', 'sentence': 4}
#
# Sampled data for list 32:
# {'original': 'like', 'error': 'likes', 'sentence': 10}
# {'original': 'like', 'error': 'lkie', 'sentence': 2}
# {'original': 'go', 'error': 'og', 'sentence': 1}
# {'original': 'walking', 'error': 'walk', 'sentence': 2}
# {'original': 'go', 'error': 'goes', 'sentence': 7}
#
# Sampled data for list 33:
# {'original': 'thinking', 'error': 'thinks', 'sentence': 17}
# {'original': 'gone', 'error': 'goes', 'sentence': 3}
# {'original': 'said', 'error': 'say', 'sentence': 8}
# {'original': 'go', 'error': 'og', 'sentence': 4}
# {'original': 'said', 'error': 'sadi', 'sentence': 3}
#
# Sampled data for list 34:
# {'original': 'come', 'error': 'comes', 'sentence': 27}
# {'original': 'call', 'error': 'call', 'sentence': 2}
# {'original': 'came', 'error': 'come', 'sentence': 7}
# {'original': 'day', 'error': 'dya', 'sentence': 5}
# {'original': 'grade', 'error': 'rgade', 'sentence': 1}
#
# Sampled data for list 35:
# {'original': 'of', 'error': 'between', 'sentence': 1}
# {'original': 'had', 'error': 'have', 'sentence': 1}
# {'original': 'in', 'error': 'until', 'sentence': 1}
# {'original': 'slow', 'error': 'solw', 'sentence': 2}
# {'original': 'go', 'error': 'og', 'sentence': 4}
#
# Sampled data for list 36:
# {'original': 'need', 'error': 'needed', 'sentence': 5}
# {'original': 'ever', 'error': 'veer', 'sentence': 1}
# {'original': 'in', 'error': 'about', 'sentence': 3}
# {'original': 'believe', 'error': 'believed', 'sentence': 2}
# {'original': 'for', 'error': 'at', 'sentence': 5}
#
# Sampled data for list 37:
# {'original': 'told', 'error': 'tells', 'sentence': 15}
# {'original': 'for', 'error': 'onto', 'sentence': 5}
# {'original': 'invited', 'error': 'invites', 'sentence': 2}
# {'original': 'party', 'error': 'paryt', 'sentence': 3}
# {'original': 'go', 'error': 'og', 'sentence': 2}
#
# Sampled data for list 38:
# {'original': 'done', 'error': 'doen', 'sentence': 2}
# {'original': 'stretched', 'error': 'stretches', 'sentence': 5}
# {'original': 'for', 'error': 'without', 'sentence': 5}
# {'original': 'on', 'error': 'within', 'sentence': 7}
# {'original': 'patient', 'error': 'patinet', 'sentence': 1}
#
# Sampled data for list 39:
# {'original': 'battled', 'error': 'battle', 'sentence': 8}
# {'original': 'loved', 'error': 'love', 'sentence': 5}
# {'original': 'made', 'error': 'makes', 'sentence': 11}
# {'original': 'think', 'error': 'thnik', 'sentence': 4}
# {'original': 'hour', 'error': 'huor', 'sentence': 1}
#
# Sampled data for list 40:
# {'original': 'into', 'error': 'down', 'sentence': 9}
# {'original': 'thing', 'error': 'hting', 'sentence': 3}
# {'original': 'knew', 'error': 'know', 'sentence': 6}
# {'original': 'started', 'error': 'start', 'sentence': 15}
# {'original': 'divulged', 'error': 'divulges', 'sentence': 9}
#
# Sampled data for list 41:
# {'original': 'patient', 'error': 'patiented', 'sentence': 3}
# {'original': 'with', 'error': 'except', 'sentence': 3}
# {'original': 'made', 'error': 'make', 'sentence': 5}
# {'original': 'went', 'error': 'goes', 'sentence': 7}
# {'original': 'barely', 'error': 'bareyl', 'sentence': 5}
#
# Sampled data for list 42:
# {'original': 'came', 'error': 'come', 'sentence': 4}
# {'original': 'came', 'error': 'comes', 'sentence': 6}
# {'original': 'stayed', 'error': 'stays', 'sentence': 11}
# {'original': 'uncle', 'error': 'uncel', 'sentence': 3}
# {'original': 'hospital', 'error': 'hospiatl', 'sentence': 5}
#
# Sampled data for list 43:
# {'original': 'ready', 'error': 'reday', 'sentence': 3}
# {'original': 'first', 'error': 'frist', 'sentence': 4}
# {'original': 'planning', 'error': 'plan', 'sentence': 4}
# {'original': 'one', 'error': 'noe', 'sentence': 1}
# {'original': 'of', 'error': 'for', 'sentence': 1}
#
# Sampled data for list 44:
# {'original': 'food', 'error': 'fodo', 'sentence': 2}
# {'original': 'on', 'error': 'outside', 'sentence': 7}
# {'original': 'texted', 'error': 'texte', 'sentence': 10}
# {'original': 'set', 'error': 'est', 'sentence': 5}
# {'original': 'hurt', 'error': 'hurts', 'sentence': 4}
#
# Sampled data for list 45:
# {'original': 'For', 'error': 'up', 'sentence': 17}
# {'original': 'give', 'error': 'gvie', 'sentence': 5}
# {'original': 'since', 'error': 'snice', 'sentence': 3}
# {'original': 'constantly', 'error': 'contsantly', 'sentence': 4}
# {'original': 'father', 'error': 'fatehr', 'sentence': 1}
#
# Sampled data for list 46:
# {'original': 'patience', 'error': 'ptaience', 'sentence': 2}
# {'original': 'would', 'error': 'woudl', 'sentence': 4}
# {'original': 'gotten', 'error': 'get', 'sentence': 21}
# {'original': 'want', 'error': 'wanted', 'sentence': 5}
# {'original': 'go', 'error': 'goes', 'sentence': 18}
#
# Sampled data for list 47:
# {'original': 'catchs', 'error': 'caught', 'sentence': 7}
# {'original': 'ate', 'error': 'aet', 'sentence': 2}
# {'original': 'enough', 'error': 'enouhg', 'sentence': 4}
# {'original': 'saw', 'error': 'swa', 'sentence': 1}
# {'original': 'saw', 'error': 'sees', 'sentence': 12}
#
# Sampled data for list 48:
# {'original': 'at', 'error': 'underneath', 'sentence': 15}
# {'original': 'do', 'error': 'does', 'sentence': 16}
# {'original': 'hears', 'error': 'heard', 'sentence': 2}
# {'original': 'Wow', 'error': 'Wwo', 'sentence': 4}
# {'original': 'patience', 'error': 'patinece', 'sentence': 9}
#
# Sampled data for list 49:
# {'original': 'sat', 'error': 'sit', 'sentence': 13}
# {'original': 'dad', 'error': 'dda', 'sentence': 4}
# {'original': 'went', 'error': 'goes', 'sentence': 4}
# {'original': 'to', 'error': 'during', 'sentence': 3}
# {'original': 'Patience', 'error': 'Pateince', 'sentence': 2}
#
# Sampled data for list 50:
# {'original': 'got', 'error': 'ogt', 'sentence': 1}
# {'original': 'patient', 'error': 'pateint', 'sentence': 1}
# {'original': 'to', 'error': 'beside', 'sentence': 1}
# {'original': 'wan', 'error': 'awn', 'sentence': 1}
# {'original': 'water', 'error': 'waetr', 'sentence': 1}
#
# Sampled data for list 51:
# {'original': 'were', 'error': 'am', 'sentence': 12}
# {'original': 'of', 'error': 'within', 'sentence': 10}
# {'original': 'patient', 'error': 'ptaient', 'sentence': 1}
# {'original': 'foster', 'error': 'fostre', 'sentence': 3}
# {'original': 'tolerated', 'error': 'tolerate', 'sentence': 16}
#
# Sampled data for list 52:
# {'original': 'for', 'error': 'before', 'sentence': 5}
# {'original': 'doing', 'error': 'does', 'sentence': 12}
# {'original': 'around', 'error': 'through', 'sentence': 8}
# {'original': 'phone', 'error': 'phoen', 'sentence': 3}
# {'original': 'good', 'error': 'good', 'sentence': 1}
#
# Sampled data for list 53:
# {'original': 'seemed', 'error': 'seem', 'sentence': 4}
# {'original': 'early', 'error': 'earyl', 'sentence': 3}
# {'original': 'got', 'error': 'gto', 'sentence': 2}
# {'original': 'on', 'error': 'accross', 'sentence': 3}
# {'original': 'found', 'error': 'finds', 'sentence': 6}
#
# Sampled data for list 54:
# {'original': 'ask', 'error': 'asks', 'sentence': 7}
# {'original': 'ask', 'error': 'asked', 'sentence': 11}
# {'original': 'waited', 'error': 'waits', 'sentence': 3}
# {'original': 'school', 'error': 'shcool', 'sentence': 6}
# {'original': 'out', 'error': 'behind', 'sentence': 1}
#
# Sampled data for list 55:
# {'original': 'stayed', 'error': 'stay', 'sentence': 10}
# {'original': 'high', 'error': 'hihg', 'sentence': 5}
# {'original': 'Like', 'error': 'iLke', 'sentence': 2}
# {'original': 'have', 'error': 'had', 'sentence': 1}
# {'original': 'made', 'error': 'makes', 'sentence': 19}
#
# Sampled data for list 56:
# {'original': 'ordered', 'error': 'orders', 'sentence': 2}
# {'original': 'came', 'error': 'come', 'sentence': 8}
# {'original': 'said', 'error': 'says', 'sentence': 10}
# {'original': 'deep', 'error': 'deep', 'sentence': 3}
# {'original': 'replied', 'error': 'replies', 'sentence': 15}
#
# Sampled data for list 57:
# {'original': 'came', 'error': 'comes', 'sentence': 4}
# {'original': 'Last', 'error': 'Lats', 'sentence': 1}
# {'original': 'stinks', 'error': 'stink', 'sentence': 10}
# {'original': 'for', 'error': 'toward', 'sentence': 9}
# {'original': 'Well', 'error': 'eWll', 'sentence': 4}
#
# Sampled data for list 58:
# {'original': 'acts', 'error': 'acted', 'sentence': 6}
# {'original': 'have', 'error': 'had', 'sentence': 10}
# {'original': 'know', 'error': 'nkow', 'sentence': 3}
# {'original': 'waiting', 'error': 'waitign', 'sentence': 1}
# {'original': 'going', 'error': 'oging', 'sentence': 4}
#
# Sampled data for list 59:
# {'original': 'kept', 'error': 'keep', 'sentence': 3}
# {'original': 'left', 'error': 'leaves', 'sentence': 6}
# {'original': 'party', 'error': 'patry', 'sentence': 2}
# {'original': 'came', 'error': 'comes', 'sentence': 4}
# {'original': 'got', 'error': 'gto', 'sentence': 4}
#
# Sampled data for list 60:
# {'original': 'go', 'error': 'og', 'sentence': 5}
# {'original': 'think', 'error': 'thought', 'sentence': 2}
# {'original': 'around', 'error': 'to', 'sentence': 15}
# {'original': 'like', 'error': 'behind', 'sentence': 13}
# {'original': 'told', 'error': 'tell', 'sentence': 10}
#
# Sampled data for list 61:
# {'original': 'sat', 'error': 'sits', 'sentence': 11}
# {'original': 'by', 'error': 'accross', 'sentence': 12}
# {'original': 'kept', 'error': 'keeps', 'sentence': 3}
# {'original': 'ease', 'error': 'eaes', 'sentence': 4}
# {'original': 'sat', 'error': 'sit', 'sentence': 9}
#
# Sampled data for list 62:
# {'original': 'wanted', 'error': 'wants', 'sentence': 7}
# {'original': 'started', 'error': 'start', 'sentence': 5}
# {'original': 'patient', 'error': 'aptient', 'sentence': 1}
# {'original': 'looked', 'error': 'look', 'sentence': 4}
# {'original': 'got', 'error': 'get', 'sentence': 9}
#
# Sampled data for list 63:
# {'original': 'leave', 'error': 'elave', 'sentence': 2}
# {'original': 'work', 'error': 'wokr', 'sentence': 1}
# {'original': 'does', 'error': 'did', 'sentence': 3}
# {'original': 'to', 'error': 'through', 'sentence': 5}
# {'original': 'goes', 'error': 'go', 'sentence': 2}
#
# Sampled data for list 64:
# {'original': 'number', 'error': 'numbre', 'sentence': 2}
# {'original': 'called', 'error': 'call', 'sentence': 3}
# {'original': 'got', 'error': 'gets', 'sentence': 9}
# {'original': 'put', 'error': 'upt', 'sentence': 4}
# {'original': 'stand', 'error': 'satnd', 'sentence': 3}
#
# Sampled data for list 65:
# {'original': 'night', 'error': 'ngiht', 'sentence': 5}
# {'original': 'learned', 'error': 'learns', 'sentence': 12}
# {'original': 'started', 'error': 'start', 'sentence': 11}
# {'original': 'up', 'error': 'toward', 'sentence': 4}
# {'original': 'had', 'error': 'have', 'sentence': 4}
#
# Sampled data for list 66:
# {'original': 'finally', 'error': 'finalyl', 'sentence': 3}
# {'original': 'told', 'error': 'tell', 'sentence': 6}
# {'original': 'told', 'error': 'todl', 'sentence': 5}
# {'original': 'asked', 'error': 'ask', 'sentence': 5}
# {'original': 'hotel', 'error': 'hotle', 'sentence': 4}
#
# Sampled data for list 67:
# {'original': 'think', 'error': 'thinks', 'sentence': 5}
# {'original': 'went', 'error': 'wetn', 'sentence': 1}
# {'original': 'large', 'error': 'lareg', 'sentence': 3}
# {'original': 'like', 'error': 'around', 'sentence': 2}
# {'original': 'worth', 'error': 'wroth', 'sentence': 5}
#
# Sampled data for list 68:
# {'original': 'felt', 'error': 'feels', 'sentence': 5}
# {'original': 'getting', 'error': 'get', 'sentence': 3}
# {'original': 'ready', 'error': 'reday', 'sentence': 2}
# {'original': 'for', 'error': 'up', 'sentence': 5}
# {'original': 'help', 'error': 'hepl', 'sentence': 5}
#
# Sampled data for list 69:
# {'original': 'time', 'error': 'tiem', 'sentence': 1}
# {'original': 'wait', 'error': 'awit', 'sentence': 2}
# {'original': 'told', 'error': 'tells', 'sentence': 6}
# {'original': 'have', 'error': 'has', 'sentence': 9}
# {'original': 'think', 'error': 'thnik', 'sentence': 3}
#
# Sampled data for list 70:
# {'original': 'ten', 'error': 'etn', 'sentence': 6}
# {'original': 'family', 'error': 'famiyl', 'sentence': 3}
# {'original': 'lunch', 'error': 'lunhc', 'sentence': 5}
# {'original': 'out', 'error': 'into', 'sentence': 5}
# {'original': 'heard', 'error': 'hears', 'sentence': 18}
#
# Sampled data for list 71:
# {'original': 'have', 'error': 'had', 'sentence': 3}
# {'original': 'in', 'error': 'under', 'sentence': 9}
# {'original': 'time', 'error': 'tmie', 'sentence': 5}
# {'original': 'lot', 'error': 'olt', 'sentence': 2}
# {'original': 'till', 'error': 'till', 'sentence': 6}
#
# Sampled data for list 72:
# {'original': 'run', 'error': 'rnu', 'sentence': 5}
# {'original': 'for', 'error': 'before', 'sentence': 7}
# {'original': 'normal', 'error': 'nomral', 'sentence': 2}
# {'original': 'f', 'error': 'fed', 'sentence': 5}
# {'original': 'everyone', 'error': 'eevryone', 'sentence': 4}
#
# Sampled data for list 73:
# {'original': 'ride', 'error': 'ried', 'sentence': 4}
# {'original': 'to', 'error': 'near', 'sentence': 1}
# {'original': 'waiting', 'error': 'waits', 'sentence': 3}
# {'original': 'for', 'error': 'along', 'sentence': 3}
# {'original': 'got', 'error': 'ogt', 'sentence': 5}
#
# Sampled data for list 74:
# {'original': 'patient', 'error': 'aptient', 'sentence': 5}
# {'original': 'People', 'error': 'Peopel', 'sentence': 4}
# {'original': 'for', 'error': 'behind', 'sentence': 12}
# {'original': 'After', 'error': 'past', 'sentence': 6}
# {'original': 'Patience', 'error': 'aPtience', 'sentence': 1}
#
# Sampled data for list 75:
# {'original': 'At', 'error': 'over', 'sentence': 4}
# {'original': 'went', 'error': 'go', 'sentence': 13}
# {'original': 'first', 'error': 'fisrt', 'sentence': 4}
# {'original': 'first', 'error': 'fisrt', 'sentence': 1}
# {'original': 'had', 'error': 'has', 'sentence': 9}
#
# Sampled data for list 76:
# {'original': 'teeth', 'error': 'teeth', 'sentence': 2}
# {'original': 'patient', 'error': 'patinet', 'sentence': 6}
# {'original': 'in', 'error': 'among', 'sentence': 5}
# {'original': 'bottom', 'error': 'bototm', 'sentence': 3}
# {'original': 'said', 'error': 'says', 'sentence': 5}
#
# Sampled data for list 77:
# {'original': 'took', 'error': 'take', 'sentence': 15}
# {'original': 'delayed', 'error': 'delays', 'sentence': 20}
# {'original': 'drive', 'error': 'driev', 'sentence': 1}
# {'original': 'to', 'error': 'within', 'sentence': 1}
# {'original': 'took', 'error': 'takes', 'sentence': 18}
#
# Sampled data for list 78:
# {'original': 'whatever', 'error': 'whaetver', 'sentence': 1}
# {'original': 'found', 'error': 'finds', 'sentence': 20}
# {'original': 'for', 'error': 'except', 'sentence': 16}
# {'original': 'from', 'error': 'before', 'sentence': 10}
# {'original': 'patient', 'error': 'patinet', 'sentence': 2}
#
# Sampled data for list 79:
# {'original': 'waiting', 'error': 'awiting', 'sentence': 1}
# {'original': 'to', 'error': 'except', 'sentence': 3}
# {'original': 'on', 'error': 'except', 'sentence': 5}
# {'original': 'patient', 'error': 'paitent', 'sentence': 4}
# {'original': 'said', 'error': 'says', 'sentence': 3}
#
# Sampled data for list 80:
# {'original': 'in', 'error': 'for', 'sentence': 3}
# {'original': 'line', 'error': 'lnie', 'sentence': 1}
# {'original': 'rode', 'error': 'rides', 'sentence': 5}
# {'original': 'hour', 'error': 'huor', 'sentence': 1}
# {'original': 'rode', 'error': 'orde', 'sentence': 3}
#
# Sampled data for list 81:
# {'original': 'little', 'error': 'ilttle', 'sentence': 1}
# {'original': 'be', 'error': 'is', 'sentence': 8}
# {'original': 'saying', 'error': 'sayign', 'sentence': 5}
# {'original': 'realize', 'error': 'realizes', 'sentence': 6}
# {'original': 'thought', 'error': 'think', 'sentence': 5}
#
# Sampled data for list 82:
# {'original': 'at', 'error': 'toward', 'sentence': 4}
# {'original': 'came', 'error': 'come', 'sentence': 24}
# {'original': 'us', 'error': 'su', 'sentence': 4}
# {'original': 'know', 'error': 'nkow', 'sentence': 1}
# {'original': 'place', 'error': 'plaec', 'sentence': 2}
#
# Sampled data for list 83:
# {'original': 'to', 'error': 'up', 'sentence': 4}
# {'original': 'turn', 'error': 'tunr', 'sentence': 3}
# {'original': 'got', 'error': 'gets', 'sentence': 5}
# {'original': 'really', 'error': 'realyl', 'sentence': 4}
# {'original': 'to', 'error': 'outside', 'sentence': 4}
#
# Sampled data for list 84:
# {'original': 'said', 'error': 'asid', 'sentence': 2}
# {'original': 'said', 'error': 'siad', 'sentence': 4}
# {'original': 'kept', 'error': 'keep', 'sentence': 8}
# {'original': 'get', 'error': 'gte', 'sentence': 1}
# {'original': 'from', 'error': 'past', 'sentence': 13}
#
# Sampled data for list 85:
# {'original': 'time', 'error': 'itme', 'sentence': 4}
# {'original': 'of', 'error': 'outside', 'sentence': 14}
# {'original': 'took', 'error': 'take', 'sentence': 6}
# {'original': 'went', 'error': 'go', 'sentence': 3}
# {'original': 'left', 'error': 'lfet', 'sentence': 3}
#
# Sampled data for list 86:
# {'original': 'need', 'error': 'needed', 'sentence': 3}
# {'original': 'reason', 'error': 'raeson', 'sentence': 4}
# {'original': 'in', 'error': 'for', 'sentence': 12}
# {'original': 'patience', 'error': 'ptaience', 'sentence': 3}
# {'original': 'needed', 'error': 'needs', 'sentence': 2}
#
# Sampled data for list 87:
# {'original': 'stayed', 'error': 'stay', 'sentence': 7}
# {'original': 'went', 'error': 'wnet', 'sentence': 4}
# {'original': 'meal', 'error': 'emal', 'sentence': 5}
# {'original': 'seen', 'error': 'sees', 'sentence': 9}
# {'original': 'fun', 'error': 'fnu', 'sentence': 2}
#
# Sampled data for list 88:
# {'original': 'went', 'error': 'goes', 'sentence': 2}
# {'original': 'B', 'error': 'B', 'sentence': 1}
# {'original': 'dress', 'error': 'dress', 'sentence': 5}
# {'original': 'got', 'error': 'gets', 'sentence': 4}
# {'original': 'got', 'error': 'get', 'sentence': 11}
#
# Sampled data for list 89:
# {'original': 'in', 'error': 'toward', 'sentence': 2}
# {'original': 'lost', 'error': 'loses', 'sentence': 5}
# {'original': 'lost', 'error': 'olst', 'sentence': 7}
# {'original': 'grabed', 'error': 'grabs', 'sentence': 4}
# {'original': 'put', 'error': 'ptu', 'sentence': 2}
#
# Sampled data for list 90:
# {'original': 'of', 'error': 'over', 'sentence': 9}
# {'original': 'had', 'error': 'has', 'sentence': 1}
# {'original': 'stay', 'error': 'stays', 'sentence': 5}
# {'original': 'five', 'error': 'ifve', 'sentence': 2}
# {'original': 'had', 'error': 'have', 'sentence': 2}
#
# Sampled data for list 91:
# {'original': 'about', 'error': 'around', 'sentence': 3}
# {'original': 'patient', 'error': 'aptient', 'sentence': 2}
# {'original': 'forget', 'error': 'forgot', 'sentence': 3}
# {'original': 'in', 'error': 'upon', 'sentence': 3}
# {'original': 'office', 'error': 'offcie', 'sentence': 1}
#
# Sampled data for list 92:
# {'original': 'watched', 'error': 'wtached', 'sentence': 4}
# {'original': 'point', 'error': 'poitn', 'sentence': 1}
# {'original': 'watch', 'error': 'awtch', 'sentence': 3}
# {'original': 'took', 'error': 'take', 'sentence': 8}
# {'original': 'to', 'error': 'behind', 'sentence': 1}
#
# Sampled data for list 93:
# {'original': 'coaster', 'error': 'cosater', 'sentence': 2}
# {'original': 'up', 'error': 'accross', 'sentence': 2}
# {'original': 'task', 'error': 'taks', 'sentence': 1}
# {'original': 'rewarded', 'error': 'reward', 'sentence': 2}
# {'original': 'to', 'error': 'outside', 'sentence': 2}
#
# Sampled data for list 94:
# {'original': 'entertain', 'error': 'entertian', 'sentence': 2}
# {'original': 'went', 'error': 'go', 'sentence': 3}
# {'original': 'went', 'error': 'ewnt', 'sentence': 2}
# {'original': 'of', 'error': 'for', 'sentence': 3}
# {'original': 'grandma', 'error': 'garndma', 'sentence': 1}
#
# Sampled data for list 95:
# {'original': 'lot', 'error': 'olt', 'sentence': 6}
# {'original': 'have', 'error': 'has', 'sentence': 4}
# {'original': 'complain', 'error': 'copmlain', 'sentence': 5}
# {'original': 'day', 'error': 'ady', 'sentence': 2}
# {'original': 'One', 'error': 'nOe', 'sentence': 1}
#
# Sampled data for list 96:
# {'original': 'got', 'error': 'gto', 'sentence': 4}
# {'original': 'arrived', 'error': 'arrives', 'sentence': 5}
# {'original': 'patient', 'error': 'patinet', 'sentence': 1}
# {'original': 'learned', 'error': 'learns', 'sentence': 8}
# {'original': 'always', 'error': 'alwasy', 'sentence': 2}
#
# Sampled data for list 97:
# {'original': 'game', 'error': 'agme', 'sentence': 3}
# {'original': 'never', 'error': 'enver', 'sentence': 4}
# {'original': 'time', 'error': 'itme', 'sentence': 1}
# {'original': 'in', 'error': 'within', 'sentence': 6}
# {'original': 'of', 'error': 'between', 'sentence': 9}
#
# Sampled data for list 98:
# {'original': 'about', 'error': 'among', 'sentence': 9}
# {'original': 'drove', 'error': 'drives', 'sentence': 2}
# {'original': 'looked', 'error': 'look', 'sentence': 6}
# {'original': 'line', 'error': 'lien', 'sentence': 5}
# {'original': 'to', 'error': 'with', 'sentence': 4}
#
# Sampled data for list 99:
# {'original': 'remember', 'error': 'remembered', 'sentence': 2}
# {'original': 'always', 'error': 'alwasy', 'sentence': 1}
# {'original': 'doctor', 'error': 'docotr', 'sentence': 1}
# {'original': 'anything', 'error': 'aynthing', 'sentence': 3}
# {'original': 'wait', 'error': 'awit', 'sentence': 2}
#
# Sampled data for list 100:
# {'original': 'think', 'error': 'thinks', 'sentence': 6}
# {'original': 'lunch', 'error': 'lnuch', 'sentence': 1}
# {'original': 'to', 'error': 'between', 'sentence': 4}
# {'original': 'advice', 'error': 'adviec', 'sentence': 2}
# {'original': 'went', 'error': 'goes', 'sentence': 4}

# %%
np.array(sampled_errors).shape
# Out:
# (100, 5)

# %%
joblib.dump(sampled_errors, 'files/error_test_100essay_5err')
# Out:
# ['files/error_test_100essay_5err']

# %%
# Function to apply errors to the essay
def apply_errors(essay, errors):
    # Tokenize the essay into sentences using NLTK
    sentences = nltk.sent_tokenize(essay)

    # Create a list to store corrected sentences
    errored_sentences = []

    # Iterate through sentences
    for i, sentence in enumerate(sentences):
        # Apply corrections to the current sentence
        for error in errors:
            # Adjust the index by subtracting 1 to match the enumeration starting from 0
            if error['sentence'] == i + 1:
                # Replace all occurrences of the incorrect text with the correction
                #sentence = sentence.replace(correction['original'], correction['correction'])
                 # Use regular expression with word boundaries to replace only whole words
                sentence = re.sub(r'\b' + re.escape(error['original']) + r'\b', error['error'], sentence)
        # Add the corrected sentence to the list
        errored_sentences.append(sentence)

    # Join the corrected sentences to form the final essay
    errored_essay = ' '.join(errored_sentences)
    return errored_essay

# Function to generate all combinations of corrections and apply them
def generate_errored_versions(essay, errors):
    errored_versions = []
    max_errors = len(errors)

    # Iterate over different numbers of corrections to apply
    for num_errors in range(1, max_errors + 1):
        for combination in itertools.combinations(errors, num_errors):
            errored_essay = apply_errors(essay, combination)
            errored_versions.append(errored_essay)
  
    return errored_versions

# Example usage
essay = "This is a tess essay. The break through was amazing. The possitive effects were clear."
errors = [
    {'original': 'tess', 'error': 'test', 'type': 'Spelling', 'sentence': 1},
    {'original': 'break through', 'error': 'breakthrough', 'type': 'Spelling', 'sentence': 2},
    {'original': 'possitive', 'error': 'positive', 'type': 'Spelling', 'sentence': 3},
]

# Generate corrected versions with combinations of 1, 2, and 3 corrections
errored_versions = generate_errored_versions(essay, errors)
errored_versions
# Out:
# ['This is a test essay. The break through was amazing. The possitive effects were clear.',
#  'This is a tess essay. The breakthrough was amazing. The possitive effects were clear.',
#  'This is a tess essay. The break through was amazing. The positive effects were clear.',
#  'This is a test essay. The breakthrough was amazing. The possitive effects were clear.',
#  'This is a test essay. The break through was amazing. The positive effects were clear.',
#  'This is a tess essay. The breakthrough was amazing. The positive effects were clear.',
#  'This is a test essay. The breakthrough was amazing. The positive effects were clear.']

# %%
error_test_100essay_5err = joblib.load('files/error_test_100essay_5err')

errored_test_100data_5err = []

for index, row in data_100.iterrows():
    try:
        errored_essays = generate_errored_versions(row['essay'], error_test_100essay_5err[index]) 
        # Append the result to the list
        errored_test_100data_5err.append(errored_essays)
    except Exception as e:
        print(f"Error processing row {index}: {e}")
        errored_test_100data_5err.append(None)  # Append None or an empty dict if an error occurs
    print(index + 1, " finished")
# Out:
# 1  finished
# 2  finished
# 3  finished
# 4  finished
# 5  finished
# 6  finished
# 7  finished
# 8  finished
# 9  finished
# 10  finished
# 11  finished
# 12  finished
# 13  finished
# 14  finished
# 15  finished
# 16  finished
# 17  finished
# 18  finished
# 19  finished
# 20  finished
# 21  finished
# 22  finished
# 23  finished
# 24  finished
# 25  finished
# 26  finished
# 27  finished
# 28  finished
# 29  finished
# 30  finished
# 31  finished
# 32  finished
# 33  finished
# 34  finished
# 35  finished
# 36  finished
# 37  finished
# 38  finished
# 39  finished
# 40  finished
# 41  finished
# 42  finished
# 43  finished
# 44  finished
# 45  finished
# 46  finished
# 47  finished
# 48  finished
# 49  finished
# 50  finished
# 51  finished
# 52  finished
# 53  finished
# 54  finished
# 55  finished
# 56  finished
# 57  finished
# 58  finished
# 59  finished
# 60  finished
# 61  finished
# 62  finished
# 63  finished
# 64  finished
# 65  finished
# 66  finished
# 67  finished
# 68  finished
# 69  finished
# 70  finished
# 71  finished
# 72  finished
# 73  finished
# 74  finished
# 75  finished
# 76  finished
# 77  finished
# 78  finished
# 79  finished
# 80  finished
# 81  finished
# 82  finished
# 83  finished
# 84  finished
# 85  finished
# 86  finished
# 87  finished
# 88  finished
# 89  finished
# 90  finished
# 91  finished
# 92  finished
# 93  finished
# 94  finished
# 95  finished
# 96  finished
# 97  finished
# 98  finished
# 99  finished
# 100  finished

# %%
np.array(errored_test_100data_5err).shape
# Out:
# (100, 31)

# %%
joblib.dump(errored_test_100data_5err, 'files/errored_test_100data_5err')
# Out:
# ['files/errored_test_100data_5err']
