# %%
import joblib
import pandas as pd
import nltk
import re
import itertools
import random
import numpy as np

# %%
data = pd.read_csv('ASAP7 Train Set.tsv', sep='\t')
data_100 = data[:100]
data_100.head()
# Out:
#    essay_id                                              essay  domain1_score
# 0     19441  Patience is tough to achieve sometimes. But th...             22
# 1     18068  Patience a helpful trait to get you through li...             24
# 2     19000  There were many of times when I was patient. T...             18
# 3     18339  A time I was patiet was when I was wating for ...             24
# 4     18297  Do you ever fell like your @CAPS1 is going to ...             21

# %%
errors = joblib.load('files/error_lists_train_100')

# %%
len(errors)
# Out:
# 100

# %%
# Function to sample 5 dictionaries from each inner list
def sample_five_from_each(inner_lists):
    return [random.sample(inner_list, min(len(inner_list), 5)) for inner_list in inner_lists]

# Sample 5 dictionaries from each inner list
sampled_errors = sample_five_from_each(errors)

print(np.array(sampled_errors).shape)

# Print the results
for idx, sampled_list in enumerate(sampled_errors):
    print(f"Sampled data for list {idx + 1}:")
    for item in sampled_list:
        print(item)
    print()
# Out:
# (100, 5)
# Sampled data for list 1:
# {'original': 'rushed', 'error': 'rush', 'sentence': 16}
# {'original': 'up', 'error': 'inside', 'sentence': 14}
# {'original': 'won', 'error': 'win', 'sentence': 43}
# {'original': 'stood', 'error': 'stand', 'sentence': 40}
# {'original': 'impatient', 'error': 'impateint', 'sentence': 2}
#
# Sampled data for list 2:
# {'original': 'of', 'error': 'among', 'sentence': 4}
# {'original': 'learned', 'error': 'learn', 'sentence': 32}
# {'original': 'patient', 'error': 'patinet', 'sentence': 5}
# {'original': 'helpful', 'error': 'ehlpful', 'sentence': 1}
# {'original': 'person', 'error': 'persno', 'sentence': 3}
#
# Sampled data for list 3:
# {'original': 'getting', 'error': 'gets', 'sentence': 3}
# {'original': 'had', 'error': 'have', 'sentence': 8}
# {'original': 'told', 'error': 'tells', 'sentence': 11}
# {'original': 'patient', 'error': 'patinet', 'sentence': 4}
# {'original': 'game', 'error': 'agme', 'sentence': 3}
#
# Sampled data for list 4:
# {'original': 'school', 'error': 'school', 'sentence': 1}
# {'original': 'staying', 'error': 'stay', 'sentence': 17}
# {'original': 'see', 'error': 'sees', 'sentence': 20}
# {'original': 'up', 'error': 'during', 'sentence': 1}
# {'original': 'case', 'error': 'csae', 'sentence': 4}
#
# Sampled data for list 5:
# {'original': 'from', 'error': 'for', 'sentence': 5}
# {'original': 'by', 'error': 'with', 'sentence': 5}
# {'original': 'school', 'error': 'school', 'sentence': 5}
# {'original': 'going', 'error': 'go', 'sentence': 12}
# {'original': 'something', 'error': 'somtehing', 'sentence': 2}
#
# Sampled data for list 6:
# {'original': 'would', 'error': 'wuold', 'sentence': 1}
# {'original': 'sat', 'error': 'sits', 'sentence': 11}
# {'original': 'for', 'error': 'beyond', 'sentence': 13}
# {'original': 'said', 'error': 'says', 'sentence': 7}
# {'original': 'like', 'error': 'ilke', 'sentence': 5}
#
# Sampled data for list 7:
# {'original': 'rang', 'error': 'rings', 'sentence': 2}
# {'original': 'rushed', 'error': 'rush', 'sentence': 4}
# {'original': 'mile', 'error': 'imle', 'sentence': 4}
# {'original': 'lunch', 'error': 'ulnch', 'sentence': 1}
# {'original': 'knew', 'error': 'knows', 'sentence': 6}
#
# Sampled data for list 8:
# {'original': 'waiting', 'error': 'waits', 'sentence': 6}
# {'original': 'got', 'error': 'get', 'sentence': 12}
# {'original': 'late', 'error': 'laet', 'sentence': 1}
# {'original': 'had', 'error': 'has', 'sentence': 13}
# {'original': 'up', 'error': 'to', 'sentence': 13}
#
# Sampled data for list 9:
# {'original': 'got', 'error': 'get', 'sentence': 4}
# {'original': 'crawled', 'error': 'crawls', 'sentence': 7}
# {'original': 'had', 'error': 'have', 'sentence': 5}
# {'original': 'Well', 'error': 'Well', 'sentence': 2}
# {'original': 'of', 'error': 'within', 'sentence': 13}
#
# Sampled data for list 10:
# {'original': 'went', 'error': 'wetn', 'sentence': 1}
# {'original': 'live', 'error': 'lives', 'sentence': 2}
# {'original': 'had', 'error': 'has', 'sentence': 4}
# {'original': 'felt', 'error': 'feel', 'sentence': 11}
# {'original': 'fanaly', 'error': 'into', 'sentence': 7}
#
# Sampled data for list 11:
# {'original': 'on', 'error': 'except', 'sentence': 32}
# {'original': 'Nana', 'error': 'Naan', 'sentence': 4}
# {'original': 'carried', 'error': 'carry', 'sentence': 21}
# {'original': 'exclaimed', 'error': 'exclaim', 'sentence': 12}
# {'original': 'got', 'error': 'get', 'sentence': 28}
#
# Sampled data for list 12:
# {'original': 'live', 'error': 'lvie', 'sentence': 3}
# {'original': 'cool', 'error': 'ocol', 'sentence': 1}
# {'original': 'line', 'error': 'lien', 'sentence': 2}
# {'original': 'try', 'error': 'tyr', 'sentence': 2}
# {'original': 'for', 'error': 'upon', 'sentence': 2}
#
# Sampled data for list 13:
# {'original': 'wondered', 'error': 'wonder', 'sentence': 15}
# {'original': 'got', 'error': 'get', 'sentence': 9}
# {'original': 'little', 'error': 'littel', 'sentence': 5}
# {'original': 'saw', 'error': 'sees', 'sentence': 7}
# {'original': 'excited', 'error': 'xecited', 'sentence': 2}
#
# Sampled data for list 14:
# {'original': 'say', 'error': 'sya', 'sentence': 2}
# {'original': 'about', 'error': 'around', 'sentence': 1}
# {'original': 'writing', 'error': 'writes', 'sentence': 1}
# {'original': 'want', 'error': 'wanted', 'sentence': 5}
# {'original': 'class', 'error': 'calss', 'sentence': 5}
#
# Sampled data for list 15:
# {'original': 'person', 'error': 'pesron', 'sentence': 3}
# {'original': 'waiting', 'error': 'waitnig', 'sentence': 6}
# {'original': 'coming', 'error': 'comes', 'sentence': 6}
# {'original': 'coming', 'error': 'ocming', 'sentence': 5}
# {'original': 'to', 'error': 'until', 'sentence': 17}
#
# Sampled data for list 16:
# {'original': 'job', 'error': 'jbo', 'sentence': 16}
# {'original': 'believe', 'error': 'believed', 'sentence': 16}
# {'original': 'about', 'error': 'against', 'sentence': 16}
# {'original': 'have', 'error': 'has', 'sentence': 12}
# {'original': 'understand', 'error': 'undersatnd', 'sentence': 14}
#
# Sampled data for list 17:
# {'original': 'out', 'error': 'up', 'sentence': 6}
# {'original': 'about', 'error': 'despite', 'sentence': 7}
# {'original': 'wondering', 'error': 'wondernig', 'sentence': 2}
# {'original': 'went', 'error': 'go', 'sentence': 1}
# {'original': 'sat', 'error': 'sits', 'sentence': 2}
#
# Sampled data for list 18:
# {'original': 'won', 'error': 'win', 'sentence': 9}
# {'original': 'in', 'error': 'to', 'sentence': 3}
# {'original': 'wanted', 'error': 'wants', 'sentence': 2}
# {'original': 'game', 'error': 'gmae', 'sentence': 1}
# {'original': 'get', 'error': 'gte', 'sentence': 3}
#
# Sampled data for list 19:
# {'original': 'have', 'error': 'has', 'sentence': 4}
# {'original': 'having', 'error': 'has', 'sentence': 1}
# {'original': 'control', 'error': 'ocntrol', 'sentence': 1}
# {'original': 'composure', 'error': 'compousre', 'sentence': 3}
# {'original': 'for', 'error': 'since', 'sentence': 4}
#
# Sampled data for list 20:
# {'original': 'nothing', 'error': 'nohting', 'sentence': 4}
# {'original': 'of', 'error': 'behind', 'sentence': 11}
# {'original': 'winning', 'error': 'iwnning', 'sentence': 3}
# {'original': 'going', 'error': 'go', 'sentence': 25}
# {'original': 'blast', 'error': 'balst', 'sentence': 2}
#
# Sampled data for list 21:
# {'original': 'whole', 'error': 'wohle', 'sentence': 3}
# {'original': 'use', 'error': 'ues', 'sentence': 2}
# {'original': 'ask', 'error': 'asked', 'sentence': 7}
# {'original': 'over', 'error': 'except', 'sentence': 10}
# {'original': 'thought', 'error': 'think', 'sentence': 3}
#
# Sampled data for list 22:
# {'original': 'like', 'error': 'within', 'sentence': 9}
# {'original': 'to', 'error': 'among', 'sentence': 10}
# {'original': 'went', 'error': 'goes', 'sentence': 6}
# {'original': 'had', 'error': 'have', 'sentence': 5}
# {'original': 'person', 'error': 'perosn', 'sentence': 4}
#
# Sampled data for list 23:
# {'original': 'Like', 'error': 'Lkie', 'sentence': 3}
# {'original': 'take', 'error': 'taek', 'sentence': 2}
# {'original': 'went', 'error': 'go', 'sentence': 3}
# {'original': 'wanted', 'error': 'wants', 'sentence': 7}
# {'original': 'mean\x92s', 'error': 'mean\x92ss', 'sentence': 2}
#
# Sampled data for list 24:
# {'original': 'on', 'error': 'over', 'sentence': 1}
# {'original': 'of', 'error': 'since', 'sentence': 2}
# {'original': 'old', 'error': 'lod', 'sentence': 4}
# {'original': 'felt', 'error': 'feel', 'sentence': 7}
# {'original': 'handling', 'error': 'hnadling', 'sentence': 1}
#
# Sampled data for list 25:
# {'original': 'dog', 'error': 'odg', 'sentence': 3}
# {'original': 'tryed', 'error': 'tries', 'sentence': 5}
# {'original': 'talking', 'error': 'talk', 'sentence': 4}
# {'original': 'patient', 'error': 'patietn', 'sentence': 1}
# {'original': 'seat', 'error': 'esat', 'sentence': 2}
#
# Sampled data for list 26:
# {'original': 'sitting', 'error': 'sit', 'sentence': 4}
# {'original': 'got', 'error': 'get', 'sentence': 10}
# {'original': 'cramped', 'error': 'cramp', 'sentence': 5}
# {'original': 'Around', 'error': 'Aroudn', 'sentence': 5}
# {'original': 'froze', 'error': 'freezes', 'sentence': 7}
#
# Sampled data for list 27:
# {'original': 'about', 'error': 'under', 'sentence': 1}
# {'original': 'wrong', 'error': 'worng', 'sentence': 3}
# {'original': 'to', 'error': 'upon', 'sentence': 5}
# {'original': 'done', 'error': 'dnoe', 'sentence': 2}
# {'original': 'have', 'error': 'has', 'sentence': 2}
#
# Sampled data for list 28:
# {'original': 'caught', 'error': 'catch', 'sentence': 15}
# {'original': 'caught', 'error': 'catches', 'sentence': 29}
# {'original': 'box', 'error': 'bxo', 'sentence': 3}
# {'original': 'to', 'error': 'over', 'sentence': 4}
# {'original': 'stayed', 'error': 'stays', 'sentence': 32}
#
# Sampled data for list 29:
# {'original': 'Patience', 'error': 'Patiecne', 'sentence': 1}
# {'original': 'has', 'error': 'had', 'sentence': 4}
# {'original': 'think', 'error': 'thought', 'sentence': 19}
# {'original': 'five', 'error': 'fvie', 'sentence': 5}
# {'original': 'out', 'error': 'by', 'sentence': 24}
#
# Sampled data for list 30:
# {'original': 'going', 'error': 'oging', 'sentence': 5}
# {'original': 'office', 'error': 'offcie', 'sentence': 3}
# {'original': 'Yes', 'error': 'Yse', 'sentence': 4}
# {'original': 'going', 'error': 'goes', 'sentence': 4}
# {'original': 'of', 'error': 'accross', 'sentence': 1}
#
# Sampled data for list 31:
# {'original': 'want', 'error': 'wants', 'sentence': 17}
# {'original': 'had', 'error': 'has', 'sentence': 7}
# {'original': 'couple', 'error': 'copule', 'sentence': 1}
# {'original': 'took', 'error': 'toko', 'sentence': 4}
# {'original': 'take', 'error': 'atke', 'sentence': 2}
#
# Sampled data for list 32:
# {'original': 'laft', 'error': 'lafted', 'sentence': 13}
# {'original': 'up', 'error': 'with', 'sentence': 5}
# {'original': 'come', 'error': 'comes', 'sentence': 5}
# {'original': 'hotel', 'error': 'hoetl', 'sentence': 2}
# {'original': 'move', 'error': 'moved', 'sentence': 7}
#
# Sampled data for list 33:
# {'original': 'want', 'error': 'wants', 'sentence': 8}
# {'original': 'wanted', 'error': 'wants', 'sentence': 3}
# {'original': 'get', 'error': 'egt', 'sentence': 5}
# {'original': 'at', 'error': 'after', 'sentence': 8}
# {'original': 'writing', 'error': 'write', 'sentence': 1}
#
# Sampled data for list 34:
# {'original': 'irritates', 'error': 'irritated', 'sentence': 11}
# {'original': 'out', 'error': 'through', 'sentence': 8}
# {'original': 'wears', 'error': 'wore', 'sentence': 10}
# {'original': 'got', 'error': 'gets', 'sentence': 3}
# {'original': 'Usually', 'error': 'Usulaly', 'sentence': 4}
#
# Sampled data for list 35:
# {'original': 'patient', 'error': 'patinet', 'sentence': 1}
# {'original': 'for', 'error': 'down', 'sentence': 16}
# {'original': 'hear', 'error': 'hears', 'sentence': 7}
# {'original': 'patient', 'error': 'paitent', 'sentence': 2}
# {'original': 'draw', 'error': 'draws', 'sentence': 9}
#
# Sampled data for list 36:
# {'original': 'have', 'error': 'had', 'sentence': 6}
# {'original': 'take', 'error': 'atke', 'sentence': 1}
# {'original': 'have', 'error': 'had', 'sentence': 9}
# {'original': 'little', 'error': 'little', 'sentence': 3}
# {'original': 'in', 'error': 'accross', 'sentence': 2}
#
# Sampled data for list 37:
# {'original': 'comes', 'error': 'came', 'sentence': 5}
# {'original': 'Patience', 'error': 'Patienec', 'sentence': 1}
# {'original': 'Like', 'error': 'Lkie', 'sentence': 4}
# {'original': 'For', 'error': 'accross', 'sentence': 3}
# {'original': 'hard', 'error': 'hrad', 'sentence': 2}
#
# Sampled data for list 38:
# {'original': 'deer', 'error': 'dere', 'sentence': 2}
# {'original': 'wath', 'error': 'waht', 'sentence': 3}
# {'original': 'come', 'error': 'came', 'sentence': 4}
# {'original': 'came', 'error': 'come', 'sentence': 5}
# {'original': 'git', 'error': 'gits', 'sentence': 6}
#
# Sampled data for list 39:
# {'original': 'got', 'error': 'ogt', 'sentence': 5}
# {'original': 'first', 'error': 'ifrst', 'sentence': 4}
# {'original': 'four', 'error': 'fuor', 'sentence': 3}
# {'original': 'in', 'error': 'to', 'sentence': 4}
# {'original': 'got', 'error': 'gets', 'sentence': 4}
#
# Sampled data for list 40:
# {'original': 'for', 'error': 'by', 'sentence': 4}
# {'original': 'down', 'error': 'during', 'sentence': 3}
# {'original': 'patient', 'error': 'patietn', 'sentence': 1}
# {'original': 'yet', 'error': 'yte', 'sentence': 2}
# {'original': 'patient', 'error': 'patietn', 'sentence': 4}
#
# Sampled data for list 41:
# {'original': 'with', 'error': 'through', 'sentence': 20}
# {'original': 'packed', 'error': 'pack', 'sentence': 18}
# {'original': 'completely', 'error': 'comlpetely', 'sentence': 5}
# {'original': 'phone', 'error': 'pohne', 'sentence': 3}
# {'original': 'day', 'error': 'dya', 'sentence': 1}
#
# Sampled data for list 42:
# {'original': 'runs', 'error': 'run', 'sentence': 9}
# {'original': 'take', 'error': 'takes', 'sentence': 3}
# {'original': 'big', 'error': 'ibg', 'sentence': 1}
# {'original': 'understanding', 'error': 'understand', 'sentence': 23}
# {'original': 'like', 'error': 'for', 'sentence': 2}
#
# Sampled data for list 43:
# {'original': 'wait', 'error': 'awit', 'sentence': 6}
# {'original': 'to', 'error': 'in', 'sentence': 3}
# {'original': 'had', 'error': 'have', 'sentence': 6}
# {'original': 'going', 'error': 'go', 'sentence': 3}
# {'original': 'time', 'error': 'itme', 'sentence': 5}
#
# Sampled data for list 44:
# {'original': 'take', 'error': 'atke', 'sentence': 5}
# {'original': 'to', 'error': 'through', 'sentence': 3}
# {'original': 'knowing', 'error': 'knows', 'sentence': 5}
# {'original': 'Patience', 'error': 'Patienec', 'sentence': 4}
# {'original': 'of', 'error': 'behind', 'sentence': 1}
#
# Sampled data for list 45:
# {'original': 'with', 'error': 'against', 'sentence': 4}
# {'original': 'today', 'error': 'toady', 'sentence': 5}
# {'original': 'ho', 'error': 'oh', 'sentence': 18}
# {'original': 'people', 'error': 'poeple', 'sentence': 1}
# {'original': 'with', 'error': 'at', 'sentence': 1}
#
# Sampled data for list 46:
# {'original': 'heading', 'error': 'head', 'sentence': 1}
# {'original': 'waited', 'error': 'waits', 'sentence': 7}
# {'original': 'done', 'error': 'do', 'sentence': 10}
# {'original': 'get', 'error': 'gte', 'sentence': 3}
# {'original': 'checked', 'error': 'checks', 'sentence': 12}
#
# Sampled data for list 47:
# {'original': 'knew', 'error': 'kenw', 'sentence': 1}
# {'original': 'did', 'error': 'do', 'sentence': 16}
# {'original': 'at', 'error': 'beside', 'sentence': 5}
# {'original': 'at', 'error': 'about', 'sentence': 3}
# {'original': 'having', 'error': 'has', 'sentence': 2}
#
# Sampled data for list 48:
# {'original': 'home', 'error': 'ohme', 'sentence': 6}
# {'original': 'doing', 'error': 'does', 'sentence': 8}
# {'original': 'for', 'error': 'before', 'sentence': 17}
# {'original': 'maring', 'error': 'mars', 'sentence': 4}
# {'original': 'helping', 'error': 'hepling', 'sentence': 3}
#
# Sampled data for list 49:
# {'original': 'At', 'error': 'since', 'sentence': 2}
# {'original': 'in', 'error': 'on', 'sentence': 2}
# {'original': 'patient', 'error': 'aptient', 'sentence': 1}
# {'original': 'patient', 'error': 'paitent', 'sentence': 2}
# {'original': 'want', 'error': 'watn', 'sentence': 2}
#
# Sampled data for list 50:
# {'original': 'wait', 'error': 'wati', 'sentence': 5}
# {'original': 'Waiting', 'error': 'Waitign', 'sentence': 6}
# {'original': 'pinkeye', 'error': 'pnikeye', 'sentence': 3}
# {'original': 'throw', 'error': 'thorw', 'sentence': 2}
# {'original': 'over', 'error': 'in', 'sentence': 6}
#
# Sampled data for list 51:
# {'original': 'took', 'error': 'takes', 'sentence': 7}
# {'original': 'for', 'error': 'past', 'sentence': 4}
# {'original': 'know', 'error': 'knows', 'sentence': 6}
# {'original': 'had', 'error': 'has', 'sentence': 2}
# {'original': 'out', 'error': 'up', 'sentence': 7}
#
# Sampled data for list 52:
# {'original': 'said', 'error': 'say', 'sentence': 2}
# {'original': 'at', 'error': 'beyond', 'sentence': 1}
# {'original': 'want', 'error': 'wanted', 'sentence': 3}
# {'original': 'for', 'error': 'outside', 'sentence': 2}
# {'original': 'took', 'error': 'took', 'sentence': 6}
#
# Sampled data for list 53:
# {'original': 'yelled', 'error': 'yell', 'sentence': 7}
# {'original': 'cried', 'error': 'cry', 'sentence': 3}
# {'original': 'stomach', 'error': 'stoamch', 'sentence': 2}
# {'original': 'cashier', 'error': 'casiher', 'sentence': 5}
# {'original': 'got', 'error': 'gets', 'sentence': 20}
#
# Sampled data for list 54:
# {'original': 'said', 'error': 'say', 'sentence': 2}
# {'original': 'go', 'error': 'og', 'sentence': 1}
# {'original': 'One', 'error': 'Oen', 'sentence': 1}
# {'original': 'in', 'error': 'upon', 'sentence': 2}
# {'original': 'went', 'error': 'wnet', 'sentence': 2}
#
# Sampled data for list 55:
# {'original': 'used', 'error': 'uesd', 'sentence': 4}
# {'original': 'crying', 'error': 'cries', 'sentence': 13}
# {'original': 'taught', 'error': 'tauhgt', 'sentence': 1}
# {'original': 'knocked', 'error': 'knockes', 'sentence': 18}
# {'original': 'though', 'error': 'tohugh', 'sentence': 5}
#
# Sampled data for list 56:
# {'original': 'patience', 'error': 'patienec', 'sentence': 2}
# {'original': 'wanted', 'error': 'want', 'sentence': 7}
# {'original': 'peek', 'error': 'peeked', 'sentence': 6}
# {'original': 'time', 'error': 'itme', 'sentence': 1}
# {'original': 'day', 'error': 'ady', 'sentence': 3}
#
# Sampled data for list 57:
# {'original': 'grandma', 'error': 'grnadma', 'sentence': 2}
# {'original': 'time', 'error': 'tmie', 'sentence': 1}
# {'original': 'on', 'error': 'about', 'sentence': 2}
# {'original': 'took', 'error': 'took', 'sentence': 4}
# {'original': 'took', 'error': 'take', 'sentence': 4}
#
# Sampled data for list 58:
# {'original': 'standing', 'error': 'stand', 'sentence': 4}
# {'original': 'saw', 'error': 'asw', 'sentence': 3}
# {'original': 'wake', 'error': 'wakes', 'sentence': 6}
# {'original': 'going', 'error': 'go', 'sentence': 2}
# {'original': 'at', 'error': 'since', 'sentence': 1}
#
# Sampled data for list 59:
# {'original': 'us', 'error': 'su', 'sentence': 5}
# {'original': 'get', 'error': 'gte', 'sentence': 2}
# {'original': 'had', 'error': 'have', 'sentence': 2}
# {'original': 'had', 'error': 'have', 'sentence': 3}
# {'original': 'finally', 'error': 'finalyl', 'sentence': 4}
#
# Sampled data for list 60:
# {'original': 'fighting', 'error': 'fights', 'sentence': 9}
# {'original': 'told', 'error': 'tells', 'sentence': 4}
# {'original': 'on', 'error': 'at', 'sentence': 5}
# {'original': 'broke', 'error': 'break', 'sentence': 8}
# {'original': 'yes', 'error': 'yse', 'sentence': 2}
#
# Sampled data for list 61:
# {'original': 'computer', 'error': 'comptuer', 'sentence': 4}
# {'original': 'year', 'error': 'yera', 'sentence': 3}
# {'original': 'Everyone', 'error': 'Everynoe', 'sentence': 1}
# {'original': 'After', 'error': 'among', 'sentence': 8}
# {'original': 'had', 'error': 'have', 'sentence': 4}
#
# Sampled data for list 62:
# {'original': 'want', 'error': 'wanted', 'sentence': 12}
# {'original': 'ago', 'error': 'aog', 'sentence': 1}
# {'original': 'told', 'error': 'tells', 'sentence': 11}
# {'original': 'decided', 'error': 'deciedd', 'sentence': 4}
# {'original': 'went', 'error': 'go', 'sentence': 5}
#
# Sampled data for list 63:
# {'original': 'flipped', 'error': 'flips', 'sentence': 9}
# {'original': 'wrote', 'error': 'writes', 'sentence': 4}
# {'original': 'walked', 'error': 'walk', 'sentence': 6}
# {'original': 'amount', 'error': 'aomunt', 'sentence': 2}
# {'original': 'part', 'error': 'aprt', 'sentence': 4}
#
# Sampled data for list 64:
# {'original': 'around', 'error': 'for', 'sentence': 7}
# {'original': 'came', 'error': 'come', 'sentence': 3}
# {'original': 'old', 'error': 'lod', 'sentence': 2}
# {'original': 'older', 'error': 'odler', 'sentence': 4}
# {'original': 'know', 'error': 'knew', 'sentence': 6}
#
# Sampled data for list 65:
# {'original': 'went', 'error': 'goes', 'sentence': 9}
# {'original': 'started', 'error': 'starts', 'sentence': 17}
# {'original': 'get', 'error': 'gte', 'sentence': 2}
# {'original': 'got', 'error': 'ogt', 'sentence': 5}
# {'original': 'going', 'error': 'go', 'sentence': 2}
#
# Sampled data for list 66:
# {'original': 'name', 'error': 'anme', 'sentence': 2}
# {'original': 'patient', 'error': 'patinet', 'sentence': 3}
# {'original': 'takes', 'error': 'took', 'sentence': 5}
# {'original': 'around', 'error': 'as', 'sentence': 9}
# {'original': 'uses', 'error': 'used', 'sentence': 6}
#
# Sampled data for list 67:
# {'original': 'patient', 'error': 'patietn', 'sentence': 4}
# {'original': 'to', 'error': 'beside', 'sentence': 3}
# {'original': 'by', 'error': 'between', 'sentence': 5}
# {'original': 'faster', 'error': 'fatser', 'sentence': 5}
# {'original': 'got', 'error': 'get', 'sentence': 13}
#
# Sampled data for list 68:
# {'original': 'fire', 'error': 'frie', 'sentence': 4}
# {'original': 'in', 'error': 'before', 'sentence': 8}
# {'original': 'in', 'error': 'under', 'sentence': 3}
# {'original': 'complained', 'error': 'complain', 'sentence': 9}
# {'original': 'office', 'error': 'offcie', 'sentence': 2}
#
# Sampled data for list 69:
# {'original': 'on', 'error': 'about', 'sentence': 4}
# {'original': 'went', 'error': 'ewnt', 'sentence': 1}
# {'original': 'ran', 'error': 'runs', 'sentence': 5}
# {'original': 'went', 'error': 'ewnt', 'sentence': 2}
# {'original': 'at', 'error': 'to', 'sentence': 1}
#
# Sampled data for list 70:
# {'original': 'wait', 'error': 'wiat', 'sentence': 3}
# {'original': 'in', 'error': 'among', 'sentence': 3}
# {'original': 'told', 'error': 'tell', 'sentence': 1}
# {'original': 'in', 'error': 'toward', 'sentence': 7}
# {'original': 'told', 'error': 'tlod', 'sentence': 4}
#
# Sampled data for list 71:
# {'original': 'on', 'error': 'behind', 'sentence': 1}
# {'original': 'inside', 'error': 'isnide', 'sentence': 1}
# {'original': 'on', 'error': 'over', 'sentence': 1}
# {'original': 'outside', 'error': 'outisde', 'sentence': 1}
# {'original': 'better', 'error': 'bettre', 'sentence': 1}
#
# Sampled data for list 72:
# {'original': 'have', 'error': 'had', 'sentence': 6}
# {'original': 'patient', 'error': 'paitent', 'sentence': 1}
# {'original': 'heard', 'error': 'hear', 'sentence': 9}
# {'original': 'in', 'error': 'upon', 'sentence': 12}
# {'original': 'tolerant', 'error': 'otlerant', 'sentence': 4}
#
# Sampled data for list 73:
# {'original': 'cause', 'error': 'casue', 'sentence': 3}
# {'original': 'car', 'error': 'acr', 'sentence': 3}
# {'original': 'helmet', 'error': 'helmte', 'sentence': 1}
# {'original': 'showed', 'error': 'shows', 'sentence': 3}
# {'original': 'patience', 'error': 'patiecne', 'sentence': 9}
#
# Sampled data for list 74:
# {'original': 'eve', 'error': 'eev', 'sentence': 4}
# {'original': 'to', 'error': 'as', 'sentence': 11}
# {'original': 'wanted', 'error': 'wants', 'sentence': 12}
# {'original': 'felt', 'error': 'feel', 'sentence': 9}
# {'original': 'eve', 'error': 'eev', 'sentence': 2}
#
# Sampled data for list 75:
# {'original': 'to', 'error': 'among', 'sentence': 5}
# {'original': 'for', 'error': 'among', 'sentence': 9}
# {'original': 'asked', 'error': 'asks', 'sentence': 4}
# {'original': 'found', 'error': 'fonud', 'sentence': 5}
# {'original': 'office', 'error': 'offcie', 'sentence': 1}
#
# Sampled data for list 76:
# {'original': 'thinking', 'error': 'thniking', 'sentence': 5}
# {'original': 'felt', 'error': 'feel', 'sentence': 7}
# {'original': 'had', 'error': 'has', 'sentence': 11}
# {'original': 'relized', 'error': 'relizes', 'sentence': 9}
# {'original': 'growl', 'error': 'grolw', 'sentence': 4}
#
# Sampled data for list 77:
# {'original': 'time', 'error': 'tmie', 'sentence': 2}
# {'original': 'math', 'error': 'amth', 'sentence': 1}
# {'original': 'out', 'error': 'until', 'sentence': 2}
# {'original': 'nat', 'error': 'ant', 'sentence': 2}
# {'original': 'quit', 'error': 'quti', 'sentence': 2}
#
# Sampled data for list 78:
# {'original': 'patience', 'error': 'patienec', 'sentence': 2}
# {'original': 'ever', 'error': 'eevr', 'sentence': 1}
# {'original': 'plastic', 'error': 'lpastic', 'sentence': 5}
# {'original': 'yelled', 'error': 'yell', 'sentence': 10}
# {'original': 'around', 'error': 'among', 'sentence': 8}
#
# Sampled data for list 79:
# {'original': 'walked', 'error': 'walks', 'sentence': 7}
# {'original': 'important', 'error': 'importnat', 'sentence': 1}
# {'original': 'go', 'error': 'og', 'sentence': 3}
# {'original': 'said', 'error': 'says', 'sentence': 5}
# {'original': 'went', 'error': 'wetn', 'sentence': 4}
#
# Sampled data for list 80:
# {'original': 'to', 'error': 'through', 'sentence': 2}
# {'original': 'for', 'error': 'until', 'sentence': 9}
# {'original': 'patient', 'error': 'pateint', 'sentence': 4}
# {'original': 'game', 'error': 'agme', 'sentence': 5}
# {'original': 'playing', 'error': 'plays', 'sentence': 5}
#
# Sampled data for list 81:
# {'original': 'had', 'error': 'have', 'sentence': 6}
# {'original': 'looking', 'error': 'look', 'sentence': 1}
# {'original': 'came', 'error': 'comes', 'sentence': 5}
# {'original': 'day', 'error': 'ady', 'sentence': 1}
# {'original': 'to', 'error': 'with', 'sentence': 6}
#
# Sampled data for list 82:
# {'original': 'on', 'error': 'around', 'sentence': 1}
# {'original': 'looking', 'error': 'look', 'sentence': 1}
# {'original': 'wanted', 'error': 'want', 'sentence': 12}
# {'original': 'came', 'error': 'caem', 'sentence': 4}
# {'original': 'traverse', 'error': 'travrese', 'sentence': 2}
#
# Sampled data for list 83:
# {'original': 'by', 'error': 'behind', 'sentence': 1}
# {'original': 'said', 'error': 'says', 'sentence': 1}
# {'original': 'have', 'error': 'has', 'sentence': 2}
# {'original': 'wait', 'error': 'awit', 'sentence': 1}
# {'original': 'patient', 'error': 'aptient', 'sentence': 2}
#
# Sampled data for list 84:
# {'original': 'whent', 'error': 'whented', 'sentence': 1}
# {'original': 'gave', 'error': 'gvae', 'sentence': 6}
# {'original': 'for', 'error': 'under', 'sentence': 5}
# {'original': 'went', 'error': 'goes', 'sentence': 2}
# {'original': 'wated', 'error': 'wate', 'sentence': 3}
#
# Sampled data for list 85:
# {'original': 'saw', 'error': 'sees', 'sentence': 5}
# {'original': 'kept', 'error': 'keep', 'sentence': 2}
# {'original': 'enough', 'error': 'neough', 'sentence': 4}
# {'original': 'trip', 'error': 'rtip', 'sentence': 1}
# {'original': 'going', 'error': 'goes', 'sentence': 12}
#
# Sampled data for list 86:
# {'original': 'to', 'error': 'as', 'sentence': 2}
# {'original': 'back', 'error': 'bcak', 'sentence': 3}
# {'original': 'took', 'error': 'took', 'sentence': 2}
# {'original': 'patient', 'error': 'paitent', 'sentence': 1}
# {'original': 'patient', 'error': 'patietn', 'sentence': 4}
#
# Sampled data for list 87:
# {'original': 'told', 'error': 'tells', 'sentence': 3}
# {'original': 'back', 'error': 'bakc', 'sentence': 5}
# {'original': 'dentist', 'error': 'dnetist', 'sentence': 4}
# {'original': 'got', 'error': 'gets', 'sentence': 6}
# {'original': 'means', 'error': 'mean', 'sentence': 5}
#
# Sampled data for list 88:
# {'original': 'impossible', 'error': 'impsosible', 'sentence': 2}
# {'original': 'in', 'error': 'since', 'sentence': 17}
# {'original': 'to', 'error': 'under', 'sentence': 10}
# {'original': 'know', 'error': 'knew', 'sentence': 21}
# {'original': 'Patience', 'error': 'Patiecne', 'sentence': 1}
#
# Sampled data for list 89:
# {'original': 'fell', 'error': 'falls', 'sentence': 16}
# {'original': 'in', 'error': 'between', 'sentence': 11}
# {'original': 'could', 'error': 'oculd', 'sentence': 1}
# {'original': 'got', 'error': 'gets', 'sentence': 9}
# {'original': 'one', 'error': 'oen', 'sentence': 9}
#
# Sampled data for list 90:
# {'original': 'need', 'error': 'needed', 'sentence': 6}
# {'original': 'patience', 'error': 'patienec', 'sentence': 2}
# {'original': 'Patience', 'error': 'Patiecne', 'sentence': 1}
# {'original': 'going', 'error': 'oging', 'sentence': 5}
# {'original': 'ask', 'error': 'aks', 'sentence': 4}
#
# Sampled data for list 91:
# {'original': 'going', 'error': 'go', 'sentence': 5}
# {'original': 'asked', 'error': 'ask', 'sentence': 6}
# {'original': 'like', 'error': 'by', 'sentence': 4}
# {'original': 'point', 'error': 'poitn', 'sentence': 1}
# {'original': 'felt', 'error': 'feel', 'sentence': 9}
#
# Sampled data for list 92:
# {'original': 'said', 'error': 'says', 'sentence': 6}
# {'original': 'said', 'error': 'asid', 'sentence': 1}
# {'original': 'dresser', 'error': 'dresesr', 'sentence': 4}
# {'original': 'to', 'error': 'except', 'sentence': 1}
# {'original': 'called', 'error': 'call', 'sentence': 9}
#
# Sampled data for list 93:
# {'original': 'for', 'error': 'past', 'sentence': 5}
# {'original': 'keep', 'error': 'keeps', 'sentence': 2}
# {'original': 'got', 'error': 'get', 'sentence': 6}
# {'original': 'something', 'error': 'somethnig', 'sentence': 4}
# {'original': 'family', 'error': 'faimly', 'sentence': 1}
#
# Sampled data for list 94:
# {'original': 'little', 'error': 'litlte', 'sentence': 2}
# {'original': 'hair', 'error': 'hari', 'sentence': 4}
# {'original': 'went', 'error': 'goes', 'sentence': 4}
# {'original': 'patient', 'error': 'aptient', 'sentence': 3}
# {'original': 'went', 'error': 'go', 'sentence': 6}
#
# Sampled data for list 95:
# {'original': 'up', 'error': 'along', 'sentence': 15}
# {'original': 'birthday', 'error': 'brithday', 'sentence': 1}
# {'original': 'wait', 'error': 'wiat', 'sentence': 2}
# {'original': 'woke', 'error': 'wake', 'sentence': 10}
# {'original': 'don\x92t', 'error': 'don\x92ted', 'sentence': 12}
#
# Sampled data for list 96:
# {'original': 'out', 'error': 'without', 'sentence': 7}
# {'original': 'ran', 'error': 'run', 'sentence': 24}
# {'original': 'one', 'error': 'oen', 'sentence': 2}
# {'original': 'understood', 'error': 'understand', 'sentence': 13}
# {'original': 'life', 'error': 'lfie', 'sentence': 1}
#
# Sampled data for list 97:
# {'original': 'best', 'error': 'ebst', 'sentence': 2}
# {'original': 'got', 'error': 'gets', 'sentence': 8}
# {'original': 'people', 'error': 'peopel', 'sentence': 5}
# {'original': 'walk', 'error': 'wakl', 'sentence': 4}
# {'original': 'told', 'error': 'todl', 'sentence': 1}
#
# Sampled data for list 98:
# {'original': 'Patience', 'error': 'Paitence', 'sentence': 1}
# {'original': 'along', 'error': 'between', 'sentence': 9}
# {'original': 'begins', 'error': 'began', 'sentence': 5}
# {'original': 'understanding', 'error': 'unedrstanding', 'sentence': 2}
# {'original': 'movie', 'error': 'moive', 'sentence': 5}
#
# Sampled data for list 99:
# {'original': 'at', 'error': 'under', 'sentence': 5}
# {'original': 'jumped', 'error': 'jump', 'sentence': 4}
# {'original': 'pool', 'error': 'polo', 'sentence': 4}
# {'original': 'used', 'error': 'use', 'sentence': 2}
# {'original': 'One', 'error': 'nOe', 'sentence': 3}
#
# Sampled data for list 100:
# {'original': 'used', 'error': 'use', 'sentence': 1}
# {'original': 'had', 'error': 'has', 'sentence': 7}
# {'original': 'use', 'error': 'ues', 'sentence': 2}
# {'original': 'on', 'error': 'outside', 'sentence': 2}
# {'original': 'of', 'error': 'despite', 'sentence': 4}

# %%
np.array(sampled_errors).shape
# Out:
# (100, 5)

# %%
joblib.dump(sampled_errors, 'files/error_train_100essay_5err')
# Out:
# ['files/error_train_100essay_5err']

# %%
# Function to apply corrections to the essay
def apply_errors(essay, errors):
    # Tokenize the essay into sentences using NLTK
    sentences = nltk.sent_tokenize(essay)

    # Create a list to store corrected sentences
    errored_sentences = []

    # Iterate through sentences
    for i, sentence in enumerate(sentences):
        # Apply corrections to the current sentence
        for error in errors:
            # Adjust the index by subtracting 1 to match the enumeration starting from 0
            if error['sentence'] == i + 1:
                # Replace all occurrences of the incorrect text with the correction
                #sentence = sentence.replace(correction['original'], correction['correction'])
                 # Use regular expression with word boundaries to replace only whole words
                sentence = re.sub(r'\b' + re.escape(error['original']) + r'\b', error['error'], sentence)
        # Add the corrected sentence to the list
        errored_sentences.append(sentence)

    # Join the corrected sentences to form the final essay
    errored_essay = ' '.join(errored_sentences)
    return errored_essay

# Function to generate all combinations of corrections and apply them
def generate_errored_versions(essay, errors):
    errored_versions = []
    max_errors = len(errors)

    # Iterate over different numbers of corrections to apply
    for num_errors in range(1, max_errors + 1):
        for combination in itertools.combinations(errors, num_errors):
            errored_essay = apply_errors(essay, combination)
            errored_versions.append(errored_essay)
  
    return errored_versions

# Example usage
essay = "This is a tess essay. The break through was amazing. The possitive effects were clear."
errors = [
    {'original': 'tess', 'error': 'test', 'type': 'Spelling', 'sentence': 1},
    {'original': 'break through', 'error': 'breakthrough', 'type': 'Spelling', 'sentence': 2},
    {'original': 'possitive', 'error': 'positive', 'type': 'Spelling', 'sentence': 3},
]

# Generate corrected versions with combinations of 1, 2, and 3 corrections
errored_versions = generate_errored_versions(essay, errors)
errored_versions
# Out:
# ['This is a test essay. The break through was amazing. The possitive effects were clear.',
#  'This is a tess essay. The breakthrough was amazing. The possitive effects were clear.',
#  'This is a tess essay. The break through was amazing. The positive effects were clear.',
#  'This is a test essay. The breakthrough was amazing. The possitive effects were clear.',
#  'This is a test essay. The break through was amazing. The positive effects were clear.',
#  'This is a tess essay. The breakthrough was amazing. The positive effects were clear.',
#  'This is a test essay. The breakthrough was amazing. The positive effects were clear.']

# %%
error_train_100essay_5err = joblib.load('files/error_train_100essay_5err')

errored_train_100data_5err = []

for index, row in data_100.iterrows():
    try:
        errored_essays = generate_errored_versions(row['essay'], error_train_100essay_5err[index]) 
        # Append the result to the list
        errored_train_100data_5err.append(errored_essays)
    except Exception as e:
        print(f"Error processing row {index}: {e}")
        errored_train_100data_5err.append(None)  # Append None or an empty dict if an error occurs
    print(index + 1, " finished")
# Out:
# 1  finished
# 2  finished
# 3  finished
# 4  finished
# 5  finished
# 6  finished
# 7  finished
# 8  finished
# 9  finished
# 10  finished
# 11  finished
# 12  finished
# 13  finished
# 14  finished
# 15  finished
# 16  finished
# 17  finished
# 18  finished
# 19  finished
# 20  finished
# 21  finished
# 22  finished
# 23  finished
# 24  finished
# 25  finished
# 26  finished
# 27  finished
# 28  finished
# 29  finished
# 30  finished
# 31  finished
# 32  finished
# 33  finished
# 34  finished
# 35  finished
# 36  finished
# 37  finished
# 38  finished
# 39  finished
# 40  finished
# 41  finished
# 42  finished
# 43  finished
# 44  finished
# 45  finished
# 46  finished
# 47  finished
# 48  finished
# 49  finished
# 50  finished
# 51  finished
# 52  finished
# 53  finished
# 54  finished
# 55  finished
# 56  finished
# 57  finished
# 58  finished
# 59  finished
# 60  finished
# 61  finished
# 62  finished
# 63  finished
# 64  finished
# 65  finished
# 66  finished
# 67  finished
# 68  finished
# 69  finished
# 70  finished
# 71  finished
# 72  finished
# 73  finished
# 74  finished
# 75  finished
# 76  finished
# 77  finished
# 78  finished
# 79  finished
# 80  finished
# 81  finished
# 82  finished
# 83  finished
# 84  finished
# 85  finished
# 86  finished
# 87  finished
# 88  finished
# 89  finished
# 90  finished
# 91  finished
# 92  finished
# 93  finished
# 94  finished
# 95  finished
# 96  finished
# 97  finished
# 98  finished
# 99  finished
# 100  finished

# %%
np.array(errored_train_100data_5err).shape
# Out:
# (100, 31)

# %%
joblib.dump(errored_train_100data_5err, 'files/errored_train_100data_5err')
# Out:
# ['files/errored_train_100data_5err']
