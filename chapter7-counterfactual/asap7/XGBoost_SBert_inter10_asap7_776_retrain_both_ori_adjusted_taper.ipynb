# %% [markdown]
# ### This is to retrain using both positive and negative counterfactuals

# %%
import xgboost
import joblib
import numpy as np
from sklearn.metrics import accuracy_score
from quadratic_weighted_kappa import quadratic_weighted_kappa
import pandas as pd
import itertools
import math

# %%
scores_ori = np.array(joblib.load("files/scores_essay_100_train_ori")).astype(float)
scores_ori.shape
# Out:
# (100,)

# %%
scores_ori = np.repeat(scores_ori, 31)

# %%
len(scores_ori)
# Out:
# 3100

# %%
joblib.dump(scores_ori, 'SCORES_ORI_3100')
# Out:
# ['SCORES_ORI_3100']

# %%
x = joblib.load('files/asap7_features_776').squeeze()
y = joblib.load("files/score_asap7")
y = y.reshape(-1,1)

feature_names = joblib.load('files/feature_names_776')
#model = joblib.load('model_asap1_778')

feats_counter_train_error = joblib.load('files/feats_counter_train_error_776').reshape(-1,776)
new_label_train_error = scores_ori.copy().reshape(3100,-1)

feats_counter_train_better = joblib.load('files/feats_counter_train_correct_776').reshape(-1,776)
new_label_train_better = scores_ori.copy().reshape(3100,-1)

# %%
new_label_train_better.shape
# Out:
# (3100, 1)

# %%
np.max(y)
# Out:
# 24

# %%
print(scores_ori.dtype)
# Out:
# float64

# %%
print(new_label_train_better.dtype)
# Out:
# float64

# %%
# =========================
# ADDED: derive min/max and a flat y for indexing
# =========================
y_flat = y.ravel()                                   # ADDED
score_min = float(np.min(y_flat))                    # ADDED
score_max = float(np.max(y_flat))                    # ADDED

# %% [markdown]
# #### Apply proposed method: Adjust worse essays label

# %%
# There are 100 essay samples with 31 variations

new_label_train_error = new_label_train_error.reshape(100,-1)
new_label_train_error.shape
# Out:
# (100, 31)

# %%
# ADDED: taper strength; k<1 = weaker taper (more separation near floor), k>1 = stronger taper
k = 0.8                                             # ADDED

n = 5
numbers = range(1, n + 1)  # Numbers from 1 to 5
ctr = 0

for i in range(len(new_label_train_error)):
    # =========================
    # ADDED: independent mapping baseline for this essay
    # =========================
    start_label = float(y_flat[i])                   # ADDED (use ORIGINAL label for essay i)
    headroom_down = start_label - score_min          # ADDED (distance to lower bound)

    # Generate combinations of varying lengths
    idx = 0
    for length in range(1, n + 1):
        combinations = itertools.combinations(numbers, length)
        delta_raw = 2 * length                       # keep your rule
        # delta_raw = round(delta_raw, 2)            # optional

        for combo in combinations:
            # =========================
            # CHANGED: soft-floor (diminishing) delta using e-base
            # =========================
            if headroom_down > 0:
                delta = headroom_down * (1.0 - math.exp(-(k * delta_raw) / headroom_down))
            else:
                delta = 0.0

            # =========================
            # CHANGED: assign from ORIGINAL label (independent), then clip
            # =========================
            new_label_train_error[i][idx] = max(start_label - delta, score_min)

            # (Optional safety clip to both sides; redundant for the lower side but harmless)
            # new_label_train_error[i][idx] = np.clip(new_label_train_error[i][idx], score_min, score_max)

            idx += 1

# %%
new_label_train_error = new_label_train_error.reshape(-1,1)
new_label_train_error.shape
# Out:
# (3100, 1)

# %%
joblib.dump(new_label_train_error, 'SCORES_ERROR_3100_TAPER')
# Out:
# ['SCORES_ERROR_3100_TAPER']

# %% [markdown]
# #### Apply proposed method: Adjust better essays label

# %%
# There are 100 essay samples with 31 variations

new_label_train_better = new_label_train_better.reshape(100,-1)
new_label_train_better.shape
# Out:
# (100, 31)

# %%
k = 0.8   # taper strength: <1 weaker taper (more separation near max), >1 stronger taper

n = 5
numbers = range(1, n + 1)

for i in range(len(new_label_train_better)):
    start_label = float(y_flat[i])                  # CHANGED: use flattened y
    headroom = score_max - start_label              # ADDED: constant headroom (independent mapping)

    idx = 0
    for length in range(1, n + 1):
        combinations = itertools.combinations(numbers, length)
        delta_raw = 1.5 * length                    # unchanged rule; keep round(...) if you prefer
        # delta_raw = round(delta_raw, 2)

        for combo in combinations:
            if headroom > 0:
                # CHANGED: e-based soft ceiling (diminishing as you approach score_max)
                delta = headroom * (1.0 - math.exp(-(k * delta_raw) / headroom))
            else:
                delta = 0.0

            # CHANGED: assign from ORIGINAL label (independent variant), then clip
            new_label_train_better[i][idx] = min(start_label + delta, score_max)

            idx += 1

# %%
new_label_train_better = new_label_train_better.reshape(-1,1)
new_label_train_better.shape
# Out:
# (3100, 1)

# %%
joblib.dump(new_label_train_error, 'SCORES_BETTER_3100_TAPER')
# Out:
# ['SCORES_BETTER_3100_TAPER']

# %%
np.array_equal(scores_ori, new_label_train_error.flatten())
np.array_equal(scores_ori, new_label_train_better.flatten())
# Out:
# False

# %%
import numpy as np
import matplotlib.pyplot as plt

n_show = 100

# Flatten and slice
ori = scores_ori[:n_show]
err = new_label_train_error[:n_show].flatten()
bet = new_label_train_better[:n_show].flatten()

# Compute and scale differences
diff_err = (err - ori) * 1000
diff_bet = (bet - ori) * 1000

# Plot
plt.figure(figsize=(12, 6))
plt.plot(diff_err, label='(Error - Original) × 1000', marker='o')
plt.plot(diff_bet, label='(Better - Original) × 1000', marker='x')
plt.axhline(0, color='gray', linestyle='--')
plt.title(f'Scaled Differences from Original Scores (First {n_show})')
plt.xlabel('Index')
plt.ylabel('Difference × 1000')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(scores_ori, bins=20, alpha=0.5, label='Original Scores')
plt.hist(new_label_train_error, bins=20, alpha=0.5, label='Error Labels')
plt.hist(new_label_train_better, bins=20, alpha=0.5, label='Better Labels')
plt.title('Score Distributions')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_counter = np.concatenate((y, new_label_train_better, new_label_train_error), axis=0).reshape(-1)
y_counter.shape
# Out:
# (7769,)

# %%
y = y_counter
y.shape
# Out:
# (7769,)

# %%
x_counter = np.concatenate((x,feats_counter_train_better, feats_counter_train_error), axis=0)
x_counter.shape
# Out:
# (7769, 776)

# %%
x = x_counter
x.shape
# Out:
# (7769, 776)

# %%
# REMOVE PROMPT OVERLAP & PROMPT OVERLAP (SYNONYM) FEATURES, AS THEY HAVE NEGATIVE CORRELATION WITH FINAL SCORE

# x_776 = np.delete(x, [5,6],axis=1)
# x_776.shape

# %%
# x = x_776
# x.shape

# %%
def get_feature_names_extended():
    inter_feats = ['Answer Length', 'Word Count', 'Average Word Length', 'Unique Word Count', 'Punctuation Density',
                  'Prompt Overlap', 'Prompt Overlap (synonyms)', 'Prompt Similarity SBert', 
                  'Spelling Error', 'Language Error']
    inter_feats = ['Answer Length', 'Word Count', 'Average Word Length', 'Unique Word Count', 'Punctuation Density',
                  'Prompt Similarity SBert', 
                  'Spelling Error', 'Language Error']
    
    sbert_feats = []
    sbert_dim = 768

    for i in range(0, sbert_dim):
    	fname = "sbert_" + str(i) 
    	sbert_feats.append(fname)
    
    feature_names = inter_feats + sbert_feats 

    print("len feature names: ", len(feature_names))
    
    return feature_names

feature_names = get_feature_names_extended()#[:12]
# Out:
# len feature names:  776

# %%
#joblib.dump(feature_names, 'feature_names_778')

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

kf = KFold(n_splits=5, shuffle=True, random_state=42)

print(kf)
# Out:
# KFold(n_splits=5, random_state=42, shuffle=True)

# %%
model = xgboost.XGBRegressor(objective ='reg:squarederror',
                colsample_bytree=0.4,
                 gamma=0,                 
                 learning_rate=0.05,
                 max_depth=4,
                 min_child_weight=1.5,
                 n_estimators=1000,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=42)

# ORI QWK :

# %%
qwk_scores = []

test_indices = []
pred_labels = []

for train_index, test_index in kf.split(x, y):
    
    X_train, X_test, Y_train, Y_test = x[train_index], x[test_index], y[train_index], y[test_index]
         
    model.fit(X_train, Y_train)
    
    predict = model.predict(X_test)
    predict = np.round(predict)
    
    pred_labels.extend(predict)
    test_indices.extend(test_index)
    
    result = quadratic_weighted_kappa(Y_test, predict)
    
    print("Qwk : ", result)
    print(X_train.shape)
    qwk_scores.append(result)
    
np.mean(qwk_scores)
# Out:
# Qwk :  0.9164255530707557
# (6215, 776)
# Qwk :  0.9296943884511883
# (6215, 776)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[152], line 10
#       6 for train_index, test_index in kf.split(x, y):
#       8     X_train, X_test, Y_train, Y_test = x[train_index], x[test_index], y[train_index], y[test_index]
# ---> 10     model.fit(X_train, Y_train)
#      12     predict = model.predict(X_test)
#      13     predict = np.round(predict)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:1025, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1014     obj = None
#    1016 (
#    1017     model,
#    1018     metric,
#    (...)
#    1023     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1024 )
# -> 1025 self._Booster = train(
#    1026     params,
#    1027     train_dmatrix,
#    1028     self.get_num_boosting_rounds(),
#    1029     evals=evals,
#    1030     early_stopping_rounds=early_stopping_rounds,
#    1031     evals_result=evals_result,
#    1032     obj=obj,
#    1033     custom_metric=metric,
#    1034     verbose_eval=verbose,
#    1035     xgb_model=model,
#    1036     callbacks=callbacks,
#    1037 )
#    1039 self._set_evaluation_result(evals_result)
#    1040 return self
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Only evaluate the original Test Set (without augmentation), but using new Model (trained with augmentation)

# %%
qwk_scores = []

for train_index, test_index in kf.split(x, y):
    
    X_train, X_test, Y_train, Y_test = x[train_index], x[test_index], y[train_index], y[test_index]

    # Filter test indices for those less than 1783
    test_index_baru = test_index[test_index < 1783]
    print("Filtered test indices count:", len(test_index_baru))
    
    print(X_train.shape)
    print(Y_train.shape)
    model.fit(X_train, Y_train)

    # Use test_index_baru to get filtered test sets from the original arrays
    X_test_baru = X_test[test_index < 1783]  # Correct filtering
    Y_test_baru = Y_test[test_index < 1783]  # Correct filtering

    print("Filtered X_test count:", len(X_test_baru))
    print("Filtered Y_test count:", len(Y_test_baru))
    
    predict = model.predict(X_test_baru)
    predict = np.round(predict)
    
    result = quadratic_weighted_kappa(Y_test_baru, predict)
    
    print("Qwk : ", result)
    qwk_scores.append(result)

mean_qwk = np.mean(qwk_scores)
print("Mean Qwk:", mean_qwk)
# Out:
# Filtered test indices count: 379
# (6215, 776)
# (6215,)
# Filtered X_test count: 379
# Filtered Y_test count: 379
# Qwk :  0.636588034720895
# Filtered test indices count: 361
# (6215, 776)
# (6215,)
# Filtered X_test count: 361
# Filtered Y_test count: 361
# Qwk :  0.6398161770687059
# Filtered test indices count: 346
# (6215, 776)
# (6215,)
# Filtered X_test count: 346
# Filtered Y_test count: 346
# Qwk :  0.657704534934976
# Filtered test indices count: 375
# (6215, 776)
# (6215,)
# Filtered X_test count: 375
# Filtered Y_test count: 375
# Qwk :  0.6966305227643188
# Filtered test indices count: 322
# (6216, 776)
# (6216,)
# Filtered X_test count: 322
# Filtered Y_test count: 322
# Qwk :  0.6863846225403557
# Mean Qwk: 0.6634247784058502

# %%
print(len(pred_labels))
print(len(test_indices))
# Out:
# 7983
# 7983

# %%
new_score = np.zeros(1783)
new_score
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
new_score[test_indices] = pred_labels_int
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 new_score[test_indices] = pred_labels_int
#
# NameError: name 'pred_labels_int' is not defined

# %%
new_score
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
new_score[60]
# Out:
# 0.0

# %%
#joblib.dump(new_score, 'score_model_normalized')

# %% [markdown]
# ## Create model

# %%
from sklearn.model_selection import train_test_split
indices = np.arange(len(x))
X_train, X_test, Y_train, Y_test, idx_train, idx_test = train_test_split(x, y, indices, test_size=0.2, random_state=42)

# %%
len(idx_test)
# Out:
# 1554

# %%
idx_test
# Out:
# array([1421, 2746, 3473, ...,  904, 1446, 7285])

# %%
# Filter the array for values less than 1783
new_array = idx_test[idx_test < 1783]
len(new_array)
# Out:
# 379

# %%
d_train = xgboost.DMatrix(X_train, label=Y_train, feature_names=feature_names)
d_test = xgboost.DMatrix(X_test, label=Y_test, feature_names=feature_names)

# %%
model = xgboost.train({"learning_rate": 0.05, "max_depth":4, 'alpha':0.75, 'lambda':0.45,}, d_train, 400, evals = [(d_test, "test")], early_stopping_rounds=50)
# Out:
# [0]	test-rmse:14.81797
# [1]	test-rmse:14.14191
# [2]	test-rmse:13.50179
# [3]	test-rmse:12.89156
# [4]	test-rmse:12.31113
# [5]	test-rmse:11.76118
# [6]	test-rmse:11.24306
# [7]	test-rmse:10.75408
# [8]	test-rmse:10.28509
# [9]	test-rmse:9.83669
# [10]	test-rmse:9.42267
# [11]	test-rmse:9.02933
# [12]	test-rmse:8.65786
# [13]	test-rmse:8.30098
# [14]	test-rmse:7.97196
# [15]	test-rmse:7.65837
# [16]	test-rmse:7.35597
# [17]	test-rmse:7.07069
# [18]	test-rmse:6.80574
# [19]	test-rmse:6.55965
# [20]	test-rmse:6.32882
# [21]	test-rmse:6.10371
# [22]	test-rmse:5.90004
# [23]	test-rmse:5.70723
# [24]	test-rmse:5.52046
# [25]	test-rmse:5.35103
# [26]	test-rmse:5.19679
# [27]	test-rmse:5.04104
# [28]	test-rmse:4.89621
# [29]	test-rmse:4.76413
# [30]	test-rmse:4.64291
# [31]	test-rmse:4.52076
# [32]	test-rmse:4.41636
# [33]	test-rmse:4.31468
# [34]	test-rmse:4.21990
# [35]	test-rmse:4.13738
# [36]	test-rmse:4.05895
# [37]	test-rmse:3.98367
# [38]	test-rmse:3.90824
# [39]	test-rmse:3.84295
# [40]	test-rmse:3.77115
# [41]	test-rmse:3.70704
# [42]	test-rmse:3.64959
# [43]	test-rmse:3.60015
# [44]	test-rmse:3.54424
# [45]	test-rmse:3.49538
# [46]	test-rmse:3.45533
# [47]	test-rmse:3.41050
# [48]	test-rmse:3.36689
# [49]	test-rmse:3.33396
# [50]	test-rmse:3.29830
# [51]	test-rmse:3.26800
# [52]	test-rmse:3.23250
# [53]	test-rmse:3.20232
# [54]	test-rmse:3.17093
# [55]	test-rmse:3.14725
# [56]	test-rmse:3.12687
# [57]	test-rmse:3.10359
# [58]	test-rmse:3.07787
# [59]	test-rmse:3.05251
# [60]	test-rmse:3.03205
# [61]	test-rmse:3.01706
# [62]	test-rmse:3.00082
# [63]	test-rmse:2.98855
# [64]	test-rmse:2.97489
# [65]	test-rmse:2.95836
# [66]	test-rmse:2.94400
# [67]	test-rmse:2.92738
# [68]	test-rmse:2.90885
# [69]	test-rmse:2.89410
# [70]	test-rmse:2.88364
# [71]	test-rmse:2.87267
# [72]	test-rmse:2.86271
# [73]	test-rmse:2.85409
# [74]	test-rmse:2.84236
# [75]	test-rmse:2.83186
# [76]	test-rmse:2.82291
# [77]	test-rmse:2.81012
# [78]	test-rmse:2.79779
# [79]	test-rmse:2.78880
# [80]	test-rmse:2.78292
# [81]	test-rmse:2.77255
# [82]	test-rmse:2.76208
# [83]	test-rmse:2.75290
# [84]	test-rmse:2.74319
# [85]	test-rmse:2.73838
# [86]	test-rmse:2.73186
# [87]	test-rmse:2.72473
# [88]	test-rmse:2.71349
# [89]	test-rmse:2.70686
# [90]	test-rmse:2.69764
# [91]	test-rmse:2.68764
# [92]	test-rmse:2.68192
# [93]	test-rmse:2.67773
# [94]	test-rmse:2.66543
# [95]	test-rmse:2.66012
# [96]	test-rmse:2.65593
# [97]	test-rmse:2.64566
# [98]	test-rmse:2.64091
# [99]	test-rmse:2.63136
# [100]	test-rmse:2.62711
# [101]	test-rmse:2.62007
# [102]	test-rmse:2.61650
# [103]	test-rmse:2.60945
# [104]	test-rmse:2.60410
# [105]	test-rmse:2.59979
# [106]	test-rmse:2.59684
# [107]	test-rmse:2.59113
# [108]	test-rmse:2.58601
# [109]	test-rmse:2.58188
# [110]	test-rmse:2.57663
# [111]	test-rmse:2.57207
# [112]	test-rmse:2.56877
# [113]	test-rmse:2.56367
# [114]	test-rmse:2.56097
# [115]	test-rmse:2.55758
# [116]	test-rmse:2.55559
# [117]	test-rmse:2.55391
# [118]	test-rmse:2.54808
# [119]	test-rmse:2.54610
# [120]	test-rmse:2.54267
# [121]	test-rmse:2.54077
# [122]	test-rmse:2.53765
# [123]	test-rmse:2.53276
# [124]	test-rmse:2.52999
# [125]	test-rmse:2.52266
# [126]	test-rmse:2.52040
# [127]	test-rmse:2.51458
# [128]	test-rmse:2.51030
# [129]	test-rmse:2.50704
# [130]	test-rmse:2.50255
# [131]	test-rmse:2.50018
# [132]	test-rmse:2.49592
# [133]	test-rmse:2.49097
# [134]	test-rmse:2.48595
# [135]	test-rmse:2.48159
# [136]	test-rmse:2.47795
# [137]	test-rmse:2.47385
# [138]	test-rmse:2.47015
# [139]	test-rmse:2.46648
# [140]	test-rmse:2.46397
# [141]	test-rmse:2.46014
# [142]	test-rmse:2.45818
# [143]	test-rmse:2.45459
# [144]	test-rmse:2.45219
# [145]	test-rmse:2.45043
# [146]	test-rmse:2.44747
# [147]	test-rmse:2.44523
# [148]	test-rmse:2.44254
# [149]	test-rmse:2.43917
# [150]	test-rmse:2.43204
# [151]	test-rmse:2.43044
# [152]	test-rmse:2.42613
# [153]	test-rmse:2.42394
# [154]	test-rmse:2.42084
# [155]	test-rmse:2.41763
# [156]	test-rmse:2.41468
# [157]	test-rmse:2.41309
# [158]	test-rmse:2.41211
# [159]	test-rmse:2.40855
# [160]	test-rmse:2.40724
# [161]	test-rmse:2.40405
# [162]	test-rmse:2.40128
# [163]	test-rmse:2.39957
# [164]	test-rmse:2.39644
# [165]	test-rmse:2.39154
# [166]	test-rmse:2.38816
# [167]	test-rmse:2.38693
# [168]	test-rmse:2.38469
# [169]	test-rmse:2.38271
# [170]	test-rmse:2.38090
# [171]	test-rmse:2.37950
# [172]	test-rmse:2.37686
# [173]	test-rmse:2.37286
# [174]	test-rmse:2.37103
# [175]	test-rmse:2.36998
# [176]	test-rmse:2.36751
# [177]	test-rmse:2.36490
# [178]	test-rmse:2.36232
# [179]	test-rmse:2.36099
# [180]	test-rmse:2.35974
# [181]	test-rmse:2.35725
# [182]	test-rmse:2.35516
# [183]	test-rmse:2.35353
# [184]	test-rmse:2.34993
# [185]	test-rmse:2.34769
# [186]	test-rmse:2.34301
# [187]	test-rmse:2.34141
# [188]	test-rmse:2.33895
# [189]	test-rmse:2.33675
# [190]	test-rmse:2.33176
# [191]	test-rmse:2.32924
# [192]	test-rmse:2.32747
# [193]	test-rmse:2.32563
# [194]	test-rmse:2.32441
# [195]	test-rmse:2.32117
# [196]	test-rmse:2.31951
# [197]	test-rmse:2.31733
# [198]	test-rmse:2.31572
# [199]	test-rmse:2.31379
# [200]	test-rmse:2.30895
# [201]	test-rmse:2.30747
# [202]	test-rmse:2.30624
# [203]	test-rmse:2.30384
# [204]	test-rmse:2.30190
# [205]	test-rmse:2.29900
# [206]	test-rmse:2.29746
# [207]	test-rmse:2.29329
# [208]	test-rmse:2.29261
# [209]	test-rmse:2.29062
# [210]	test-rmse:2.28907
# [211]	test-rmse:2.28560
# [212]	test-rmse:2.28172
# [213]	test-rmse:2.27946
# [214]	test-rmse:2.27679
# [215]	test-rmse:2.27579
# [216]	test-rmse:2.27375
# [217]	test-rmse:2.27125
# [218]	test-rmse:2.26999
# [219]	test-rmse:2.26790
# [220]	test-rmse:2.26559
# [221]	test-rmse:2.26395
# [222]	test-rmse:2.26112
# [223]	test-rmse:2.25966
# [224]	test-rmse:2.25795
# [225]	test-rmse:2.25535
# [226]	test-rmse:2.25455
# [227]	test-rmse:2.25337
# [228]	test-rmse:2.25140
# [229]	test-rmse:2.25047
# [230]	test-rmse:2.24869
# [231]	test-rmse:2.24846
# [232]	test-rmse:2.24768
# [233]	test-rmse:2.24646
# [234]	test-rmse:2.24482
# [235]	test-rmse:2.24371
# [236]	test-rmse:2.24141
# [237]	test-rmse:2.24042
# [238]	test-rmse:2.23917
# [239]	test-rmse:2.23841
# [240]	test-rmse:2.23680
# [241]	test-rmse:2.23473
# [242]	test-rmse:2.23161
# [243]	test-rmse:2.22987
# [244]	test-rmse:2.22778
# [245]	test-rmse:2.22675
# [246]	test-rmse:2.22577
# [247]	test-rmse:2.22327
# [248]	test-rmse:2.22233
# [249]	test-rmse:2.22146
# [250]	test-rmse:2.21838
# [251]	test-rmse:2.21701
# [252]	test-rmse:2.21563
# [253]	test-rmse:2.21445
# [254]	test-rmse:2.21385
# [255]	test-rmse:2.21139
# [256]	test-rmse:2.20799
# [257]	test-rmse:2.20587
# [258]	test-rmse:2.20334
# [259]	test-rmse:2.20243
# [260]	test-rmse:2.19920
# [261]	test-rmse:2.19608
# [262]	test-rmse:2.19422
# [263]	test-rmse:2.19311
# [264]	test-rmse:2.19242
# [265]	test-rmse:2.19162
# [266]	test-rmse:2.18996
# [267]	test-rmse:2.18904
# [268]	test-rmse:2.18696
# [269]	test-rmse:2.18604
# [270]	test-rmse:2.18484
# [271]	test-rmse:2.18287
# [272]	test-rmse:2.18033
# [273]	test-rmse:2.17934
# [274]	test-rmse:2.17906
# [275]	test-rmse:2.17842
# [276]	test-rmse:2.17668
# [277]	test-rmse:2.17530
# [278]	test-rmse:2.17394
# [279]	test-rmse:2.17360
# [280]	test-rmse:2.17316
# [281]	test-rmse:2.17160
# [282]	test-rmse:2.17048
# [283]	test-rmse:2.16985
# [284]	test-rmse:2.16694
# [285]	test-rmse:2.16403
# [286]	test-rmse:2.16148
# [287]	test-rmse:2.16041
# [288]	test-rmse:2.15843
# [289]	test-rmse:2.15663
# [290]	test-rmse:2.15630
# [291]	test-rmse:2.15534
# [292]	test-rmse:2.15484
# [293]	test-rmse:2.15423
# [294]	test-rmse:2.15284
# [295]	test-rmse:2.15245
# [296]	test-rmse:2.15095
# [297]	test-rmse:2.15031
# [298]	test-rmse:2.14735
# [299]	test-rmse:2.14602
# [300]	test-rmse:2.14352
# [301]	test-rmse:2.14240
# [302]	test-rmse:2.14019
# [303]	test-rmse:2.14001
# [304]	test-rmse:2.13915
# [305]	test-rmse:2.13854
# [306]	test-rmse:2.13715
# [307]	test-rmse:2.13559
# [308]	test-rmse:2.13478
# [309]	test-rmse:2.13399
# [310]	test-rmse:2.13276
# [311]	test-rmse:2.13209
# [312]	test-rmse:2.13063
# [313]	test-rmse:2.12998
# [314]	test-rmse:2.12785
# [315]	test-rmse:2.12760
# [316]	test-rmse:2.12532
# [317]	test-rmse:2.12477
# [318]	test-rmse:2.12257
# [319]	test-rmse:2.12215
# [320]	test-rmse:2.12081
# [321]	test-rmse:2.11949
# [322]	test-rmse:2.11831
# [323]	test-rmse:2.11774
# [324]	test-rmse:2.11698
# [325]	test-rmse:2.11466
# [326]	test-rmse:2.11274
# [327]	test-rmse:2.11105
# [328]	test-rmse:2.11105
# [329]	test-rmse:2.11086
# [330]	test-rmse:2.11029
# [331]	test-rmse:2.10811
# [332]	test-rmse:2.10722
# [333]	test-rmse:2.10584
# [334]	test-rmse:2.10528
# [335]	test-rmse:2.10516
# [336]	test-rmse:2.10437
# [337]	test-rmse:2.10335
# [338]	test-rmse:2.10283
# [339]	test-rmse:2.10230
# [340]	test-rmse:2.09979
# [341]	test-rmse:2.09785
# [342]	test-rmse:2.09747
# [343]	test-rmse:2.09672
# [344]	test-rmse:2.09569
# [345]	test-rmse:2.09379
# [346]	test-rmse:2.09262
# [347]	test-rmse:2.09080
# [348]	test-rmse:2.09007
# [349]	test-rmse:2.08899
# [350]	test-rmse:2.08783
# [351]	test-rmse:2.08694
# [352]	test-rmse:2.08496
# [353]	test-rmse:2.08464
# [354]	test-rmse:2.08476
# [355]	test-rmse:2.08224
# [356]	test-rmse:2.08189
# [357]	test-rmse:2.08044
# [358]	test-rmse:2.07878
# [359]	test-rmse:2.07860
# [360]	test-rmse:2.07698
# [361]	test-rmse:2.07657
# [362]	test-rmse:2.07655
# [363]	test-rmse:2.07540
# [364]	test-rmse:2.07482
# [365]	test-rmse:2.07468
# [366]	test-rmse:2.07440
# [367]	test-rmse:2.07307
# [368]	test-rmse:2.07300
# [369]	test-rmse:2.07176
# [370]	test-rmse:2.06998
# [371]	test-rmse:2.06819
# [372]	test-rmse:2.06765
# [373]	test-rmse:2.06667
# [374]	test-rmse:2.06539
# [375]	test-rmse:2.06517
# [376]	test-rmse:2.06409
# [377]	test-rmse:2.06340
# [378]	test-rmse:2.06288
# [379]	test-rmse:2.06203
# [380]	test-rmse:2.06167
# [381]	test-rmse:2.06141
# [382]	test-rmse:2.06062
# [383]	test-rmse:2.05895
# [384]	test-rmse:2.05865
# [385]	test-rmse:2.05765
# [386]	test-rmse:2.05661
# [387]	test-rmse:2.05606
# [388]	test-rmse:2.05522
# [389]	test-rmse:2.05466
# [390]	test-rmse:2.05401
# [391]	test-rmse:2.05375
# [392]	test-rmse:2.05333
# [393]	test-rmse:2.05175
# [394]	test-rmse:2.05117
# [395]	test-rmse:2.05102
# [396]	test-rmse:2.05043
# [397]	test-rmse:2.04973
# [398]	test-rmse:2.04895
# [399]	test-rmse:2.04809

# %%
yxgb_pred = model.predict(d_test)
yxgb_pred = np.round(yxgb_pred)

# %%
accuracy_score(yxgb_pred, np.round(Y_test))
# Out:
# 0.2503217503217503

# %%
quadratic_weighted_kappa(yxgb_pred, Y_test)
# Out:
# 0.9032978246018754

# %%
joblib.dump(model, 'files/model_asap7_776_counter_both_ori_adjusted_taper')
# Out:
# ['files/model_asap7_776_counter_both_ori_adjusted_taper']

# %% [markdown]
# ## Model interpretation

# %%
imp_vals = model.get_fscore()
#print(imp_vals)
feature_important = model.get_score(importance_type='weight')
feats_sorted = sorted(feature_important.items(), key=lambda x: x[1], reverse=True)
aa_25 = feats_sorted[:25]

# %%
x_axis = [i[0] for i in aa_25]
y_axis = [i[1] for i in aa_25]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,25))
plt.title("GB Best-25 Features", fontsize=40)
plt.bar(x_axis, y_axis, width=0.8, align='center')
plt.xticks(x_axis, fontsize=40, rotation=80)
plt.ylabel("F Score", fontsize=40)
plt.yticks(fontsize=40)
plt.tight_layout()
plt.savefig('gb_best_25.png')
plt.show()

# %% [markdown]
# ### Get Testing Data

# %%
import joblib

# %%
asap1 = joblib.load('files/asap1_essay')

# %%
len(asap1)
# Out:
# 1783

# %%
asap1
# Out:
#       essay_id                                              essay  \
# 0            1  Dear local newspaper, I think effects computer...
# 1            2  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2            3  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3            4  Dear Local Newspaper, @CAPS1 I have found that...
# 4            5  Dear @LOCATION1, I know having computers has a...
# ...        ...                                                ...
# 1778      1783  Dear @CAPS1, @CAPS2 several reasons on way I t...
# 1779      1784  Do a adults and kids spend to much time on the...
# 1780      1785  My opinion is that people should have computer...
# 1781      1786  Dear readers, I think that its good and bad to...
# 1782      1787  Dear - Local Newspaper I agree thats computers...
#
#       domain1_score
# 0                 8
# 1                 9
# 2                 7
# 3                10
# 4                 8
# ...             ...
# 1778              8
# 1779              7
# 1780              8
# 1781              2
# 1782              7
#
# [1783 rows x 3 columns]

# %%
type(asap1)
# Out:
# pandas.core.frame.DataFrame

# %%
asap1_test = asap1.iloc[idx_test]

# %%
len(asap1_test)
# Out:
# 357

# %%
#asap1_test

# %%
asap1_test.to_csv('ASAP1 Test Set.tsv', index=False, sep='\t')

# %%
df = pd.read_csv('ASAP1 Test Set.tsv', sep='\t', encoding = "ISO-8859-1")

# %% [markdown]
# ### Get Training Data

# %%
asap1_train = asap1.iloc[idx_train]

# %%
len(asap1_train)
# Out:
# 1426

# %%
asap1_train.to_csv('ASAP1 Train Set.tsv', index=False, sep='\t')

# %%
df = pd.read_csv('ASAP1 Train Set.tsv', sep='\t', encoding = "ISO-8859-1")

# %%
import itertools 

n = 4 # OPEN AI GIVES A LOT OF SUGGESTIONS
numbers = range(1, n + 1) 

ctr = 0
for length in range(1, n + 1):
    print("Combination with length: ", length)
    combinations = itertools.combinations(numbers, length)
    delta = 0.4 * length  # Adjust delta based on length
    delta = round(delta, 2)
    for combo in combinations:
        print(combo)
        ctr += 1

print("Total number: ", ctr)
# Out:
# Combination with length:  1
# (1,)
# (2,)
# (3,)
# (4,)
# Combination with length:  2
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 4)
# Combination with length:  3
# (1, 2, 3)
# (1, 2, 4)
# (1, 3, 4)
# (2, 3, 4)
# Combination with length:  4
# (1, 2, 3, 4)
# Total number:  15

# %%
FROM 1 ESSAY --> we generate 31 new better essays --> Why 31 --> 2^n - 1 --> 2 ^ 5 -1 = 31

# %%
I TOOK 100 ESSAYS RANDOMLY --> 3100 NEW BETTER ESSAYS --> WE NEED NEW LABELS FOR THOSE 3100 DATA

# %%
THEN, WE DO THE SAME FROM EXACTLY THE SAME 100 ESSAYS --> BUT NOW WORSE ESSAYS --> 3100 NEW ESSAYS

# %%
SO, IN THE END WE HAVE 6200 AUGMENTATION DATA
THE ORIGINAL ESSAYS ARE ONLY 1700 DATA

# %%
n = 5
numbers = range(1, n + 1)  # Numbers from 1 to 5
ctr = 0

for i in range(len(new_label_train_error)):
    # Generate combinations of varying lengths
    idx = 0
    for length in range(1, n + 1):
        combinations = itertools.combinations(numbers, length)
        delta = 0.3 * length  # Adjust delta based on length
        delta = round(delta, 2)
        for combo in combinations:
            new_label_train_error[i][idx] -= delta
            print(combo)
            idx += 1

# %%
import itertools
n = 4
numbers = range(1, n + 1)
ctr = 0

for length in range(1, n + 1):
    combinations = itertools.combinations(numbers, length)
    print("length: ", length)
    for combo in combinations:
        print(combo)
        ctr += 1
print("Total : ", ctr)
# Out:
# length:  1
# (1,)
# (2,)
# (3,)
# (4,)
# length:  2
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 4)
# length:  3
# (1, 2, 3)
# (1, 2, 4)
# (1, 3, 4)
# (2, 3, 4)
# length:  4
# (1, 2, 3, 4)
# Total :  15

# %%
import itertools
n = 5
numbers = range(1, n + 1)
ctr = 0

for length in range(1, n + 1):
    combinations = math.comb(len(numbers), length)
    print("length: ", length)
    for j in range(combinations):
        print(length)
        ctr += 1
print("Total : ", ctr)
# Out:
# length:  1
# 1
# 1
# 1
# 1
# 1
# length:  2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# length:  3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# length:  4
# 4
# 4
# 4
# 4
# 4
# length:  5
# 5
# Total :  31

# %%
import math

def binomial(n, k):
    return math.comb(n, k)

def cumulative_sums(n):
    S = [0]  # S(0) = 0
    for k in range(1, n + 1):
        S.append(S[k - 1] + binomial(n, k))  # Cumulative sum
    return S

def generate_k_array(n):
    S = cumulative_sums(n)  # Get cumulative sums
    print(S)
    result = []
    
    for i in range(S[-1]):  # Iterate up to the total number of combinations
        for k in range(1, n + 1):
            if S[k - 1] <= i < S[k]:
                result.append(k)  # Append the current k
                break  # Move to the next index

    return result

# Example usage
n = 4
k_array = generate_k_array(n)
print(k_array)
# Out:
# 0
# 4
# 10
# 14
# [0, 4, 10, 14, 15]
# [1, 1, 1, 1, 2, 2, 2, 2, 2, 2, 3, 3, 3, 3, 4]

# %%
binomial(4,2)
# Out:
# 6

# %%
cumulative_sums(4)
# Out:
# S[k-1] :  0
# n :  4 k :  1
# S[k-1] :  4
# n :  4 k :  2
# S[k-1] :  10
# n :  4 k :  3
# S[k-1] :  14
# n :  4 k :  4
# [0, 4, 10, 14, 15]
