# %%
import joblib
import pandas as pd
import nltk
import re
import itertools
import random
import numpy as np

# %%
data = pd.read_csv('ASAP1 Train Set.tsv', sep='\t')
data_100 = data[:100]
data_100.head()
# Out:
#    essay_id                                              essay  domain1_score
# 0       176  Computers and the @CAPS1 were a technological ...             10
# 1       632  People using computers is a good way for them ...             10
# 2      1108  Dear local newspaper, @CAPS1 you can see, abou...              9
# 3      1747  Dear local Newspaper, I think computer technog...              8
# 4      1016  Dear @CAPS1 @CAPS2, More and more people use c...              8

# %%
corrections = joblib.load('files/json_responses_train_100')
#correction_train_100essay_5corr = joblib.load('correction_train_100essay_5corr')

# %%
# Function to sample 5 dictionaries from each inner list
def sample_five_from_each(inner_lists):
    return [random.sample(inner_list, min(len(inner_list), 5)) for inner_list in inner_lists]

# Sample 5 dictionaries from each inner list
sampled_corrections = sample_five_from_each(corrections)

print(np.array(sampled_corrections).shape)

# Print the results
for idx, sampled_list in enumerate(sampled_corrections):
    print(f"Sampled data for list {idx + 1}:")
    for item in sampled_list:
        print(item)
    print()
# Out:
# (100, 5)
# Sampled data for list 1:
# {'original': 'meton', 'correction': 'met on', 'type': 'Spelling', 'sentence': 10}
# {'original': 'offose', 'correction': 'oppose', 'type': 'Spelling', 'sentence': 4}
# {'original': 'then', 'correction': 'them', 'type': 'Spelling', 'sentence': 12}
# {'original': 'main cause to', 'correction': 'main cause of', 'type': 'Word Choice', 'sentence': 7}
# {'original': 'cutt', 'correction': 'cut', 'type': 'Spelling', 'sentence': 19}
#
# Sampled data for list 2:
# {'original': 'reccommend', 'correction': 'recommend', 'type': 'Spelling', 'sentence': 5}
# {'original': 'milli-seconds', 'correction': 'milliseconds', 'type': 'Spelling', 'sentence': 3}
# {'original': 'woh', 'correction': 'who', 'type': 'Spelling', 'sentence': 12}
# {'original': 'wonder ful', 'correction': 'wonderful', 'type': 'Spelling', 'sentence': 2}
# {'original': 'let', 'correction': 'lets', 'type': 'Grammatical', 'sentence': 8}
#
# Sampled data for list 3:
# {'original': 'to:', 'correction': 'too,', 'type': 'Punctuation', 'sentence': 27}
# {'original': 'over weight', 'correction': 'overweight', 'type': 'Spelling', 'sentence': 28}
# {'original': 'benificial', 'correction': 'beneficial', 'type': 'Spelling', 'sentence': 38}
# {'original': 'update', 'correction': 'updated', 'type': 'Grammatical', 'sentence': 15}
# {'original': 'Family lives', 'correction': 'Families live', 'type': 'Grammatical', 'sentence': 5}
#
# Sampled data for list 4:
# {'original': 'cordanation', 'correction': 'coordination', 'type': 'Spelling', 'sentence': 6}
# {'original': 'freinds', 'correction': 'friends', 'type': 'Spelling', 'sentence': 12}
# {'original': 'onlone', 'correction': 'online', 'type': 'Spelling', 'sentence': 3}
# {'original': 'cordination', 'correction': 'coordination', 'type': 'Spelling', 'sentence': 16}
# {'original': 'our', 'correction': 'are', 'type': 'Grammatical', 'sentence': 14}
#
# Sampled data for list 5:
# {'original': 'defenitly', 'correction': 'definitely', 'type': 'Spelling', 'sentence': 14}
# {'original': 'the thing', 'correction': 'the things', 'type': 'Grammatical', 'sentence': 13}
# {'original': 'theose', 'correction': 'those', 'type': 'Spelling', 'sentence': 1}
# {'original': 'now', 'correction': 'say now', 'type': 'Grammatical', 'sentence': 20}
# {'original': 'Hopfully', 'correction': 'Hopefully', 'type': 'Spelling', 'sentence': 18}
#
# Sampled data for list 6:
# {'original': 'their', 'correction': "they're", 'type': 'Grammatical', 'sentence': 8}
# {'original': 'Also, after taking a poll.', 'correction': 'Also, after taking a poll,', 'type': 'Grammatical', 'sentence': 17}
# {'original': 'everyday', 'correction': 'every day', 'type': 'Word Choice', 'sentence': 22}
# {'original': 'elementary - schoolers', 'correction': 'elementary-schoolers', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'much much', 'correction': 'much, much', 'type': 'Grammatical', 'sentence': 15}
#
# Sampled data for list 7:
# {'original': 'reasearch', 'correction': 'research', 'type': 'Spelling', 'sentence': 9}
# {'original': 'got', 'correction': 'get', 'type': 'Grammatical', 'sentence': 15}
# {'original': 'unless then', 'correction': 'in less than', 'type': 'Word Choice', 'sentence': 14}
# {'original': "Doesn't computers", 'correction': "Don't computers", 'type': 'Grammatical', 'sentence': 18}
# {'original': 'alway', 'correction': 'always', 'type': 'Spelling', 'sentence': 37}
#
# Sampled data for list 8:
# {'original': 'a flash card', 'correction': 'and flash cards', 'type': 'Grammatical', 'sentence': 18}
# {'original': 'quicker easier', 'correction': 'quicker and easier', 'type': 'Grammatical', 'sentence': 27}
# {'original': 'othe', 'correction': 'other', 'type': 'Spelling', 'sentence': 20}
# {'original': 'skype', 'correction': 'Skype', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'buy', 'correction': 'by', 'type': 'Spelling', 'sentence': 18}
#
# Sampled data for list 9:
# {'original': 'agrees', 'correction': 'agree', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'christmas', 'correction': 'Christmas', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'families', 'correction': 'family', 'type': 'Word Choice', 'sentence': 14}
# {'original': 'whats so ever', 'correction': 'whatsoever', 'type': 'Spelling', 'sentence': 24}
# {'original': 'neice', 'correction': 'niece', 'type': 'Spelling', 'sentence': 11}
#
# Sampled data for list 10:
# {'original': 'not getting', 'correction': 'not to get', 'type': 'Grammatical', 'sentence': 37}
# {'original': 'you family', 'correction': 'your family', 'type': 'Grammatical', 'sentence': 35}
# {'original': 'infromation', 'correction': 'information', 'type': 'Spelling', 'sentence': 5}
# {'original': 'sourse', 'correction': 'source', 'type': 'Spelling', 'sentence': 5}
# {'original': 'guled', 'correction': 'glued', 'type': 'Spelling', 'sentence': 14}
#
# Sampled data for list 11:
# {'original': 'librarys', 'correction': 'libraries', 'type': 'Spelling', 'sentence': 33}
# {'original': 'Oviously', 'correction': 'Obviously', 'type': 'Spelling', 'sentence': 28}
# {'original': 'peole', 'correction': 'people', 'type': 'Spelling', 'sentence': 18}
# {'original': 'scaresly', 'correction': 'scarcely', 'type': 'Spelling', 'sentence': 26}
# {'original': 'strength', 'correction': 'strengthen', 'type': 'Grammatical', 'sentence': 10}
#
# Sampled data for list 12:
# {'original': 'convinent', 'correction': 'convenient', 'type': 'Spelling', 'sentence': 3}
# {'original': 'convinent', 'correction': 'convenient', 'type': 'Spelling', 'sentence': 11}
# {'original': 'bored', 'correction': 'bored?', 'type': 'Grammatical', 'sentence': 13}
# {'original': 'enteratinment', 'correction': 'entertainment', 'type': 'Spelling', 'sentence': 23}
# {'original': 'talk', 'correction': 'talks', 'type': 'Grammatical', 'sentence': 18}
#
# Sampled data for list 13:
# {'original': 'amont', 'correction': 'amount', 'type': 'Spelling', 'sentence': 10}
# {'original': 'useing', 'correction': 'using', 'type': 'Spelling', 'sentence': 4}
# {'original': 'shure', 'correction': 'sure', 'type': 'Spelling', 'sentence': 11}
# {'original': 'enuf', 'correction': 'enough', 'type': 'Spelling', 'sentence': 11}
# {'original': 'computors', 'correction': 'computers', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 14:
# {'original': 'layeris', 'correction': 'layer is', 'type': 'Spelling', 'sentence': 29}
# {'original': 'predilors', 'correction': 'predators', 'type': 'Spelling', 'sentence': 10}
# {'original': 'internent', 'correction': 'internet', 'type': 'Spelling', 'sentence': 7}
# {'original': 'toxix', 'correction': 'toxic', 'type': 'Spelling', 'sentence': 21}
# {'original': 'benifit', 'correction': 'benefit', 'type': 'Spelling', 'sentence': 30}
#
# Sampled data for list 15:
# {'original': 'there', 'correction': 'their', 'type': 'Grammatical', 'sentence': 25}
# {'original': 'now a days', 'correction': 'nowadays', 'type': 'Spelling', 'sentence': 20}
# {'original': 'now a days', 'correction': 'nowadays', 'type': 'Spelling', 'sentence': 2}
# {'original': 'everyday', 'correction': 'every day', 'type': 'Word Choice', 'sentence': 9}
# {'original': 'obeast', 'correction': 'obese', 'type': 'Spelling', 'sentence': 19}
#
# Sampled data for list 16:
# {'original': 'exersize', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 17}
# {'original': 'exmaple', 'correction': 'example', 'type': 'Spelling', 'sentence': 20}
# {'original': 'to computers', 'correction': 'computers', 'type': 'Grammatical', 'sentence': 25}
# {'original': 'the', 'correction': 'their', 'type': 'Grammatical', 'sentence': 16}
# {'original': 'exersize', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 16}
#
# Sampled data for list 17:
# {'original': 'the the', 'correction': 'the', 'type': 'Grammatical', 'sentence': 13}
# {'original': "don't live", 'correction': "who don't live", 'type': 'Grammatical', 'sentence': 17}
# {'original': 'teach to kids kids', 'correction': 'teach kids, kids', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'In conclusions', 'correction': 'In conclusion', 'type': 'Grammatical', 'sentence': 24}
# {'original': 'to but', 'correction': 'too, but', 'type': 'Grammatical', 'sentence': 6}
#
# Sampled data for list 18:
# {'original': 'be looking', 'correction': 'are looking', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'Thats', 'correction': "That's", 'type': 'Grammatical', 'sentence': 5}
# {'original': 'you', 'correction': 'your', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'olny', 'correction': 'only', 'type': 'Spelling', 'sentence': 14}
# {'original': 'be happend', 'correction': 'happens', 'type': 'Grammatical', 'sentence': 8}
#
# Sampled data for list 19:
# {'original': 'there', 'correction': 'their', 'type': 'Word Choice', 'sentence': 7}
# {'original': 'for their life', 'correction': 'for their lives', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'poeple', 'correction': 'people', 'type': 'Spelling', 'sentence': 16}
# {'original': 'mantain', 'correction': 'maintain', 'type': 'Spelling', 'sentence': 5}
# {'original': 'uisng', 'correction': 'using', 'type': 'Spelling', 'sentence': 7}
#
# Sampled data for list 20:
# {'original': 'geting', 'correction': 'getting', 'type': 'Spelling', 'sentence': 13}
# {'original': 'somtimes', 'correction': 'sometimes', 'type': 'Spelling', 'sentence': 11}
# {'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 8}
# {'original': 'infront', 'correction': 'in front', 'type': 'Spelling', 'sentence': 15}
# {'original': 'effect', 'correction': 'affect', 'type': 'Word Choice', 'sentence': 7}
#
# Sampled data for list 21:
# {'original': 'however', 'correction': 'but', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'have', 'correction': 'has', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'It can be seen, how', 'correction': 'It can be seen how', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'boxes of ten', 'correction': 'boxes often', 'type': 'Spelling', 'sentence': 22}
# {'original': 'Finally the obesity rate', 'correction': 'Finally, the obesity rate', 'type': 'Grammatical', 'sentence': 21}
#
# Sampled data for list 22:
# {'original': 'are', 'correction': 'is', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'proffestional', 'correction': 'professional', 'type': 'Spelling', 'sentence': 9}
# {'original': 'there', 'correction': 'their', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'coutries', 'correction': 'countries', 'type': 'Spelling', 'sentence': 16}
# {'original': 'othe', 'correction': 'other', 'type': 'Spelling', 'sentence': 5}
#
# Sampled data for list 23:
# {'original': 'ANd', 'correction': 'And', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'hapy', 'correction': 'happy', 'type': 'Spelling', 'sentence': 14}
# {'original': 'on computer', 'correction': 'on the computer', 'type': 'Grammatical', 'sentence': 21}
# {'original': 'exercising', 'correction': 'exercise', 'type': 'Grammatical', 'sentence': 12}
# {'original': 'program', 'correction': 'programs', 'type': 'Grammatical', 'sentence': 11}
#
# Sampled data for list 24:
# {'original': 'computor', 'correction': 'computer', 'type': 'Spelling', 'sentence': 5}
# {'original': 'computors', 'correction': 'computers', 'type': 'Spelling', 'sentence': 26}
# {'original': 'computors', 'correction': 'computers', 'type': 'Spelling', 'sentence': 1}
# {'original': 'plain', 'correction': 'plainly', 'type': 'Word Choice', 'sentence': 9}
# {'original': 'than', 'correction': 'then', 'type': 'Word Choice', 'sentence': 24}
#
# Sampled data for list 25:
# {'original': 'where could you get', 'correction': 'where would you get', 'type': 'Word Choice', 'sentence': 6}
# {'original': 'One you can use them', 'correction': 'First, you can use them', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'from a it', 'correction': 'from a book, it', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'you you have', 'correction': 'you with what you have', 'type': 'Grammatical', 'sentence': 16}
# {'original': 'then', 'correction': 'than', 'type': 'Grammatical', 'sentence': 21}
#
# Sampled data for list 26:
# {'original': 'it', 'correction': 'them', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'either', 'correction': 'whether', 'type': 'Word Choice', 'sentence': 30}
# {'original': 'the the', 'correction': 'the', 'type': 'Grammatical', 'sentence': 31}
# {'original': 'Now-a-days', 'correction': 'Nowadays', 'type': 'Spelling', 'sentence': 10}
# {'original': 'for', 'correction': 'to find', 'type': 'Word Choice', 'sentence': 30}
#
# Sampled data for list 27:
# {'original': 'efficently', 'correction': 'efficiently', 'type': 'Spelling', 'sentence': 1}
# {'original': 'being stuck', 'correction': 'we were stuck', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'an organization that assists in global disasters comes from online.', 'correction': 'an organization that assists in global disasters, comes from online donations.', 'type': 'Grammatical', 'sentence': 6}
# {'original': "@CAPS5't", 'correction': "Shouldn't", 'type': 'Grammatical', 'sentence': 16}
# {'original': 'we would be last', 'correction': 'we would be lost', 'type': 'Word Choice', 'sentence': 26}
#
# Sampled data for list 28:
# {'original': 'innappropriate', 'correction': 'inappropriate', 'type': 'Spelling', 'sentence': 26}
# {'original': 'Governer', 'correction': 'Governor', 'type': 'Spelling', 'sentence': 29}
# {'original': 'on and on', 'correction': 'continuously', 'type': 'Word Choice', 'sentence': 7}
# {'original': 'on', 'correction': 'one', 'type': 'Spelling', 'sentence': 8}
# {'original': 'embarrasing', 'correction': 'embarrassing', 'type': 'Spelling', 'sentence': 26}
#
# Sampled data for list 29:
# {'original': 'excersize', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 23}
# {'original': 'is', 'correction': 'are', 'type': 'Grammatical', 'sentence': 20}
# {'original': 'faraway', 'correction': 'far-away', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'naturistic', 'correction': 'natural', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'everyday', 'correction': 'every day', 'type': 'Word Choice', 'sentence': 18}
#
# Sampled data for list 30:
# {'original': 'bullyed', 'correction': 'bullied', 'type': 'Spelling', 'sentence': 5}
# {'original': 'thing', 'correction': 'things', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'game', 'correction': 'games', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'their', 'correction': 'there', 'type': 'Word Choice', 'sentence': 11}
#
# Sampled data for list 31:
# {'original': 'biusness', 'correction': 'business', 'type': 'Spelling', 'sentence': 9}
# {'original': 'technoligy', 'correction': 'technology', 'type': 'Spelling', 'sentence': 26}
# {'original': 'unhealty', 'correction': 'unhealthy', 'type': 'Spelling', 'sentence': 19}
# {'original': 'to much', 'correction': 'too much', 'type': 'Grammatical', 'sentence': 19}
# {'original': 'amuzed', 'correction': 'amused', 'type': 'Spelling', 'sentence': 15}
#
# Sampled data for list 32:
# {'original': 'wont', 'correction': 'want', 'type': 'Spelling', 'sentence': 19}
# {'original': 'yuorself', 'correction': 'yourself', 'type': 'Spelling', 'sentence': 21}
# {'original': 'Basicly', 'correction': 'Basically', 'type': 'Spelling', 'sentence': 14}
# {'original': 'ur', 'correction': 'your', 'type': 'Spelling', 'sentence': 9}
# {'original': 'interet', 'correction': 'internet', 'type': 'Spelling', 'sentence': 18}
#
# Sampled data for list 33:
# {'original': 'me go', 'correction': 'me', 'type': 'Other', 'sentence': 6}
# {'original': 'everyday', 'correction': 'every day', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 5}
# {'original': 'their', 'correction': 'there', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'then', 'correction': 'them', 'type': 'Spelling', 'sentence': 15}
#
# Sampled data for list 34:
# {'original': 'far away', 'correction': 'faraway', 'type': 'Word Choice', 'sentence': 13}
# {'original': 'far away', 'correction': 'faraway', 'type': 'Word Choice', 'sentence': 3}
# {'original': "month's", 'correction': 'months', 'type': 'Grammatical', 'sentence': 19}
# {'original': 'us learn', 'correction': 'us to learn', 'type': 'Grammatical', 'sentence': 26}
# {'original': 'video taping a posting', 'correction': 'videotaping and posting', 'type': 'Grammatical', 'sentence': 24}
#
# Sampled data for list 35:
# {'original': 'you', 'correction': 'You', 'type': 'Grammatical', 'sentence': 8}
# {'original': 'the matter of seconds', 'correction': 'a matter of seconds', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'cant', 'correction': "can't", 'type': 'Grammatical', 'sentence': 21}
# {'original': 'teaches you homework that you did', 'correction': 'it helps you with homework', 'type': 'Grammatical', 'sentence': 22}
# {'original': 'many', 'correction': 'money', 'type': 'Spelling', 'sentence': 16}
#
# Sampled data for list 36:
# {'original': 'futiristic', 'correction': 'futuristic', 'type': 'Spelling', 'sentence': 2}
# {'original': 'Compuers', 'correction': 'Computers', 'type': 'Spelling', 'sentence': 21}
# {'original': 'peoples', 'correction': "people's", 'type': 'Grammatical', 'sentence': 21}
# {'original': 'suceed', 'correction': 'succeed', 'type': 'Spelling', 'sentence': 6}
# {'original': 'habbit', 'correction': 'habit', 'type': 'Spelling', 'sentence': 8}
#
# Sampled data for list 37:
# {'original': 'in side', 'correction': 'inside', 'type': 'Spelling', 'sentence': 23}
# {'original': 'But why do some people think that it is hurting our society.', 'correction': 'But why do some people think that it is hurting our society?', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'effect', 'correction': 'affect', 'type': 'Word Choice', 'sentence': 26}
# {'original': 'So how could those things be harmful to society.', 'correction': 'So how could those things be harmful to society?', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'a job.', 'correction': 'jobs.', 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 38:
# {'original': 'speed', 'correction': 'spend', 'type': 'Spelling', 'sentence': 9}
# {'original': 'flies', 'correction': 'files', 'type': 'Spelling', 'sentence': 4}
# {'original': 'to to', 'correction': 'to', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'communy', 'correction': 'community', 'type': 'Spelling', 'sentence': 10}
# {'original': 'you', 'correction': 'your', 'type': 'Grammatical', 'sentence': 8}
#
# Sampled data for list 39:
# {'original': 'gives', 'correction': 'give', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'contries', 'correction': 'countries', 'type': 'Spelling', 'sentence': 6}
# {'original': '@MONTH1', 'correction': 'may', 'type': 'Word Choice', 'sentence': 20}
# {'original': 'see it on @CAPS1.V.', 'correction': 'see it on TV.', 'type': 'Word Choice', 'sentence': 7}
# {'original': 'be unite', 'correction': 'being united', 'type': 'Grammatical', 'sentence': 17}
#
# Sampled data for list 40:
# {'original': 'spened', 'correction': 'spend', 'type': 'Spelling', 'sentence': 3}
# {'original': 'test', 'correction': 'tests', 'type': 'Grammatical', 'sentence': 13}
# {'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 11}
# {'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 25}
# {'original': 'forget', 'correction': 'forgot', 'type': 'Grammatical', 'sentence': 16}
#
# Sampled data for list 41:
# {'original': 'there', 'correction': 'their', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'becuse', 'correction': 'because', 'type': 'Spelling', 'sentence': 39}
# {'original': 'at young a young age', 'correction': 'at a young age', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'realized', 'correction': 'realize', 'type': 'Grammatical', 'sentence': 20}
# {'original': 'family guy', 'correction': 'Family Guy', 'type': 'Grammatical', 'sentence': 35}
#
# Sampled data for list 42:
# {'original': 'Computer', 'correction': 'Computers', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'then do they exercise', 'correction': 'then they do not exercise', 'type': 'Grammatical', 'sentence': 15}
# {'original': 'affect', 'correction': 'effect', 'type': 'Word Choice', 'sentence': 27}
# {'original': 'graet', 'correction': 'great', 'type': 'Spelling', 'sentence': 22}
# {'original': 'days', 'correction': 'rays', 'type': 'Word Choice', 'sentence': 12}
#
# Sampled data for list 43:
# {'original': 'past', 'correction': 'pass', 'type': 'Word Choice', 'sentence': 38}
# {'original': 'weeked', 'correction': 'weekend', 'type': 'Spelling', 'sentence': 14}
# {'original': 'This an', 'correction': 'This is an', 'type': 'Grammatical', 'sentence': 50}
# {'original': 'computer', 'correction': 'computers', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'payed', 'correction': 'paid', 'type': 'Spelling', 'sentence': 27}
#
# Sampled data for list 44:
# {'original': 'oponion', 'correction': 'opinion', 'type': 'Spelling', 'sentence': 4}
# {'original': 'Thats', 'correction': "That's", 'type': 'Grammatical', 'sentence': 12}
# {'original': 'todays', 'correction': "today's", 'type': 'Grammatical', 'sentence': 2}
# {'original': 'likley', 'correction': 'likely', 'type': 'Spelling', 'sentence': 16}
# {'original': 'in', 'correction': 'and', 'type': 'Grammatical', 'sentence': 5}
#
# Sampled data for list 45:
# {'original': 'gives', 'correction': 'give', 'type': 'Grammatical', 'sentence': 17}
# {'original': 'Not', 'correction': 'not', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'your', 'correction': "you're", 'type': 'Grammatical', 'sentence': 11}
# {'original': 'on the for a while', 'correction': 'on the computer for a while', 'type': 'Grammatical', 'sentence': 23}
# {'original': 'you their', 'correction': 'use their', 'type': 'Grammatical', 'sentence': 24}
#
# Sampled data for list 46:
# {'original': 'everytime', 'correction': 'every time', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'corporal', 'correction': 'corporate', 'type': 'Word Choice', 'sentence': 36}
# {'original': 'youtube', 'correction': 'YouTube', 'type': 'Spelling', 'sentence': 19}
# {'original': 'must have', 'correction': 'must-have', 'type': 'Grammatical', 'sentence': 27}
# {'original': 'yousupposed', 'correction': 'you supposed', 'type': 'Grammatical', 'sentence': 20}
#
# Sampled data for list 47:
# {'original': 'along', 'correction': 'a long', 'type': 'Spelling', 'sentence': 20}
# {'original': 'commertials', 'correction': 'commercials', 'type': 'Spelling', 'sentence': 17}
# {'original': 'waiting', 'correction': 'writing', 'type': 'Spelling', 'sentence': 2}
# {'original': 'ect', 'correction': 'etc.', 'type': 'Spelling', 'sentence': 18}
# {'original': 'avertisements', 'correction': 'advertisements', 'type': 'Spelling', 'sentence': 17}
#
# Sampled data for list 48:
# {'original': 'There', 'correction': "They're", 'type': 'Grammatical', 'sentence': 30}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 11}
# {'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 12}
# {'original': 'alows', 'correction': 'allows', 'type': 'Spelling', 'sentence': 36}
# {'original': 'there', 'correction': 'their', 'type': 'Grammatical', 'sentence': 24}
#
# Sampled data for list 49:
# {'original': 'I think its very bad', 'correction': 'are very bad', 'type': 'Grammatical', 'sentence': 12}
# {'original': 'come down stairs', 'correction': 'come downstairs', 'type': 'Word Choice', 'sentence': 6}
# {'original': 'out a less time', 'correction': 'for less time', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'lost', 'correction': 'lose', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'of electrical bill', 'correction': 'on electrical bills', 'type': 'Word Choice', 'sentence': 10}
#
# Sampled data for list 50:
# {'original': 'get it done without the computers', 'correction': 'get it done', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'Were', 'correction': 'Where', 'type': 'Spelling', 'sentence': 3}
# {'original': 'computer', 'correction': 'computers', 'type': 'Grammatical', 'sentence': 8}
# {'original': 'go sign up', 'correction': 'sign up', 'type': 'Grammatical', 'sentence': 18}
# {'original': 'have hogged', 'correction': 'may hog', 'type': 'Word Choice', 'sentence': 13}
#
# Sampled data for list 51:
# {'original': 'everytime', 'correction': 'every time', 'type': 'Spelling', 'sentence': 25}
# {'original': 'laer', 'correction': 'later', 'type': 'Spelling', 'sentence': 33}
# {'original': 'more easy', 'correction': 'easier', 'type': 'Word Choice', 'sentence': 11}
# {'original': 'whta', 'correction': 'what', 'type': 'Spelling', 'sentence': 35}
# {'original': 'a awesome', 'correction': 'an awesome', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 52:
# {'original': 'gosep', 'correction': 'gossip', 'type': 'Spelling', 'sentence': 7}
# {'original': 'peopel', 'correction': 'people', 'type': 'Spelling', 'sentence': 9}
# {'original': 'Lstly', 'correction': 'Lastly', 'type': 'Spelling', 'sentence': 4}
# {'original': 'hard use too', 'correction': 'hard to get used to', 'type': 'Grammatical', 'sentence': 19}
# {'original': 'beign', 'correction': 'being', 'type': 'Spelling', 'sentence': 19}
#
# Sampled data for list 53:
# {'original': 'bann', 'correction': 'ban', 'type': 'Spelling', 'sentence': 28}
# {'original': 'messangers', 'correction': 'messages', 'type': 'Spelling', 'sentence': 24}
# {'original': 'everyday', 'correction': 'every day', 'type': 'Word Choice', 'sentence': 8}
# {'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 4}
# {'original': 'a size fourteen in waist', 'correction': 'a size fourteen in the waist', 'type': 'Grammatical', 'sentence': 12}
#
# Sampled data for list 54:
# {'original': 'effect', 'correction': 'affect', 'type': 'Word Choice', 'sentence': 1}
# {'original': "kid's", 'correction': 'kids', 'type': 'Grammatical', 'sentence': 4}
# {'original': "agree's", 'correction': 'agrees', 'type': 'Grammatical', 'sentence': 5}
# {'original': "freind's", 'correction': 'friends', 'type': 'Spelling', 'sentence': 7}
# {'original': 'youv', 'correction': "you've", 'type': 'Grammatical', 'sentence': 11}
#
# Sampled data for list 55:
# {'original': 'inernet', 'correction': 'internet', 'type': 'Spelling', 'sentence': 13}
# {'original': 'at', 'correction': 'of', 'type': 'Word Choice', 'sentence': 10}
# {'original': 'exerise', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 10}
# {'original': 'healty', 'correction': 'healthy', 'type': 'Spelling', 'sentence': 6}
# {'original': 'conforts', 'correction': 'comforts', 'type': 'Spelling', 'sentence': 10}
#
# Sampled data for list 56:
# {'original': 'your', 'correction': "you're", 'type': 'Grammatical', 'sentence': 7}
# {'original': 'your', 'correction': "you're", 'type': 'Grammatical', 'sentence': 12}
# {'original': 'grabing', 'correction': 'grabbing', 'type': 'Spelling', 'sentence': 2}
# {'original': 'I', 'correction': 'If', 'type': 'Grammatical', 'sentence': 16}
# {'original': 'realy', 'correction': 'really', 'type': 'Spelling', 'sentence': 16}
#
# Sampled data for list 57:
# {'original': 'hace', 'correction': 'have', 'type': 'Spelling', 'sentence': 20}
# {'original': 'adult', 'correction': 'adults', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'to much', 'correction': 'too much', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'comminicate', 'correction': 'communicate', 'type': 'Spelling', 'sentence': 20}
# {'original': 'what ever', 'correction': 'whatever', 'type': 'Spelling', 'sentence': 18}
#
# Sampled data for list 58:
# {'original': 'comppare', 'correction': 'compare', 'type': 'Spelling', 'sentence': 14}
# {'original': 'moter', 'correction': 'mother', 'type': 'Spelling', 'sentence': 20}
# {'original': 'Finaly', 'correction': 'Finally', 'type': 'Spelling', 'sentence': 26}
# {'original': 'con', 'correction': 'can', 'type': 'Spelling', 'sentence': 15}
# {'original': 'they', 'correction': 'the', 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 59:
# {'original': 'thing', 'correction': 'things', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'facebook', 'correction': 'Facebook', 'type': 'Word Choice', 'sentence': 9}
# {'original': 'deppresion', 'correction': 'Depression', 'type': 'Spelling', 'sentence': 15}
# {'original': 'vack', 'correction': 'back', 'type': 'Spelling', 'sentence': 14}
# {'original': 'and or', 'correction': 'and/or', 'type': 'Grammatical', 'sentence': 8}
#
# Sampled data for list 60:
# {'original': 'must', 'correction': 'most', 'type': 'Spelling', 'sentence': 3}
# {'original': 'suchn', 'correction': 'such', 'type': 'Spelling', 'sentence': 4}
# {'original': 'dung', 'correction': 'doing', 'type': 'Spelling', 'sentence': 6}
# {'original': 'trip', 'correction': 'trips', 'type': 'Grammatical', 'sentence': 13}
# {'original': 'are @CAPS1 keeps', 'correction': 'keep', 'type': 'Grammatical', 'sentence': 3}
#
# Sampled data for list 61:
# {'original': '@CAPS4 since @CAPS7 wife died, @CAPS7 daughter has been @CAPS7 only companion.', 'correction': "@CAPS4 since @CAPS7's wife died, @CAPS7's daughter has been @CAPS7's only companion.", 'type': 'Grammatical', 'sentence': 12}
# {'original': 'a variety @ORGANIZATION1 forms @ORGANIZATION1 communication', 'correction': 'a variety of forms of communication', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'quick easy', 'correction': 'quick and easy', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'out society', 'correction': 'our society', 'type': 'Word Choice', 'sentence': 15}
# {'original': 'commonication', 'correction': 'communication', 'type': 'Spelling', 'sentence': 32}
#
# Sampled data for list 62:
# {'original': 'wait', 'correction': 'weight', 'type': 'Spelling', 'sentence': 14}
# {'original': 'advance', 'correction': 'advancement', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'america', 'correction': 'America', 'type': 'Grammatical', 'sentence': 15}
# {'original': 'Families relationships', 'correction': 'Family relationships', 'type': 'Grammatical', 'sentence': 18}
# {'original': 'surfin', 'correction': 'surfing', 'type': 'Spelling', 'sentence': 13}
#
# Sampled data for list 63:
# {'original': 'an', 'correction': 'and', 'type': 'Spelling', 'sentence': 25}
# {'original': 'natue', 'correction': 'nature', 'type': 'Spelling', 'sentence': 4}
# {'original': 'peoples', 'correction': "people's", 'type': 'Grammatical', 'sentence': 30}
# {'original': 'their', 'correction': 'that', 'type': 'Word Choice', 'sentence': 24}
# {'original': 'famlies', 'correction': 'families', 'type': 'Spelling', 'sentence': 31}
#
# Sampled data for list 64:
# {'original': 'learn', 'correction': 'learned', 'type': 'Grammatical', 'sentence': 21}
# {'original': 'foren', 'correction': 'foreign', 'type': 'Spelling', 'sentence': 25}
# {'original': 'techolagy', 'correction': 'technology', 'type': 'Spelling', 'sentence': 8}
# {'original': 'reson', 'correction': 'reason', 'type': 'Spelling', 'sentence': 5}
# {'original': 'benafate', 'correction': 'benefit', 'type': 'Spelling', 'sentence': 4}
#
# Sampled data for list 65:
# {'original': 'that are distance apart', 'correction': 'that are distant apart', 'type': 'Word Choice', 'sentence': 16}
# {'original': 'exactaly', 'correction': 'exactly', 'type': 'Spelling', 'sentence': 12}
# {'original': 'Computers are vital source', 'correction': 'Computers are a vital source', 'type': 'Grammatical', 'sentence': 29}
# {'original': 'his and doctors', 'correction': 'his doctors', 'type': 'Grammatical', 'sentence': 12}
# {'original': 'on a computers', 'correction': 'on a computer', 'type': 'Grammatical', 'sentence': 26}
#
# Sampled data for list 66:
# {'original': 'compter', 'correction': 'computer', 'type': 'Spelling', 'sentence': 1}
# {'original': 'im', 'correction': "I'm", 'type': 'Grammatical', 'sentence': 11}
# {'original': 'abillty', 'correction': 'ability', 'type': 'Spelling', 'sentence': 10}
# {'original': "sim's", 'correction': 'Sims', 'type': 'Spelling', 'sentence': 7}
# {'original': "you'r", 'correction': "you're", 'type': 'Grammatical', 'sentence': 7}
#
# Sampled data for list 67:
# {'original': 'There for', 'correction': 'Therefore', 'type': 'Grammatical', 'sentence': 25}
# {'original': 'from in other activities', 'correction': 'from other activities', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'Copmputers', 'correction': 'Computers', 'type': 'Spelling', 'sentence': 13}
# {'original': 'peoples', 'correction': "people's", 'type': 'Grammatical', 'sentence': 1}
# {'original': 'then', 'correction': 'them', 'type': 'Grammatical', 'sentence': 24}
#
# Sampled data for list 68:
# {'original': 'becoming reaching', 'correction': 'becoming and reaching', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'comunication', 'correction': 'communication', 'type': 'Spelling', 'sentence': 8}
# {'original': 'stafisticated', 'correction': 'sophisticated', 'type': 'Spelling', 'sentence': 7}
# {'original': 'on a on', 'correction': 'an A on', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'Computer are', 'correction': 'Computers are', 'type': 'Grammatical', 'sentence': 7}
#
# Sampled data for list 69:
# {'original': 'awareness timing', 'correction': 'awareness, timing', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'are warned', 'correction': 'have warned', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'hassels', 'correction': 'hassles', 'type': 'Spelling', 'sentence': 10}
# {'original': 'better then', 'correction': 'better than', 'type': 'Grammatical', 'sentence': 18}
# {'original': 'far away', 'correction': 'faraway', 'type': 'Word Choice', 'sentence': 10}
#
# Sampled data for list 70:
# {'original': 'recieved', 'correction': 'received', 'type': 'Spelling', 'sentence': 19}
# {'original': 'addicy', 'correction': 'addict', 'type': 'Spelling', 'sentence': 8}
# {'original': 'dangerouis', 'correction': 'dangerous', 'type': 'Spelling', 'sentence': 4}
# {'original': 'whivh', 'correction': 'which', 'type': 'Spelling', 'sentence': 32}
# {'original': 'thing thing', 'correction': 'thing after thing', 'type': 'Word Choice', 'sentence': 21}
#
# Sampled data for list 71:
# {'original': 'Thank-you', 'correction': 'Thank you', 'type': 'Spelling', 'sentence': 31}
# {'original': 'you', 'correction': 'your', 'type': 'Grammatical', 'sentence': 30}
# {'original': 'affect', 'correction': 'effect', 'type': 'Word Choice', 'sentence': 28}
# {'original': 'happend', 'correction': 'happened', 'type': 'Spelling', 'sentence': 27}
# {'original': 'have walk', 'correction': 'have walked', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 72:
# {'original': 'you', 'correction': 'your', 'type': 'Grammatical', 'sentence': 19}
# {'original': 'rize', 'correction': 'rise', 'type': 'Spelling', 'sentence': 23}
# {'original': 'Wouldnt', 'correction': "Wouldn't", 'type': 'Grammatical', 'sentence': 20}
# {'original': 'unhealithy', 'correction': 'unhealthily', 'type': 'Spelling', 'sentence': 24}
# {'original': 'computer', 'correction': 'computers', 'type': 'Grammatical', 'sentence': 28}
#
# Sampled data for list 73:
# {'original': "don'@CAPS1", 'correction': "don't", 'type': 'Spelling', 'sentence': 12}
# {'original': 'togeather', 'correction': 'together', 'type': 'Spelling', 'sentence': 6}
# {'original': 'becomeing', 'correction': 'becoming', 'type': 'Spelling', 'sentence': 8}
# {'original': 'over weight', 'correction': 'overweight', 'type': 'Spelling', 'sentence': 8}
# {'original': 'news paper', 'correction': 'newspaper', 'type': 'Spelling', 'sentence': 10}
#
# Sampled data for list 74:
# {'original': 'fst', 'correction': 'fast', 'type': 'Spelling', 'sentence': 17}
# {'original': "woudn't", 'correction': "wouldn't", 'type': 'Spelling', 'sentence': 33}
# {'original': 'allo', 'correction': 'allow', 'type': 'Spelling', 'sentence': 3}
# {'original': 'will', 'correction': 'all', 'type': 'Spelling', 'sentence': 26}
# {'original': 'allows', 'correction': 'allow', 'type': 'Grammatical', 'sentence': 24}
#
# Sampled data for list 75:
# {'original': 'for ever', 'correction': 'forever', 'type': 'Spelling', 'sentence': 11}
# {'original': 'loose', 'correction': 'lose', 'type': 'Spelling', 'sentence': 10}
# {'original': 'you', 'correction': 'your', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'effect', 'correction': 'affect', 'type': 'Word Choice', 'sentence': 8}
# {'original': 'realized', 'correction': 'realize', 'type': 'Grammatical', 'sentence': 16}
#
# Sampled data for list 76:
# {'original': '@CAPS1', 'correction': 'when', 'type': 'Word Choice', 'sentence': 19}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 2}
# {'original': '@CAPS1', 'correction': 'for', 'type': 'Word Choice', 'sentence': 4}
# {'original': '@CAPS1', 'correction': 'for', 'type': 'Word Choice', 'sentence': 14}
# {'original': 'Dont', 'correction': "Don't", 'type': 'Grammatical', 'sentence': 5}
#
# Sampled data for list 77:
# {'original': 'effect', 'correction': 'effects', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 13}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 19}
# {'original': 'ect', 'correction': 'etc.', 'type': 'Spelling', 'sentence': 7}
# {'original': 'probaly', 'correction': 'probably', 'type': 'Spelling', 'sentence': 12}
#
# Sampled data for list 78:
# {'original': 'thier', 'correction': 'their', 'type': 'Spelling', 'sentence': 12}
# {'original': 'thier', 'correction': 'their', 'type': 'Spelling', 'sentence': 13}
# {'original': 'cutrogeous', 'correction': 'outrageous', 'type': 'Spelling', 'sentence': 10}
# {'original': '@CAPS1 has come', 'correction': 'it has come', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'exersize', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 9}
#
# Sampled data for list 79:
# {'original': 'use do', 'correction': 'do', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'the society', 'correction': 'society', 'type': 'Word Choice', 'sentence': 31}
# {'original': 'their', 'correction': 'there', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'it obvious', 'correction': 'is it obvious', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'source to do school work on', 'correction': 'tool for doing school work', 'type': 'Word Choice', 'sentence': 3}
#
# Sampled data for list 80:
# {'original': 'aldut', 'correction': 'adult', 'type': 'Spelling', 'sentence': 14}
# {'original': ',.', 'correction': '.', 'type': 'Grammatical', 'sentence': 19}
# {'original': 'lets', 'correction': "let's", 'type': 'Grammatical', 'sentence': 11}
# {'original': 'lets', 'correction': "let's", 'type': 'Grammatical', 'sentence': 5}
# {'original': 'lets', 'correction': "let's", 'type': 'Grammatical', 'sentence': 22}
#
# Sampled data for list 81:
# {'original': 'yes', 'correction': 'Yes', 'type': 'Grammatical', 'sentence': 25}
# {'original': 'thing', 'correction': 'things', 'type': 'Grammatical', 'sentence': 22}
# {'original': 'are', 'correction': 'are you', 'type': 'Grammatical', 'sentence': 15}
# {'original': 'game', 'correction': 'games', 'type': 'Grammatical', 'sentence': 12}
# {'original': 'be', 'correction': 'being', 'type': 'Grammatical', 'sentence': 20}
#
# Sampled data for list 82:
# {'original': 'faraway', 'correction': 'far away', 'type': 'Word Choice', 'sentence': 16}
# {'original': 'Theres', 'correction': "There's", 'type': 'Grammatical', 'sentence': 27}
# {'original': 'then', 'correction': 'than', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'acctually', 'correction': 'actually', 'type': 'Spelling', 'sentence': 15}
# {'original': 'your selfdown', 'correction': 'yourself down', 'type': 'Grammatical', 'sentence': 20}
#
# Sampled data for list 83:
# {'original': 'Whilesome', 'correction': 'While some', 'type': 'Grammatical', 'sentence': 34}
# {'original': "student's", 'correction': "students'", 'type': 'Grammatical', 'sentence': 15}
# {'original': 'friends is', 'correction': 'friends are', 'type': 'Grammatical', 'sentence': 21}
# {'original': 'nusence', 'correction': 'nuisance', 'type': 'Spelling', 'sentence': 9}
# {'original': 'well-know', 'correction': 'well-known', 'type': 'Spelling', 'sentence': 7}
#
# Sampled data for list 84:
# {'original': 'affect', 'correction': 'effect', 'type': 'Word Choice', 'sentence': 17}
# {'original': 'affect', 'correction': 'effect', 'type': 'Word Choice', 'sentence': 24}
# {'original': 'affect', 'correction': 'effect', 'type': 'Word Choice', 'sentence': 22}
# {'original': 'cites', 'correction': 'sites', 'type': 'Spelling', 'sentence': 9}
# {'original': 'affective', 'correction': 'effective', 'type': 'Spelling', 'sentence': 8}
#
# Sampled data for list 85:
# {'original': 'it', 'correction': 'them', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'for along time', 'correction': 'for a long time', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'are the computer', 'correction': 'are on the computer', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'tyoes', 'correction': 'types', 'type': 'Spelling', 'sentence': 1}
# {'original': 'gained.', 'correction': 'gained weight.', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 86:
# {'original': 'definetly', 'correction': 'definitely', 'type': 'Spelling', 'sentence': 5}
# {'original': 'same of bejeweled', 'correction': 'game of Bejeweled', 'type': 'Word Choice', 'sentence': 7}
# {'original': 'home work', 'correction': 'homework', 'type': 'Spelling', 'sentence': 30}
# {'original': 'a easy sources', 'correction': 'an easy source', 'type': 'Grammatical', 'sentence': 20}
# {'original': 'a bout', 'correction': 'about', 'type': 'Spelling', 'sentence': 11}
#
# Sampled data for list 87:
# {'original': 'instant message', 'correction': 'instant messaging', 'type': 'Word Choice', 'sentence': 6}
# {'original': 'facebook', 'correction': 'Facebook', 'type': 'Spelling', 'sentence': 6}
# {'original': '@CAPS1', 'correction': 'Do', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'myspace', 'correction': 'MySpace', 'type': 'Spelling', 'sentence': 6}
# {'original': '@CAPS1', 'correction': 'can', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 88:
# {'original': 'loose', 'correction': 'lose', 'type': 'Spelling', 'sentence': 3}
# {'original': 'makeing', 'correction': 'making', 'type': 'Spelling', 'sentence': 25}
# {'original': 'haveing', 'correction': 'having', 'type': 'Spelling', 'sentence': 11}
# {'original': 'dictionarys', 'correction': 'dictionaries', 'type': 'Spelling', 'sentence': 15}
# {'original': 'highschool', 'correction': 'high school', 'type': 'Spelling', 'sentence': 10}
#
# Sampled data for list 89:
# {'original': 'america', 'correction': 'America', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'to days', 'correction': "today's", 'type': 'Grammatical', 'sentence': 14}
# {'original': 'our', 'correction': 'are', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'you', 'correction': 'You', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'weather', 'correction': 'whether', 'type': 'Word Choice', 'sentence': 1}
#
# Sampled data for list 90:
# {'original': 'is an amazing website', 'correction': '[missing subject] is an amazing website', 'type': 'Grammatical', 'sentence': 20}
# {'original': 'facebook', 'correction': 'Facebook', 'type': 'Capitalization', 'sentence': 14}
# {'original': 'all of the sudden', 'correction': 'all of a sudden', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'we was', 'correction': 'we were', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'importances', 'correction': 'important information', 'type': 'Word Choice', 'sentence': 3}
#
# Sampled data for list 91:
# {'original': 'resson', 'correction': 'reason', 'type': 'Spelling', 'sentence': 6}
# {'original': 'resson', 'correction': 'reason', 'type': 'Spelling', 'sentence': 16}
# {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'resson', 'correction': 'reason', 'type': 'Spelling', 'sentence': 19}
# {'original': 'or', 'correction': 'our', 'type': 'Spelling', 'sentence': 16}
#
# Sampled data for list 92:
# {'original': 'expericing', 'correction': 'experiencing', 'type': 'Spelling', 'sentence': 1}
# {'original': 'rating', 'correction': 'eating', 'type': 'Word Choice', 'sentence': 6}
# {'original': 'Computers are addicting you go on for five minutes and you forget all what you do before you know it you have @CAPS1 hours.', 'correction': 'Computers are addicting. You go on for five minutes, and you forget all that you do. Before you know it, you have spent @CAPS1 hours.', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'alos', 'correction': 'also', 'type': 'Spelling', 'sentence': 3}
# {'original': 'does time', 'correction': 'does over time', 'type': 'Grammatical', 'sentence': 9}
#
# Sampled data for list 93:
# {'original': 'to fat', 'correction': 'too fat', 'type': 'Grammatical', 'sentence': 24}
# {'original': 'pating', 'correction': 'eating', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'veidos', 'correction': 'videos', 'type': 'Spelling', 'sentence': 21}
# {'original': 'there', 'correction': 'their', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'a play', 'correction': 'and play', 'type': 'Grammatical', 'sentence': 15}
#
# Sampled data for list 94:
# {'original': 'cordination', 'correction': 'coordination', 'type': 'Spelling', 'sentence': 33}
# {'original': 'benifit', 'correction': 'benefit', 'type': 'Spelling', 'sentence': 32}
# {'original': 'phane', 'correction': 'phone', 'type': 'Spelling', 'sentence': 11}
# {'original': 'ti', 'correction': 'to', 'type': 'Spelling', 'sentence': 30}
# {'original': 'finsing', 'correction': 'finding', 'type': 'Spelling', 'sentence': 3}
#
# Sampled data for list 95:
# {'original': 'As for myself', 'correction': 'As for me', 'type': 'Word Choice', 'sentence': 3}
# {'original': 'Lets', 'correction': "Let's", 'type': 'Grammatical', 'sentence': 18}
# {'original': 'simultaniously', 'correction': 'simultaneously', 'type': 'Spelling', 'sentence': 10}
# {'original': 'abilitys', 'correction': 'abilities', 'type': 'Spelling', 'sentence': 21}
# {'original': 'Finaly', 'correction': 'Finally', 'type': 'Spelling', 'sentence': 8}
#
# Sampled data for list 96:
# {'original': 'is that computers give', 'correction': 'computers give', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'Using the computer to go on multiple websites, is actually easier.', 'correction': 'Using the computer to go on multiple websites is actually easier.', 'type': 'Grammatical', 'sentence': 13}
# {'original': 'far away places', 'correction': 'faraway places', 'type': 'Word Choice', 'sentence': 11}
# {'original': 'All of these, and more give you the opportunity', 'correction': 'All of these and more give you the opportunity', 'type': 'Grammatical', 'sentence': 20}
# {'original': 'a positive effect on people', 'correction': 'a positive influence on people', 'type': 'Word Choice', 'sentence': 25}
#
# Sampled data for list 97:
# {'original': 'comuter', 'correction': 'computer', 'type': 'Spelling', 'sentence': 24}
# {'original': 'onto', 'correction': 'on', 'type': 'Word Choice', 'sentence': 4}
# {'original': "wan't", 'correction': 'want', 'type': 'Spelling', 'sentence': 25}
# {'original': 'Also people', 'correction': 'Also, people', 'type': 'Grammatical', 'sentence': 22}
# {'original': 'they rather', 'correction': "they'd rather", 'type': 'Grammatical', 'sentence': 20}
#
# Sampled data for list 98:
# {'original': 'millenium', 'correction': 'millennium', 'type': 'Spelling', 'sentence': 1}
# {'original': 'bases', 'correction': 'basis', 'type': 'Word Choice', 'sentence': 17}
# {'original': 'intellegence', 'correction': 'intelligence', 'type': 'Spelling', 'sentence': 26}
# {'original': 'is', 'correction': 'are', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'twitter', 'correction': 'Twitter', 'type': 'Grammatical', 'sentence': 18}
#
# Sampled data for list 99:
# {'original': 'tha', 'correction': 'that', 'type': 'Spelling', 'sentence': 6}
# {'original': 'ar', 'correction': 'are', 'type': 'Spelling', 'sentence': 16}
# {'original': 'websitees', 'correction': 'websites', 'type': 'Spelling', 'sentence': 15}
# {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'foe', 'correction': 'for', 'type': 'Spelling', 'sentence': 21}
#
# Sampled data for list 100:
# {'original': 'a easier', 'correction': 'an easier', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'wheather', 'correction': 'whether', 'type': 'Spelling', 'sentence': 2}
# {'original': 'some one', 'correction': 'someone', 'type': 'Spelling', 'sentence': 8}
# {'original': 'america', 'correction': 'America', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'nessisary', 'correction': 'necessary', 'type': 'Spelling', 'sentence': 17}

# %%
joblib.dump(sampled_corrections, 'files/correction_train_100essay_5corr')
# Out:
# ['files/correction_train_100essay_5corr']

# %%
# Function to apply corrections to the essay
def apply_corrections_grammar(essay, corrections):
    # Tokenize the essay into sentences using NLTK
    sentences = nltk.sent_tokenize(essay)

    # Create a list to store corrected sentences
    corrected_sentences = []

    # Iterate through sentences
    for i, sentence in enumerate(sentences):
        # Apply corrections to the current sentence
        for correction in corrections:
            # Adjust the index by subtracting 1 to match the enumeration starting from 0
            if correction['sentence'] == i + 1:
                # Replace all occurrences of the incorrect text with the correction
                #sentence = sentence.replace(correction['original'], correction['correction'])
                 # Use regular expression with word boundaries to replace only whole words
                sentence = re.sub(r'\b' + re.escape(correction['original']) + r'\b', correction['correction'], sentence)
        # Add the corrected sentence to the list
        corrected_sentences.append(sentence)

    # Join the corrected sentences to form the final essay
    corrected_essay = ' '.join(corrected_sentences)
    return corrected_essay

# Function to generate all combinations of corrections and apply them
def generate_corrected_versions(essay, corrections):
    corrected_versions = []
    max_corrections = len(corrections)

    # Iterate over different numbers of corrections to apply
    for num_corrections in range(1, max_corrections + 1):
        for combination in itertools.combinations(corrections, num_corrections):
            corrected_essay = apply_corrections_grammar(essay, combination)
            corrected_versions.append(corrected_essay)
  
    return corrected_versions

# # Example usage
# essay = "This is a tess essay. The break through was amazing. The possitive effects were clear."
# corrections = [
#     {'original': 'tess', 'correction': 'test', 'type': 'Spelling', 'sentence': 1},
#     {'original': 'break through', 'correction': 'breakthrough', 'type': 'Spelling', 'sentence': 2},
#     {'original': 'possitive', 'correction': 'positive', 'type': 'Spelling', 'sentence': 3},
# ]

# # Generate corrected versions with combinations of 1, 2, and 3 corrections
# corrected_versions = generate_corrected_versions(essay, corrections)
# corrected_versions

# %%
correction_train_100essay_5corr = joblib.load('files/correction_train_100essay_5corr')

corrected_train_100data_5corr = []

for index, row in data_100.iterrows():
    try:
        correted_essays = generate_corrected_versions(row['essay'], correction_train_100essay_5corr[index]) 
        # Append the result to the list
        corrected_train_100data_5corr.append(correted_essays)
    except Exception as e:
        print(f"Error processing row {index}: {e}")
        corrected_train_100data_5corr.append(None)  # Append None or an empty dict if an error occurs

# %%
np.array(corrected_train_100data_5corr).shape
# Out:
# (100, 31)

# %%
joblib.dump(corrected_train_100data_5corr, 'files/corrected_train_100data_5corr')
# Out:
# ['files/corrected_train_100data_5corr']
