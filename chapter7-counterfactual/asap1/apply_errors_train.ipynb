# %%
import joblib
import pandas as pd
import nltk
import re
import itertools
import random
import numpy as np

# %%
data = pd.read_csv('ASAP1 Train Set.tsv', sep='\t')
data_100 = data[:100]
data_100.head()
# Out:
#    essay_id                                              essay  domain1_score
# 0       176  Computers and the @CAPS1 were a technological ...             10
# 1       632  People using computers is a good way for them ...             10
# 2      1108  Dear local newspaper, @CAPS1 you can see, abou...              9
# 3      1747  Dear local Newspaper, I think computer technog...              8
# 4      1016  Dear @CAPS1 @CAPS2, More and more people use c...              8

# %%
errors = joblib.load('files/error_lists_train_100')

# %%
len(errors)
# Out:
# 100

# %%
# Function to sample 5 dictionaries from each inner list
def sample_five_from_each(inner_lists):
    return [random.sample(inner_list, min(len(inner_list), 5)) for inner_list in inner_lists]

# Sample 5 dictionaries from each inner list
sampled_errors = sample_five_from_each(errors)

print(np.array(sampled_errors).shape)

# Print the results
for idx, sampled_list in enumerate(sampled_errors):
    print(f"Sampled data for list {idx + 1}:")
    for item in sampled_list:
        print(item)
    print()
# Out:
# (100, 5)
# Sampled data for list 1:
# {'original': 'like', 'error': 'near', 'sentence': 11}
# {'original': 'decrease', 'error': 'decraese', 'sentence': 5}
# {'original': 'steal', 'error': 'steals', 'sentence': 17}
# {'original': 'technological', 'error': 'techonlogical', 'sentence': 1}
# {'original': 'before', 'error': 'among', 'sentence': 19}
#
# Sampled data for list 2:
# {'original': 'let', 'error': 'lets', 'sentence': 8}
# {'original': 'way', 'error': 'awy', 'sentence': 1}
# {'original': 'like', 'error': 'since', 'sentence': 15}
# {'original': 'got', 'error': 'gets', 'sentence': 7}
# {'original': 'surf', 'error': 'sruf', 'sentence': 3}
#
# Sampled data for list 3:
# {'original': 'getting', 'error': 'gettnig', 'sentence': 2}
# {'original': 'has', 'error': 'had', 'sentence': 29}
# {'original': 'quite', 'error': 'qutie', 'sentence': 5}
# {'original': 'people', 'error': 'peolpe', 'sentence': 4}
# {'original': 'went', 'error': 'goes', 'sentence': 15}
#
# Sampled data for list 4:
# {'original': 'think', 'error': 'htink', 'sentence': 2}
# {'original': 'think', 'error': 'thought', 'sentence': 1}
# {'original': 'to', 'error': 'beyond', 'sentence': 12}
# {'original': 'work', 'error': 'wokr', 'sentence': 3}
# {'original': 'gets', 'error': 'got', 'sentence': 18}
#
# Sampled data for list 5:
# {'original': 'forget', 'error': 'fogret', 'sentence': 3}
# {'original': 'forget', 'error': 'foregt', 'sentence': 2}
# {'original': 'makes', 'error': 'make', 'sentence': 8}
# {'original': 'soend', 'error': 'soends', 'sentence': 5}
# {'original': 'helps', 'error': 'helped', 'sentence': 6}
#
# Sampled data for list 6:
# {'original': 'in', 'error': 'toward', 'sentence': 7}
# {'original': 'house', 'error': 'houes', 'sentence': 1}
# {'original': 'in', 'error': 'through', 'sentence': 13}
# {'original': 'away', 'error': 'waay', 'sentence': 5}
# {'original': 'keeping', 'error': 'keeps', 'sentence': 5}
#
# Sampled data for list 7:
# {'original': 'know', 'error': 'knew', 'sentence': 16}
# {'original': 'at', 'error': 'of', 'sentence': 12}
# {'original': 'be', 'error': 'is', 'sentence': 34}
# {'original': 'off', 'error': 'behind', 'sentence': 8}
# {'original': 'went', 'error': 'goes', 'sentence': 13}
#
# Sampled data for list 8:
# {'original': 'have', 'error': 'has', 'sentence': 14}
# {'original': 'sending', 'error': 'senidng', 'sentence': 5}
# {'original': 'rely', 'error': 'relies', 'sentence': 4}
# {'original': 'of', 'error': 'underneath', 'sentence': 12}
# {'original': 'homework', 'error': 'homewrok', 'sentence': 4}
#
# Sampled data for list 9:
# {'original': 'time', 'error': 'itme', 'sentence': 3}
# {'original': 'teach', 'error': 'teaches', 'sentence': 22}
# {'original': 'important', 'error': 'miportant', 'sentence': 5}
# {'original': 'about', 'error': 'along', 'sentence': 22}
# {'original': 'use', 'error': 'ues', 'sentence': 1}
#
# Sampled data for list 10:
# {'original': 'from', 'error': 'among', 'sentence': 21}
# {'original': 'bet', 'error': 'bets', 'sentence': 30}
# {'original': 'to', 'error': 'around', 'sentence': 41}
# {'original': 'got', 'error': 'get', 'sentence': 15}
# {'original': 'family', 'error': 'famliy', 'sentence': 5}
#
# Sampled data for list 11:
# {'original': 'actual', 'error': 'atcual', 'sentence': 2}
# {'original': 'into', 'error': 'through', 'sentence': 11}
# {'original': 'filled', 'error': 'fill', 'sentence': 1}
# {'original': 'human', 'error': 'uhman', 'sentence': 3}
# {'original': 'talk', 'error': 'atlk', 'sentence': 5}
#
# Sampled data for list 12:
# {'original': 'rely', 'error': 'relies', 'sentence': 12}
# {'original': 'agree', 'error': 'agreed', 'sentence': 1}
# {'original': 'of', 'error': 'up', 'sentence': 23}
# {'original': 'good', 'error': 'ogod', 'sentence': 3}
# {'original': 'find', 'error': 'fnid', 'sentence': 5}
#
# Sampled data for list 13:
# {'original': 'think', 'error': 'thought', 'sentence': 1}
# {'original': 'on', 'error': 'for', 'sentence': 12}
# {'original': 'on', 'error': 'up', 'sentence': 4}
# {'original': 'important', 'error': 'impotrant', 'sentence': 2}
# {'original': 'mentioned', 'error': 'mentions', 'sentence': 12}
#
# Sampled data for list 14:
# {'original': 'lives', 'error': 'lived', 'sentence': 27}
# {'original': 'say', 'error': 'says', 'sentence': 13}
# {'original': 'distroyed', 'error': 'distroye', 'sentence': 30}
# {'original': 'bulling', 'error': 'ublling', 'sentence': 4}
# {'original': 'found', 'error': 'find', 'sentence': 6}
#
# Sampled data for list 15:
# {'original': 'school', 'error': 'school', 'sentence': 4}
# {'original': 'need', 'error': 'needed', 'sentence': 11}
# {'original': 'get', 'error': 'gets', 'sentence': 21}
# {'original': 'sports', 'error': 'sporst', 'sentence': 1}
# {'original': 'on', 'error': 'onto', 'sentence': 2}
#
# Sampled data for list 16:
# {'original': 'make', 'error': 'makes', 'sentence': 16}
# {'original': 'eye', 'error': 'eey', 'sentence': 2}
# {'original': 'ability', 'error': 'abliity', 'sentence': 5}
# {'original': 'changed', 'error': 'change', 'sentence': 28}
# {'original': 'to', 'error': 'except', 'sentence': 2}
#
# Sampled data for list 17:
# {'original': 'for', 'error': 'despite', 'sentence': 23}
# {'original': 'have', 'error': 'had', 'sentence': 24}
# {'original': 'look', 'error': 'looked', 'sentence': 12}
# {'original': 'have', 'error': 'had', 'sentence': 1}
# {'original': 'even', 'error': 'evne', 'sentence': 5}
#
# Sampled data for list 18:
# {'original': 'someone', 'error': 'smoeone', 'sentence': 3}
# {'original': 'disagree', 'error': 'disagere', 'sentence': 2}
# {'original': 'know', 'error': 'knows', 'sentence': 4}
# {'original': 'at', 'error': 'past', 'sentence': 3}
# {'original': 'say', 'error': 'said', 'sentence': 14}
#
# Sampled data for list 19:
# {'original': 's', 'error': 'sed', 'sentence': 22}
# {'original': 'diet', 'error': 'dite', 'sentence': 5}
# {'original': 'guess', 'error': 'guesses', 'sentence': 15}
# {'original': 'hope', 'error': 'hopes', 'sentence': 23}
# {'original': 'in', 'error': 'near', 'sentence': 18}
#
# Sampled data for list 20:
# {'original': 'computer', 'error': 'comupter', 'sentence': 5}
# {'original': 'said', 'error': 'says', 'sentence': 9}
# {'original': 'on', 'error': 'beside', 'sentence': 2}
# {'original': 'tolled', 'error': 'tolls', 'sentence': 8}
# {'original': 'look', 'error': 'looked', 'sentence': 14}
#
# Sampled data for list 21:
# {'original': 'get', 'error': 'got', 'sentence': 20}
# {'original': 'end', 'error': 'ends', 'sentence': 27}
# {'original': 'use', 'error': 'used', 'sentence': 1}
# {'original': 'harmful', 'error': 'harmufl', 'sentence': 2}
# {'original': 'of', 'error': 'behind', 'sentence': 22}
#
# Sampled data for list 22:
# {'original': 'help', 'error': 'helped', 'sentence': 3}
# {'original': 'allow', 'error': 'allowed', 'sentence': 5}
# {'original': 'attention', 'error': 'atetntion', 'sentence': 1}
# {'original': 'of', 'error': 'around', 'sentence': 21}
# {'original': 'of', 'error': 'up', 'sentence': 1}
#
# Sampled data for list 23:
# {'original': 'precious', 'error': 'rpecious', 'sentence': 2}
# {'original': 'of', 'error': 'up', 'sentence': 12}
# {'original': 'need', 'error': 'nede', 'sentence': 4}
# {'original': 'writers', 'error': 'writered', 'sentence': 13}
# {'original': 'includes', 'error': 'include', 'sentence': 1}
#
# Sampled data for list 24:
# {'original': 'Dear', 'error': 'eDar', 'sentence': 1}
# {'original': 'need', 'error': 'needs', 'sentence': 24}
# {'original': 'in', 'error': 'with', 'sentence': 12}
# {'original': 'spend', 'error': 'spned', 'sentence': 2}
# {'original': 'says', 'error': 'said', 'sentence': 9}
#
# Sampled data for list 25:
# {'original': 'Dear', 'error': 'Daer', 'sentence': 1}
# {'original': 'have', 'error': 'has', 'sentence': 1}
# {'original': 'on', 'error': 'by', 'sentence': 15}
# {'original': 'information', 'error': 'informtaion', 'sentence': 3}
# {'original': 'for', 'error': 'as', 'sentence': 16}
#
# Sampled data for list 26:
# {'original': 'computer', 'error': 'copmuter', 'sentence': 5}
# {'original': 'made', 'error': 'makes', 'sentence': 24}
# {'original': 'stay', 'error': 'stya', 'sentence': 4}
# {'original': 'kept', 'error': 'keep', 'sentence': 2}
# {'original': 'has', 'error': 'had', 'sentence': 26}
#
# Sampled data for list 27:
# {'original': 'of', 'error': 'between', 'sentence': 12}
# {'original': 'states', 'error': 'state', 'sentence': 14}
# {'original': 'world', 'error': 'wordl', 'sentence': 1}
# {'original': 'helps', 'error': 'help', 'sentence': 11}
# {'original': 'have', 'error': 'had', 'sentence': 15}
#
# Sampled data for list 28:
# {'original': 'benefit', 'error': 'benefti', 'sentence': 1}
# {'original': 'chat', 'error': 'caht', 'sentence': 4}
# {'original': 'heard', 'error': 'hears', 'sentence': 1}
# {'original': 'began', 'error': 'begin', 'sentence': 24}
# {'original': 'talk', 'error': 'takl', 'sentence': 5}
#
# Sampled data for list 29:
# {'original': 'says', 'error': 'say', 'sentence': 21}
# {'original': 'Dear', 'error': 'Dera', 'sentence': 1}
# {'original': 'believe', 'error': 'believes', 'sentence': 16}
# {'original': 'According', 'error': 'Accroding', 'sentence': 5}
# {'original': 'showed', 'error': 'shows', 'sentence': 6}
#
# Sampled data for list 30:
# {'original': 'say', 'error': 'sya', 'sentence': 5}
# {'original': 'school', 'error': 'school', 'sentence': 2}
# {'original': 'heard', 'error': 'hears', 'sentence': 7}
# {'original': 'hear', 'error': 'heard', 'sentence': 6}
# {'original': 'wrong', 'error': 'rwong', 'sentence': 4}
#
# Sampled data for list 31:
# {'original': 'think', 'error': 'tihnk', 'sentence': 2}
# {'original': 'notice', 'error': 'notices', 'sentence': 17}
# {'original': 'to', 'error': 'into', 'sentence': 24}
# {'original': 'gone', 'error': 'goes', 'sentence': 10}
# {'original': 'argument', 'error': 'agrument', 'sentence': 5}
#
# Sampled data for list 32:
# {'original': 'society', 'error': 'socieyt', 'sentence': 1}
# {'original': 'growing', 'error': 'grow', 'sentence': 5}
# {'original': 'of', 'error': 'past', 'sentence': 17}
# {'original': 'have', 'error': 'has', 'sentence': 12}
# {'original': 'benifit', 'error': 'benifits', 'sentence': 11}
#
# Sampled data for list 33:
# {'original': 'have', 'error': 'has', 'sentence': 15}
# {'original': 'makes', 'error': 'make', 'sentence': 7}
# {'original': 'computer', 'error': 'comupter', 'sentence': 5}
# {'original': 'time', 'error': 'itme', 'sentence': 4}
# {'original': 'detailed', 'error': 'detialed', 'sentence': 2}
#
# Sampled data for list 34:
# {'original': 'opinion', 'error': 'opniion', 'sentence': 1}
# {'original': 'introduced', 'error': 'introduce', 'sentence': 19}
# {'original': 'reason', 'error': 'erason', 'sentence': 5}
# {'original': 'information', 'error': 'infomration', 'sentence': 3}
# {'original': 'improved', 'error': 'improves', 'sentence': 1}
#
# Sampled data for list 35:
# {'original': 'for', 'error': 'before', 'sentence': 1}
# {'original': 'Finally', 'error': 'Finalyl', 'sentence': 4}
# {'original': 'think', 'error': 'thikn', 'sentence': 1}
# {'original': 'makes', 'error': 'make', 'sentence': 4}
# {'original': 'world', 'error': 'wolrd', 'sentence': 2}
#
# Sampled data for list 36:
# {'original': 'have', 'error': 'had', 'sentence': 4}
# {'original': 'computer', 'error': 'compuetr', 'sentence': 3}
# {'original': 'use', 'error': 'used', 'sentence': 18}
# {'original': 'made', 'error': 'make', 'sentence': 7}
# {'original': 'people', 'error': 'epople', 'sentence': 4}
#
# Sampled data for list 37:
# {'original': 'people', 'error': 'peopel', 'sentence': 4}
# {'original': 'go', 'error': 'goes', 'sentence': 22}
# {'original': 'for', 'error': 'before', 'sentence': 10}
# {'original': 'Dear', 'error': 'eDar', 'sentence': 1}
# {'original': 'think', 'error': 'tihnk', 'sentence': 3}
#
# Sampled data for list 38:
# {'original': 'need', 'error': 'ened', 'sentence': 5}
# {'original': 'need', 'error': 'needed', 'sentence': 8}
# {'original': 'good', 'error': 'godo', 'sentence': 2}
# {'original': 'think', 'error': 'thinks', 'sentence': 2}
# {'original': 'in', 'error': 'until', 'sentence': 5}
#
# Sampled data for list 39:
# {'original': 'effect', 'error': 'effect', 'sentence': 2}
# {'original': 'have', 'error': 'has', 'sentence': 21}
# {'original': 'help', 'error': 'helped', 'sentence': 3}
# {'original': 'also', 'error': 'aslo', 'sentence': 4}
# {'original': 'live', 'error': 'liev', 'sentence': 5}
#
# Sampled data for list 40:
# {'original': 'forget', 'error': 'forgets', 'sentence': 21}
# {'original': 'computer', 'error': 'copmuter', 'sentence': 4}
# {'original': 'time', 'error': 'tiem', 'sentence': 3}
# {'original': 'time', 'error': 'tiem', 'sentence': 1}
# {'original': 'spend', 'error': 'spent', 'sentence': 24}
#
# Sampled data for list 41:
# {'original': 'realized', 'error': 'realize', 'sentence': 20}
# {'original': 'went', 'error': 'go', 'sentence': 3}
# {'original': 'went', 'error': 'wnet', 'sentence': 3}
# {'original': 'know', 'error': 'knows', 'sentence': 24}
# {'original': 'blow', 'error': 'blew', 'sentence': 35}
#
# Sampled data for list 42:
# {'original': 'time', 'error': 'itme', 'sentence': 3}
# {'original': 'takes', 'error': 'take', 'sentence': 25}
# {'original': 'affected', 'error': 'affects', 'sentence': 24}
# {'original': 'affect', 'error': 'affected', 'sentence': 5}
# {'original': 'to', 'error': 'beyond', 'sentence': 2}
#
# Sampled data for list 43:
# {'original': 'protects', 'error': 'protect', 'sentence': 37}
# {'original': 'local', 'error': 'locla', 'sentence': 1}
# {'original': 'enjoy', 'error': 'nejoy', 'sentence': 2}
# {'original': 'positive', 'error': 'opsitive', 'sentence': 5}
# {'original': 'in', 'error': 'until', 'sentence': 1}
#
# Sampled data for list 44:
# {'original': 'let', 'error': 'lte', 'sentence': 5}
# {'original': 'school', 'error': 'scholo', 'sentence': 3}
# {'original': 'Dear', 'error': 'Dera', 'sentence': 1}
# {'original': 'up', 'error': 'against', 'sentence': 11}
# {'original': 's', 'error': 'sed', 'sentence': 12}
#
# Sampled data for list 45:
# {'original': 'on', 'error': 'without', 'sentence': 14}
# {'original': 'computer', 'error': 'comptuer', 'sentence': 5}
# {'original': 'might', 'error': 'mihgt', 'sentence': 3}
# {'original': 'concerned', 'error': 'concerns', 'sentence': 1}
# {'original': 'people', 'error': 'peopel', 'sentence': 4}
#
# Sampled data for list 46:
# {'original': 'provide', 'error': 'provided', 'sentence': 3}
# {'original': 'remember', 'error': 'remembered', 'sentence': 26}
# {'original': 'Dear', 'error': 'eDar', 'sentence': 1}
# {'original': 'told', 'error': 'tell', 'sentence': 33}
# {'original': 'type', 'error': 'typed', 'sentence': 25}
#
# Sampled data for list 47:
# {'original': 'at', 'error': 'with', 'sentence': 8}
# {'original': 'letter', 'error': 'letter', 'sentence': 2}
# {'original': 'right', 'error': 'rigth', 'sentence': 5}
# {'original': 'have', 'error': 'has', 'sentence': 5}
# {'original': 'bound', 'error': 'binds', 'sentence': 17}
#
# Sampled data for list 48:
# {'original': 'heat', 'error': 'heta', 'sentence': 5}
# {'original': 'use', 'error': 'uses', 'sentence': 16}
# {'original': 'save', 'error': 'saved', 'sentence': 37}
# {'original': 'about', 'error': 'with', 'sentence': 21}
# {'original': 'bad', 'error': 'bda', 'sentence': 4}
#
# Sampled data for list 49:
# {'original': 'spend', 'error': 'sepnd', 'sentence': 5}
# {'original': 'long', 'error': 'lnog', 'sentence': 4}
# {'original': 'bad', 'error': 'bda', 'sentence': 2}
# {'original': 'could', 'error': 'coudl', 'sentence': 3}
# {'original': 'of', 'error': 'underneath', 'sentence': 12}
#
# Sampled data for list 50:
# {'original': 'get', 'error': 'egt', 'sentence': 5}
# {'original': 'turn', 'error': 'trun', 'sentence': 3}
# {'original': 'hogged', 'error': 'hogs', 'sentence': 13}
# {'original': 'place', 'error': 'lpace', 'sentence': 2}
# {'original': 'like', 'error': 'liek', 'sentence': 1}
#
# Sampled data for list 51:
# {'original': 'needs', 'error': 'needed', 'sentence': 21}
# {'original': 'for', 'error': 'near', 'sentence': 8}
# {'original': 'Last', 'error': 'Lsat', 'sentence': 5}
# {'original': 'asked', 'error': 'ask', 'sentence': 29}
# {'original': 'school', 'error': 'cshool', 'sentence': 3}
#
# Sampled data for list 52:
# {'original': 'talk', 'error': 'takl', 'sentence': 3}
# {'original': 'like', 'error': 'likes', 'sentence': 6}
# {'original': 'say', 'error': 'sya', 'sentence': 4}
# {'original': 'use', 'error': 'ues', 'sentence': 5}
# {'original': 'love', 'error': 'loves', 'sentence': 12}
#
# Sampled data for list 53:
# {'original': 'without', 'error': 'within', 'sentence': 27}
# {'original': 'society', 'error': 'socitey', 'sentence': 2}
# {'original': 'became', 'error': 'becomes', 'sentence': 23}
# {'original': 'reminds', 'error': 'remind', 'sentence': 22}
# {'original': 'In', 'error': 'except', 'sentence': 24}
#
# Sampled data for list 54:
# {'original': 'else', 'error': 'eles', 'sentence': 4}
# {'original': 'good', 'error': 'ogod', 'sentence': 2}
# {'original': 'proof', 'error': 'porof', 'sentence': 5}
# {'original': 'through', 'error': 'beside', 'sentence': 7}
# {'original': 'effect', 'error': 'effetc', 'sentence': 1}
#
# Sampled data for list 55:
# {'original': 'to', 'error': 'except', 'sentence': 6}
# {'original': 'rested', 'error': 'rests', 'sentence': 16}
# {'original': 'talking', 'error': 'talks', 'sentence': 8}
# {'original': 'say', 'error': 'said', 'sentence': 7}
# {'original': 'many', 'error': 'mayn', 'sentence': 5}
#
# Sampled data for list 56:
# {'original': 'maybe', 'error': 'amybe', 'sentence': 4}
# {'original': 'working', 'error': 'work', 'sentence': 8}
# {'original': 'with', 'error': 'behind', 'sentence': 12}
# {'original': 'friend', 'error': 'firend', 'sentence': 3}
# {'original': 'playing', 'error': 'play', 'sentence': 16}
#
# Sampled data for list 57:
# {'original': 'Another', 'error': 'Anotehr', 'sentence': 4}
# {'original': 'video', 'error': 'viedo', 'sentence': 5}
# {'original': 'like', 'error': 'outside', 'sentence': 12}
# {'original': 'think', 'error': 'thinks', 'sentence': 25}
# {'original': 'want', 'error': 'wants', 'sentence': 15}
#
# Sampled data for list 58:
# {'original': 'important', 'error': 'imoprtant', 'sentence': 5}
# {'original': 'way', 'error': 'wya', 'sentence': 2}
# {'original': 'have', 'error': 'has', 'sentence': 27}
# {'original': 'one', 'error': 'noe', 'sentence': 4}
# {'original': 'revelotivizied', 'error': 'revelotivizies', 'sentence': 2}
#
# Sampled data for list 59:
# {'original': 'thought', 'error': 'thinks', 'sentence': 18}
# {'original': 'spend', 'error': 'psend', 'sentence': 5}
# {'original': 'out', 'error': 'except', 'sentence': 20}
# {'original': 'through', 'error': 'until', 'sentence': 15}
# {'original': 'whether', 'error': 'whehter', 'sentence': 4}
#
# Sampled data for list 60:
# {'original': 'gave', 'error': 'gives', 'sentence': 21}
# {'original': 'to', 'error': 'past', 'sentence': 24}
# {'original': 'made', 'error': 'maed', 'sentence': 1}
# {'original': 'allows', 'error': 'allowed', 'sentence': 16}
# {'original': 'allows', 'error': 'allow', 'sentence': 24}
#
# Sampled data for list 61:
# {'original': 'teach', 'error': 'teaches', 'sentence': 28}
# {'original': 'necessary', 'error': 'necsesary', 'sentence': 3}
# {'original': 'argue', 'error': 'argues', 'sentence': 2}
# {'original': 'miss', 'error': 'miss', 'sentence': 5}
# {'original': 'benefit', 'error': 'benefti', 'sentence': 1}
#
# Sampled data for list 62:
# {'original': 'to', 'error': 'despite', 'sentence': 11}
# {'original': 'great', 'error': 'gerat', 'sentence': 5}
# {'original': 'affect', 'error': 'fafect', 'sentence': 1}
# {'original': 'taking', 'error': 'takes', 'sentence': 8}
# {'original': 'ruined', 'error': 'ruins', 'sentence': 18}
#
# Sampled data for list 63:
# {'original': 'spend', 'error': 'spends', 'sentence': 4}
# {'original': 'hear', 'error': 'heard', 'sentence': 28}
# {'original': 'important', 'error': 'miportant', 'sentence': 3}
# {'original': 'have', 'error': 'has', 'sentence': 5}
# {'original': 'lose', 'error': 'lsoe', 'sentence': 4}
#
# Sampled data for list 64:
# {'original': 'possible', 'error': 'posisble', 'sentence': 2}
# {'original': 'thought', 'error': 'thuoght', 'sentence': 3}
# {'original': 'of', 'error': 'upon', 'sentence': 24}
# {'original': 'make', 'error': 'makes', 'sentence': 19}
# {'original': 'always', 'error': 'awlays', 'sentence': 1}
#
# Sampled data for list 65:
# {'original': 'in', 'error': 'underneath', 'sentence': 18}
# {'original': 'helped', 'error': 'help', 'sentence': 18}
# {'original': 'help', 'error': 'helped', 'sentence': 27}
# {'original': 'help', 'error': 'ehlp', 'sentence': 2}
# {'original': 'learned', 'error': 'learn', 'sentence': 10}
#
# Sampled data for list 66:
# {'original': 'across', 'error': 'under', 'sentence': 7}
# {'original': 'on', 'error': 'beside', 'sentence': 4}
# {'original': 'share', 'error': 'shares', 'sentence': 10}
# {'original': 'show', 'error': 'hsow', 'sentence': 3}
# {'original': 'smart', 'error': 'smrat', 'sentence': 1}
#
# Sampled data for list 67:
# {'original': 'become', 'error': 'beocme', 'sentence': 1}
# {'original': 'after', 'error': 'near', 'sentence': 5}
# {'original': 'always', 'error': 'laways', 'sentence': 4}
# {'original': 'of', 'error': 'behind', 'sentence': 16}
# {'original': 'people', 'error': 'epople', 'sentence': 2}
#
# Sampled data for list 68:
# {'original': 'supply', 'error': 'spuply', 'sentence': 2}
# {'original': 'say', 'error': 'says', 'sentence': 10}
# {'original': 'out', 'error': 'as', 'sentence': 12}
# {'original': 'supplied', 'error': 'supply', 'sentence': 3}
# {'original': 'computer', 'error': 'compuetr', 'sentence': 3}
#
# Sampled data for list 69:
# {'original': 'many', 'error': 'mayn', 'sentence': 5}
# {'original': 'look', 'error': 'olok', 'sentence': 2}
# {'original': 'of', 'error': 'without', 'sentence': 6}
# {'original': 'in', 'error': 'at', 'sentence': 19}
# {'original': 'warned', 'error': 'warns', 'sentence': 1}
#
# Sampled data for list 70:
# {'original': 'of', 'error': 'about', 'sentence': 16}
# {'original': 'end', 'error': 'edn', 'sentence': 4}
# {'original': 'recieved', 'error': 'recieve', 'sentence': 19}
# {'original': 'growing', 'error': 'rgowing', 'sentence': 2}
# {'original': 'feel', 'error': 'felt', 'sentence': 5}
#
# Sampled data for list 71:
# {'original': 'helps', 'error': 'help', 'sentence': 5}
# {'original': 'eye', 'error': 'yee', 'sentence': 5}
# {'original': 'phenomenal', 'error': 'pehnomenal', 'sentence': 4}
# {'original': 'Dear', 'error': 'Dera', 'sentence': 1}
# {'original': 'have', 'error': 'has', 'sentence': 27}
#
# Sampled data for list 72:
# {'original': 'overweight', 'error': 'voerweight', 'sentence': 3}
# {'original': 'than', 'error': 'until', 'sentence': 17}
# {'original': 'used', 'error': 'use', 'sentence': 27}
# {'original': 'playing', 'error': 'plays', 'sentence': 18}
# {'original': 'normal', 'error': 'normla', 'sentence': 2}
#
# Sampled data for list 73:
# {'original': 'need', 'error': 'needs', 'sentence': 3}
# {'original': 'think', 'error': 'thought', 'sentence': 11}
# {'original': 'for', 'error': 'outside', 'sentence': 3}
# {'original': 'go', 'error': 'og', 'sentence': 5}
# {'original': 'important', 'error': 'imporatnt', 'sentence': 1}
#
# Sampled data for list 74:
# {'original': 'writing', 'error': 'write', 'sentence': 9}
# {'original': 'agrees', 'error': 'agreed', 'sentence': 29}
# {'original': 'people', 'error': 'epople', 'sentence': 3}
# {'original': 'allow', 'error': 'allows', 'sentence': 31}
# {'original': 'homework', 'error': 'hoemwork', 'sentence': 4}
#
# Sampled data for list 75:
# {'original': 'know', 'error': 'knows', 'sentence': 16}
# {'original': 'time', 'error': 'tiem', 'sentence': 2}
# {'original': 'goes', 'error': 'oges', 'sentence': 5}
# {'original': 'in', 'error': 'outside', 'sentence': 6}
# {'original': 'exerciceing', 'error': 'exercicees', 'sentence': 7}
#
# Sampled data for list 76:
# {'original': 'relying', 'error': 'rely', 'sentence': 12}
# {'original': 'many', 'error': 'mayn', 'sentence': 3}
# {'original': 'negative', 'error': 'negtaive', 'sentence': 2}
# {'original': 'allows', 'error': 'allow', 'sentence': 4}
# {'original': 'society', 'error': 'soceity', 'sentence': 5}
#
# Sampled data for list 77:
# {'original': 'wasted', 'error': 'waste', 'sentence': 17}
# {'original': 'time', 'error': 'tiem', 'sentence': 2}
# {'original': 'using', 'error': 'use', 'sentence': 19}
# {'original': 'happened', 'error': 'happens', 'sentence': 16}
# {'original': 'with', 'error': 'on', 'sentence': 7}
#
# Sampled data for list 78:
# {'original': 'school', 'error': 'scohol', 'sentence': 4}
# {'original': 'On', 'error': 'accross', 'sentence': 17}
# {'original': 'next', 'error': 'enxt', 'sentence': 5}
# {'original': 'say', 'error': 'said', 'sentence': 15}
# {'original': 'out', 'error': 'upon', 'sentence': 15}
#
# Sampled data for list 79:
# {'original': 'touch', 'error': 'otuch', 'sentence': 5}
# {'original': 'have', 'error': 'has', 'sentence': 21}
# {'original': 'benefit', 'error': 'beenfit', 'sentence': 2}
# {'original': 'come', 'error': 'cmoe', 'sentence': 1}
# {'original': 'with', 'error': 'underneath', 'sentence': 23}
#
# Sampled data for list 80:
# {'original': 'reason', 'error': 'raeson', 'sentence': 3}
# {'original': 'show', 'error': 'shows', 'sentence': 14}
# {'original': 'show', 'error': 'showed', 'sentence': 20}
# {'original': 'keeping', 'error': 'keepign', 'sentence': 2}
# {'original': 'people', 'error': 'peopel', 'sentence': 5}
#
# Sampled data for list 81:
# {'original': 'doing', 'error': 'does', 'sentence': 10}
# {'original': 'know', 'error': 'konw', 'sentence': 6}
# {'original': 'have', 'error': 'had', 'sentence': 25}
# {'original': 'effect', 'error': 'efefct', 'sentence': 1}
# {'original': 'play', 'error': 'played', 'sentence': 15}
#
# Sampled data for list 82:
# {'original': 'people', 'error': 'epople', 'sentence': 2}
# {'original': 'have', 'error': 'had', 'sentence': 19}
# {'original': 'talk', 'error': 'tlak', 'sentence': 3}
# {'original': 'help', 'error': 'hepl', 'sentence': 4}
# {'original': 'local', 'error': 'lcoal', 'sentence': 1}
#
# Sampled data for list 83:
# {'original': 'technology', 'error': 'technoloyg', 'sentence': 1}
# {'original': 'judging', 'error': 'judges', 'sentence': 6}
# {'original': 'wrong', 'error': 'wrnog', 'sentence': 5}
# {'original': 'makes', 'error': 'make', 'sentence': 19}
# {'original': 'help', 'error': 'helps', 'sentence': 7}
#
# Sampled data for list 84:
# {'original': 'allow', 'error': 'allowed', 'sentence': 2}
# {'original': 'on', 'error': 'despite', 'sentence': 25}
# {'original': 'help', 'error': 'helps', 'sentence': 26}
# {'original': 'have', 'error': 'has', 'sentence': 25}
# {'original': 'find', 'error': 'finds', 'sentence': 8}
#
# Sampled data for list 85:
# {'original': 'time', 'error': 'tmie', 'sentence': 3}
# {'original': 'much', 'error': 'mcuh', 'sentence': 2}
# {'original': 'use', 'error': 'ues', 'sentence': 1}
# {'original': 'at', 'error': 'except', 'sentence': 3}
# {'original': 'bad', 'error': 'abd', 'sentence': 4}
#
# Sampled data for list 86:
# {'original': 'decided', 'error': 'decides', 'sentence': 26}
# {'original': 'new', 'error': 'enw', 'sentence': 1}
# {'original': 'goes', 'error': 'go', 'sentence': 14}
# {'original': 'helps', 'error': 'helped', 'sentence': 11}
# {'original': 'to', 'error': 'in', 'sentence': 21}
#
# Sampled data for list 87:
# {'original': 'for', 'error': 'over', 'sentence': 9}
# {'original': 'local', 'error': 'lcoal', 'sentence': 1}
# {'original': 'using', 'error': 'use', 'sentence': 6}
# {'original': 'sometimes', 'error': 'someitmes', 'sentence': 5}
# {'original': 'think', 'error': 'thinks', 'sentence': 7}
#
# Sampled data for list 88:
# {'original': 'think', 'error': 'thought', 'sentence': 19}
# {'original': 'people', 'error': 'pepole', 'sentence': 5}
# {'original': 'done', 'error': 'does', 'sentence': 20}
# {'original': 'everyday', 'error': 'everydya', 'sentence': 3}
# {'original': 'losing', 'error': 'loses', 'sentence': 21}
#
# Sampled data for list 89:
# {'original': 'positive', 'error': 'positvie', 'sentence': 2}
# {'original': 'have', 'error': 'had', 'sentence': 11}
# {'original': 'across', 'error': 'acorss', 'sentence': 3}
# {'original': 'brain', 'error': 'brian', 'sentence': 5}
# {'original': 'from', 'error': 'among', 'sentence': 4}
#
# Sampled data for list 90:
# {'original': 'us', 'error': 'su', 'sentence': 3}
# {'original': 'than', 'error': 'until', 'sentence': 5}
# {'original': 'of', 'error': 'outside', 'sentence': 4}
# {'original': 'make', 'error': 'amke', 'sentence': 2}
# {'original': 'applied', 'error': 'applies', 'sentence': 9}
#
# Sampled data for list 91:
# {'original': 'agrees', 'error': 'agree', 'sentence': 4}
# {'original': 'local', 'error': 'olcal', 'sentence': 1}
# {'original': 'on', 'error': 'over', 'sentence': 16}
# {'original': 'have', 'error': 'has', 'sentence': 19}
# {'original': 'statting', 'error': 'statte', 'sentence': 18}
#
# Sampled data for list 92:
# {'original': 'for', 'error': 'despite', 'sentence': 11}
# {'original': 'takes', 'error': 'took', 'sentence': 15}
# {'original': 'big', 'error': 'bgi', 'sentence': 4}
# {'original': 'causes', 'error': 'caused', 'sentence': 3}
# {'original': 'caused', 'error': 'causes', 'sentence': 5}
#
# Sampled data for list 93:
# {'original': 'day', 'error': 'dya', 'sentence': 1}
# {'original': 'think', 'error': 'thinks', 'sentence': 1}
# {'original': 'have', 'error': 'has', 'sentence': 20}
# {'original': 'on', 'error': 'over', 'sentence': 18}
# {'original': 'sit', 'error': 'sits', 'sentence': 4}
#
# Sampled data for list 94:
# {'original': 'easier', 'error': 'esaier', 'sentence': 4}
# {'original': 'use', 'error': 'sue', 'sentence': 5}
# {'original': 'use', 'error': 'used', 'sentence': 29}
# {'original': 'finsing', 'error': 'finses', 'sentence': 3}
# {'original': 'allow', 'error': 'allows', 'sentence': 30}
#
# Sampled data for list 95:
# {'original': 'is', 'error': 'was', 'sentence': 1}
# {'original': 'harm', 'error': 'ahrm', 'sentence': 4}
# {'original': 'going', 'error': 'goes', 'sentence': 17}
# {'original': 'trying', 'error': 'tries', 'sentence': 13}
# {'original': 'of', 'error': 'up', 'sentence': 5}
#
# Sampled data for list 96:
# {'original': 'agree', 'error': 'agreed', 'sentence': 17}
# {'original': 'want', 'error': 'wants', 'sentence': 22}
# {'original': 'about', 'error': 'between', 'sentence': 3}
# {'original': 'hand', 'error': 'hnad', 'sentence': 3}
# {'original': 'computer', 'error': 'copmuter', 'sentence': 1}
#
# Sampled data for list 97:
# {'original': 'filled', 'error': 'fills', 'sentence': 1}
# {'original': 'even', 'error': 'eevn', 'sentence': 3}
# {'original': 'life', 'error': 'lief', 'sentence': 5}
# {'original': 'need', 'error': 'needs', 'sentence': 24}
# {'original': 'happened', 'error': 'happens', 'sentence': 11}
#
# Sampled data for list 98:
# {'original': 'taught', 'error': 'teaches', 'sentence': 25}
# {'original': 'with', 'error': 'near', 'sentence': 18}
# {'original': 'keeps', 'error': 'kept', 'sentence': 18}
# {'original': 'everyone', 'error': 'eevryone', 'sentence': 2}
# {'original': 'with', 'error': 'among', 'sentence': 5}
#
# Sampled data for list 99:
# {'original': 'without', 'error': 'onto', 'sentence': 2}
# {'original': 'used', 'error': 'uses', 'sentence': 18}
# {'original': 'think', 'error': 'thought', 'sentence': 6}
# {'original': 'local', 'error': 'loacl', 'sentence': 3}
# {'original': 'provide', 'error': 'provides', 'sentence': 24}
#
# Sampled data for list 100:
# {'original': 'to', 'error': 'in', 'sentence': 1}
# {'original': 'allow', 'error': 'allows', 'sentence': 15}
# {'original': 'run', 'error': 'urn', 'sentence': 5}
# {'original': 'run', 'error': 'runs', 'sentence': 5}
# {'original': 'growing', 'error': 'gorwing', 'sentence': 2}

# %%
np.array(sampled_errors).shape
# Out:
# (100, 5)

# %%
joblib.dump(sampled_errors, 'files/error_train_100essay_5err')
# Out:
# ['files/error_train_100essay_5err']

# %%
# Function to apply corrections to the essay
def apply_errors(essay, errors):
    # Tokenize the essay into sentences using NLTK
    sentences = nltk.sent_tokenize(essay)

    # Create a list to store corrected sentences
    errored_sentences = []

    # Iterate through sentences
    for i, sentence in enumerate(sentences):
        # Apply corrections to the current sentence
        for error in errors:
            # Adjust the index by subtracting 1 to match the enumeration starting from 0
            if error['sentence'] == i + 1:
                # Replace all occurrences of the incorrect text with the correction
                #sentence = sentence.replace(correction['original'], correction['correction'])
                 # Use regular expression with word boundaries to replace only whole words
                sentence = re.sub(r'\b' + re.escape(error['original']) + r'\b', error['error'], sentence)
        # Add the corrected sentence to the list
        errored_sentences.append(sentence)

    # Join the corrected sentences to form the final essay
    errored_essay = ' '.join(errored_sentences)
    return errored_essay

# Function to generate all combinations of corrections and apply them
def generate_errored_versions(essay, errors):
    errored_versions = []
    max_errors = len(errors)

    # Iterate over different numbers of corrections to apply
    for num_errors in range(1, max_errors + 1):
        for combination in itertools.combinations(errors, num_errors):
            errored_essay = apply_errors(essay, combination)
            errored_versions.append(errored_essay)
  
    return errored_versions

# Example usage
essay = "This is a tess essay. The break through was amazing. The possitive effects were clear."
errors = [
    {'original': 'tess', 'error': 'test', 'type': 'Spelling', 'sentence': 1},
    {'original': 'break through', 'error': 'breakthrough', 'type': 'Spelling', 'sentence': 2},
    {'original': 'possitive', 'error': 'positive', 'type': 'Spelling', 'sentence': 3},
]

# Generate corrected versions with combinations of 1, 2, and 3 corrections
errored_versions = generate_errored_versions(essay, errors)
errored_versions
# Out:
# ['This is a test essay. The break through was amazing. The possitive effects were clear.',
#  'This is a tess essay. The breakthrough was amazing. The possitive effects were clear.',
#  'This is a tess essay. The break through was amazing. The positive effects were clear.',
#  'This is a test essay. The breakthrough was amazing. The possitive effects were clear.',
#  'This is a test essay. The break through was amazing. The positive effects were clear.',
#  'This is a tess essay. The breakthrough was amazing. The positive effects were clear.',
#  'This is a test essay. The breakthrough was amazing. The positive effects were clear.']

# %%
error_train_100essay_5err = joblib.load('files/error_train_100essay_5err')

errored_train_100data_5err = []

for index, row in data_100.iterrows():
    try:
        errored_essays = generate_errored_versions(row['essay'], error_train_100essay_5err[index]) 
        # Append the result to the list
        errored_train_100data_5err.append(errored_essays)
    except Exception as e:
        print(f"Error processing row {index}: {e}")
        errored_train_100data_5err.append(None)  # Append None or an empty dict if an error occurs
    print(index + 1, " finished")
# Out:
# 1  finished
# 2  finished
# 3  finished
# 4  finished
# 5  finished
# 6  finished
# 7  finished
# 8  finished
# 9  finished
# 10  finished
# 11  finished
# 12  finished
# 13  finished
# 14  finished
# 15  finished
# 16  finished
# 17  finished
# 18  finished
# 19  finished
# 20  finished
# 21  finished
# 22  finished
# 23  finished
# 24  finished
# 25  finished
# 26  finished
# 27  finished
# 28  finished
# 29  finished
# 30  finished
# 31  finished
# 32  finished
# 33  finished
# 34  finished
# 35  finished
# 36  finished
# 37  finished
# 38  finished
# 39  finished
# 40  finished
# 41  finished
# 42  finished
# 43  finished
# 44  finished
# 45  finished
# 46  finished
# 47  finished
# 48  finished
# 49  finished
# 50  finished
# 51  finished
# 52  finished
# 53  finished
# 54  finished
# 55  finished
# 56  finished
# 57  finished
# 58  finished
# 59  finished
# 60  finished
# 61  finished
# 62  finished
# 63  finished
# 64  finished
# 65  finished
# 66  finished
# 67  finished
# 68  finished
# 69  finished
# 70  finished
# 71  finished
# 72  finished
# 73  finished
# 74  finished
# 75  finished
# 76  finished
# 77  finished
# 78  finished
# 79  finished
# 80  finished
# 81  finished
# 82  finished
# 83  finished
# 84  finished
# 85  finished
# 86  finished
# 87  finished
# 88  finished
# 89  finished
# 90  finished
# 91  finished
# 92  finished
# 93  finished
# 94  finished
# 95  finished
# 96  finished
# 97  finished
# 98  finished
# 99  finished
# 100  finished

# %%
np.array(errored_train_100data_5err).shape
# Out:
# (100, 31)

# %%
joblib.dump(errored_train_100data_5err, 'files/errored_train_100data_5err')
# Out:
# ['files/errored_train_100data_5err']
