# %%
import joblib
import numpy as np

# %%
feats_counter_train_error = joblib.load('files/feats_counter_train_correct_778')
feats_counter_test_error = joblib.load('files/feats_counter_test_correct_778')
asap_features = joblib.load('files/asap1_features_778')

# %%
print(feats_counter_train_error.shape)
print(feats_counter_test_error.shape)
print(asap_features.shape)
# Out:
# (100, 31, 1, 778)
# (100, 31, 1, 778)
# (1783, 1, 778)

# %%
feats_counter_train_error_776 = np.delete(feats_counter_train_error, [5,6],axis=3)
print(feats_counter_train_error_776.shape)

feats_counter_test_error_776 = np.delete(feats_counter_test_error, [5,6],axis=3)
print(feats_counter_test_error_776.shape)

asap_features_776 = np.delete(asap_features, [5,6],axis=2)
print(asap_features_776.shape)
# Out:
# (100, 31, 1, 776)
# (100, 31, 1, 776)
# (1783, 1, 776)

# %%
joblib.dump(feats_counter_train_error_776, 'files/feats_counter_train_correct_776')
joblib.dump(feats_counter_train_error_776, 'files/feats_counter_test_correct_776')
joblib.dump(asap_features_776, 'files/asap1_features_776')
# Out:
# ['files/asap1_features_776']
