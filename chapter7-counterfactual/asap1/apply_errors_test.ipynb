# %%
import joblib
import pandas as pd
import nltk
import re
import itertools
import random
import numpy as np

# %%
data = pd.read_csv('ASAP1 Test Set.tsv', sep='\t')
data_100 = data[:100]
data_100.head()
# Out:
#    essay_id                                              essay  domain1_score
# 0       827  I think computers have a postitive affect on p...              6
# 1      1477  I blive that computers have a lot of effects o...              6
# 2       234  Many people think that computers are not a goo...              8
# 3       801  Dear Newspaper people, @CAPS1 you might heard ...              9
# 4       780  More and more people are using computers on a ...              9

# %%
errors = joblib.load('files/error_lists_test_100')
#error_test_100essay_5err = joblib.load('error_test_100essay_5err')

# %%
# Function to sample 5 dictionaries from each inner list
def sample_five_from_each(inner_lists):
    return [random.sample(inner_list, min(len(inner_list), 5)) for inner_list in inner_lists]

# Sample 5 dictionaries from each inner list
sampled_errors = sample_five_from_each(errors)

print(np.array(sampled_errors).shape)

# Print the results
for idx, sampled_list in enumerate(sampled_errors):
    print(f"Sampled data for list {idx + 1}:")
    for item in sampled_list:
        print(item)
    print()
# Out:
# (100, 5)
# Sampled data for list 1:
# {'original': 'like', 'error': 'ilke', 'sentence': 4}
# {'original': 'think', 'error': 'thought', 'sentence': 1}
# {'original': 'society', 'error': 'soicety', 'sentence': 2}
# {'original': 'interact', 'error': 'intercat', 'sentence': 3}
# {'original': 'to', 'error': 'around', 'sentence': 2}
#
# Sampled data for list 2:
# {'original': 'lose', 'error': 'loses', 'sentence': 2}
# {'original': 'see', 'error': 'ese', 'sentence': 2}
# {'original': 'like', 'error': 'along', 'sentence': 2}
# {'original': 'set', 'error': 'est', 'sentence': 3}
# {'original': 'people', 'error': 'poeple', 'sentence': 1}
#
# Sampled data for list 3:
# {'original': 'exercise', 'error': 'exrecise', 'sentence': 2}
# {'original': 'maybe', 'error': 'myabe', 'sentence': 4}
# {'original': 'beneficial', 'error': 'ebneficial', 'sentence': 5}
# {'original': 'looked', 'error': 'look', 'sentence': 19}
# {'original': 'have', 'error': 'has', 'sentence': 24}
#
# Sampled data for list 4:
# {'original': 'up', 'error': 'except', 'sentence': 39}
# {'original': 'agree', 'error': 'argee', 'sentence': 2}
# {'original': 'fly', 'error': 'fyl', 'sentence': 5}
# {'original': 'new', 'error': 'enw', 'sentence': 3}
# {'original': 'Time', 'error': 'Tmie', 'sentence': 4}
#
# Sampled data for list 5:
# {'original': 'know', 'error': 'knows', 'sentence': 19}
# {'original': 'time', 'error': 'tmie', 'sentence': 2}
# {'original': 'show', 'error': 'shows', 'sentence': 10}
# {'original': 'causes', 'error': 'cause', 'sentence': 9}
# {'original': 'time', 'error': 'tiem', 'sentence': 4}
#
# Sampled data for list 6:
# {'original': 'looking', 'error': 'look', 'sentence': 19}
# {'original': 'heard', 'error': 'hears', 'sentence': 1}
# {'original': 'live', 'error': 'lvie', 'sentence': 5}
# {'original': 'think', 'error': 'thikn', 'sentence': 2}
# {'original': 'on', 'error': 'at', 'sentence': 8}
#
# Sampled data for list 7:
# {'original': 'to', 'error': 'on', 'sentence': 18}
# {'original': 'gives', 'error': 'give', 'sentence': 12}
# {'original': 'on', 'error': 'upon', 'sentence': 1}
# {'original': 'people', 'error': 'pepole', 'sentence': 2}
# {'original': 'Read', 'error': 'Raed', 'sentence': 4}
#
# Sampled data for list 8:
# {'original': 'idea', 'error': 'ieda', 'sentence': 1}
# {'original': 'Chatting', 'error': 'Chattign', 'sentence': 5}
# {'original': 'of', 'error': 'until', 'sentence': 1}
# {'original': 'for', 'error': 'among', 'sentence': 2}
# {'original': 'loves', 'error': 'love', 'sentence': 16}
#
# Sampled data for list 9:
# {'original': 'people', 'error': 'pepole', 'sentence': 2}
# {'original': 'use', 'error': 'used', 'sentence': 18}
# {'original': 'people', 'error': 'pepole', 'sentence': 1}
# {'original': 'understand', 'error': 'understood', 'sentence': 21}
# {'original': 'about', 'error': 'near', 'sentence': 6}
#
# Sampled data for list 10:
# {'original': 'outside', 'error': 'otuside', 'sentence': 1}
# {'original': 'said', 'error': 'says', 'sentence': 20}
# {'original': 'negative', 'error': 'negtaive', 'sentence': 4}
# {'original': 'try', 'error': 'tries', 'sentence': 3}
# {'original': 'in', 'error': 'with', 'sentence': 19}
#
# Sampled data for list 11:
# {'original': 'study', 'error': 'stuyd', 'sentence': 2}
# {'original': 'hope', 'error': 'hopes', 'sentence': 27}
# {'original': 'asked', 'error': 'ask', 'sentence': 19}
# {'original': 'ends', 'error': 'end', 'sentence': 24}
# {'original': 'one', 'error': 'noe', 'sentence': 5}
#
# Sampled data for list 12:
# {'original': 'hit', 'error': 'hits', 'sentence': 21}
# {'original': 'benefits', 'error': 'benefit', 'sentence': 10}
# {'original': 'School', 'error': 'School', 'sentence': 4}
# {'original': 'wrong', 'error': 'wrogn', 'sentence': 2}
# {'original': 'for', 'error': 'among', 'sentence': 27}
#
# Sampled data for list 13:
# {'original': 'ran', 'error': 'runs', 'sentence': 18}
# {'original': 'do', 'error': 'did', 'sentence': 17}
# {'original': 'browning', 'error': 'borwning', 'sentence': 1}
# {'original': 'do', 'error': 'does', 'sentence': 11}
# {'original': 'on', 'error': 'onto', 'sentence': 16}
#
# Sampled data for list 14:
# {'original': 'with', 'error': 'up', 'sentence': 4}
# {'original': 'Dear', 'error': 'eDar', 'sentence': 1}
# {'original': 'require', 'error': 'required', 'sentence': 10}
# {'original': 'class', 'error': 'clsas', 'sentence': 5}
# {'original': 'research', 'error': 'researhc', 'sentence': 3}
#
# Sampled data for list 15:
# {'original': 'society', 'error': 'osciety', 'sentence': 1}
# {'original': 'like', 'error': 'lkie', 'sentence': 5}
# {'original': 'believe', 'error': 'believes', 'sentence': 1}
# {'original': 'like', 'error': 'after', 'sentence': 5}
# {'original': 'betters', 'error': 'well', 'sentence': 22}
#
# Sampled data for list 16:
# {'original': 'efficient', 'error': 'effiicent', 'sentence': 5}
# {'original': 'Dear', 'error': 'Dera', 'sentence': 1}
# {'original': 'have', 'error': 'has', 'sentence': 23}
# {'original': 'with', 'error': 'accross', 'sentence': 20}
# {'original': 'asking', 'error': 'asks', 'sentence': 6}
#
# Sampled data for list 17:
# {'original': 'with', 'error': 'despite', 'sentence': 8}
# {'original': 'people', 'error': 'poeple', 'sentence': 4}
# {'original': 'turn', 'error': 'turned', 'sentence': 1}
# {'original': 'mind', 'error': 'midn', 'sentence': 5}
# {'original': 'After', 'error': 'accross', 'sentence': 15}
#
# Sampled data for list 18:
# {'original': 'information', 'error': 'informatino', 'sentence': 4}
# {'original': 'say', 'error': 'says', 'sentence': 15}
# {'original': 'on', 'error': 'onto', 'sentence': 16}
# {'original': 'keep', 'error': 'kept', 'sentence': 20}
# {'original': 'thought', 'error': 'think', 'sentence': 11}
#
# Sampled data for list 19:
# {'original': 'out', 'error': 'toward', 'sentence': 8}
# {'original': 'Without', 'error': 'outside', 'sentence': 12}
# {'original': 'hope', 'error': 'hopes', 'sentence': 16}
# {'original': 'page', 'error': 'apge', 'sentence': 2}
# {'original': 'believe', 'error': 'believed', 'sentence': 1}
#
# Sampled data for list 20:
# {'original': 'need', 'error': 'needs', 'sentence': 6}
# {'original': 'with', 'error': 'for', 'sentence': 16}
# {'original': 'people', 'error': 'pepole', 'sentence': 3}
# {'original': 'feel', 'error': 'felt', 'sentence': 2}
# {'original': 'use', 'error': 'ues', 'sentence': 1}
#
# Sampled data for list 21:
# {'original': 'Dear', 'error': 'Dera', 'sentence': 1}
# {'original': 'pay', 'error': 'pays', 'sentence': 33}
# {'original': 'would', 'error': 'wuold', 'sentence': 5}
# {'original': 'believe', 'error': 'believes', 'sentence': 5}
# {'original': 'about', 'error': 'at', 'sentence': 22}
#
# Sampled data for list 22:
# {'original': 'computer', 'error': 'copmuter', 'sentence': 3}
# {'original': 'world', 'error': 'owrld', 'sentence': 5}
# {'original': 'think', 'error': 'thinks', 'sentence': 2}
# {'original': 'inform', 'error': 'inofrm', 'sentence': 1}
# {'original': 'in', 'error': 'toward', 'sentence': 5}
#
# Sampled data for list 23:
# {'original': 'says', 'error': 'said', 'sentence': 5}
# {'original': 'on', 'error': 'toward', 'sentence': 5}
# {'original': 'school', 'error': 'shcool', 'sentence': 1}
# {'original': 'many', 'error': 'amny', 'sentence': 3}
# {'original': 'called', 'error': 'calls', 'sentence': 13}
#
# Sampled data for list 24:
# {'original': 'think', 'error': 'tihnk', 'sentence': 1}
# {'original': 'made', 'error': 'make', 'sentence': 4}
# {'original': 'on', 'error': 'beside', 'sentence': 11}
# {'original': 'buy', 'error': 'bought', 'sentence': 5}
# {'original': 'effective', 'error': 'effectiev', 'sentence': 4}
#
# Sampled data for list 25:
# {'original': 'sitting', 'error': 'sittnig', 'sentence': 3}
# {'original': 'computer', 'error': 'cmoputer', 'sentence': 2}
# {'original': 'think', 'error': 'thinks', 'sentence': 5}
# {'original': 'from', 'error': 'by', 'sentence': 1}
# {'original': 'spending', 'error': 'spenidng', 'sentence': 1}
#
# Sampled data for list 26:
# {'original': 'said', 'error': 'say', 'sentence': 30}
# {'original': 'bring', 'error': 'brought', 'sentence': 36}
# {'original': 'want', 'error': 'wants', 'sentence': 31}
# {'original': 'one', 'error': 'oen', 'sentence': 3}
# {'original': 'useful', 'error': 'useufl', 'sentence': 2}
#
# Sampled data for list 27:
# {'original': 'within', 'error': 'withni', 'sentence': 4}
# {'original': 'going', 'error': 'go', 'sentence': 15}
# {'original': 'day', 'error': 'dya', 'sentence': 1}
# {'original': 'require', 'error': 'required', 'sentence': 13}
# {'original': 'fit', 'error': 'fti', 'sentence': 5}
#
# Sampled data for list 28:
# {'original': 'gaining', 'error': 'gainnig', 'sentence': 4}
# {'original': 'gaining', 'error': 'gains', 'sentence': 4}
# {'original': 'talking', 'error': 'talks', 'sentence': 14}
# {'original': 'seemed', 'error': 'seem', 'sentence': 6}
# {'original': 'positive', 'error': 'psoitive', 'sentence': 1}
#
# Sampled data for list 29:
# {'original': 'believe', 'error': 'believed', 'sentence': 1}
# {'original': 'allow', 'error': 'alolw', 'sentence': 1}
# {'original': 'over', 'error': 'about', 'sentence': 4}
# {'original': 'in', 'error': 'underneath', 'sentence': 4}
# {'original': 'believe', 'error': 'beleive', 'sentence': 1}
#
# Sampled data for list 30:
# {'original': 'of', 'error': 'except', 'sentence': 13}
# {'original': 'provide', 'error': 'provdie', 'sentence': 5}
# {'original': 'know', 'error': 'knows', 'sentence': 6}
# {'original': 'By', 'error': 'between', 'sentence': 17}
# {'original': 'communication', 'error': 'comumnication', 'sentence': 2}
#
# Sampled data for list 31:
# {'original': 'ask', 'error': 'sak', 'sentence': 2}
# {'original': 'wondering', 'error': 'wonder', 'sentence': 18}
# {'original': 'instance', 'error': 'insatnce', 'sentence': 5}
# {'original': 'country', 'error': 'counrty', 'sentence': 4}
# {'original': 'in', 'error': 'except', 'sentence': 2}
#
# Sampled data for list 32:
# {'original': 'help', 'error': 'helped', 'sentence': 24}
# {'original': 'writting', 'error': 'writte', 'sentence': 13}
# {'original': 'close', 'error': 'colse', 'sentence': 4}
# {'original': 'paper', 'error': 'paepr', 'sentence': 3}
# {'original': 'good', 'error': 'godo', 'sentence': 1}
#
# Sampled data for list 33:
# {'original': 'give', 'error': 'gives', 'sentence': 25}
# {'original': 'increase', 'error': 'incresae', 'sentence': 4}
# {'original': 'tha', 'error': 'hta', 'sentence': 5}
# {'original': 'on', 'error': 'accross', 'sentence': 16}
# {'original': 'allow', 'error': 'allowed', 'sentence': 5}
#
# Sampled data for list 34:
# {'original': 'pure', 'error': 'puer', 'sentence': 4}
# {'original': 'hope', 'error': 'hopes', 'sentence': 22}
# {'original': 'use', 'error': 'uses', 'sentence': 24}
# {'original': 'everyday', 'error': 'everdyay', 'sentence': 6}
# {'original': 'people', 'error': 'epople', 'sentence': 7}
#
# Sampled data for list 35:
# {'original': 'as', 'error': 'behind', 'sentence': 11}
# {'original': 'live', 'error': 'liev', 'sentence': 1}
# {'original': 'of', 'error': 'on', 'sentence': 25}
# {'original': 'know', 'error': 'knew', 'sentence': 18}
# {'original': 'feel', 'error': 'feels', 'sentence': 4}
#
# Sampled data for list 36:
# {'original': 'house', 'error': 'ohuse', 'sentence': 1}
# {'original': 'computer', 'error': 'comupter', 'sentence': 5}
# {'original': 'runs', 'error': 'run', 'sentence': 5}
# {'original': 'much', 'error': 'mcuh', 'sentence': 2}
# {'original': 'have', 'error': 'had', 'sentence': 11}
#
# Sampled data for list 37:
# {'original': 'writing', 'error': 'wirting', 'sentence': 1}
# {'original': 'know', 'error': 'knew', 'sentence': 9}
# {'original': 'learn', 'error': 'leran', 'sentence': 2}
# {'original': 'benefits', 'error': 'benefited', 'sentence': 3}
# {'original': 'couple', 'error': 'copule', 'sentence': 3}
#
# Sampled data for list 38:
# {'original': 'allowing', 'error': 'allow', 'sentence': 16}
# {'original': 'have', 'error': 'had', 'sentence': 23}
# {'original': 'helps', 'error': 'helped', 'sentence': 20}
# {'original': 'away', 'error': 'waay', 'sentence': 4}
# {'original': 'talk', 'error': 'atlk', 'sentence': 3}
#
# Sampled data for list 39:
# {'original': 'saves', 'error': 'save', 'sentence': 7}
# {'original': 'remember', 'error': 'remembers', 'sentence': 14}
# {'original': 'with', 'error': 'on', 'sentence': 27}
# {'original': 'Dear', 'error': 'Daer', 'sentence': 1}
# {'original': 'teaches', 'error': 'teach', 'sentence': 32}
#
# Sampled data for list 40:
# {'original': 'go', 'error': 'goes', 'sentence': 19}
# {'original': 'on', 'error': 'underneath', 'sentence': 16}
# {'original': 'about', 'error': 'as', 'sentence': 23}
# {'original': 'like', 'error': 'likes', 'sentence': 10}
# {'original': 'bad', 'error': 'bda', 'sentence': 1}
#
# Sampled data for list 41:
# {'original': 'into', 'error': 'since', 'sentence': 25}
# {'original': 'understand', 'error': 'understands', 'sentence': 1}
# {'original': 'by', 'error': 'for', 'sentence': 11}
# {'original': 'many', 'error': 'mayn', 'sentence': 4}
# {'original': 'believe', 'error': 'believed', 'sentence': 23}
#
# Sampled data for list 42:
# {'original': 'to', 'error': 'after', 'sentence': 6}
# {'original': 'say', 'error': 'said', 'sentence': 24}
# {'original': 'disadvantage', 'error': 'idsadvantage', 'sentence': 3}
# {'original': 'disadvantage', 'error': 'disadavntage', 'sentence': 5}
# {'original': 'of', 'error': 'into', 'sentence': 10}
#
# Sampled data for list 43:
# {'original': 'saying', 'error': 'says', 'sentence': 11}
# {'original': 'for', 'error': 'on', 'sentence': 5}
# {'original': 'support', 'error': 'suppotr', 'sentence': 2}
# {'original': 'agree', 'error': 'agreed', 'sentence': 12}
# {'original': 'people', 'error': 'poeple', 'sentence': 5}
#
# Sampled data for list 44:
# {'original': 'have', 'error': 'had', 'sentence': 4}
# {'original': 'people', 'error': 'pepole', 'sentence': 4}
# {'original': 'with', 'error': 'since', 'sentence': 5}
# {'original': 'great', 'error': 'gerat', 'sentence': 1}
# {'original': 'keep', 'error': 'keep', 'sentence': 5}
#
# Sampled data for list 45:
# {'original': 'beleive', 'error': 'beleives', 'sentence': 9}
# {'original': 'use', 'error': 'used', 'sentence': 20}
# {'original': 'email', 'error': 'emailed', 'sentence': 13}
# {'original': 'many', 'error': 'amny', 'sentence': 2}
# {'original': 'three', 'error': 'three', 'sentence': 4}
#
# Sampled data for list 46:
# {'original': 'college', 'error': 'colleeg', 'sentence': 3}
# {'original': 'valuable', 'error': 'valuabel', 'sentence': 2}
# {'original': 'on', 'error': 'between', 'sentence': 7}
# {'original': 'of', 'error': 'up', 'sentence': 10}
# {'original': 'child', 'error': 'chlid', 'sentence': 5}
#
# Sampled data for list 47:
# {'original': 'waiting', 'error': 'wait', 'sentence': 18}
# {'original': 'increases', 'error': 'increased', 'sentence': 22}
# {'original': 'ever', 'error': 'eevr', 'sentence': 5}
# {'original': 'spend', 'error': 'spned', 'sentence': 4}
# {'original': 'up', 'error': 'to', 'sentence': 27}
#
# Sampled data for list 48:
# {'original': 'nice', 'error': 'niec', 'sentence': 5}
# {'original': 'going', 'error': 'goes', 'sentence': 6}
# {'original': 'of', 'error': 'since', 'sentence': 29}
# {'original': 'shows', 'error': 'showed', 'sentence': 29}
# {'original': 'spend', 'error': 'psend', 'sentence': 4}
#
# Sampled data for list 49:
# {'original': 'country', 'error': 'countyr', 'sentence': 2}
# {'original': 'might', 'error': 'mihgt', 'sentence': 4}
# {'original': 'out', 'error': 'for', 'sentence': 1}
# {'original': 'family', 'error': 'famliy', 'sentence': 3}
# {'original': 'in', 'error': 'accross', 'sentence': 19}
#
# Sampled data for list 50:
# {'original': 'without', 'error': 'until', 'sentence': 6}
# {'original': 'have', 'error': 'has', 'sentence': 10}
# {'original': 'make', 'error': 'mkae', 'sentence': 3}
# {'original': 'make', 'error': 'makes', 'sentence': 2}
# {'original': 'benefit', 'error': 'benefti', 'sentence': 1}
#
# Sampled data for list 51:
# {'original': 'look', 'error': 'looked', 'sentence': 8}
# {'original': 'help', 'error': 'helps', 'sentence': 3}
# {'original': 'orders', 'error': 'ordered', 'sentence': 16}
# {'original': 'in', 'error': 'at', 'sentence': 16}
# {'original': 'science', 'error': 'sceince', 'sentence': 4}
#
# Sampled data for list 52:
# {'original': 'up', 'error': 'past', 'sentence': 15}
# {'original': 'attention', 'error': 'attentino', 'sentence': 2}
# {'original': 'used', 'error': 'uses', 'sentence': 17}
# {'original': 'bought', 'error': 'buy', 'sentence': 8}
# {'original': 'correct', 'error': 'corrcet', 'sentence': 3}
#
# Sampled data for list 53:
# {'original': 'high', 'error': 'hgih', 'sentence': 2}
# {'original': 'hurt', 'error': 'hurts', 'sentence': 20}
# {'original': 'school', 'error': 'scohol', 'sentence': 4}
# {'original': 'doing', 'error': 'do', 'sentence': 3}
# {'original': 'to', 'error': 'with', 'sentence': 2}
#
# Sampled data for list 54:
# {'original': 'body', 'error': 'bdoy', 'sentence': 5}
# {'original': 'time', 'error': 'itme', 'sentence': 2}
# {'original': 'amount', 'error': 'aomunt', 'sentence': 3}
# {'original': 'help', 'error': 'hlep', 'sentence': 1}
# {'original': 'of', 'error': 'down', 'sentence': 18}
#
# Sampled data for list 55:
# {'original': 'On', 'error': 'inside', 'sentence': 20}
# {'original': 'believe', 'error': 'believed', 'sentence': 33}
# {'original': 'think', 'error': 'thikn', 'sentence': 2}
# {'original': 'found', 'error': 'finds', 'sentence': 32}
# {'original': 'play', 'error': 'plays', 'sentence': 19}
#
# Sampled data for list 56:
# {'original': 'want', 'error': 'wnat', 'sentence': 3}
# {'original': 'think', 'error': 'thikn', 'sentence': 1}
# {'original': 'on', 'error': 'past', 'sentence': 4}
# {'original': 'sites', 'error': 'sited', 'sentence': 10}
# {'original': 'try', 'error': 'tried', 'sentence': 9}
#
# Sampled data for list 57:
# {'original': 'time', 'error': 'itme', 'sentence': 1}
# {'original': 'harder', 'error': 'haredr', 'sentence': 3}
# {'original': 'decreased', 'error': 'decrease', 'sentence': 9}
# {'original': 'talk', 'error': 'takl', 'sentence': 5}
# {'original': 'kept', 'error': 'keep', 'sentence': 24}
#
# Sampled data for list 58:
# {'original': 'say', 'error': 'said', 'sentence': 8}
# {'original': 'to', 'error': 'for', 'sentence': 9}
# {'original': 'in', 'error': 'into', 'sentence': 7}
# {'original': 'nothing', 'error': 'nothnig', 'sentence': 3}
# {'original': 'two', 'error': 'wto', 'sentence': 5}
#
# Sampled data for list 59:
# {'original': 'like', 'error': 'over', 'sentence': 2}
# {'original': 'see', 'error': 'saw', 'sentence': 12}
# {'original': 'tell', 'error': 'etll', 'sentence': 4}
# {'original': 'allow', 'error': 'allows', 'sentence': 3}
# {'original': 'positive', 'error': 'poistive', 'sentence': 2}
#
# Sampled data for list 60:
# {'original': 'thrown', 'error': 'throw', 'sentence': 6}
# {'original': 'healthy', 'error': 'heatlhy', 'sentence': 3}
# {'original': 'have', 'error': 'has', 'sentence': 5}
# {'original': 'as', 'error': 'under', 'sentence': 9}
# {'original': 'thrown', 'error': 'thorwn', 'sentence': 5}
#
# Sampled data for list 61:
# {'original': 'teach', 'error': 'tecah', 'sentence': 4}
# {'original': 'teach', 'error': 'taught', 'sentence': 4}
# {'original': 'on', 'error': 'around', 'sentence': 8}
# {'original': 'have', 'error': 'has', 'sentence': 8}
# {'original': 'stay', 'error': 'tsay', 'sentence': 3}
#
# Sampled data for list 62:
# {'original': 'essay', 'error': 'esasy', 'sentence': 4}
# {'original': 'give', 'error': 'gave', 'sentence': 3}
# {'original': 'have', 'error': 'has', 'sentence': 27}
# {'original': 'in', 'error': 'among', 'sentence': 31}
# {'original': 'say', 'error': 'says', 'sentence': 17}
#
# Sampled data for list 63:
# {'original': 'car', 'error': 'cra', 'sentence': 4}
# {'original': 'changed', 'error': 'change', 'sentence': 18}
# {'original': 'on', 'error': 'except', 'sentence': 28}
# {'original': 'to', 'error': 'with', 'sentence': 1}
# {'original': 'know', 'error': 'knows', 'sentence': 33}
#
# Sampled data for list 64:
# {'original': 'believe', 'error': 'believes', 'sentence': 2}
# {'original': 'Also', 'error': 'Alos', 'sentence': 4}
# {'original': 'computer', 'error': 'comptuer', 'sentence': 1}
# {'original': 'know', 'error': 'knew', 'sentence': 13}
# {'original': 'turned', 'error': 'turn', 'sentence': 7}
#
# Sampled data for list 65:
# {'original': 'educate', 'error': 'educated', 'sentence': 4}
# {'original': 'effect', 'error': 'effetc', 'sentence': 3}
# {'original': 'easier', 'error': 'esaier', 'sentence': 2}
# {'original': 'make', 'error': 'makes', 'sentence': 20}
# {'original': 'might', 'error': 'mgiht', 'sentence': 5}
#
# Sampled data for list 66:
# {'original': 'find', 'error': 'fnid', 'sentence': 2}
# {'original': 'help', 'error': 'helped', 'sentence': 4}
# {'original': 'spend', 'error': 'spent', 'sentence': 6}
# {'original': 'be', 'error': 'was', 'sentence': 7}
# {'original': 'use', 'error': 'used', 'sentence': 5}
#
# Sampled data for list 67:
# {'original': 'on', 'error': 'except', 'sentence': 13}
# {'original': 'as', 'error': 'by', 'sentence': 5}
# {'original': 'make', 'error': 'made', 'sentence': 4}
# {'original': 'teach', 'error': 'tecah', 'sentence': 2}
# {'original': 'yet', 'error': 'eyt', 'sentence': 3}
#
# Sampled data for list 68:
# {'original': 'make', 'error': 'made', 'sentence': 10}
# {'original': 'to', 'error': 'despite', 'sentence': 20}
# {'original': 'figured', 'error': 'figures', 'sentence': 14}
# {'original': 'like', 'error': 'ilke', 'sentence': 4}
# {'original': 'leave', 'error': 'leaves', 'sentence': 9}
#
# Sampled data for list 69:
# {'original': 'have', 'error': 'has', 'sentence': 10}
# {'original': 'enjoy', 'error': 'enojy', 'sentence': 4}
# {'original': 'time', 'error': 'tmie', 'sentence': 1}
# {'original': 'on', 'error': 'toward', 'sentence': 24}
# {'original': 'bonding', 'error': 'bonidng', 'sentence': 3}
#
# Sampled data for list 70:
# {'original': 'think', 'error': 'thinks', 'sentence': 5}
# {'original': 'as', 'error': 'in', 'sentence': 16}
# {'original': 'use', 'error': 'ues', 'sentence': 5}
# {'original': 'article', 'error': 'atricle', 'sentence': 3}
# {'original': 'get', 'error': 'gte', 'sentence': 1}
#
# Sampled data for list 71:
# {'original': 'help', 'error': 'helped', 'sentence': 3}
# {'original': 'in', 'error': 'despite', 'sentence': 8}
# {'original': 'of', 'error': 'beyond', 'sentence': 17}
# {'original': 'find', 'error': 'fidn', 'sentence': 3}
# {'original': 'play', 'error': 'plays', 'sentence': 17}
#
# Sampled data for list 72:
# {'original': 'have', 'error': 'had', 'sentence': 5}
# {'original': 'missing', 'error': 'misses', 'sentence': 17}
# {'original': 'strong', 'error': 'tsrong', 'sentence': 1}
# {'original': 'in', 'error': 'toward', 'sentence': 22}
# {'original': 'have', 'error': 'had', 'sentence': 15}
#
# Sampled data for list 73:
# {'original': 'of', 'error': 'toward', 'sentence': 5}
# {'original': 'in', 'error': 'except', 'sentence': 9}
# {'original': 'made', 'error': 'makes', 'sentence': 19}
# {'original': 'positive', 'error': 'poistive', 'sentence': 5}
# {'original': 'way', 'error': 'awy', 'sentence': 3}
#
# Sampled data for list 74:
# {'original': 'in', 'error': 'around', 'sentence': 10}
# {'original': 'useful', 'error': 'uesful', 'sentence': 1}
# {'original': '@MONTH1', 'error': '@month1ed', 'sentence': 17}
# {'original': 'like', 'error': 'during', 'sentence': 25}
# {'original': 'believe', 'error': 'believed', 'sentence': 1}
#
# Sampled data for list 75:
# {'original': 'people', 'error': 'pepole', 'sentence': 3}
# {'original': 'of', 'error': 'in', 'sentence': 16}
# {'original': 'found', 'error': 'find', 'sentence': 34}
# {'original': 'helps', 'error': 'helped', 'sentence': 35}
# {'original': 'benefit', 'error': 'bneefit', 'sentence': 1}
#
# Sampled data for list 76:
# {'original': 'lasts', 'error': 'lasted', 'sentence': 7}
# {'original': 'prevent', 'error': 'prevents', 'sentence': 4}
# {'original': 'screen', 'error': 'srceen', 'sentence': 2}
# {'original': 'taken', 'error': 'takes', 'sentence': 8}
# {'original': 'spent', 'error': 'spends', 'sentence': 2}
#
# Sampled data for list 77:
# {'original': 'urge', 'error': 'urged', 'sentence': 24}
# {'original': 'around', 'error': 'past', 'sentence': 3}
# {'original': 'brought', 'error': 'bring', 'sentence': 2}
# {'original': 'family', 'error': 'fmaily', 'sentence': 5}
# {'original': 'health', 'error': 'healht', 'sentence': 3}
#
# Sampled data for list 78:
# {'original': 'fun', 'error': 'fnu', 'sentence': 3}
# {'original': 'interact', 'error': 'interatc', 'sentence': 2}
# {'original': 'flipping', 'error': 'flips', 'sentence': 16}
# {'original': 'to', 'error': 'through', 'sentence': 12}
# {'original': 'gave', 'error': 'give', 'sentence': 19}
#
# Sampled data for list 79:
# {'original': 'as', 'error': 'within', 'sentence': 26}
# {'original': 'rec', 'error': 'recs', 'sentence': 26}
# {'original': 'to', 'error': 'inside', 'sentence': 20}
# {'original': 'really', 'error': 'relaly', 'sentence': 2}
# {'original': 'take', 'error': 'atke', 'sentence': 3}
#
# Sampled data for list 80:
# {'original': 'Dear', 'error': 'Dera', 'sentence': 1}
# {'original': 'benefit', 'error': 'benefited', 'sentence': 5}
# {'original': 'have', 'error': 'had', 'sentence': 1}
# {'original': 'had', 'error': 'has', 'sentence': 16}
# {'original': 'for', 'error': 'beside', 'sentence': 39}
#
# Sampled data for list 81:
# {'original': 'enough', 'error': 'enoguh', 'sentence': 3}
# {'original': 'think', 'error': 'thinks', 'sentence': 1}
# {'original': 'serious', 'error': 'esrious', 'sentence': 2}
# {'original': 'looking', 'error': 'oloking', 'sentence': 4}
# {'original': 'on', 'error': 'along', 'sentence': 1}
#
# Sampled data for list 82:
# {'original': 'think', 'error': 'thinks', 'sentence': 2}
# {'original': 'for', 'error': 'at', 'sentence': 10}
# {'original': 'allows', 'error': 'allow', 'sentence': 5}
# {'original': 'think', 'error': 'tihnk', 'sentence': 2}
# {'original': 'around', 'error': 'upon', 'sentence': 12}
#
# Sampled data for list 83:
# {'original': 'have', 'error': 'has', 'sentence': 30}
# {'original': 'nothing', 'error': 'ntohing', 'sentence': 5}
# {'original': 'know', 'error': 'knew', 'sentence': 7}
# {'original': 'uncle', 'error': 'ucnle', 'sentence': 3}
# {'original': 'prepared', 'error': 'prepraed', 'sentence': 4}
#
# Sampled data for list 84:
# {'original': 'says', 'error': 'said', 'sentence': 10}
# {'original': 'writing', 'error': 'wirting', 'sentence': 3}
# {'original': 'going', 'error': 'goes', 'sentence': 21}
# {'original': 'people', 'error': 'poeple', 'sentence': 2}
# {'original': 'brought', 'error': 'bring', 'sentence': 1}
#
# Sampled data for list 85:
# {'original': 'whith', 'error': 'underneath', 'sentence': 2}
# {'original': 'stop', 'error': 'tsop', 'sentence': 5}
# {'original': 'arent', 'error': 'aretn', 'sentence': 1}
# {'original': 'one', 'error': 'noe', 'sentence': 2}
# {'original': 'for', 'error': 'as', 'sentence': 9}
#
# Sampled data for list 86:
# {'original': 'than', 'error': 'along', 'sentence': 3}
# {'original': 'live', 'error': 'lvie', 'sentence': 1}
# {'original': 'save', 'error': 'svae', 'sentence': 1}
# {'original': 'new', 'error': 'enw', 'sentence': 3}
# {'original': 'for', 'error': 'since', 'sentence': 2}
#
# Sampled data for list 87:
# {'original': 'about', 'error': 'down', 'sentence': 2}
# {'original': 'career', 'error': 'carere', 'sentence': 5}
# {'original': 'think', 'error': 'thought', 'sentence': 2}
# {'original': 'teach', 'error': 'taech', 'sentence': 4}
# {'original': 'learn', 'error': 'laern', 'sentence': 2}
#
# Sampled data for list 88:
# {'original': 'Newspaper', 'error': 'Neswpaper', 'sentence': 1}
# {'original': 'use', 'error': 'sue', 'sentence': 3}
# {'original': 'allows', 'error': 'allow', 'sentence': 2}
# {'original': 'valued', 'error': 'values', 'sentence': 15}
# {'original': 'learn', 'error': 'leran', 'sentence': 2}
#
# Sampled data for list 89:
# {'original': 'show', 'error': 'shows', 'sentence': 13}
# {'original': 'effect', 'error': 'effect', 'sentence': 4}
# {'original': 'think', 'error': 'thinks', 'sentence': 1}
# {'original': 'on', 'error': 'despite', 'sentence': 7}
# {'original': 'really', 'error': 'really', 'sentence': 2}
#
# Sampled data for list 90:
# {'original': 'In', 'error': 'of', 'sentence': 8}
# {'original': 'let', 'error': 'elt', 'sentence': 4}
# {'original': 'helps', 'error': 'helped', 'sentence': 6}
# {'original': 'school', 'error': 'school', 'sentence': 5}
# {'original': 'of', 'error': 'around', 'sentence': 15}
#
# Sampled data for list 91:
# {'original': 'getting', 'error': 'gets', 'sentence': 4}
# {'original': 'doing', 'error': 'does', 'sentence': 5}
# {'original': 'giving', 'error': 'givnig', 'sentence': 1}
# {'original': 'depressed', 'error': 'depress', 'sentence': 9}
# {'original': 'think', 'error': 'thinks', 'sentence': 1}
#
# Sampled data for list 92:
# {'original': 'with', 'error': 'around', 'sentence': 3}
# {'original': 'getting', 'error': 'gettign', 'sentence': 4}
# {'original': 'believe', 'error': 'believes', 'sentence': 1}
# {'original': 'hope', 'error': 'hopes', 'sentence': 16}
# {'original': 'Also', 'error': 'Alos', 'sentence': 3}
#
# Sampled data for list 93:
# {'original': 'ever', 'error': 'eevr', 'sentence': 1}
# {'original': 'went', 'error': 'goes', 'sentence': 13}
# {'original': 'spend', 'error': 'psend', 'sentence': 2}
# {'original': 'on', 'error': 'except', 'sentence': 11}
# {'original': 'ever', 'error': 'veer', 'sentence': 3}
#
# Sampled data for list 94:
# {'original': 'did', 'error': 'do', 'sentence': 14}
# {'original': 'learn', 'error': 'laern', 'sentence': 6}
# {'original': 'concerned', 'error': 'concrened', 'sentence': 5}
# {'original': 'without', 'error': 'toward', 'sentence': 10}
# {'original': 'knew', 'error': 'knows', 'sentence': 16}
#
# Sampled data for list 95:
# {'original': 'doing', 'error': 'do', 'sentence': 5}
# {'original': 'time', 'error': 'tiem', 'sentence': 1}
# {'original': 'race', 'error': 'raced', 'sentence': 6}
# {'original': 'invented', 'error': 'invent', 'sentence': 17}
# {'original': 'technology', 'error': 'technoolgy', 'sentence': 3}
#
# Sampled data for list 96:
# {'original': 'believe', 'error': 'believed', 'sentence': 1}
# {'original': 'stop', 'error': 'sotp', 'sentence': 5}
# {'original': 'get', 'error': 'gets', 'sentence': 20}
# {'original': 'body', 'error': 'obdy', 'sentence': 3}
# {'original': 'great', 'error': 'rgeat', 'sentence': 2}
#
# Sampled data for list 97:
# {'original': 'use', 'error': 'used', 'sentence': 17}
# {'original': 'help', 'error': 'hepl', 'sentence': 2}
# {'original': 'relied', 'error': 'relies', 'sentence': 13}
# {'original': 'in', 'error': 'inside', 'sentence': 5}
# {'original': 'of', 'error': 'by', 'sentence': 15}
#
# Sampled data for list 98:
# {'original': 'spending', 'error': 'spends', 'sentence': 1}
# {'original': 'by', 'error': 'in', 'sentence': 4}
# {'original': 'spending', 'error': 'spendnig', 'sentence': 1}
# {'original': 'everyone', 'error': 'everynoe', 'sentence': 2}
# {'original': 'never', 'error': 'nevre', 'sentence': 4}
#
# Sampled data for list 99:
# {'original': 'learning', 'error': 'laerning', 'sentence': 3}
# {'original': 'use', 'error': 'used', 'sentence': 6}
# {'original': 'on', 'error': 'between', 'sentence': 7}
# {'original': 'have', 'error': 'had', 'sentence': 12}
# {'original': 'world', 'error': 'wordl', 'sentence': 1}
#
# Sampled data for list 100:
# {'original': 'at', 'error': 'through', 'sentence': 7}
# {'original': 'to', 'error': 'inside', 'sentence': 15}
# {'original': 'forgot', 'error': 'forgoted', 'sentence': 6}
# {'original': 'schoolwork', 'error': 'schoolowrk', 'sentence': 2}
# {'original': 'ran', 'error': 'run', 'sentence': 12}

# %%
np.array(sampled_errors).shape
# Out:
# (100, 5)

# %%
joblib.dump(sampled_errors, 'files/error_test_100essay_5err')
# Out:
# ['files/error_test_100essay_5err']

# %%
# Function to apply errors to the essay
def apply_errors(essay, errors):
    # Tokenize the essay into sentences using NLTK
    sentences = nltk.sent_tokenize(essay)

    # Create a list to store corrected sentences
    errored_sentences = []

    # Iterate through sentences
    for i, sentence in enumerate(sentences):
        # Apply corrections to the current sentence
        for error in errors:
            # Adjust the index by subtracting 1 to match the enumeration starting from 0
            if error['sentence'] == i + 1:
                # Replace all occurrences of the incorrect text with the correction
                #sentence = sentence.replace(correction['original'], correction['correction'])
                 # Use regular expression with word boundaries to replace only whole words
                sentence = re.sub(r'\b' + re.escape(error['original']) + r'\b', error['error'], sentence)
        # Add the corrected sentence to the list
        errored_sentences.append(sentence)

    # Join the corrected sentences to form the final essay
    errored_essay = ' '.join(errored_sentences)
    return errored_essay

# Function to generate all combinations of corrections and apply them
def generate_errored_versions(essay, errors):
    errored_versions = []
    max_errors = len(errors)

    # Iterate over different numbers of corrections to apply
    for num_errors in range(1, max_errors + 1):
        for combination in itertools.combinations(errors, num_errors):
            errored_essay = apply_errors(essay, combination)
            errored_versions.append(errored_essay)
  
    return errored_versions

# Example usage
essay = "This is a tess essay. The break through was amazing. The possitive effects were clear."
errors = [
    {'original': 'tess', 'error': 'test', 'type': 'Spelling', 'sentence': 1},
    {'original': 'break through', 'error': 'breakthrough', 'type': 'Spelling', 'sentence': 2},
    {'original': 'possitive', 'error': 'positive', 'type': 'Spelling', 'sentence': 3},
]

# Generate corrected versions with combinations of 1, 2, and 3 corrections
errored_versions = generate_errored_versions(essay, errors)
errored_versions
# Out:
# ['This is a test essay. The break through was amazing. The possitive effects were clear.',
#  'This is a tess essay. The breakthrough was amazing. The possitive effects were clear.',
#  'This is a tess essay. The break through was amazing. The positive effects were clear.',
#  'This is a test essay. The breakthrough was amazing. The possitive effects were clear.',
#  'This is a test essay. The break through was amazing. The positive effects were clear.',
#  'This is a tess essay. The breakthrough was amazing. The positive effects were clear.',
#  'This is a test essay. The breakthrough was amazing. The positive effects were clear.']

# %%
error_test_100essay_5err = joblib.load('files/error_test_100essay_5err')

errored_test_100data_5err = []

for index, row in data_100.iterrows():
    try:
        errored_essays = generate_errored_versions(row['essay'], error_test_100essay_5err[index]) 
        # Append the result to the list
        errored_test_100data_5err.append(errored_essays)
    except Exception as e:
        print(f"Error processing row {index}: {e}")
        errored_test_100data_5err.append(None)  # Append None or an empty dict if an error occurs
    print(index + 1, " finished")
# Out:
# 1  finished
# 2  finished
# 3  finished
# 4  finished
# 5  finished
# 6  finished
# 7  finished
# 8  finished
# 9  finished
# 10  finished
# 11  finished
# 12  finished
# 13  finished
# 14  finished
# 15  finished
# 16  finished
# 17  finished
# 18  finished
# 19  finished
# 20  finished
# 21  finished
# 22  finished
# 23  finished
# 24  finished
# 25  finished
# 26  finished
# 27  finished
# 28  finished
# 29  finished
# 30  finished
# 31  finished
# 32  finished
# 33  finished
# 34  finished
# 35  finished
# 36  finished
# 37  finished
# 38  finished
# 39  finished
# 40  finished
# 41  finished
# 42  finished
# 43  finished
# 44  finished
# 45  finished
# 46  finished
# 47  finished
# 48  finished
# 49  finished
# 50  finished
# 51  finished
# 52  finished
# 53  finished
# 54  finished
# 55  finished
# 56  finished
# 57  finished
# 58  finished
# 59  finished
# 60  finished
# 61  finished
# 62  finished
# 63  finished
# 64  finished
# 65  finished
# 66  finished
# 67  finished
# 68  finished
# 69  finished
# 70  finished
# 71  finished
# 72  finished
# 73  finished
# 74  finished
# 75  finished
# 76  finished
# 77  finished
# 78  finished
# 79  finished
# 80  finished
# 81  finished
# 82  finished
# 83  finished
# 84  finished
# 85  finished
# 86  finished
# 87  finished
# 88  finished
# 89  finished
# 90  finished
# 91  finished
# 92  finished
# 93  finished
# 94  finished
# 95  finished
# 96  finished
# 97  finished
# 98  finished
# 99  finished
# 100  finished

# %%
np.array(errored_test_100data_5err).shape
# Out:
# (100, 31)

# %%
joblib.dump(errored_test_100data_5err, 'files/errored_test_100data_5err')
# Out:
# ['files/errored_test_100data_5err']
