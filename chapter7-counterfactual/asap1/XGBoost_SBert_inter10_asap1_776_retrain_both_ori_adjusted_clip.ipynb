# %% [markdown]
# ### This is to retrain using both positive and negative counterfactuals

# %%
import xgboost
import joblib
import numpy as np
from sklearn.metrics import accuracy_score
from quadratic_weighted_kappa import quadratic_weighted_kappa
import pandas as pd
import itertools
import math

# %%
scores_ori = np.array(joblib.load("files/scores_essay_100_train_ori")).astype(float)
scores_ori.shape
# Out:
# (100,)

# %%
scores_ori = np.repeat(scores_ori, 31)

# %%
len(scores_ori)
# Out:
# 3100

# %%
x = joblib.load('files/asap1_features_776').squeeze()
y = joblib.load("files/score_asap1")
y = y.reshape(-1,1)

feature_names = joblib.load('files/feature_names_776')
#model = joblib.load('model_asap1_778')

feats_counter_train_error = joblib.load('files/feats_counter_train_error_776').reshape(-1,776)
new_label_train_error = scores_ori.copy().reshape(3100,-1)

feats_counter_train_better = joblib.load('files/feats_counter_train_correct_776').reshape(-1,776)
new_label_train_better = scores_ori.copy().reshape(3100,-1)

# %%
new_label_train_better.shape
# Out:
# (3100, 1)

# %%
np.min(y)
# Out:
# 2

# %%
print(scores_ori.dtype)
# Out:
# float64

# %%
print(new_label_train_better.dtype)
# Out:
# float64

# %%
# =========================
# ADDED: derive min/max and a flat y for indexing
# =========================
y_flat = y.ravel()                                   # ADDED
score_min = float(np.min(y_flat))                    # ADDED
score_max = float(np.max(y_flat))                    # ADDED

# %% [markdown]
# #### Apply proposed method: Adjust worse essays label

# %%
# There are 100 essay samples with 31 variations

new_label_train_error = new_label_train_error.reshape(100,-1)
new_label_train_error.shape
# Out:
# (100, 31)

# %%
n = 5
numbers = range(1, n + 1)  # Numbers from 1 to 5
ctr = 0

for i in range(len(new_label_train_error)):
    # Generate combinations of varying lengths
    idx = 0
    for length in range(1, n + 1):
        combinations = itertools.combinations(numbers, length)
        delta = 0.9 * length  # Adjust delta based on length
        delta = round(delta, 2)
        for combo in combinations:
            new_label_train_error[i][idx] -= delta
            # ADDED: clip this updated label to the valid score range
            new_label_train_error[i][idx] = np.clip(
                new_label_train_error[i][idx], score_min, score_max
            )  # ADDED
            # print("after: ", matrices[i][idx])
            idx += 1

# %%
new_label_train_error = new_label_train_error.reshape(-1,1)
new_label_train_error.shape
# Out:
# (3100, 1)

# %% [markdown]
# #### Apply proposed method: Adjust better essays label

# %%
# There are 100 essay samples with 31 variations

new_label_train_better = new_label_train_better.reshape(100,-1)
new_label_train_better.shape
# Out:
# (100, 31)

# %%
n = 5
numbers = range(1, n + 1)  # Numbers from 1 to 5
ctr = 0

for i in range(len(new_label_train_better)):
    # Generate combinations of varying lengths
    idx = 0
    for length in range(1, n + 1):
        combinations = itertools.combinations(numbers, length)
        delta = 0.8 * length  # Adjust delta based on length
        delta = round(delta, 2)
        for combo in combinations:
            new_label_train_better[i][idx] += delta
            # ADDED: clip this updated label to the valid score range
            new_label_train_better[i][idx] = np.clip(
                new_label_train_better[i][idx], score_min, score_max
            )  # ADDED
            # print("after: ", matrices[i][idx])
            idx += 1

# %%
new_label_train_better = new_label_train_better.reshape(-1,1)
new_label_train_better.shape
# Out:
# (3100, 1)

# %%
np.array_equal(scores_ori, new_label_train_error.flatten())
np.array_equal(scores_ori, new_label_train_better.flatten())
# Out:
# False

# %%
import numpy as np
import matplotlib.pyplot as plt

n_show = 100

# Flatten and slice
ori = scores_ori[:n_show]
err = new_label_train_error[:n_show].flatten()
bet = new_label_train_better[:n_show].flatten()

# Compute and scale differences
diff_err = (err - ori) * 1000
diff_bet = (bet - ori) * 1000

# Plot
plt.figure(figsize=(12, 6))
plt.plot(diff_err, label='(Error - Original) × 1000', marker='o')
plt.plot(diff_bet, label='(Better - Original) × 1000', marker='x')
plt.axhline(0, color='gray', linestyle='--')
plt.title(f'Scaled Differences from Original Scores (First {n_show})')
plt.xlabel('Index')
plt.ylabel('Difference × 1000')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(scores_ori, bins=20, alpha=0.5, label='Original Scores')
plt.hist(new_label_train_error, bins=20, alpha=0.5, label='Error Labels')
plt.hist(new_label_train_better, bins=20, alpha=0.5, label='Better Labels')
plt.title('Score Distributions')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_counter = np.concatenate((y, new_label_train_better, new_label_train_error), axis=0).reshape(-1)
y_counter.shape
# Out:
# (7983,)

# %%
y = y_counter
y.shape
# Out:
# (7983,)

# %%
x_counter = np.concatenate((x,feats_counter_train_better, feats_counter_train_error), axis=0)
x_counter.shape
# Out:
# (7983, 776)

# %%
x = x_counter
x.shape
# Out:
# (7983, 776)

# %%
# REMOVE PROMPT OVERLAP & PROMPT OVERLAP (SYNONYM) FEATURES, AS THEY HAVE NEGATIVE CORRELATION WITH FINAL SCORE

# x_776 = np.delete(x, [5,6],axis=1)
# x_776.shape

# %%
# x = x_776
# x.shape

# %%
def get_feature_names_extended():
    inter_feats = ['Answer Length', 'Word Count', 'Average Word Length', 'Unique Word Count', 'Punctuation Density',
                  'Prompt Overlap', 'Prompt Overlap (synonyms)', 'Prompt Similarity SBert', 
                  'Spelling Error', 'Language Error']
    inter_feats = ['Answer Length', 'Word Count', 'Average Word Length', 'Unique Word Count', 'Punctuation Density',
                  'Prompt Similarity SBert', 
                  'Spelling Error', 'Language Error']
    
    sbert_feats = []
    sbert_dim = 768

    for i in range(0, sbert_dim):
    	fname = "sbert_" + str(i) 
    	sbert_feats.append(fname)
    
    feature_names = inter_feats + sbert_feats 

    print("len feature names: ", len(feature_names))
    
    return feature_names

feature_names = get_feature_names_extended()#[:12]
# Out:
# len feature names:  776

# %%
#joblib.dump(feature_names, 'feature_names_778')

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

kf = KFold(n_splits=5, shuffle=True, random_state=42)

print(kf)
# Out:
# KFold(n_splits=5, random_state=42, shuffle=True)

# %%
model = xgboost.XGBRegressor(objective ='reg:squarederror',
                colsample_bytree=0.4,
                 gamma=0,                 
                 learning_rate=0.05,
                 max_depth=4,
                 min_child_weight=1.5,
                 n_estimators=1000,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=42)

# ORI QWK :

# %%
# qwk_scores = []

# test_indices = []
# pred_labels = []

# for train_index, test_index in kf.split(x, y):
    
#     X_train, X_test, Y_train, Y_test = x[train_index], x[test_index], y[train_index], y[test_index]
         
#     model.fit(X_train, Y_train)
    
#     predict = model.predict(X_test)
#     predict = np.round(predict)
    
#     pred_labels.extend(predict)
#     test_indices.extend(test_index)
    
#     result = quadratic_weighted_kappa(Y_test, predict)
    
#     print("Qwk : ", result)
#     print(X_train.shape)
#     qwk_scores.append(result)
    
# np.mean(qwk_scores)

# %% [markdown]
# ##### Only evaluate the original Test Set (without augmentation), but using new Model (trained with augmentation)

# %%
qwk_scores = []

for train_index, test_index in kf.split(x, y):
    
    X_train, X_test, Y_train, Y_test = x[train_index], x[test_index], y[train_index], y[test_index]

    # Filter test indices for those less than 1783
    test_index_baru = test_index[test_index < 1783]
    print("Filtered test indices count:", len(test_index_baru))
    
    print(X_train.shape)
    print(Y_train.shape)
    model.fit(X_train, Y_train)

    # Use test_index_baru to get filtered test sets from the original arrays
    X_test_baru = X_test[test_index < 1783]  # Correct filtering
    Y_test_baru = Y_test[test_index < 1783]  # Correct filtering

    print("Filtered X_test count:", len(X_test_baru))
    print("Filtered Y_test count:", len(Y_test_baru))
    
    predict = model.predict(X_test_baru)
    predict = np.round(predict)
    
    result = quadratic_weighted_kappa(Y_test_baru, predict)
    
    print("Qwk : ", result)
    qwk_scores.append(result)

mean_qwk = np.mean(qwk_scores)
print("Mean Qwk:", mean_qwk)
# Out:
# Filtered test indices count: 380
# (6386, 776)
# (6386,)
# Filtered X_test count: 380
# Filtered Y_test count: 380
# Qwk :  0.716300856050681
# Filtered test indices count: 366
# (6386, 776)
# (6386,)
# Filtered X_test count: 366
# Filtered Y_test count: 366
# Qwk :  0.7733845810297809
# Filtered test indices count: 339
# (6386, 776)
# (6386,)
# Filtered X_test count: 339
# Filtered Y_test count: 339
# Qwk :  0.7404350335936374
# Filtered test indices count: 376
# (6387, 776)
# (6387,)
# Filtered X_test count: 376
# Filtered Y_test count: 376
# Qwk :  0.7512524808595661
# Filtered test indices count: 322
# (6387, 776)
# (6387,)
# Filtered X_test count: 322
# Filtered Y_test count: 322
# Qwk :  0.730287265124626
# Mean Qwk: 0.7423320433316583

# %%
print(len(pred_labels))
print(len(test_indices))
# Out:
# 7983
# 7983

# %%
new_score = np.zeros(1783)
new_score
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
new_score[test_indices] = pred_labels_int
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 new_score[test_indices] = pred_labels_int
#
# NameError: name 'pred_labels_int' is not defined

# %%
new_score
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
new_score[60]
# Out:
# 0.0

# %%
#joblib.dump(new_score, 'score_model_normalized')

# %% [markdown]
# ## Create model

# %%
from sklearn.model_selection import train_test_split
indices = np.arange(len(x))
X_train, X_test, Y_train, Y_test, idx_train, idx_test = train_test_split(x, y, indices, test_size=0.2, random_state=42)

# %%
len(idx_test)
# Out:
# 1597

# %%
idx_test
# Out:
# array([6572, 7314, 4119, ..., 2348, 1746, 4881])

# %%
# Filter the array for values less than 1783
new_array = idx_test[idx_test < 1783]
len(new_array)
# Out:
# 380

# %%
d_train = xgboost.DMatrix(X_train, label=Y_train, feature_names=feature_names)
d_test = xgboost.DMatrix(X_test, label=Y_test, feature_names=feature_names)

# %%
model = xgboost.train({"learning_rate": 0.05, "max_depth":4, 'alpha':0.75, 'lambda':0.45,}, d_train, 400, evals = [(d_test, "test")], early_stopping_rounds=50)
# Out:
# [0]	test-rmse:8.16823
# [1]	test-rmse:7.78367
# [2]	test-rmse:7.42083
# [3]	test-rmse:7.07642
# [4]	test-rmse:6.75208
# [5]	test-rmse:6.44493
# [6]	test-rmse:6.15236
# [7]	test-rmse:5.87534
# [8]	test-rmse:5.61355
# [9]	test-rmse:5.36526
# [10]	test-rmse:5.13061
# [11]	test-rmse:4.90978
# [12]	test-rmse:4.70118
# [13]	test-rmse:4.50268
# [14]	test-rmse:4.31769
# [15]	test-rmse:4.13980
# [16]	test-rmse:3.97495
# [17]	test-rmse:3.81821
# [18]	test-rmse:3.66945
# [19]	test-rmse:3.53040
# [20]	test-rmse:3.40052
# [21]	test-rmse:3.27815
# [22]	test-rmse:3.16200
# [23]	test-rmse:3.05495
# [24]	test-rmse:2.95437
# [25]	test-rmse:2.85834
# [26]	test-rmse:2.76926
# [27]	test-rmse:2.68578
# [28]	test-rmse:2.60862
# [29]	test-rmse:2.53692
# [30]	test-rmse:2.46720
# [31]	test-rmse:2.40193
# [32]	test-rmse:2.34248
# [33]	test-rmse:2.28928
# [34]	test-rmse:2.23575
# [35]	test-rmse:2.18864
# [36]	test-rmse:2.14098
# [37]	test-rmse:2.10031
# [38]	test-rmse:2.06392
# [39]	test-rmse:2.02444
# [40]	test-rmse:1.99069
# [41]	test-rmse:1.95817
# [42]	test-rmse:1.93043
# [43]	test-rmse:1.90257
# [44]	test-rmse:1.87785
# [45]	test-rmse:1.85556
# [46]	test-rmse:1.83320
# [47]	test-rmse:1.81430
# [48]	test-rmse:1.79601
# [49]	test-rmse:1.78007
# [50]	test-rmse:1.76060
# [51]	test-rmse:1.74244
# [52]	test-rmse:1.73031
# [53]	test-rmse:1.71808
# [54]	test-rmse:1.70337
# [55]	test-rmse:1.69300
# [56]	test-rmse:1.68373
# [57]	test-rmse:1.67249
# [58]	test-rmse:1.66351
# [59]	test-rmse:1.65319
# [60]	test-rmse:1.64558
# [61]	test-rmse:1.63750
# [62]	test-rmse:1.63127
# [63]	test-rmse:1.62416
# [64]	test-rmse:1.61852
# [65]	test-rmse:1.61400
# [66]	test-rmse:1.60721
# [67]	test-rmse:1.60370
# [68]	test-rmse:1.59809
# [69]	test-rmse:1.59373
# [70]	test-rmse:1.58993
# [71]	test-rmse:1.58159
# [72]	test-rmse:1.57647
# [73]	test-rmse:1.57087
# [74]	test-rmse:1.56829
# [75]	test-rmse:1.56505
# [76]	test-rmse:1.55788
# [77]	test-rmse:1.55444
# [78]	test-rmse:1.55235
# [79]	test-rmse:1.54934
# [80]	test-rmse:1.54721
# [81]	test-rmse:1.54326
# [82]	test-rmse:1.53958
# [83]	test-rmse:1.53775
# [84]	test-rmse:1.53579
# [85]	test-rmse:1.53241
# [86]	test-rmse:1.53078
# [87]	test-rmse:1.52941
# [88]	test-rmse:1.52730
# [89]	test-rmse:1.52412
# [90]	test-rmse:1.52197
# [91]	test-rmse:1.51901
# [92]	test-rmse:1.51720
# [93]	test-rmse:1.51445
# [94]	test-rmse:1.51136
# [95]	test-rmse:1.50930
# [96]	test-rmse:1.50576
# [97]	test-rmse:1.50173
# [98]	test-rmse:1.49587
# [99]	test-rmse:1.49418
# [100]	test-rmse:1.49335
# [101]	test-rmse:1.48954
# [102]	test-rmse:1.48804
# [103]	test-rmse:1.48633
# [104]	test-rmse:1.48355
# [105]	test-rmse:1.48070
# [106]	test-rmse:1.47838
# [107]	test-rmse:1.47764
# [108]	test-rmse:1.47585
# [109]	test-rmse:1.47345
# [110]	test-rmse:1.46964
# [111]	test-rmse:1.46828
# [112]	test-rmse:1.46565
# [113]	test-rmse:1.46357
# [114]	test-rmse:1.46184
# [115]	test-rmse:1.46061
# [116]	test-rmse:1.45730
# [117]	test-rmse:1.45458
# [118]	test-rmse:1.45314
# [119]	test-rmse:1.45097
# [120]	test-rmse:1.44964
# [121]	test-rmse:1.44846
# [122]	test-rmse:1.44687
# [123]	test-rmse:1.44484
# [124]	test-rmse:1.44311
# [125]	test-rmse:1.44102
# [126]	test-rmse:1.43905
# [127]	test-rmse:1.43722
# [128]	test-rmse:1.43511
# [129]	test-rmse:1.43381
# [130]	test-rmse:1.43210
# [131]	test-rmse:1.42989
# [132]	test-rmse:1.42577
# [133]	test-rmse:1.42382
# [134]	test-rmse:1.42191
# [135]	test-rmse:1.42057
# [136]	test-rmse:1.41843
# [137]	test-rmse:1.41601
# [138]	test-rmse:1.41499
# [139]	test-rmse:1.41236
# [140]	test-rmse:1.41077
# [141]	test-rmse:1.40741
# [142]	test-rmse:1.40531
# [143]	test-rmse:1.40336
# [144]	test-rmse:1.40177
# [145]	test-rmse:1.39823
# [146]	test-rmse:1.39692
# [147]	test-rmse:1.39483
# [148]	test-rmse:1.39390
# [149]	test-rmse:1.39270
# [150]	test-rmse:1.39022
# [151]	test-rmse:1.38849
# [152]	test-rmse:1.38672
# [153]	test-rmse:1.38439
# [154]	test-rmse:1.38282
# [155]	test-rmse:1.38175
# [156]	test-rmse:1.38008
# [157]	test-rmse:1.37838
# [158]	test-rmse:1.37658
# [159]	test-rmse:1.37463
# [160]	test-rmse:1.37328
# [161]	test-rmse:1.37151
# [162]	test-rmse:1.36976
# [163]	test-rmse:1.36740
# [164]	test-rmse:1.36651
# [165]	test-rmse:1.36531
# [166]	test-rmse:1.36224
# [167]	test-rmse:1.36142
# [168]	test-rmse:1.36010
# [169]	test-rmse:1.35817
# [170]	test-rmse:1.35686
# [171]	test-rmse:1.35574
# [172]	test-rmse:1.35313
# [173]	test-rmse:1.35127
# [174]	test-rmse:1.34972
# [175]	test-rmse:1.34835
# [176]	test-rmse:1.34743
# [177]	test-rmse:1.34580
# [178]	test-rmse:1.34457
# [179]	test-rmse:1.34308
# [180]	test-rmse:1.34193
# [181]	test-rmse:1.34082
# [182]	test-rmse:1.33991
# [183]	test-rmse:1.33853
# [184]	test-rmse:1.33584
# [185]	test-rmse:1.33426
# [186]	test-rmse:1.33305
# [187]	test-rmse:1.33131
# [188]	test-rmse:1.32972
# [189]	test-rmse:1.32866
# [190]	test-rmse:1.32655
# [191]	test-rmse:1.32469
# [192]	test-rmse:1.32333
# [193]	test-rmse:1.32274
# [194]	test-rmse:1.32190
# [195]	test-rmse:1.32061
# [196]	test-rmse:1.31860
# [197]	test-rmse:1.31709
# [198]	test-rmse:1.31600
# [199]	test-rmse:1.31500
# [200]	test-rmse:1.31377
# [201]	test-rmse:1.31249
# [202]	test-rmse:1.31176
# [203]	test-rmse:1.31062
# [204]	test-rmse:1.30730
# [205]	test-rmse:1.30650
# [206]	test-rmse:1.30510
# [207]	test-rmse:1.30409
# [208]	test-rmse:1.30218
# [209]	test-rmse:1.30104
# [210]	test-rmse:1.29956
# [211]	test-rmse:1.29755
# [212]	test-rmse:1.29619
# [213]	test-rmse:1.29527
# [214]	test-rmse:1.29301
# [215]	test-rmse:1.29054
# [216]	test-rmse:1.28826
# [217]	test-rmse:1.28699
# [218]	test-rmse:1.28483
# [219]	test-rmse:1.28340
# [220]	test-rmse:1.28199
# [221]	test-rmse:1.28055
# [222]	test-rmse:1.27893
# [223]	test-rmse:1.27770
# [224]	test-rmse:1.27636
# [225]	test-rmse:1.27526
# [226]	test-rmse:1.27402
# [227]	test-rmse:1.27307
# [228]	test-rmse:1.27175
# [229]	test-rmse:1.27039
# [230]	test-rmse:1.26933
# [231]	test-rmse:1.26877
# [232]	test-rmse:1.26766
# [233]	test-rmse:1.26678
# [234]	test-rmse:1.26589
# [235]	test-rmse:1.26508
# [236]	test-rmse:1.26351
# [237]	test-rmse:1.26236
# [238]	test-rmse:1.26129
# [239]	test-rmse:1.26023
# [240]	test-rmse:1.25752
# [241]	test-rmse:1.25428
# [242]	test-rmse:1.25291
# [243]	test-rmse:1.25219
# [244]	test-rmse:1.25118
# [245]	test-rmse:1.25044
# [246]	test-rmse:1.24939
# [247]	test-rmse:1.24844
# [248]	test-rmse:1.24620
# [249]	test-rmse:1.24479
# [250]	test-rmse:1.24268
# [251]	test-rmse:1.24191
# [252]	test-rmse:1.24050
# [253]	test-rmse:1.23741
# [254]	test-rmse:1.23608
# [255]	test-rmse:1.23309
# [256]	test-rmse:1.23240
# [257]	test-rmse:1.23161
# [258]	test-rmse:1.23015
# [259]	test-rmse:1.22859
# [260]	test-rmse:1.22779
# [261]	test-rmse:1.22689
# [262]	test-rmse:1.22566
# [263]	test-rmse:1.22416
# [264]	test-rmse:1.22261
# [265]	test-rmse:1.21917
# [266]	test-rmse:1.21656
# [267]	test-rmse:1.21487
# [268]	test-rmse:1.21357
# [269]	test-rmse:1.21265
# [270]	test-rmse:1.21173
# [271]	test-rmse:1.20959
# [272]	test-rmse:1.20728
# [273]	test-rmse:1.20609
# [274]	test-rmse:1.20537
# [275]	test-rmse:1.20461
# [276]	test-rmse:1.20418
# [277]	test-rmse:1.20247
# [278]	test-rmse:1.20140
# [279]	test-rmse:1.20070
# [280]	test-rmse:1.19925
# [281]	test-rmse:1.19701
# [282]	test-rmse:1.19507
# [283]	test-rmse:1.19362
# [284]	test-rmse:1.19308
# [285]	test-rmse:1.19218
# [286]	test-rmse:1.19087
# [287]	test-rmse:1.18951
# [288]	test-rmse:1.18693
# [289]	test-rmse:1.18621
# [290]	test-rmse:1.18540
# [291]	test-rmse:1.18390
# [292]	test-rmse:1.18332
# [293]	test-rmse:1.18175
# [294]	test-rmse:1.18068
# [295]	test-rmse:1.17910
# [296]	test-rmse:1.17857
# [297]	test-rmse:1.17668
# [298]	test-rmse:1.17625
# [299]	test-rmse:1.17470
# [300]	test-rmse:1.17332
# [301]	test-rmse:1.17163
# [302]	test-rmse:1.17104
# [303]	test-rmse:1.17025
# [304]	test-rmse:1.16911
# [305]	test-rmse:1.16783
# [306]	test-rmse:1.16654
# [307]	test-rmse:1.16541
# [308]	test-rmse:1.16425
# [309]	test-rmse:1.16347
# [310]	test-rmse:1.16275
# [311]	test-rmse:1.16200
# [312]	test-rmse:1.16020
# [313]	test-rmse:1.15873
# [314]	test-rmse:1.15795
# [315]	test-rmse:1.15738
# [316]	test-rmse:1.15660
# [317]	test-rmse:1.15507
# [318]	test-rmse:1.15421
# [319]	test-rmse:1.15339
# [320]	test-rmse:1.15226
# [321]	test-rmse:1.15171
# [322]	test-rmse:1.15115
# [323]	test-rmse:1.15079
# [324]	test-rmse:1.15014
# [325]	test-rmse:1.14847
# [326]	test-rmse:1.14719
# [327]	test-rmse:1.14635
# [328]	test-rmse:1.14571
# [329]	test-rmse:1.14458
# [330]	test-rmse:1.14375
# [331]	test-rmse:1.14310
# [332]	test-rmse:1.14257
# [333]	test-rmse:1.14190
# [334]	test-rmse:1.14152
# [335]	test-rmse:1.14008
# [336]	test-rmse:1.13872
# [337]	test-rmse:1.13795
# [338]	test-rmse:1.13730
# [339]	test-rmse:1.13612
# [340]	test-rmse:1.13489
# [341]	test-rmse:1.13427
# [342]	test-rmse:1.13363
# [343]	test-rmse:1.13253
# [344]	test-rmse:1.13142
# [345]	test-rmse:1.12923
# [346]	test-rmse:1.12844
# [347]	test-rmse:1.12728
# [348]	test-rmse:1.12639
# [349]	test-rmse:1.12616
# [350]	test-rmse:1.12525
# [351]	test-rmse:1.12468
# [352]	test-rmse:1.12361
# [353]	test-rmse:1.12230
# [354]	test-rmse:1.12195
# [355]	test-rmse:1.12111
# [356]	test-rmse:1.12026
# [357]	test-rmse:1.11897
# [358]	test-rmse:1.11666
# [359]	test-rmse:1.11575
# [360]	test-rmse:1.11457
# [361]	test-rmse:1.11344
# [362]	test-rmse:1.11157
# [363]	test-rmse:1.11036
# [364]	test-rmse:1.10897
# [365]	test-rmse:1.10833
# [366]	test-rmse:1.10822
# [367]	test-rmse:1.10778
# [368]	test-rmse:1.10736
# [369]	test-rmse:1.10641
# [370]	test-rmse:1.10506
# [371]	test-rmse:1.10411
# [372]	test-rmse:1.10312
# [373]	test-rmse:1.10241
# [374]	test-rmse:1.10176
# [375]	test-rmse:1.10038
# [376]	test-rmse:1.09968
# [377]	test-rmse:1.09875
# [378]	test-rmse:1.09758
# [379]	test-rmse:1.09699
# [380]	test-rmse:1.09641
# [381]	test-rmse:1.09583
# [382]	test-rmse:1.09304
# [383]	test-rmse:1.09214
# [384]	test-rmse:1.09130
# [385]	test-rmse:1.09067
# [386]	test-rmse:1.08974
# [387]	test-rmse:1.08888
# [388]	test-rmse:1.08670
# [389]	test-rmse:1.08544
# [390]	test-rmse:1.08482
# [391]	test-rmse:1.08442
# [392]	test-rmse:1.08315
# [393]	test-rmse:1.08172
# [394]	test-rmse:1.08136
# [395]	test-rmse:1.08079
# [396]	test-rmse:1.08042
# [397]	test-rmse:1.07867
# [398]	test-rmse:1.07711
# [399]	test-rmse:1.07606

# %%
yxgb_pred = model.predict(d_test)
yxgb_pred = np.round(yxgb_pred)

# %%
accuracy_score(yxgb_pred, np.round(Y_test))
# Out:
# 0.27050720100187853

# %%
quadratic_weighted_kappa(yxgb_pred, Y_test)
# Out:
# 0.826983747370766

# %%
joblib.dump(model, 'files/model_asap1_776_counter_both_ori_adjusted_clip')
# Out:
# ['files/model_asap1_776_counter_both_ori_adjusted_clip']

# %% [markdown]
# ## Model interpretation

# %%
imp_vals = model.get_fscore()
#print(imp_vals)
feature_important = model.get_score(importance_type='weight')
feats_sorted = sorted(feature_important.items(), key=lambda x: x[1], reverse=True)
aa_25 = feats_sorted[:25]

# %%
x_axis = [i[0] for i in aa_25]
y_axis = [i[1] for i in aa_25]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,25))
plt.title("GB Best-25 Features", fontsize=40)
plt.bar(x_axis, y_axis, width=0.8, align='center')
plt.xticks(x_axis, fontsize=40, rotation=80)
plt.ylabel("F Score", fontsize=40)
plt.yticks(fontsize=40)
plt.tight_layout()
plt.savefig('gb_best_25.png')
plt.show()

# %% [markdown]
# ### Get Testing Data

# %%
import joblib

# %%
asap1 = joblib.load('files/asap1_essay')

# %%
len(asap1)
# Out:
# 1783

# %%
asap1
# Out:
#       essay_id                                              essay  \
# 0            1  Dear local newspaper, I think effects computer...
# 1            2  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2            3  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3            4  Dear Local Newspaper, @CAPS1 I have found that...
# 4            5  Dear @LOCATION1, I know having computers has a...
# ...        ...                                                ...
# 1778      1783  Dear @CAPS1, @CAPS2 several reasons on way I t...
# 1779      1784  Do a adults and kids spend to much time on the...
# 1780      1785  My opinion is that people should have computer...
# 1781      1786  Dear readers, I think that its good and bad to...
# 1782      1787  Dear - Local Newspaper I agree thats computers...
#
#       domain1_score
# 0                 8
# 1                 9
# 2                 7
# 3                10
# 4                 8
# ...             ...
# 1778              8
# 1779              7
# 1780              8
# 1781              2
# 1782              7
#
# [1783 rows x 3 columns]

# %%
type(asap1)
# Out:
# pandas.core.frame.DataFrame

# %%
asap1_test = asap1.iloc[idx_test]

# %%
len(asap1_test)
# Out:
# 357

# %%
#asap1_test

# %%
asap1_test.to_csv('ASAP1 Test Set.tsv', index=False, sep='\t')

# %%
df = pd.read_csv('ASAP1 Test Set.tsv', sep='\t', encoding = "ISO-8859-1")

# %% [markdown]
# ### Get Training Data

# %%
asap1_train = asap1.iloc[idx_train]

# %%
len(asap1_train)
# Out:
# 1426

# %%
asap1_train.to_csv('ASAP1 Train Set.tsv', index=False, sep='\t')

# %%
df = pd.read_csv('ASAP1 Train Set.tsv', sep='\t', encoding = "ISO-8859-1")

# %%
import itertools 

n = 4 # OPEN AI GIVES A LOT OF SUGGESTIONS
numbers = range(1, n + 1) 

ctr = 0
for length in range(1, n + 1):
    print("Combination with length: ", length)
    combinations = itertools.combinations(numbers, length)
    delta = 0.4 * length  # Adjust delta based on length
    delta = round(delta, 2)
    for combo in combinations:
        print(combo)
        ctr += 1

print("Total number: ", ctr)
# Out:
# Combination with length:  1
# (1,)
# (2,)
# (3,)
# (4,)
# Combination with length:  2
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 4)
# Combination with length:  3
# (1, 2, 3)
# (1, 2, 4)
# (1, 3, 4)
# (2, 3, 4)
# Combination with length:  4
# (1, 2, 3, 4)
# Total number:  15

# %%
FROM 1 ESSAY --> we generate 31 new better essays --> Why 31 --> 2^n - 1 --> 2 ^ 5 -1 = 31

# %%
I TOOK 100 ESSAYS RANDOMLY --> 3100 NEW BETTER ESSAYS --> WE NEED NEW LABELS FOR THOSE 3100 DATA

# %%
THEN, WE DO THE SAME FROM EXACTLY THE SAME 100 ESSAYS --> BUT NOW WORSE ESSAYS --> 3100 NEW ESSAYS

# %%
SO, IN THE END WE HAVE 6200 AUGMENTATION DATA
THE ORIGINAL ESSAYS ARE ONLY 1700 DATA

# %%
n = 5
numbers = range(1, n + 1)  # Numbers from 1 to 5
ctr = 0

for i in range(len(new_label_train_error)):
    # Generate combinations of varying lengths
    idx = 0
    for length in range(1, n + 1):
        combinations = itertools.combinations(numbers, length)
        delta = 0.3 * length  # Adjust delta based on length
        delta = round(delta, 2)
        for combo in combinations:
            new_label_train_error[i][idx] -= delta
            print(combo)
            idx += 1

# %%
import itertools
n = 4
numbers = range(1, n + 1)
ctr = 0

for length in range(1, n + 1):
    combinations = itertools.combinations(numbers, length)
    print("length: ", length)
    for combo in combinations:
        print(combo)
        ctr += 1
print("Total : ", ctr)
# Out:
# length:  1
# (1,)
# (2,)
# (3,)
# (4,)
# length:  2
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 4)
# length:  3
# (1, 2, 3)
# (1, 2, 4)
# (1, 3, 4)
# (2, 3, 4)
# length:  4
# (1, 2, 3, 4)
# Total :  15

# %%
import itertools
n = 5
numbers = range(1, n + 1)
ctr = 0

for length in range(1, n + 1):
    combinations = math.comb(len(numbers), length)
    print("length: ", length)
    for j in range(combinations):
        print(length)
        ctr += 1
print("Total : ", ctr)
# Out:
# length:  1
# 1
# 1
# 1
# 1
# 1
# length:  2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# length:  3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# length:  4
# 4
# 4
# 4
# 4
# 4
# length:  5
# 5
# Total :  31

# %%
import math

def binomial(n, k):
    return math.comb(n, k)

def cumulative_sums(n):
    S = [0]  # S(0) = 0
    for k in range(1, n + 1):
        S.append(S[k - 1] + binomial(n, k))  # Cumulative sum
    return S

def generate_k_array(n):
    S = cumulative_sums(n)  # Get cumulative sums
    print(S)
    result = []
    
    for i in range(S[-1]):  # Iterate up to the total number of combinations
        for k in range(1, n + 1):
            if S[k - 1] <= i < S[k]:
                result.append(k)  # Append the current k
                break  # Move to the next index

    return result

# Example usage
n = 4
k_array = generate_k_array(n)
print(k_array)
# Out:
# 0
# 4
# 10
# 14
# [0, 4, 10, 14, 15]
# [1, 1, 1, 1, 2, 2, 2, 2, 2, 2, 3, 3, 3, 3, 4]

# %%
binomial(4,2)
# Out:
# 6

# %%
cumulative_sums(4)
# Out:
# S[k-1] :  0
# n :  4 k :  1
# S[k-1] :  4
# n :  4 k :  2
# S[k-1] :  10
# n :  4 k :  3
# S[k-1] :  14
# n :  4 k :  4
# [0, 4, 10, 14, 15]

# %%
import numpy as np
import matplotlib.pyplot as plt

def build_grids(rows):
    # rows: list of dicts with keys: dpos, dneg, better, worse, qwk
    dpos_vals = sorted({r['dpos'] for r in rows})
    dneg_vals = sorted({r['dneg'] for r in rows})
    R, C = len(dneg_vals), len(dpos_vals)
    def grid(key):
        G = np.full((R, C), np.nan)
        for r in rows:
            i = dneg_vals.index(r['dneg'])
            j = dpos_vals.index(r['dpos'])
            G[i, j] = r[key]
        return G, np.array(dpos_vals), np.array(dneg_vals)
    return grid

def plot_heatmaps_from_rows(rows, title=""):
    make = build_grids(rows)
    qwk, dpos, dneg = make('qwk')
    better, _, _    = make('better')
    worse, _, _     = make('worse')

    fig, axes = plt.subplots(1, 3, figsize=(14, 4), constrained_layout=True)
    mats = [qwk, better, worse]
    names = ['QWK', 'Better accuracy (%)', 'Worse accuracy (%)']
    cmaps = ['viridis', 'Blues', 'Reds']

    for ax, M, name, cmap in zip(axes, mats, names, cmaps):
        M_masked = np.ma.masked_invalid(M)  # <- hides NaNs instead of showing a blank
        im = ax.imshow(
            M_masked, origin='lower', aspect='auto', cmap=cmap,
            extent=[dpos.min(), dpos.max(), dneg.min(), dneg.max()]
        )
        ax.set_xlabel(r'$\delta^+$')
        ax.set_ylabel(r'$\delta^-$')
        ax.set_title(name)
        fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

        # mark best QWK
        if name == 'QWK' and np.isfinite(M).any():
            r, c = np.unravel_index(np.nanargmax(M), M.shape)
            ax.plot(dpos[c], dneg[r], marker='*', markersize=12,
                    color='yellow', mec='k', mew=0.6)

    fig.suptitle(title, y=1.02)
    plt.show()

# %%
rows_asap1 = [
    {"dpos": 0.2, "dneg": 0.3, "better": 70.45, "worse": 50.02, "qwk": 0.838},
    {"dpos": 0.3, "dneg": 0.4, "better": 74.61, "worse": 55.49, "qwk": 0.834},
    {"dpos": 0.4, "dneg": 0.5, "better": 77.03, "worse": 57.40, "qwk": 0.832},
    {"dpos": 0.5, "dneg": 0.7, "better": 79.40, "worse": 61.99, "qwk": 0.786},  # example
    {"dpos": 1.6, "dneg": 2.0, "better": 93.06, "worse": 80.97, "qwk": 0.627},
]
plot_heatmaps_from_rows(rows_asap1, title="ASAP-1: effect of (δ⁺, δ⁻)")
