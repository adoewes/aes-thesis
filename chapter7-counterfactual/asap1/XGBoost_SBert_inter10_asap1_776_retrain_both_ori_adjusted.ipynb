# %% [markdown]
# ### This is to retrain using both positive and negative counterfactuals

# %%
import xgboost
import joblib
import numpy as np
from sklearn.metrics import accuracy_score
from quadratic_weighted_kappa import quadratic_weighted_kappa
import pandas as pd
import itertools

# %%
scores_ori = np.array(joblib.load("files/scores_essay_100_train_ori")).astype(float)
scores_ori.shape
# Out:
# (100,)

# %%
scores_ori = np.repeat(scores_ori, 31)

# %%
len(scores_ori)
# Out:
# 3100

# %%
x = joblib.load('files/asap1_features_776').squeeze()
y = joblib.load("files/score_asap1")
y = y.reshape(-1,1)

feature_names = joblib.load('files/feature_names_776')
#model = joblib.load('model_asap1_778')

feats_counter_train_error = joblib.load('files/feats_counter_train_error_776').reshape(-1,776)
new_label_train_error = scores_ori.copy().reshape(3100,-1)

feats_counter_train_better = joblib.load('files/feats_counter_train_correct_776').reshape(-1,776)
new_label_train_better = scores_ori.copy().reshape(3100,-1)

# %%
new_label_train_better.shape
# Out:
# (3100, 1)

# %%
np.max(y)
# Out:
# 12

# %%
print(scores_ori.dtype)
# Out:
# float64

# %%
print(new_label_train_better.dtype)
# Out:
# float64

# %% [markdown]
# #### Apply proposed method: Adjust worse essays label

# %%
# There are 100 essay samples with 31 variations

new_label_train_error = new_label_train_error.reshape(100,-1)
new_label_train_error.shape
# Out:
# (100, 31)

# %%
n = 5
numbers = range(1, n + 1)  # Numbers from 1 to 5
ctr = 0

for i in range(len(new_label_train_error)):
    # Generate combinations of varying lengths
    idx = 0
    for length in range(1, n + 1):
        combinations = itertools.combinations(numbers, length)
        delta = 0.7 * length  # Adjust delta based on length
        delta = round(delta, 2)
        for combo in combinations:
            # print("i: ", i, ", idx: ", idx)
            # print("delta: ", delta)
            # print("ori: ", matrices[i][idx])
            new_label_train_error[i][idx] -= delta
            # print("after: ", matrices[i][idx])
            idx += 1

# %%
new_label_train_error = new_label_train_error.reshape(-1,1)
new_label_train_error.shape
# Out:
# (3100, 1)

# %% [markdown]
# #### Apply proposed method: Adjust better essays label

# %%
# There are 100 essay samples with 31 variations

new_label_train_better = new_label_train_better.reshape(100,-1)
new_label_train_better.shape
# Out:
# (100, 31)

# %%
n = 5
numbers = range(1, n + 1)  # Numbers from 1 to 5
ctr = 0

for i in range(len(new_label_train_better)):
    # Generate combinations of varying lengths
    idx = 0
    for length in range(1, n + 1):
        combinations = itertools.combinations(numbers, length)
        delta = 0.5 * length  # Adjust delta based on length
        delta = round(delta, 2)
        for combo in combinations:
            # print("i: ", i, ", idx: ", idx)
            # print("delta: ", delta)
            # print("ori: ", matrices[i][idx])
            new_label_train_better[i][idx] += delta
            # print("after: ", matrices[i][idx])
            idx += 1

# %%
new_label_train_better = new_label_train_better.reshape(-1,1)
new_label_train_better.shape
# Out:
# (3100, 1)

# %%
np.array_equal(scores_ori, new_label_train_error.flatten())
np.array_equal(scores_ori, new_label_train_better.flatten())
# Out:
# False

# %%
import numpy as np
import matplotlib.pyplot as plt

n_show = 100

# Flatten and slice
ori = scores_ori[:n_show]
err = new_label_train_error[:n_show].flatten()
bet = new_label_train_better[:n_show].flatten()

# Compute and scale differences
diff_err = (err - ori) * 1000
diff_bet = (bet - ori) * 1000

# Plot
plt.figure(figsize=(12, 6))
plt.plot(diff_err, label='(Error - Original) × 1000', marker='o')
plt.plot(diff_bet, label='(Better - Original) × 1000', marker='x')
plt.axhline(0, color='gray', linestyle='--')
plt.title(f'Scaled Differences from Original Scores (First {n_show})')
plt.xlabel('Index')
plt.ylabel('Difference × 1000')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(scores_ori, bins=20, alpha=0.5, label='Original Scores')
plt.hist(new_label_train_error, bins=20, alpha=0.5, label='Error Labels')
plt.hist(new_label_train_better, bins=20, alpha=0.5, label='Better Labels')
plt.title('Score Distributions')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_counter = np.concatenate((y, new_label_train_better, new_label_train_error), axis=0).reshape(-1)
y_counter.shape
# Out:
# (7983,)

# %%
y = y_counter
y.shape
# Out:
# (7983,)

# %%
x_counter = np.concatenate((x,feats_counter_train_better, feats_counter_train_error), axis=0)
x_counter.shape
# Out:
# (7983, 776)

# %%
x = x_counter
x.shape
# Out:
# (7983, 776)

# %%
# REMOVE PROMPT OVERLAP & PROMPT OVERLAP (SYNONYM) FEATURES, AS THEY HAVE NEGATIVE CORRELATION WITH FINAL SCORE

# x_776 = np.delete(x, [5,6],axis=1)
# x_776.shape

# %%
# x = x_776
# x.shape

# %%
def get_feature_names_extended():
    inter_feats = ['Answer Length', 'Word Count', 'Average Word Length', 'Unique Word Count', 'Punctuation Density',
                  'Prompt Overlap', 'Prompt Overlap (synonyms)', 'Prompt Similarity SBert', 
                  'Spelling Error', 'Language Error']
    inter_feats = ['Answer Length', 'Word Count', 'Average Word Length', 'Unique Word Count', 'Punctuation Density',
                  'Prompt Similarity SBert', 
                  'Spelling Error', 'Language Error']
    
    sbert_feats = []
    sbert_dim = 768

    for i in range(0, sbert_dim):
    	fname = "sbert_" + str(i) 
    	sbert_feats.append(fname)
    
    feature_names = inter_feats + sbert_feats 

    print("len feature names: ", len(feature_names))
    
    return feature_names

feature_names = get_feature_names_extended()#[:12]
# Out:
# len feature names:  776

# %%
#joblib.dump(feature_names, 'feature_names_778')

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

kf = KFold(n_splits=5, shuffle=True, random_state=42)

print(kf)
# Out:
# KFold(n_splits=5, random_state=42, shuffle=True)

# %%
model = xgboost.XGBRegressor(objective ='reg:squarederror',
                colsample_bytree=0.4,
                 gamma=0,                 
                 learning_rate=0.05,
                 max_depth=4,
                 min_child_weight=1.5,
                 n_estimators=1000,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=42)

# ORI QWK :

# %%
# qwk_scores = []

# test_indices = []
# pred_labels = []

# for train_index, test_index in kf.split(x, y):
    
#     X_train, X_test, Y_train, Y_test = x[train_index], x[test_index], y[train_index], y[test_index]
         
#     model.fit(X_train, Y_train)
    
#     predict = model.predict(X_test)
#     predict = np.round(predict)
    
#     pred_labels.extend(predict)
#     test_indices.extend(test_index)
    
#     result = quadratic_weighted_kappa(Y_test, predict)
    
#     print("Qwk : ", result)
#     print(X_train.shape)
#     qwk_scores.append(result)
    
# np.mean(qwk_scores)

# %% [markdown]
# ##### Only evaluate the original Test Set (without augmentation), but using new Model (trained with augmentation)

# %%
qwk_scores = []

for train_index, test_index in kf.split(x, y):
    
    X_train, X_test, Y_train, Y_test = x[train_index], x[test_index], y[train_index], y[test_index]

    # Filter test indices for those less than 1783
    test_index_baru = test_index[test_index < 1783]
    print("Filtered test indices count:", len(test_index_baru))
    
    print(X_train.shape)
    print(Y_train.shape)
    model.fit(X_train, Y_train)

    # Use test_index_baru to get filtered test sets from the original arrays
    X_test_baru = X_test[test_index < 1783]  # Correct filtering
    Y_test_baru = Y_test[test_index < 1783]  # Correct filtering

    print("Filtered X_test count:", len(X_test_baru))
    print("Filtered Y_test count:", len(Y_test_baru))
    
    predict = model.predict(X_test_baru)
    predict = np.round(predict)
    
    result = quadratic_weighted_kappa(Y_test_baru, predict)
    
    print("Qwk : ", result)
    qwk_scores.append(result)

mean_qwk = np.mean(qwk_scores)
print("Mean Qwk:", mean_qwk)
# Out:
# Filtered test indices count: 380
# (6386, 776)
# (6386,)
# Filtered X_test count: 380
# Filtered Y_test count: 380
# Qwk :  0.7408719931271477
# Filtered test indices count: 366
# (6386, 776)
# (6386,)
# Filtered X_test count: 366
# Filtered Y_test count: 366
# Qwk :  0.8172580243841753
# Filtered test indices count: 339
# (6386, 776)
# (6386,)
# Filtered X_test count: 339
# Filtered Y_test count: 339
# Qwk :  0.7990037482535847
# Filtered test indices count: 376
# (6387, 776)
# (6387,)
# Filtered X_test count: 376
# Filtered Y_test count: 376
# Qwk :  0.7982335649655925
# Filtered test indices count: 322
# (6387, 776)
# (6387,)
# Filtered X_test count: 322
# Filtered Y_test count: 322
# Qwk :  0.7757471177689159
# Mean Qwk: 0.7862228896998832

# %%
print(len(pred_labels))
print(len(test_indices))
# Out:
# 7983
# 7983

# %%
new_score = np.zeros(1783)
new_score
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
new_score[test_indices] = pred_labels_int
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 new_score[test_indices] = pred_labels_int
#
# NameError: name 'pred_labels_int' is not defined

# %%
new_score
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
new_score[60]
# Out:
# 0.0

# %%
#joblib.dump(new_score, 'score_model_normalized')

# %% [markdown]
# ## Create model

# %%
from sklearn.model_selection import train_test_split
indices = np.arange(len(x))
X_train, X_test, Y_train, Y_test, idx_train, idx_test = train_test_split(x, y, indices, test_size=0.2, random_state=42)

# %%
len(idx_test)
# Out:
# 1597

# %%
idx_test
# Out:
# array([6572, 7314, 4119, ..., 2348, 1746, 4881])

# %%
# Filter the array for values less than 1783
new_array = idx_test[idx_test < 1783]
len(new_array)
# Out:
# 380

# %%
d_train = xgboost.DMatrix(X_train, label=Y_train, feature_names=feature_names)
d_test = xgboost.DMatrix(X_test, label=Y_test, feature_names=feature_names)

# %%
model = xgboost.train({"learning_rate": 0.05, "max_depth":4, 'alpha':0.75, 'lambda':0.45,}, d_train, 400, evals = [(d_test, "test")], early_stopping_rounds=50)
# Out:
# [0]	test-rmse:8.11522
# [1]	test-rmse:7.72496
# [2]	test-rmse:7.35501
# [3]	test-rmse:7.00426
# [4]	test-rmse:6.67105
# [5]	test-rmse:6.35518
# [6]	test-rmse:6.05715
# [7]	test-rmse:5.77545
# [8]	test-rmse:5.50831
# [9]	test-rmse:5.25501
# [10]	test-rmse:5.01371
# [11]	test-rmse:4.78648
# [12]	test-rmse:4.57194
# [13]	test-rmse:4.36849
# [14]	test-rmse:4.17526
# [15]	test-rmse:3.99348
# [16]	test-rmse:3.82046
# [17]	test-rmse:3.65678
# [18]	test-rmse:3.50283
# [19]	test-rmse:3.35828
# [20]	test-rmse:3.22072
# [21]	test-rmse:3.09107
# [22]	test-rmse:2.96879
# [23]	test-rmse:2.85294
# [24]	test-rmse:2.74535
# [25]	test-rmse:2.64316
# [26]	test-rmse:2.54776
# [27]	test-rmse:2.45768
# [28]	test-rmse:2.37453
# [29]	test-rmse:2.29431
# [30]	test-rmse:2.21951
# [31]	test-rmse:2.15014
# [32]	test-rmse:2.08386
# [33]	test-rmse:2.02221
# [34]	test-rmse:1.96641
# [35]	test-rmse:1.91262
# [36]	test-rmse:1.86394
# [37]	test-rmse:1.81833
# [38]	test-rmse:1.77446
# [39]	test-rmse:1.73259
# [40]	test-rmse:1.69360
# [41]	test-rmse:1.65922
# [42]	test-rmse:1.62461
# [43]	test-rmse:1.59386
# [44]	test-rmse:1.56591
# [45]	test-rmse:1.53892
# [46]	test-rmse:1.51389
# [47]	test-rmse:1.49233
# [48]	test-rmse:1.46948
# [49]	test-rmse:1.45103
# [50]	test-rmse:1.43515
# [51]	test-rmse:1.41795
# [52]	test-rmse:1.40225
# [53]	test-rmse:1.38554
# [54]	test-rmse:1.37283
# [55]	test-rmse:1.35998
# [56]	test-rmse:1.34883
# [57]	test-rmse:1.33547
# [58]	test-rmse:1.32654
# [59]	test-rmse:1.31767
# [60]	test-rmse:1.30988
# [61]	test-rmse:1.30272
# [62]	test-rmse:1.29570
# [63]	test-rmse:1.28723
# [64]	test-rmse:1.27826
# [65]	test-rmse:1.27006
# [66]	test-rmse:1.26505
# [67]	test-rmse:1.25915
# [68]	test-rmse:1.25464
# [69]	test-rmse:1.24965
# [70]	test-rmse:1.24544
# [71]	test-rmse:1.24039
# [72]	test-rmse:1.23668
# [73]	test-rmse:1.23200
# [74]	test-rmse:1.22756
# [75]	test-rmse:1.22260
# [76]	test-rmse:1.21943
# [77]	test-rmse:1.21748
# [78]	test-rmse:1.21328
# [79]	test-rmse:1.21066
# [80]	test-rmse:1.20768
# [81]	test-rmse:1.20424
# [82]	test-rmse:1.20149
# [83]	test-rmse:1.19935
# [84]	test-rmse:1.19608
# [85]	test-rmse:1.19416
# [86]	test-rmse:1.19280
# [87]	test-rmse:1.18985
# [88]	test-rmse:1.18765
# [89]	test-rmse:1.18668
# [90]	test-rmse:1.18529
# [91]	test-rmse:1.18049
# [92]	test-rmse:1.17907
# [93]	test-rmse:1.17712
# [94]	test-rmse:1.17483
# [95]	test-rmse:1.17202
# [96]	test-rmse:1.17055
# [97]	test-rmse:1.16799
# [98]	test-rmse:1.16669
# [99]	test-rmse:1.16391
# [100]	test-rmse:1.16300
# [101]	test-rmse:1.16100
# [102]	test-rmse:1.15766
# [103]	test-rmse:1.15568
# [104]	test-rmse:1.15436
# [105]	test-rmse:1.15303
# [106]	test-rmse:1.15097
# [107]	test-rmse:1.15005
# [108]	test-rmse:1.14815
# [109]	test-rmse:1.14665
# [110]	test-rmse:1.14489
# [111]	test-rmse:1.14397
# [112]	test-rmse:1.14227
# [113]	test-rmse:1.13996
# [114]	test-rmse:1.13643
# [115]	test-rmse:1.13473
# [116]	test-rmse:1.13274
# [117]	test-rmse:1.13188
# [118]	test-rmse:1.12964
# [119]	test-rmse:1.12744
# [120]	test-rmse:1.12557
# [121]	test-rmse:1.12482
# [122]	test-rmse:1.12371
# [123]	test-rmse:1.12257
# [124]	test-rmse:1.12028
# [125]	test-rmse:1.11844
# [126]	test-rmse:1.11745
# [127]	test-rmse:1.11611
# [128]	test-rmse:1.11467
# [129]	test-rmse:1.11353
# [130]	test-rmse:1.11189
# [131]	test-rmse:1.10969
# [132]	test-rmse:1.10889
# [133]	test-rmse:1.10692
# [134]	test-rmse:1.10481
# [135]	test-rmse:1.10128
# [136]	test-rmse:1.09963
# [137]	test-rmse:1.09755
# [138]	test-rmse:1.09607
# [139]	test-rmse:1.09528
# [140]	test-rmse:1.09318
# [141]	test-rmse:1.09244
# [142]	test-rmse:1.08951
# [143]	test-rmse:1.08856
# [144]	test-rmse:1.08733
# [145]	test-rmse:1.08585
# [146]	test-rmse:1.08398
# [147]	test-rmse:1.08218
# [148]	test-rmse:1.08082
# [149]	test-rmse:1.07949
# [150]	test-rmse:1.07862
# [151]	test-rmse:1.07711
# [152]	test-rmse:1.07631
# [153]	test-rmse:1.07490
# [154]	test-rmse:1.07357
# [155]	test-rmse:1.07242
# [156]	test-rmse:1.07136
# [157]	test-rmse:1.06989
# [158]	test-rmse:1.06847
# [159]	test-rmse:1.06731
# [160]	test-rmse:1.06604
# [161]	test-rmse:1.06511
# [162]	test-rmse:1.06366
# [163]	test-rmse:1.06265
# [164]	test-rmse:1.06191
# [165]	test-rmse:1.06046
# [166]	test-rmse:1.05913
# [167]	test-rmse:1.05812
# [168]	test-rmse:1.05730
# [169]	test-rmse:1.05571
# [170]	test-rmse:1.05401
# [171]	test-rmse:1.05263
# [172]	test-rmse:1.04959
# [173]	test-rmse:1.04901
# [174]	test-rmse:1.04758
# [175]	test-rmse:1.04694
# [176]	test-rmse:1.04636
# [177]	test-rmse:1.04600
# [178]	test-rmse:1.04548
# [179]	test-rmse:1.04408
# [180]	test-rmse:1.04326
# [181]	test-rmse:1.04247
# [182]	test-rmse:1.04134
# [183]	test-rmse:1.04027
# [184]	test-rmse:1.03882
# [185]	test-rmse:1.03822
# [186]	test-rmse:1.03746
# [187]	test-rmse:1.03489
# [188]	test-rmse:1.03383
# [189]	test-rmse:1.03345
# [190]	test-rmse:1.03152
# [191]	test-rmse:1.03106
# [192]	test-rmse:1.02994
# [193]	test-rmse:1.02919
# [194]	test-rmse:1.02797
# [195]	test-rmse:1.02712
# [196]	test-rmse:1.02626
# [197]	test-rmse:1.02566
# [198]	test-rmse:1.02506
# [199]	test-rmse:1.02362
# [200]	test-rmse:1.02235
# [201]	test-rmse:1.02160
# [202]	test-rmse:1.02101
# [203]	test-rmse:1.02035
# [204]	test-rmse:1.01878
# [205]	test-rmse:1.01775
# [206]	test-rmse:1.01687
# [207]	test-rmse:1.01565
# [208]	test-rmse:1.01364
# [209]	test-rmse:1.01272
# [210]	test-rmse:1.01216
# [211]	test-rmse:1.01141
# [212]	test-rmse:1.00960
# [213]	test-rmse:1.00797
# [214]	test-rmse:1.00629
# [215]	test-rmse:1.00506
# [216]	test-rmse:1.00390
# [217]	test-rmse:1.00350
# [218]	test-rmse:1.00209
# [219]	test-rmse:1.00104
# [220]	test-rmse:1.00020
# [221]	test-rmse:0.99937
# [222]	test-rmse:0.99795
# [223]	test-rmse:0.99678
# [224]	test-rmse:0.99629
# [225]	test-rmse:0.99509
# [226]	test-rmse:0.99373
# [227]	test-rmse:0.99259
# [228]	test-rmse:0.99076
# [229]	test-rmse:0.98904
# [230]	test-rmse:0.98714
# [231]	test-rmse:0.98662
# [232]	test-rmse:0.98602
# [233]	test-rmse:0.98535
# [234]	test-rmse:0.98402
# [235]	test-rmse:0.98285
# [236]	test-rmse:0.98172
# [237]	test-rmse:0.98099
# [238]	test-rmse:0.98023
# [239]	test-rmse:0.97970
# [240]	test-rmse:0.97700
# [241]	test-rmse:0.97652
# [242]	test-rmse:0.97546
# [243]	test-rmse:0.97456
# [244]	test-rmse:0.97403
# [245]	test-rmse:0.97331
# [246]	test-rmse:0.97224
# [247]	test-rmse:0.97081
# [248]	test-rmse:0.96883
# [249]	test-rmse:0.96799
# [250]	test-rmse:0.96719
# [251]	test-rmse:0.96665
# [252]	test-rmse:0.96474
# [253]	test-rmse:0.96388
# [254]	test-rmse:0.96279
# [255]	test-rmse:0.96233
# [256]	test-rmse:0.96200
# [257]	test-rmse:0.96141
# [258]	test-rmse:0.96106
# [259]	test-rmse:0.96069
# [260]	test-rmse:0.96012
# [261]	test-rmse:0.95844
# [262]	test-rmse:0.95813
# [263]	test-rmse:0.95724
# [264]	test-rmse:0.95612
# [265]	test-rmse:0.95519
# [266]	test-rmse:0.95476
# [267]	test-rmse:0.95351
# [268]	test-rmse:0.95250
# [269]	test-rmse:0.95156
# [270]	test-rmse:0.95098
# [271]	test-rmse:0.95069
# [272]	test-rmse:0.94983
# [273]	test-rmse:0.94920
# [274]	test-rmse:0.94880
# [275]	test-rmse:0.94710
# [276]	test-rmse:0.94648
# [277]	test-rmse:0.94559
# [278]	test-rmse:0.94459
# [279]	test-rmse:0.94358
# [280]	test-rmse:0.94269
# [281]	test-rmse:0.94191
# [282]	test-rmse:0.94132
# [283]	test-rmse:0.94084
# [284]	test-rmse:0.93971
# [285]	test-rmse:0.93872
# [286]	test-rmse:0.93811
# [287]	test-rmse:0.93725
# [288]	test-rmse:0.93664
# [289]	test-rmse:0.93610
# [290]	test-rmse:0.93497
# [291]	test-rmse:0.93417
# [292]	test-rmse:0.93322
# [293]	test-rmse:0.93305
# [294]	test-rmse:0.93266
# [295]	test-rmse:0.93174
# [296]	test-rmse:0.93044
# [297]	test-rmse:0.92913
# [298]	test-rmse:0.92850
# [299]	test-rmse:0.92777
# [300]	test-rmse:0.92643
# [301]	test-rmse:0.92600
# [302]	test-rmse:0.92561
# [303]	test-rmse:0.92521
# [304]	test-rmse:0.92458
# [305]	test-rmse:0.92392
# [306]	test-rmse:0.92349
# [307]	test-rmse:0.92268
# [308]	test-rmse:0.92164
# [309]	test-rmse:0.92139
# [310]	test-rmse:0.92073
# [311]	test-rmse:0.91968
# [312]	test-rmse:0.91955
# [313]	test-rmse:0.91881
# [314]	test-rmse:0.91851
# [315]	test-rmse:0.91797
# [316]	test-rmse:0.91704
# [317]	test-rmse:0.91645
# [318]	test-rmse:0.91551
# [319]	test-rmse:0.91491
# [320]	test-rmse:0.91427
# [321]	test-rmse:0.91348
# [322]	test-rmse:0.91276
# [323]	test-rmse:0.91228
# [324]	test-rmse:0.91193
# [325]	test-rmse:0.91135
# [326]	test-rmse:0.91080
# [327]	test-rmse:0.90994
# [328]	test-rmse:0.90957
# [329]	test-rmse:0.90911
# [330]	test-rmse:0.90878
# [331]	test-rmse:0.90805
# [332]	test-rmse:0.90766
# [333]	test-rmse:0.90728
# [334]	test-rmse:0.90543
# [335]	test-rmse:0.90487
# [336]	test-rmse:0.90430
# [337]	test-rmse:0.90360
# [338]	test-rmse:0.90299
# [339]	test-rmse:0.90245
# [340]	test-rmse:0.90167
# [341]	test-rmse:0.90113
# [342]	test-rmse:0.89921
# [343]	test-rmse:0.89800
# [344]	test-rmse:0.89758
# [345]	test-rmse:0.89723
# [346]	test-rmse:0.89656
# [347]	test-rmse:0.89598
# [348]	test-rmse:0.89508
# [349]	test-rmse:0.89460
# [350]	test-rmse:0.89373
# [351]	test-rmse:0.89349
# [352]	test-rmse:0.89289
# [353]	test-rmse:0.89192
# [354]	test-rmse:0.89030
# [355]	test-rmse:0.88881
# [356]	test-rmse:0.88734
# [357]	test-rmse:0.88702
# [358]	test-rmse:0.88570
# [359]	test-rmse:0.88532
# [360]	test-rmse:0.88469
# [361]	test-rmse:0.88330
# [362]	test-rmse:0.88288
# [363]	test-rmse:0.88227
# [364]	test-rmse:0.88179
# [365]	test-rmse:0.88147
# [366]	test-rmse:0.88116
# [367]	test-rmse:0.88011
# [368]	test-rmse:0.87990
# [369]	test-rmse:0.87938
# [370]	test-rmse:0.87861
# [371]	test-rmse:0.87810
# [372]	test-rmse:0.87747
# [373]	test-rmse:0.87694
# [374]	test-rmse:0.87666
# [375]	test-rmse:0.87557
# [376]	test-rmse:0.87499
# [377]	test-rmse:0.87469
# [378]	test-rmse:0.87333
# [379]	test-rmse:0.87260
# [380]	test-rmse:0.87145
# [381]	test-rmse:0.87008
# [382]	test-rmse:0.86976
# [383]	test-rmse:0.86909
# [384]	test-rmse:0.86880
# [385]	test-rmse:0.86749
# [386]	test-rmse:0.86640
# [387]	test-rmse:0.86592
# [388]	test-rmse:0.86564
# [389]	test-rmse:0.86483
# [390]	test-rmse:0.86425
# [391]	test-rmse:0.86305
# [392]	test-rmse:0.86242
# [393]	test-rmse:0.86194
# [394]	test-rmse:0.86085
# [395]	test-rmse:0.86026
# [396]	test-rmse:0.85947
# [397]	test-rmse:0.85907
# [398]	test-rmse:0.85879
# [399]	test-rmse:0.85871

# %%
yxgb_pred = model.predict(d_test)
yxgb_pred = np.round(yxgb_pred)

# %%
accuracy_score(yxgb_pred, np.round(Y_test))
# Out:
# 0.408891671884784

# %%
quadratic_weighted_kappa(yxgb_pred, Y_test)
# Out:
# 0.8318520113158258

# %%
joblib.dump(model, 'files/model_asap1_776_counter_both_ori_adjusted')
# Out:
# ['files/model_asap1_776_counter_both_ori_adjusted']

# %% [markdown]
# ## Model interpretation

# %%
imp_vals = model.get_fscore()
#print(imp_vals)
feature_important = model.get_score(importance_type='weight')
feats_sorted = sorted(feature_important.items(), key=lambda x: x[1], reverse=True)
aa_25 = feats_sorted[:25]

# %%
x_axis = [i[0] for i in aa_25]
y_axis = [i[1] for i in aa_25]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,25))
plt.title("GB Best-25 Features", fontsize=40)
plt.bar(x_axis, y_axis, width=0.8, align='center')
plt.xticks(x_axis, fontsize=40, rotation=80)
plt.ylabel("F Score", fontsize=40)
plt.yticks(fontsize=40)
plt.tight_layout()
plt.savefig('gb_best_25.png')
plt.show()

# %% [markdown]
# ### Get Testing Data

# %%
import joblib

# %%
asap1 = joblib.load('files/asap1_essay')

# %%
len(asap1)
# Out:
# 1783

# %%
asap1
# Out:
#       essay_id                                              essay  \
# 0            1  Dear local newspaper, I think effects computer...
# 1            2  Dear @CAPS1 @CAPS2, I believe that using compu...
# 2            3  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...
# 3            4  Dear Local Newspaper, @CAPS1 I have found that...
# 4            5  Dear @LOCATION1, I know having computers has a...
# ...        ...                                                ...
# 1778      1783  Dear @CAPS1, @CAPS2 several reasons on way I t...
# 1779      1784  Do a adults and kids spend to much time on the...
# 1780      1785  My opinion is that people should have computer...
# 1781      1786  Dear readers, I think that its good and bad to...
# 1782      1787  Dear - Local Newspaper I agree thats computers...
#
#       domain1_score
# 0                 8
# 1                 9
# 2                 7
# 3                10
# 4                 8
# ...             ...
# 1778              8
# 1779              7
# 1780              8
# 1781              2
# 1782              7
#
# [1783 rows x 3 columns]

# %%
type(asap1)
# Out:
# pandas.core.frame.DataFrame

# %%
asap1_test = asap1.iloc[idx_test]

# %%
len(asap1_test)
# Out:
# 357

# %%
#asap1_test

# %%
asap1_test.to_csv('ASAP1 Test Set.tsv', index=False, sep='\t')

# %%
df = pd.read_csv('ASAP1 Test Set.tsv', sep='\t', encoding = "ISO-8859-1")

# %% [markdown]
# ### Get Training Data

# %%
asap1_train = asap1.iloc[idx_train]

# %%
len(asap1_train)
# Out:
# 1426

# %%
asap1_train.to_csv('ASAP1 Train Set.tsv', index=False, sep='\t')

# %%
df = pd.read_csv('ASAP1 Train Set.tsv', sep='\t', encoding = "ISO-8859-1")

# %%
import itertools 

n = 4 # OPEN AI GIVES A LOT OF SUGGESTIONS
numbers = range(1, n + 1) 

ctr = 0
for length in range(1, n + 1):
    print("Combination with length: ", length)
    combinations = itertools.combinations(numbers, length)
    delta = 0.4 * length  # Adjust delta based on length
    delta = round(delta, 2)
    for combo in combinations:
        print(combo)
        ctr += 1

print("Total number: ", ctr)
# Out:
# Combination with length:  1
# (1,)
# (2,)
# (3,)
# (4,)
# Combination with length:  2
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 4)
# Combination with length:  3
# (1, 2, 3)
# (1, 2, 4)
# (1, 3, 4)
# (2, 3, 4)
# Combination with length:  4
# (1, 2, 3, 4)
# Total number:  15

# %%
FROM 1 ESSAY --> we generate 31 new better essays --> Why 31 --> 2^n - 1 --> 2 ^ 5 -1 = 31

# %%
I TOOK 100 ESSAYS RANDOMLY --> 3100 NEW BETTER ESSAYS --> WE NEED NEW LABELS FOR THOSE 3100 DATA

# %%
THEN, WE DO THE SAME FROM EXACTLY THE SAME 100 ESSAYS --> BUT NOW WORSE ESSAYS --> 3100 NEW ESSAYS

# %%
SO, IN THE END WE HAVE 6200 AUGMENTATION DATA
THE ORIGINAL ESSAYS ARE ONLY 1700 DATA

# %%
n = 5
numbers = range(1, n + 1)  # Numbers from 1 to 5
ctr = 0

for i in range(len(new_label_train_error)):
    # Generate combinations of varying lengths
    idx = 0
    for length in range(1, n + 1):
        combinations = itertools.combinations(numbers, length)
        delta = 0.3 * length  # Adjust delta based on length
        delta = round(delta, 2)
        for combo in combinations:
            new_label_train_error[i][idx] -= delta
            print(combo)
            idx += 1

# %%
import itertools
n = 4
numbers = range(1, n + 1)
ctr = 0

for length in range(1, n + 1):
    combinations = itertools.combinations(numbers, length)
    print("length: ", length)
    for combo in combinations:
        print(combo)
        ctr += 1
print("Total : ", ctr)
# Out:
# length:  1
# (1,)
# (2,)
# (3,)
# (4,)
# length:  2
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 4)
# length:  3
# (1, 2, 3)
# (1, 2, 4)
# (1, 3, 4)
# (2, 3, 4)
# length:  4
# (1, 2, 3, 4)
# Total :  15

# %%
import itertools
n = 5
numbers = range(1, n + 1)
ctr = 0

for length in range(1, n + 1):
    combinations = math.comb(len(numbers), length)
    print("length: ", length)
    for j in range(combinations):
        print(length)
        ctr += 1
print("Total : ", ctr)
# Out:
# length:  1
# 1
# 1
# 1
# 1
# 1
# length:  2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# length:  3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# length:  4
# 4
# 4
# 4
# 4
# 4
# length:  5
# 5
# Total :  31

# %%
import math

def binomial(n, k):
    return math.comb(n, k)

def cumulative_sums(n):
    S = [0]  # S(0) = 0
    for k in range(1, n + 1):
        S.append(S[k - 1] + binomial(n, k))  # Cumulative sum
    return S

def generate_k_array(n):
    S = cumulative_sums(n)  # Get cumulative sums
    print(S)
    result = []
    
    for i in range(S[-1]):  # Iterate up to the total number of combinations
        for k in range(1, n + 1):
            if S[k - 1] <= i < S[k]:
                result.append(k)  # Append the current k
                break  # Move to the next index

    return result

# Example usage
n = 4
k_array = generate_k_array(n)
print(k_array)
# Out:
# 0
# 4
# 10
# 14
# [0, 4, 10, 14, 15]
# [1, 1, 1, 1, 2, 2, 2, 2, 2, 2, 3, 3, 3, 3, 4]

# %%
binomial(4,2)
# Out:
# 6

# %%
cumulative_sums(4)
# Out:
# S[k-1] :  0
# n :  4 k :  1
# S[k-1] :  4
# n :  4 k :  2
# S[k-1] :  10
# n :  4 k :  3
# S[k-1] :  14
# n :  4 k :  4
# [0, 4, 10, 14, 15]
