# %%
import joblib
import pandas as pd
import nltk
import re
import itertools
import numpy as np
import random

# %%
data = pd.read_csv('ASAP1 Test Set.tsv', sep='\t')
data_100 = data[:100]
data_100.head()
# Out:
#    essay_id                                              essay  domain1_score
# 0       827  I think computers have a postitive affect on p...              6
# 1      1477  I blive that computers have a lot of effects o...              6
# 2       234  Many people think that computers are not a goo...              8
# 3       801  Dear Newspaper people, @CAPS1 you might heard ...              9
# 4       780  More and more people are using computers on a ...              9

# %%
corrections = joblib.load('files/json_responses_test_100')
corrections
# Out:
# [[{'original': 'postitive',
#    'correction': 'positive',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'affect',
#    'correction': 'effect',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'Your',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'Computer',
#    'correction': 'Computers',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'exciseses',
#    'correction': 'exercises',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'it take',
#    'correction': 'it takes',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'postitive',
#    'correction': 'positive',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'affect',
#    'correction': 'effect',
#    'type': 'Word Choice',
#    'sentence': 9}],
#  [{'original': 'blive',
#    'correction': 'believe',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'there',
#    'correction': 'their',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'there',
#    'correction': 'their',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'there',
#    'correction': 'their',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'you eyes',
#    'correction': 'your eyes',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'set',
#    'correction': 'sit',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'you eyes',
#    'correction': 'your eyes',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'gets',
#    'correction': 'get',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'you @MONTH1 lose',
#    'correction': 'you might lose',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'woudnt',
#    'correction': "wouldn't",
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'staff',
#    'correction': 'stuff',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'set',
#    'correction': 'sit',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'you body',
#    'correction': 'your body',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'set',
#    'correction': 'sit',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'exersice',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'in other word',
#    'correction': 'in other words',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'you body',
#    'correction': 'your body',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'ran',
#    'correction': 'run',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'set',
#    'correction': 'sit',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'Thrid',
#    'correction': 'Third',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'you',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'you',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'you mind',
#    'correction': 'your mind',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'be think',
#    'correction': 'be thinking',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'every thing',
#    'correction': 'everything',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'you',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'thinkin',
#    'correction': 'thinking',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'Fanilly',
#    'correction': 'Finally',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'every on',
#    'correction': 'everyone',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'spened',
#    'correction': 'spend',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'exersing',
#    'correction': 'exercising',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'act side',
#    'correction': 'activities outside',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'are',
#    'correction': 'or',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'you',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'exersice',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 2},
#   {'original': 'your',
#    'correction': 'their',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'maybe',
#    'correction': 'may be',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'first off',
#    'correction': 'First off',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'Whether it',
#    'correction': "Whether it's",
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'You',
#    'correction': 'you',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'into about',
#    'correction': 'into',
#    'type': 'Word Choice',
#    'sentence': 17},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 26}],
#  [{'original': 'heard',
#    'correction': 'hear',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'thing',
#    'correction': 'think',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'theyare',
#    'correction': 'they are',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'flys',
#    'correction': 'flies',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'ben', 'correction': 'been', 'type': 'Spelling', 'sentence': 6},
#   {'original': 'minets',
#    'correction': 'minutes',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'hole',
#    'correction': 'whole',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'could of',
#    'correction': 'could have',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'camra',
#    'correction': 'camera',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'andd',
#    'correction': 'and',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'art',
#    'correction': 'out',
#    'type': 'Word Choice',
#    'sentence': 13},
#   {'original': 'place',
#    'correction': 'places',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'Thats',
#    'correction': "That's",
#    'type': 'Grammatical',
#    'sentence': 25},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 25},
#   {'original': 'erson',
#    'correction': 'person',
#    'type': 'Spelling',
#    'sentence': 27},
#   {'original': 'familys',
#    'correction': 'families',
#    'type': 'Spelling',
#    'sentence': 29},
#   {'original': 'Meny',
#    'correction': 'Many',
#    'type': 'Spelling',
#    'sentence': 30},
#   {'original': 'excresing',
#    'correction': 'exercising',
#    'type': 'Spelling',
#    'sentence': 32},
#   {'original': 'than',
#    'correction': 'than',
#    'type': 'Grammatical',
#    'sentence': 34},
#   {'original': 'at leat',
#    'correction': 'at least',
#    'type': 'Spelling',
#    'sentence': 35},
#   {'original': 'callories',
#    'correction': 'calories',
#    'type': 'Spelling',
#    'sentence': 35},
#   {'original': 'Other',
#    'correction': 'Others',
#    'type': 'Grammatical',
#    'sentence': 36},
#   {'original': 'plack',
#    'correction': 'plaque',
#    'type': 'Spelling',
#    'sentence': 38},
#   {'original': 'In sted',
#    'correction': 'Instead',
#    'type': 'Spelling',
#    'sentence': 39},
#   {'original': 'rtimes',
#    'correction': 'times',
#    'type': 'Spelling',
#    'sentence': 40},
#   {'original': 'lisen',
#    'correction': 'listen',
#    'type': 'Spelling',
#    'sentence': 42},
#   {'original': 'insire',
#    'correction': 'inspire',
#    'type': 'Spelling',
#    'sentence': 43},
#   {'original': 'with out',
#    'correction': 'without',
#    'type': 'Grammatical',
#    'sentence': 46}],
#  [{'original': 'and healthy',
#    'correction': 'being healthy',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'excersising',
#    'correction': 'exercising',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'Profesor',
#    'correction': 'Professor',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'excersise',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'obeast',
#    'correction': 'obese',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'communities',
#    'correction': "community's",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'folowing',
#    'correction': 'following',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'gamed',
#    'correction': 'gained',
#    'type': 'Word Choice',
#    'sentence': 7},
#   {'original': 'push ups',
#    'correction': 'push-ups',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'less on',
#    'correction': 'lead to',
#    'type': 'Word Choice',
#    'sentence': 9},
#   {'original': 'life style',
#    'correction': 'lifestyle',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'their our',
#    'correction': 'they are on',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'familieis',
#    'correction': 'families',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'depresion',
#    'correction': 'depression',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'a new came',
#    'correction': 'a new student came',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': "from he wasn't that kid",
#    'correction': "from another school, he wasn't that kind of kid",
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'doing just fun',
#    'correction': 'doing just fine',
#    'type': 'Word Choice',
#    'sentence': 12},
#   {'original': 'the next year started',
#    'correction': 'the next year started,',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'at the end of he school',
#    'correction': 'at the end of the school year',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'keep in touch with an of his friend',
#    'correction': 'kept in touch with any of his friends',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'to his parents',
#    'correction': 'with his parents',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'that week of from the rest',
#    'correction': 'that he was off from the rest',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': "don't much",
#    'correction': "didn't do much",
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'the we got back the',
#    'correction': 'then we got back on',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'finaly',
#    'correction': 'finally',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'and teachers told us he ran away from',
#    'correction': 'and the teachers told us he ran away',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'to much',
#    'correction': 'too much',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'in their computers',
#    'correction': 'on their computers',
#    'type': 'Word Choice',
#    'sentence': 17}],
#  [{'original': 'they, disable',
#    'correction': 'they disable',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'For example ,',
#    'correction': 'For example,',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'you got him',
#    'correction': 'you find them',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'ig', 'correction': 'if', 'type': 'Spelling', 'sentence': 8},
#   {'original': 'would of had',
#    'correction': 'would have had',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'exsample',
#    'correction': 'example',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'you project',
#    'correction': 'your project',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'thats',
#    'correction': "that's",
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'say you been',
#    'correction': "say you've been",
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'their',
#    'correction': 'the',
#    'type': 'Word Choice',
#    'sentence': 14},
#   {'original': 'on more exsample',
#    'correction': 'one more example',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'sosme',
#    'correction': 'some',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'for exsample',
#    'correction': 'For example',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'lette',
#    'correction': 'letter',
#    'type': 'Spelling',
#    'sentence': 20}],
#  [{'original': 'effect',
#    'correction': 'affect',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'effect',
#    'correction': 'affect',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'people lifes',
#    'correction': "people's lives",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': '@CAPS1',
#    'correction': 'social media',
#    'type': 'Word Choice',
#    'sentence': 7},
#   {'original': 'Its',
#    'correction': "It's",
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'an webpage',
#    'correction': 'a webpage',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'I gives',
#    'correction': 'It gives',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'ne', 'correction': 'new', 'type': 'Spelling', 'sentence': 12},
#   {'original': 'diffrent',
#    'correction': 'different',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'wont',
#    'correction': "won't",
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'friend',
#    'correction': 'friends',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'when ever',
#    'correction': 'whenever',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'learn new places',
#    'correction': 'learn about new places',
#    'type': 'Word Choice',
#    'sentence': 18},
#   {'original': 'all these days',
#    'correction': 'all these things',
#    'type': 'Word Choice',
#    'sentence': 19}],
#  [{'original': 'nepaper',
#    'correction': 'newspaper',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'reacently',
#    'correction': 'recently',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'the idea of computers are not very productive',
#    'correction': 'the idea that computers are not very productive',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'informatin',
#    'correction': 'information',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'overcused',
#    'correction': 'overused',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'reason',
#    'correction': 'reasons',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'aroung',
#    'correction': 'around',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'hace',
#    'correction': 'have',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'taking',
#    'correction': 'talking',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'Plagourism',
#    'correction': 'Plagiarism',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'People',
#    'correction': 'people',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'van', 'correction': 'can', 'type': 'Spelling', 'sentence': 10},
#   {'original': 'plagorism',
#    'correction': 'plagiarism',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'copred',
#    'correction': 'copied',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'for',
#    'correction': 'font',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'Teachers immediately you have to talk',
#    'correction': 'Teachers immediately know you have to talk',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'playorise',
#    'correction': 'plagiarize',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'computer',
#    'correction': 'computers',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'or', 'correction': 'of', 'type': 'Spelling', 'sentence': 16}],
#  [{'original': 'comunicate',
#    'correction': 'communicate',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'Dont',
#    'correction': "Don't",
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'decitions',
#    'correction': 'decisions',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'helps',
#    'correction': 'help',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'quicly',
#    'correction': 'quickly',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'google',
#    'correction': 'Google',
#    'type': 'Word Choice',
#    'sentence': 8},
#   {'original': 'ask',
#    'correction': 'Ask',
#    'type': 'Word Choice',
#    'sentence': 8},
#   {'original': 'were',
#    'correction': 'where',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'at how much',
#    'correction': 'how much',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'comunicate',
#    'correction': 'communicate',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'facebook',
#    'correction': 'Facebook',
#    'type': 'Word Choice',
#    'sentence': 17},
#   {'original': 'oovoo',
#    'correction': 'Oovoo',
#    'type': 'Word Choice',
#    'sentence': 17},
#   {'original': 'are',
#    'correction': 'is',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 20},
#   {'original': 'Thats',
#    'correction': "That's",
#    'type': 'Grammatical',
#    'sentence': 22},
#   {'original': 'their',
#    'correction': "they're",
#    'type': 'Grammatical',
#    'sentence': 22},
#   {'original': 'Never the less',
#    'correction': 'Nevertheless',
#    'type': 'Word Choice',
#    'sentence': 24},
#   {'original': 'comunicate',
#    'correction': 'communicate',
#    'type': 'Spelling',
#    'sentence': 24},
#   {'original': 'decition',
#    'correction': 'decision',
#    'type': 'Spelling',
#    'sentence': 25}],
#  [{'original': 'but',
#    'correction': 'also',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'too', 'correction': 'to', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'apropprate',
#    'correction': 'inappropriate',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'of', 'correction': 'off', 'type': 'Spelling', 'sentence': 5},
#   {'original': 'attack',
#    'correction': 'attach',
#    'type': 'Word Choice',
#    'sentence': 6},
#   {'original': 'tred mill',
#    'correction': 'treadmill',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'of', 'correction': 'off', 'type': 'Spelling', 'sentence': 12},
#   {'original': 'inapropprate',
#    'correction': 'inappropriate',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'peoples',
#    'correction': "people's",
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'theses',
#    'correction': 'these',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'with out',
#    'correction': 'without',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'attrack',
#    'correction': 'attract',
#    'type': 'Spelling',
#    'sentence': 24},
#   {'original': 'donot',
#    'correction': 'do not',
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'there',
#    'correction': 'their',
#    'type': 'Grammatical',
#    'sentence': 25},
#   {'original': 'with out',
#    'correction': 'without',
#    'type': 'Spelling',
#    'sentence': 27},
#   {'original': 'inappronrate',
#    'correction': 'inappropriate',
#    'type': 'Spelling',
#    'sentence': 28}],
#  [{'original': 'computers I believe',
#    'correction': 'computers. I believe',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'such as, hand-eye coordination and how that, can',
#    'correction': 'such as hand-eye coordination and how that can',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'Also you',
#    'correction': 'Also, you',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'My first reason being socialization.',
#    'correction': 'My first reason is socialization.',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'i think',
#    'correction': 'I think',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'one example',
#    'correction': 'One example',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'in a recent poll',
#    'correction': 'In a recent poll',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'This can range from the @CAPS2.S to hungary in seconds.',
#    'correction': 'This can range from the @CAPS2.S to Hungary in seconds.',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'I would say this because even though books are good they use hard to find.',
#    'correction': 'I would say this because even though books are good, they are hard to find.',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'This being you can from wikipedia all the way to the infamous google in just .',
#    'correction': 'This means you can go from Wikipedia all the way to the infamous Google in just seconds.',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'Another reason I believe computers are good for studies in that you have endless.',
#    'correction': 'Another reason I believe computers are good for studies is that you have endless resources.',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'you will get a the .',
#    'correction': 'you will get the information you need.',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'The lost .',
#    'correction': 'The lost information can be found easily.',
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'My third and final reason is computer give you exceptional hand-eye coordination can because I know accountant.',
#    'correction': 'My third and final reason is computers give you exceptional hand-eye coordination because I know an accountant.',
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'i asked him',
#    'correction': 'I asked him',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': '@CAPS4 thats one job exemple, another would be real state.',
#    'correction': "@CAPS4 that's one job example, another would be real estate.",
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'Due to computers multiple options you can look up because in the your client.',
#    'correction': "Due to computers' multiple options, you can look up information for your client.",
#    'type': 'Grammatical',
#    'sentence': 22},
#   {'original': 'efficiecnt',
#    'correction': 'efficient',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': "and and bye's front steps.",
#    'correction': 'and by the front steps.',
#    'type': 'Grammatical',
#    'sentence': 26}],
#  [{'original': 'on todays society',
#    'correction': "in today's society",
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'todays',
#    'correction': "today's",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'proffesional',
#    'correction': 'professional',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'coud',
#    'correction': 'could',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'google',
#    'correction': 'Google',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'blc',
#    'correction': 'because',
#    'type': 'Word Choice',
#    'sentence': 9},
#   {'original': 'benifited',
#    'correction': 'benefited',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'deffinetly',
#    'correction': 'definitely',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': "profile's",
#    'correction': "profiles'",
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'I you',
#    'correction': 'if you',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'wornes',
#    'correction': 'worry not',
#    'type': 'Word Choice',
#    'sentence': 13},
#   {'original': 'theirs',
#    'correction': "there's",
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'comingup',
#    'correction': 'coming up',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'theyve',
#    'correction': "they've",
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'deffinetly',
#    'correction': 'definitely',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'says',
#    'correction': 'say',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'everytime',
#    'correction': 'every time',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'assignement',
#    'correction': 'assignment',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'Lets',
#    'correction': "Let's",
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'commerical',
#    'correction': 'commercial',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'you project',
#    'correction': 'your project',
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'power ',
#    'correction': 'PowerPoint',
#    'type': 'Word Choice',
#    'sentence': 18},
#   {'original': 'espically',
#    'correction': 'especially',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'youre',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 20},
#   {'original': 'garenteed',
#    'correction': 'guaranteed',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'canbe',
#    'correction': 'can be',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'projects',
#    'correction': 'project',
#    'type': 'Grammatical',
#    'sentence': 24},
#   {'original': 'wonna',
#    'correction': 'want to',
#    'type': 'Word Choice',
#    'sentence': 24},
#   {'original': 'exersising',
#    'correction': 'exercising',
#    'type': 'Spelling',
#    'sentence': 26},
#   {'original': 'shows',
#    'correction': 'show',
#    'type': 'Grammatical',
#    'sentence': 26},
#   {'original': 'change',
#    'correction': 'changed',
#    'type': 'Grammatical',
#    'sentence': 27},
#   {'original': 'your',
#    'correction': 'your life has',
#    'type': 'Grammatical',
#    'sentence': 29},
#   {'original': 'benefitted',
#    'correction': 'benefited',
#    'type': 'Spelling',
#    'sentence': 29}],
#  [{'original': 'Coumputors',
#    'correction': 'Computers',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'mind browning',
#    'correction': 'mind-blowing',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'somone',
#    'correction': 'someone',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'financhely',
#    'correction': 'financially',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'perduce',
#    'correction': 'produce',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'amasing',
#    'correction': 'amazing',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'graphis',
#    'correction': 'graphics',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'aritist',
#    'correction': 'artists',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'Coumputrs',
#    'correction': 'Computers',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'for great',
#    'correction': 'great',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'recer antal acitivitys',
#    'correction': 'recreational activities',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'I not',
#    'correction': "I'm not",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'activitys',
#    'correction': 'activities',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'lets',
#    'correction': "let's",
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'benifits',
#    'correction': 'benefits',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'We use to',
#    'correction': 'We used to',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'chets',
#    'correction': 'chests',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'securty',
#    'correction': 'security',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'invist',
#    'correction': 'invest',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'invisting',
#    'correction': 'investing',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'hd', 'correction': 'HD', 'type': 'Spelling', 'sentence': 9},
#   {'original': 'fourmula',
#    'correction': 'formula',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'wort',
#    'correction': 'work',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'graphis',
#    'correction': 'graphics',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'coumputers',
#    'correction': 'computers',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'graphis',
#    'correction': 'graphics',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'coumputor',
#    'correction': 'computer',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'dose',
#    'correction': 'does',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'lern',
#    'correction': 'learn',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'perduce',
#    'correction': 'produce',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'graphis',
#    'correction': 'graphics',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'recerantol acivitys',
#    'correction': 'recreational activities',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'todays',
#    'correction': "today's",
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'engoy',
#    'correction': 'enjoy',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'then selfs',
#    'correction': 'themselves',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'ran', 'correction': 'can', 'type': 'Spelling', 'sentence': 18},
#   {'original': 'there is nothing stressed out',
#    'correction': 'there is nothing wrong with being stressed out',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'vidos',
#    'correction': 'videos',
#    'type': 'Spelling',
#    'sentence': 19},
#   {'original': 'use to',
#    'correction': 'used to',
#    'type': 'Grammatical',
#    'sentence': 20},
#   {'original': 'coumpurts',
#    'correction': 'computers',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'plan gobo',
#    'correction': 'plans or goals',
#    'type': 'Word Choice',
#    'sentence': 21},
#   {'original': 'somones',
#    'correction': "someone's",
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'socal',
#    'correction': 'social',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'takin',
#    'correction': 'taken',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'world of war craft',
#    'correction': 'World of Warcraft',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 22},
#   {'original': 'chek',
#    'correction': 'check',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'you tube',
#    'correction': 'YouTube',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'hoped you readers',
#    'correction': 'hope you readers enjoyed',
#    'type': 'Grammatical',
#    'sentence': 24},
#   {'original': 'bennafit',
#    'correction': 'benefit',
#    'type': 'Spelling',
#    'sentence': 25}],
#  [{'original': 'a benefit',
#    'correction': 'benefits',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'in town',
#    'correction': 'in touch',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'tribute',
#    'correction': 'contribute',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'parket',
#    'correction': 'packet',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 6},
#   {'original': 'google',
#    'correction': 'Google',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'wore',
#    'correction': 'were',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'some jobs',
#    'correction': 'Some jobs',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'some people',
#    'correction': 'Some people',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'a cheetah',
#    'correction': 'a cheetah runs',
#    'type': 'Word Choice',
#    'sentence': 12},
#   {'original': 'gateway communication',
#    'correction': 'gateway for communication',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'if',
#    'correction': 'If',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'photos with',
#    'correction': 'photos with,',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'of', 'correction': 'or', 'type': 'Spelling', 'sentence': 19},
#   {'original': 'please',
#    'correction': 'please,',
#    'type': 'Grammatical',
#    'sentence': 20}],
#  [{'original': 'benefitual',
#    'correction': 'beneficial',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'This because',
#    'correction': 'This is because',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'helps',
#    'correction': 'help',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'has',
#    'correction': 'have',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'you trying',
#    'correction': "you're trying",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': "a @CAPS2 without computers I wouldn't know what to do.",
#    'correction': "@CAPS2 without computers, I wouldn't know what to do.",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'has',
#    'correction': 'have',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'design',
#    'correction': 'designed',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'have with',
#    'correction': 'help with',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'the',
#    'correction': 'they',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'a essay',
#    'correction': 'an essay',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'tommorrow',
#    'correction': 'tomorrow',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'simple',
#    'correction': 'simply',
#    'type': 'Word Choice',
#    'sentence': 7},
#   {'original': 'Your',
#    'correction': "You'll",
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'saild',
#    'correction': 'solid',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'a wait',
#    'correction': 'await',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'replys',
#    'correction': 'replies',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'chating',
#    'correction': 'chatting',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'This where',
#    'correction': 'This is where',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'life',
#    'correction': 'live',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'the @CAPS5',
#    'correction': 'The @CAPS5',
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'This websites',
#    'correction': 'These websites',
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'base',
#    'correction': 'based',
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'charater',
#    'correction': 'character',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'chose',
#    'correction': 'choose',
#    'type': 'Word Choice',
#    'sentence': 21},
#   {'original': 'mother',
#    'correction': 'another',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'betters',
#    'correction': 'betters',
#    'type': 'Word Choice',
#    'sentence': 22},
#   {'original': 'ones',
#    'correction': "one's",
#    'type': 'Grammatical',
#    'sentence': 24},
#   {'original': 'succed',
#    'correction': 'succeed',
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'truely',
#    'correction': 'truly',
#    'type': 'Spelling',
#    'sentence': 26}],
#  [{'original': 'nain',
#    'correction': 'main',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'second',
#    'correction': 'seconds',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'phenominon',
#    'correction': 'phenomenon',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'wonder',
#    'correction': 'wonders',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'some', 'correction': 'so', 'type': 'Spelling', 'sentence': 4},
#   {'original': 'aproximately',
#    'correction': 'approximately',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'book',
#    'correction': 'books',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'way',
#    'correction': 'ways',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'cheif',
#    'correction': 'chief',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'explotion',
#    'correction': 'explosion',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'surviers',
#    'correction': "survivors'",
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'insted',
#    'correction': 'instead',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'eficentcy',
#    'correction': 'efficiency',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'iload',
#    'correction': 'load',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'centiped',
#    'correction': 'centipede',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'cenipeeds',
#    'correction': 'centipedes',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'thats',
#    'correction': "that's",
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'a least',
#    'correction': 'at least',
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'I would',
#    'correction': 'It would',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'she most likely',
#    'correction': 'she is most likely',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'computer',
#    'correction': 'computers',
#    'type': 'Grammatical',
#    'sentence': 20},
#   {'original': 'sudject',
#    'correction': 'subject',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'butterflys',
#    'correction': 'butterflies',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'wedsites',
#    'correction': 'websites',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'enviorment',
#    'correction': 'environment',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'eviorments',
#    'correction': 'environments',
#    'type': 'Spelling',
#    'sentence': 24}],
#  [{'original': 'there',
#    'correction': 'their',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'Encouragment',
#    'correction': 'Encouragement',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'you',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'our', 'correction': 'out', 'type': 'Spelling', 'sentence': 5},
#   {'original': 'Scheduleing',
#    'correction': 'Scheduling',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'The goverment',
#    'correction': 'The government',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'you',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'then',
#    'correction': 'Then',
#    'type': 'Grammatical',
#    'sentence': 20}],
#  [{'original': 'pragraphs',
#    'correction': 'paragraphs',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'what',
#    'correction': 'whom',
#    'type': 'Word Choice',
#    'sentence': 10},
#   {'original': 'ture',
#    'correction': 'true',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'I',
#    'correction': 'Many',
#    'type': 'Word Choice',
#    'sentence': 15},
#   {'original': 'wikipedia',
#    'correction': 'Wikipedia',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'any one',
#    'correction': 'anyone',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'reson',
#    'correction': 'reason',
#    'type': 'Spelling',
#    'sentence': 19},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'exsersize',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'comperters',
#    'correction': 'computers',
#    'type': 'Spelling',
#    'sentence': 27}],
#  [{'original': 'far', 'correction': 'for', 'type': 'Spelling', 'sentence': 1},
#   {'original': 'societey',
#    'correction': 'society',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'the',
#    'correction': 'they',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'eascier',
#    'correction': 'easier',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'peoples',
#    'correction': "people's",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'buenesness',
#    'correction': 'business',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': "dosn't",
#    'correction': "doesn't",
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'excirsize',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'knew',
#    'correction': 'know',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'have',
#    'correction': 'do',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'of',
#    'correction': 'aware',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'somthig',
#    'correction': 'something',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'peope',
#    'correction': 'people',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': "dosen't",
#    'correction': "doesn't",
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'excersize',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'scheol',
#    'correction': 'school',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'thert',
#    'correction': 'there',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'buerensness',
#    'correction': 'business',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'couse',
#    'correction': 'because',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'paren',
#    'correction': 'parent',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'Coumpouters',
#    'correction': 'Computers',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'becaus',
#    'correction': 'because',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'ex',
#    'correction': 'etc.',
#    'type': 'Word Choice',
#    'sentence': 10},
#   {'original': 'Coumpotors',
#    'correction': 'Computers',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'Coumputer',
#    'correction': 'Computer',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'las',
#    'correction': 'last',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'enternet',
#    'correction': 'internet',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'everthing',
#    'correction': 'everything',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'whatch',
#    'correction': 'watch',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'coiuld',
#    'correction': 'could',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'wont',
#    'correction': "won't",
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'an',
#    'correction': 'and',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'then',
#    'correction': 'them',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'I', 'correction': 'if', 'type': 'Grammatical', 'sentence': 15},
#   {'original': 'childre',
#    'correction': 'children',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'woud',
#    'correction': 'would',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'adulds',
#    'correction': 'adults',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'fun',
#    'correction': 'run',
#    'type': 'Word Choice',
#    'sentence': 15},
#   {'original': 'busnesses',
#    'correction': 'businesses',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'us',
#    'correction': 'without',
#    'type': 'Word Choice',
#    'sentence': 15},
#   {'original': 'theught',
#    'correction': 'thought',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'coumptors',
#    'correction': 'computers',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'fun',
#    'correction': 'run',
#    'type': 'Word Choice',
#    'sentence': 17},
#   {'original': 'withouoght',
#    'correction': 'without',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'coumputer',
#    'correction': 'computer',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'coumputr',
#    'correction': 'computer',
#    'type': 'Spelling',
#    'sentence': 17}],
#  [{'original': 'that those people that think',
#    'correction': 'that those people who think',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'it more, and interact',
#    'correction': 'it more and interact',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'Also, should enjoy life.',
#    'correction': 'Also, they should enjoy life.',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'read in detail, as to why',
#    'correction': 'read in detail why',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'exercise more, they need',
#    'correction': 'exercise more; they need',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'get off of computer.',
#    'correction': 'get off the computer.',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'gey away from it',
#    'correction': 'get away from it',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'the reasons I feel this why are',
#    'correction': 'the reasons I feel this way are',
#    'type': 'Grammatical',
#    'sentence': 18}],
#  [{'original': 'excirsising',
#    'correction': 'exercising',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'whats',
#    'correction': "what's",
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'truely',
#    'correction': 'truly',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'Polution',
#    'correction': 'Pollution',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'Their',
#    'correction': 'Therefore',
#    'type': 'Word Choice',
#    'sentence': 20},
#   {'original': 'excirsive',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'Consiquently',
#    'correction': 'Consequently',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'loosing',
#    'correction': 'losing',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'card',
#    'correction': 'and',
#    'type': 'Grammatical',
#    'sentence': 22},
#   {'original': 'you',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 25},
#   {'original': 'resonsibly',
#    'correction': 'responsibly',
#    'type': 'Spelling',
#    'sentence': 27},
#   {'original': 'english',
#    'correction': 'English',
#    'type': 'Grammatical',
#    'sentence': 28},
#   {'original': 'befor',
#    'correction': 'before',
#    'type': 'Spelling',
#    'sentence': 28},
#   {'original': 'reativeness',
#    'correction': 'creativeness',
#    'type': 'Spelling',
#    'sentence': 29},
#   {'original': 'definetley',
#    'correction': 'definitely',
#    'type': 'Spelling',
#    'sentence': 31},
#   {'original': 'effecting',
#    'correction': 'affecting',
#    'type': 'Word Choice',
#    'sentence': 31},
#   {'original': 'negetively',
#    'correction': 'negatively',
#    'type': 'Spelling',
#    'sentence': 31},
#   {'original': 'pay chedes',
#    'correction': 'paychecks',
#    'type': 'Spelling',
#    'sentence': 33},
#   {'original': 'fancey',
#    'correction': 'fancy',
#    'type': 'Spelling',
#    'sentence': 34},
# ...
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'ranning',
#    'correction': 'running',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'Just be easier',
#    'correction': 'It would be easier',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'sopping wet doing just you in a robe sipping hot choclate on the computer',
#    'correction': 'sopping wet, just you in a robe sipping hot chocolate on the computer',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': "yo udon't",
#    'correction': "you don't",
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'went to talk',
#    'correction': 'want to talk',
#    'type': 'Word Choice',
#    'sentence': 10},
#   {'original': 'what if something happened that you needed to know about you could just go on the internet and look it up',
#    'correction': 'what if something happened that you needed to know about? You could just go on the internet and look it up',
#    'type': 'Grammatical',
#    'sentence': 14}],
#  [{'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 4},
#   {'original': 'understant',
#    'correction': 'understand',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'Every intelligent citizen would @CAPS1 that computer @MONTH1 have wrong information.',
#    'correction': 'Every intelligent citizen would agree that computers sometimes have wrong information.',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'were',
#    'correction': 'where',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 28},
#   {'original': 'these',
#    'correction': 'there',
#    'type': 'Word Choice',
#    'sentence': 34},
#   {'original': 'excersizing',
#    'correction': 'exercising',
#    'type': 'Spelling',
#    'sentence': 37},
#   {'original': 'In addition just going outside can do more.',
#    'correction': 'In addition, just going outside can do more.',
#    'type': 'Grammatical',
#    'sentence': 38},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 42},
#   {'original': 'then',
#    'correction': 'than',
#    'type': 'Word Choice',
#    'sentence': 42},
#   {'original': 'fashion',
#    'correction': 'fashioned',
#    'type': 'Word Choice',
#    'sentence': 42}],
#  [{'original': '!!', 'correction': '!', 'type': 'Grammatical', 'sentence': 2},
#   {'original': "!, @CAPS1 I didn't where did you find out, on the computer.",
#    'correction': "@CAPS1, I didn't know. Where did you find out, on the computer?",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': "leave's",
#    'correction': 'leaves',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'thing',
#    'correction': 'things',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': "give's",
#    'correction': 'gives',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'thing',
#    'correction': 'things',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': "know'lleage",
#    'correction': 'knowledge',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': "strugle's",
#    'correction': 'struggles',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': "so thing's",
#    'correction': 'some things',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'Its',
#    'correction': 'It',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': "help's",
#    'correction': 'helps',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': "launage's",
#    'correction': 'languages',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'affect',
#    'correction': 'effect',
#    'type': 'Word Choice',
#    'sentence': 11},
#   {'original': "year's",
#    'correction': 'years',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': "live's",
#    'correction': 'lives',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'experts family',
#    'correction': "expert's family",
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': "love one's",
#    'correction': 'loved ones',
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': "sight's",
#    'correction': 'sights',
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': "food's",
#    'correction': 'foods',
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'shone',
#    'correction': 'shown',
#    'type': 'Spelling',
#    'sentence': 19},
#   {'original': 'neve sene',
#    'correction': 'never seen',
#    'type': 'Spelling',
#    'sentence': 19},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 22},
#   {'original': 'their',
#    'correction': "they're",
#    'type': 'Grammatical',
#    'sentence': 22},
#   {'original': 'compute',
#    'correction': 'computer',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'touch',
#    'correction': 'teach',
#    'type': 'Spelling',
#    'sentence': 23}],
#  [{'original': 'foucusing',
#    'correction': 'focusing',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'relized',
#    'correction': 'realized',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'teachers',
#    'correction': "teacher's",
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'commonicate',
#    'correction': 'communicate',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'knowhere',
#    'correction': 'nowhere',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'childeren',
#    'correction': 'children',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'reaserch',
#    'correction': 'research',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'availble',
#    'correction': 'available',
#    'type': 'Spelling',
#    'sentence': 18},
#   {'original': 'repertative',
#    'correction': 'repetitive',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'once and a while',
#    'correction': 'once in a while',
#    'type': 'Word Choice',
#    'sentence': 25}],
#  [{'original': 'Dear, Newspaper',
#    'correction': 'Dear Newspaper',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'computer',
#    'correction': 'computers',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'horrorable',
#    'correction': 'horrible',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'exercise enjoy',
#    'correction': 'exercise, enjoy',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'have good time',
#    'correction': 'have a good time',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'you body',
#    'correction': 'your body',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'stop the life span could be greatly shorten',
#    'correction': 'stop, the life span could be greatly shortened',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'shorten',
#    'correction': 'shortened',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'the being healthy',
#    'correction': 'than being healthy',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'out side',
#    'correction': 'outside',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'parensts',
#    'correction': 'parents',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'the being healthy',
#    'correction': 'than being healthy',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'out side',
#    'correction': 'outside',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'with',
#    'correction': 'will',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'vitimans',
#    'correction': 'vitamins',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'with',
#    'correction': 'will',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'some thing',
#    'correction': 'something',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'the my',
#    'correction': 'that my',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'me and her',
#    'correction': 'she and I',
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'you friends',
#    'correction': 'your friends',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'horrorable',
#    'correction': 'horrible',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'you life',
#    'correction': 'your life',
#    'type': 'Grammatical',
#    'sentence': 20},
#   {'original': 'you friends',
#    'correction': 'your friends',
#    'type': 'Grammatical',
#    'sentence': 20}],
#  [{'original': 'relie',
#    'correction': 'rely',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'noone',
#    'correction': 'no one',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': '@ORGANIZATION2',
#    'correction': 'Google',
#    'type': 'Word Choice',
#    'sentence': 6},
#   {'original': '@CAPS3',
#    'correction': 'know',
#    'type': 'Word Choice',
#    'sentence': 9},
#   {'original': 'reasearch',
#    'correction': 'research',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'relie',
#    'correction': 'rely',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'For example the @ORGANIZATION1 job.',
#    'correction': 'For example, the sanitation job.',
#    'type': 'Word Choice',
#    'sentence': 16},
#   {'original': "Let's not forget about what lawyers do?",
#    'correction': "Let's not forget about what lawyers do.",
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'incart',
#    'correction': 'in court',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'ever',
#    'correction': 'over',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'half the million',
#    'correction': 'half of the million',
#    'type': 'Grammatical',
#    'sentence': 22},
#   {'original': 'never seen',
#    'correction': 'never have seen',
#    'type': 'Grammatical',
#    'sentence': 25},
#   {'original': 'Strategy come',
#    'correction': 'Strategy comes',
#    'type': 'Grammatical',
#    'sentence': 30},
#   {'original': "It's now or never do you agree that computers have positive effects on people?",
#    'correction': "It's now or never; do you agree that computers have positive effects on people?",
#    'type': 'Grammatical',
#    'sentence': 33}],
#  [{'original': 'everyone',
#    'correction': 'Everyone',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'computers addictive',
#    'correction': 'computers are addictive',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'but',
#    'correction': 'But',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'but',
#    'correction': 'But',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'making',
#    'correction': 'make',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'addicting',
#    'correction': 'addictive',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'never ending',
#    'correction': 'never-ending',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'there',
#    'correction': 'their',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'learning of catching',
#    'correction': 'learning or catching',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'secod',
#    'correction': 'second',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'faraway',
#    'correction': 'far away',
#    'type': 'Word Choice',
#    'sentence': 9},
#   {'original': 'facebook',
#    'correction': 'Facebook',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'videochat',
#    'correction': 'video chat',
#    'type': 'Word Choice',
#    'sentence': 10},
#   {'original': 'microsoft word',
#    'correction': 'Microsoft Word',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'powerpoint',
#    'correction': 'PowerPoint',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'power points',
#    'correction': 'PowerPoints',
#    'type': 'Grammatical',
#    'sentence': 18}],
#  [{'original': 'use',
#    'correction': 'use,',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'computers, everyone',
#    'correction': 'computers; everyone',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'things what',
#    'correction': 'thing. What',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'say',
#    'correction': 'saying',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'I.ming',
#    'correction': 'I.M.',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'lets',
#    'correction': "let's",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'tree',
#    'correction': 'text',
#    'type': 'Word Choice',
#    'sentence': 6},
#   {'original': 'feild',
#    'correction': 'field',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'theres',
#    'correction': "there's",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'wen', 'correction': 'when', 'type': 'Spelling', 'sentence': 7},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'comunicate',
#    'correction': 'communicate',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'hi-tect',
#    'correction': 'high-tech',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'thousand',
#    'correction': 'thousands of',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': "aunt's lisa",
#    'correction': 'aunt Lisa',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'todays',
#    'correction': "today's",
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'ran',
#    'correction': 'run',
#    'type': 'Word Choice',
#    'sentence': 11},
#   {'original': 'each registers',
#    'correction': 'cash registers',
#    'type': 'Word Choice',
#    'sentence': 11},
#   {'original': 'car',
#    'correction': 'cars',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'Lets',
#    'correction': "Let's say",
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'tells',
#    'correction': 'boss tells',
#    'type': 'Word Choice',
#    'sentence': 15},
#   {'original': 'can do it the computer',
#    'correction': 'can do it on the computer',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 15},
#   {'original': 'dads',
#    'correction': "dad's",
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'of he',
#    'correction': 'so he',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'witch',
#    'correction': 'which',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'Do you are one?',
#    'correction': 'Do you have one?',
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'school was computers .',
#    'correction': 'school with computers.',
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'atendence',
#    'correction': 'attendance',
#    'type': 'Spelling',
#    'sentence': 19},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 22},
#   {'original': 'is',
#    'correction': 'there is',
#    'type': 'Grammatical',
#    'sentence': 23},
#   {'original': 'were',
#    'correction': 'where',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'call',
#    'correction': 'called',
#    'type': 'Grammatical',
#    'sentence': 24},
#   {'original': 'every one',
#    'correction': 'everyone',
#    'type': 'Spelling',
#    'sentence': 26},
#   {'original': 'are',
#    'correction': 'they are',
#    'type': 'Grammatical',
#    'sentence': 29},
#   {'original': 'know',
#    'correction': 'not know',
#    'type': 'Grammatical',
#    'sentence': 30},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 32}]]

# %%
# Function to sample 5 dictionaries from each inner list
def sample_five_from_each(inner_lists):
    return [random.sample(inner_list, min(len(inner_list), 5)) for inner_list in inner_lists]

# Sample 5 dictionaries from each inner list
sampled_corrections = sample_five_from_each(corrections)

#print(np.array(sampled_corrections).shape)

# Print the results
for idx, sampled_list in enumerate(sampled_corrections):
    print(f"Sampled data for list {idx + 1}:")
    for item in sampled_list:
        print(item)
    print()
# Out:
# Sampled data for list 1:
# {'original': 'it take', 'correction': 'it takes', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'affect', 'correction': 'effect', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'affect', 'correction': 'effect', 'type': 'Word Choice', 'sentence': 9}
# {'original': 'postitive', 'correction': 'positive', 'type': 'Spelling', 'sentence': 9}
# {'original': 'Computer', 'correction': 'Computers', 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 2:
# {'original': 'every on', 'correction': 'everyone', 'type': 'Spelling', 'sentence': 5}
# {'original': 'thinkin', 'correction': 'thinking', 'type': 'Spelling', 'sentence': 4}
# {'original': 'you @MONTH1 lose', 'correction': 'you might lose', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'act side', 'correction': 'activities outside', 'type': 'Word Choice', 'sentence': 5}
# {'original': 'there', 'correction': 'their', 'type': 'Word Choice', 'sentence': 1}
#
# Sampled data for list 3:
# {'original': 'You', 'correction': 'you', 'type': 'Grammatical', 'sentence': 16}
# {'original': 'Whether it', 'correction': "Whether it's", 'type': 'Grammatical', 'sentence': 10}
# {'original': 'into about', 'correction': 'into', 'type': 'Word Choice', 'sentence': 17}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 26}
# {'original': 'your', 'correction': 'their', 'type': 'Word Choice', 'sentence': 3}
#
# Sampled data for list 4:
# {'original': 'erson', 'correction': 'person', 'type': 'Spelling', 'sentence': 27}
# {'original': 'lisen', 'correction': 'listen', 'type': 'Spelling', 'sentence': 42}
# {'original': 'andd', 'correction': 'and', 'type': 'Spelling', 'sentence': 12}
# {'original': 'art', 'correction': 'out', 'type': 'Word Choice', 'sentence': 13}
# {'original': 'callories', 'correction': 'calories', 'type': 'Spelling', 'sentence': 35}
#
# Sampled data for list 5:
# {'original': 'that week of from the rest', 'correction': 'that he was off from the rest', 'type': 'Grammatical', 'sentence': 13}
# {'original': 'at the end of he school', 'correction': 'at the end of the school year', 'type': 'Grammatical', 'sentence': 12}
# {'original': 'the we got back the', 'correction': 'then we got back on', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'excersising', 'correction': 'exercising', 'type': 'Spelling', 'sentence': 4}
# {'original': 'excersise', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 5}
#
# Sampled data for list 6:
# {'original': 'for exsample', 'correction': 'For example', 'type': 'Spelling', 'sentence': 17}
# {'original': 'your', 'correction': "you're", 'type': 'Grammatical', 'sentence': 19}
# {'original': 'exsample', 'correction': 'example', 'type': 'Spelling', 'sentence': 9}
# {'original': 'lette', 'correction': 'letter', 'type': 'Spelling', 'sentence': 20}
# {'original': 'say you been', 'correction': "say you've been", 'type': 'Grammatical', 'sentence': 12}
#
# Sampled data for list 7:
# {'original': 'all these days', 'correction': 'all these things', 'type': 'Word Choice', 'sentence': 19}
# {'original': 'Its', 'correction': "It's", 'type': 'Grammatical', 'sentence': 8}
# {'original': 'when ever', 'correction': 'whenever', 'type': 'Spelling', 'sentence': 16}
# {'original': 'learn new places', 'correction': 'learn about new places', 'type': 'Word Choice', 'sentence': 18}
# {'original': 'I gives', 'correction': 'It gives', 'type': 'Grammatical', 'sentence': 12}
#
# Sampled data for list 8:
# {'original': 'reason', 'correction': 'reasons', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'hace', 'correction': 'have', 'type': 'Spelling', 'sentence': 6}
# {'original': 'Teachers immediately you have to talk', 'correction': 'Teachers immediately know you have to talk', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'van', 'correction': 'can', 'type': 'Spelling', 'sentence': 10}
# {'original': 'or', 'correction': 'of', 'type': 'Spelling', 'sentence': 16}
#
# Sampled data for list 9:
# {'original': 'ask', 'correction': 'Ask', 'type': 'Word Choice', 'sentence': 8}
# {'original': 'comunicate', 'correction': 'communicate', 'type': 'Spelling', 'sentence': 5}
# {'original': 'their', 'correction': "they're", 'type': 'Grammatical', 'sentence': 22}
# {'original': 'decition', 'correction': 'decision', 'type': 'Spelling', 'sentence': 25}
# {'original': 'their', 'correction': 'there', 'type': 'Grammatical', 'sentence': 13}
#
# Sampled data for list 10:
# {'original': 'tred mill', 'correction': 'treadmill', 'type': 'Spelling', 'sentence': 12}
# {'original': 'peoples', 'correction': "people's", 'type': 'Grammatical', 'sentence': 15}
# {'original': 'attack', 'correction': 'attach', 'type': 'Word Choice', 'sentence': 6}
# {'original': 'too', 'correction': 'to', 'type': 'Spelling', 'sentence': 3}
# {'original': 'attrack', 'correction': 'attract', 'type': 'Spelling', 'sentence': 24}
#
# Sampled data for list 11:
# {'original': 'This being you can from wikipedia all the way to the infamous google in just .', 'correction': 'This means you can go from Wikipedia all the way to the infamous Google in just seconds.', 'type': 'Grammatical', 'sentence': 14}
# {'original': '@CAPS4 thats one job exemple, another would be real state.', 'correction': "@CAPS4 that's one job example, another would be real estate.", 'type': 'Grammatical', 'sentence': 21}
# {'original': 'i think', 'correction': 'I think', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'you will get a the .', 'correction': 'you will get the information you need.', 'type': 'Grammatical', 'sentence': 16}
# {'original': 'computers I believe', 'correction': 'computers. I believe', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 12:
# {'original': 'benefitted', 'correction': 'benefited', 'type': 'Spelling', 'sentence': 29}
# {'original': 'garenteed', 'correction': 'guaranteed', 'type': 'Spelling', 'sentence': 20}
# {'original': 'commerical', 'correction': 'commercial', 'type': 'Spelling', 'sentence': 17}
# {'original': 'espically', 'correction': 'especially', 'type': 'Spelling', 'sentence': 20}
# {'original': 'coud', 'correction': 'could', 'type': 'Spelling', 'sentence': 7}
#
# Sampled data for list 13:
# {'original': 'mind browning', 'correction': 'mind-blowing', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'cant', 'correction': "can't", 'type': 'Grammatical', 'sentence': 21}
# {'original': 'world of war craft', 'correction': 'World of Warcraft', 'type': 'Spelling', 'sentence': 22}
# {'original': 'hoped you readers', 'correction': 'hope you readers enjoyed', 'type': 'Grammatical', 'sentence': 24}
# {'original': 'recer antal acitivitys', 'correction': 'recreational activities', 'type': 'Spelling', 'sentence': 4}
#
# Sampled data for list 14:
# {'original': 'parket', 'correction': 'packet', 'type': 'Spelling', 'sentence': 5}
# {'original': 'tribute', 'correction': 'contribute', 'type': 'Word Choice', 'sentence': 3}
# {'original': 'dont', 'correction': "don't", 'type': 'Grammatical', 'sentence': 4}
# {'original': 'gateway communication', 'correction': 'gateway for communication', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'a cheetah', 'correction': 'a cheetah runs', 'type': 'Word Choice', 'sentence': 12}
#
# Sampled data for list 15:
# {'original': 'charater', 'correction': 'character', 'type': 'Spelling', 'sentence': 21}
# {'original': 'saild', 'correction': 'solid', 'type': 'Spelling', 'sentence': 8}
# {'original': 'truely', 'correction': 'truly', 'type': 'Spelling', 'sentence': 26}
# {'original': 'design', 'correction': 'designed', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'This websites', 'correction': 'These websites', 'type': 'Grammatical', 'sentence': 18}
#
# Sampled data for list 16:
# {'original': 'enviorment', 'correction': 'environment', 'type': 'Spelling', 'sentence': 23}
# {'original': 'sudject', 'correction': 'subject', 'type': 'Spelling', 'sentence': 20}
# {'original': 'phenominon', 'correction': 'phenomenon', 'type': 'Spelling', 'sentence': 2}
# {'original': 'iload', 'correction': 'load', 'type': 'Spelling', 'sentence': 15}
# {'original': 'cheif', 'correction': 'chief', 'type': 'Spelling', 'sentence': 10}
#
# Sampled data for list 17:
# {'original': 'you', 'correction': 'your', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'The goverment', 'correction': 'The government', 'type': 'Spelling', 'sentence': 11}
# {'original': 'Scheduleing', 'correction': 'Scheduling', 'type': 'Spelling', 'sentence': 6}
# {'original': 'alot', 'correction': 'a lot', 'type': 'Spelling', 'sentence': 10}
# {'original': 'you', 'correction': 'your', 'type': 'Grammatical', 'sentence': 19}
#
# Sampled data for list 18:
# {'original': 'wikipedia', 'correction': 'Wikipedia', 'type': 'Grammatical', 'sentence': 16}
# {'original': 'alot', 'correction': 'a lot', 'type': 'Spelling', 'sentence': 22}
# {'original': 'what', 'correction': 'whom', 'type': 'Word Choice', 'sentence': 10}
# {'original': 'any one', 'correction': 'anyone', 'type': 'Spelling', 'sentence': 16}
# {'original': 'ture', 'correction': 'true', 'type': 'Spelling', 'sentence': 14}
#
# Sampled data for list 19:
# {'original': 'enternet', 'correction': 'internet', 'type': 'Spelling', 'sentence': 14}
# {'original': 'eascier', 'correction': 'easier', 'type': 'Spelling', 'sentence': 2}
# {'original': 'coumputr', 'correction': 'computer', 'type': 'Spelling', 'sentence': 17}
# {'original': 'adulds', 'correction': 'adults', 'type': 'Spelling', 'sentence': 15}
# {'original': 'somthig', 'correction': 'something', 'type': 'Spelling', 'sentence': 6}
#
# Sampled data for list 20:
# {'original': 'the reasons I feel this why are', 'correction': 'the reasons I feel this way are', 'type': 'Grammatical', 'sentence': 18}
# {'original': 'read in detail, as to why', 'correction': 'read in detail why', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'gey away from it', 'correction': 'get away from it', 'type': 'Spelling', 'sentence': 11}
# {'original': 'get off of computer.', 'correction': 'get off the computer.', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'that those people that think', 'correction': 'that those people who think', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 21:
# {'original': 'Consiquently', 'correction': 'Consequently', 'type': 'Spelling', 'sentence': 21}
# {'original': 'resonsibly', 'correction': 'responsibly', 'type': 'Spelling', 'sentence': 27}
# {'original': 'pay chedes', 'correction': 'paychecks', 'type': 'Spelling', 'sentence': 33}
# {'original': 'english', 'correction': 'English', 'type': 'Grammatical', 'sentence': 28}
# {'original': 'unuseful', 'correction': 'useless', 'type': 'Word Choice', 'sentence': 44}
#
# Sampled data for list 22:
# {'original': 'go gives', 'correction': 'get', 'type': 'Word Choice', 'sentence': 7}
# {'original': 'the the', 'correction': 'the', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'inform', 'correction': 'informs', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'beleive', 'correction': 'believe', 'type': 'Spelling', 'sentence': 4}
# {'original': 'because, I', 'correction': 'because I', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 23:
# {'original': 'eisier', 'correction': 'easier', 'type': 'Spelling', 'sentence': 5}
# {'original': 'game while not only are fun improve', 'correction': 'games, while not only fun, improve', 'type': 'Grammatical', 'sentence': 12}
# {'original': 'redundunt', 'correction': 'redundant', 'type': 'Spelling', 'sentence': 6}
# {'original': 'benifits', 'correction': 'benefits', 'type': 'Spelling', 'sentence': 25}
# {'original': 'exiting', 'correction': 'exciting', 'type': 'Spelling', 'sentence': 26}
#
# Sampled data for list 24:
# {'original': 'computer are', 'correction': 'computers are', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'Peple', 'correction': 'People', 'type': 'Spelling', 'sentence': 3}
# {'original': 'compter', 'correction': 'computer', 'type': 'Spelling', 'sentence': 6}
# {'original': 'daster', 'correction': 'faster', 'type': 'Spelling', 'sentence': 4}
# {'original': 'computer are', 'correction': 'computers are', 'type': 'Grammatical', 'sentence': 13}
#
# Sampled data for list 25:
# {'original': 'there', 'correction': 'their', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'whats', 'correction': "what's", 'type': 'Grammatical', 'sentence': 4}
# {'original': 'to', 'correction': 'too', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'there', 'correction': "they're", 'type': 'Grammatical', 'sentence': 6}
# {'original': 'moveing', 'correction': 'moving', 'type': 'Spelling', 'sentence': 3}
#
# Sampled data for list 26:
# {'original': 'other', 'correction': 'others', 'type': 'Grammatical', 'sentence': 18}
# {'original': 'most definately', 'correction': 'most definitely', 'type': 'Spelling', 'sentence': 32}
# {'original': 'extremely faster', 'correction': 'much faster', 'type': 'Word Choice', 'sentence': 19}
# {'original': "@CAPS3't", 'correction': "don't", 'type': 'Grammatical', 'sentence': 7}
# {'original': 'a computers', 'correction': 'a computer', 'type': 'Grammatical', 'sentence': 15}
#
# Sampled data for list 27:
# {'original': 'think', 'correction': 'thinking', 'type': 'Grammatical', 'sentence': 19}
# {'original': 'whats', 'correction': "what's", 'type': 'Grammatical', 'sentence': 13}
# {'original': 'then', 'correction': 'than', 'type': 'Word Choice', 'sentence': 3}
# {'original': 'gone', 'correction': 'game', 'type': 'Spelling', 'sentence': 17}
# {'original': "are't", 'correction': "aren't", 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 28:
# {'original': 'unnecissary', 'correction': 'unnecessary', 'type': 'Spelling', 'sentence': 4}
# {'original': 'infront', 'correction': 'in front', 'type': 'Grammatical', 'sentence': 19}
# {'original': 'arnt', 'correction': "aren't", 'type': 'Spelling', 'sentence': 2}
# {'original': 'perfessionals', 'correction': 'professionals', 'type': 'Spelling', 'sentence': 23}
# {'original': 'Whats', 'correction': "What's", 'type': 'Spelling', 'sentence': 15}
#
# Sampled data for list 29:
# {'original': 'Useing', 'correction': 'Using', 'type': 'Spelling', 'sentence': 2}
# {'original': 'you self', 'correction': 'yourself', 'type': 'Grammatical', 'sentence': 1}
# {'original': 're eyes', 'correction': 'their eyes', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 2}
# {'original': 'excersize', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 30:
# {'original': 'affect', 'correction': 'effect', 'type': 'Word Choice', 'sentence': 19}
# {'original': 'ar', 'correction': 'are', 'type': 'Spelling', 'sentence': 16}
# {'original': 'technicly', 'correction': 'technically', 'type': 'Spelling', 'sentence': 17}
# {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'posative', 'correction': 'positive', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 31:
# {'original': 'cant', 'correction': "can't", 'type': 'Grammatical', 'sentence': 18}
# {'original': 'the has', 'correction': 'the internet has', 'type': 'Word Choice', 'sentence': 24}
# {'original': 'foreigh', 'correction': 'foreign', 'type': 'Spelling', 'sentence': 4}
# {'original': 'those', 'correction': 'there', 'type': 'Word Choice', 'sentence': 14}
# {'original': 'wil', 'correction': 'will', 'type': 'Spelling', 'sentence': 16}
#
# Sampled data for list 32:
# {'original': 'abut', 'correction': 'about', 'type': 'Spelling', 'sentence': 11}
# {'original': 'saved', 'correction': 'save', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'A home computer', 'correction': 'Home computers', 'type': 'Grammatical', 'sentence': 21}
# {'original': 'price', 'correction': 'piece', 'type': 'Word Choice', 'sentence': 23}
# {'original': 'is', 'correction': 'are', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 33:
# {'original': 'tha', 'correction': 'the', 'type': 'Spelling', 'sentence': 5}
# {'original': 'was', 'correction': 'were', 'type': 'Grammatical', 'sentence': 15}
# {'original': 'rareley', 'correction': 'rarely', 'type': 'Spelling', 'sentence': 20}
# {'original': 'what your doing', 'correction': "what you're doing", 'type': 'Grammatical', 'sentence': 7}
# {'original': 'america', 'correction': 'America', 'type': 'Grammatical', 'sentence': 23}
#
# Sampled data for list 34:
# {'original': 'the baseball bats the pencils you we are all made by', 'correction': 'the baseball bats, the pencils we use are all made by', 'type': 'Grammatical', 'sentence': 15}
# {'original': 'everday', 'correction': 'everyday', 'type': 'Spelling', 'sentence': 24}
# {'original': 'one move step', 'correction': 'one more step', 'type': 'Spelling', 'sentence': 8}
# {'original': 'give people to learn', 'correction': 'give people the opportunity to learn', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'biult', 'correction': 'built', 'type': 'Spelling', 'sentence': 11}
#
# Sampled data for list 35:
# {'original': 'magazeens', 'correction': 'magazines', 'type': 'Spelling', 'sentence': 5}
# {'original': 'trulthfully', 'correction': 'truthfully', 'type': 'Spelling', 'sentence': 25}
# {'original': 'Insead', 'correction': 'Instead', 'type': 'Spelling', 'sentence': 16}
# {'original': 'imediatly', 'correction': 'immediately', 'type': 'Spelling', 'sentence': 5}
# {'original': 'increadable', 'correction': 'incredible', 'type': 'Spelling', 'sentence': 26}
#
# Sampled data for list 36:
# {'original': 'electrisity', 'correction': 'electricity', 'type': 'Spelling', 'sentence': 14}
# {'original': 'paly', 'correction': 'play', 'type': 'Spelling', 'sentence': 12}
# {'original': 'when you the computer', 'correction': 'when you use the computer', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'is', 'correction': 'spends', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'thier', 'correction': 'their', 'type': 'Spelling', 'sentence': 8}
#
# Sampled data for list 37:
# {'original': 'world wide web', 'correction': 'World Wide Web', 'type': 'Capitalization', 'sentence': 11}
# {'original': 'threw', 'correction': 'through', 'type': 'Spelling', 'sentence': 19}
# {'original': 'threw', 'correction': 'through', 'type': 'Spelling', 'sentence': 9}
# {'original': 'beacuse', 'correction': 'because', 'type': 'Spelling', 'sentence': 16}
# {'original': 'threw', 'correction': 'through', 'type': 'Spelling', 'sentence': 11}
#
# Sampled data for list 38:
# {'original': 'their, it', 'correction': 'them, and it', 'type': 'Grammatical', 'sentence': 20}
# {'original': 'it is using', 'correction': 'if using', 'type': 'Grammatical', 'sentence': 25}
# {'original': 'langages', 'correction': 'languages', 'type': 'Spelling', 'sentence': 23}
# {'original': 'dictionary', 'correction': 'dictionaries', 'type': 'Grammatical', 'sentence': 23}
# {'original': 'prounociation', 'correction': 'pronunciation', 'type': 'Spelling', 'sentence': 23}
#
# Sampled data for list 39:
# {'original': 'than', 'correction': 'then', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'learne any thing', 'correction': 'learn anything', 'type': 'Spelling', 'sentence': 14}
# {'original': 'now', 'correction': 'new', 'type': 'Spelling', 'sentence': 31}
# {'original': 'freen', 'correction': 'free', 'type': 'Spelling', 'sentence': 23}
# {'original': 'tele phones', 'correction': 'telephones', 'type': 'Spelling', 'sentence': 23}
#
# Sampled data for list 40:
# {'original': 'other student', 'correction': 'other students', 'type': 'Grammatical', 'sentence': 16}
# {'original': 'but all the time', 'correction': 'but not all the time', 'type': 'Grammatical', 'sentence': 20}
# {'original': 'Student', 'correction': 'Students', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'much more places', 'correction': 'many more places', 'type': 'Word Choice', 'sentence': 17}
# {'original': 'than', 'correction': 'while', 'type': 'Word Choice', 'sentence': 14}
#
# Sampled data for list 41:
# {'original': 'thing', 'correction': 'think', 'type': 'Spelling', 'sentence': 2}
# {'original': 'we to problem', 'correction': 'we come to the problem', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'making bad .', 'correction': 'making bad decisions.', 'type': 'Grammatical', 'sentence': 20}
# {'original': 'alot', 'correction': 'a lot', 'type': 'Spelling', 'sentence': 2}
# {'original': 'Plus while so much you will be prone to using in , thus you with, nothing but a bad grade.', 'correction': 'Plus, while using it so much, you will be prone to distractions, thus leaving you with nothing but a bad grade.', 'type': 'Grammatical', 'sentence': 13}
#
# Sampled data for list 42:
# {'original': 'your', 'correction': 'their', 'type': 'Word Choice', 'sentence': 13}
# {'original': 'reasonings', 'correction': 'reasons', 'type': 'Word Choice', 'sentence': 26}
# {'original': 'became', 'correction': 'become', 'type': 'Grammatical', 'sentence': 21}
# {'original': 'ruins', 'correction': 'ruin', 'type': 'Grammatical', 'sentence': 19}
# {'original': 'alot', 'correction': 'a lot', 'type': 'Spelling', 'sentence': 14}
#
# Sampled data for list 43:
# {'original': "computer's", 'correction': 'computers', 'type': 'Grammatical', 'sentence': 13}
# {'original': "Computer's", 'correction': 'Computers', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'excercize', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 5}
# {'original': 'effect', 'correction': 'affect', 'type': 'Word Choice', 'sentence': 5}
# {'original': 'to', 'correction': 'too', 'type': 'Grammatical', 'sentence': 7}
#
# Sampled data for list 44:
# {'original': 'a bad acession', 'correction': 'a bad recession', 'type': 'Spelling', 'sentence': 12}
# {'original': 'out dated', 'correction': 'outdated', 'type': 'Spelling', 'sentence': 17}
# {'original': 'their', 'correction': "they're", 'type': 'Grammatical', 'sentence': 29}
# {'original': 'definetly', 'correction': 'definitely', 'type': 'Spelling', 'sentence': 22}
# {'original': 'their', 'correction': "they're", 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 45:
# {'original': 'convienience', 'correction': 'convenience', 'type': 'Spelling', 'sentence': 22}
# {'original': 'helps', 'correction': 'help', 'type': 'Grammatical', 'sentence': 19}
# {'original': 'reason', 'correction': 'reasons', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'beleive', 'correction': 'believe', 'type': 'Spelling', 'sentence': 9}
# {'original': 'convienience', 'correction': 'convenience', 'type': 'Spelling', 'sentence': 3}
#
# Sampled data for list 46:
# {'original': 'health', 'correction': 'healthy', 'type': 'Word Choice', 'sentence': 14}
# {'original': 'the thev', 'correction': 'the', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'uses', 'correction': 'use', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'suceed', 'correction': 'succeed', 'type': 'Spelling', 'sentence': 1}
# {'original': 'leperdy', 'correction': 'Jeopardy', 'type': 'Spelling', 'sentence': 7}
#
# Sampled data for list 47:
# {'original': 'okey', 'correction': 'day', 'type': 'Word Choice', 'sentence': 24}
# {'original': 'any thing', 'correction': 'anything', 'type': 'Spelling', 'sentence': 26}
# {'original': 'word', 'correction': 'worn', 'type': 'Spelling', 'sentence': 14}
# {'original': 'saftey', 'correction': 'safety', 'type': 'Spelling', 'sentence': 24}
# {'original': 'over weight', 'correction': 'overweight', 'type': 'Spelling', 'sentence': 11}
#
# Sampled data for list 48:
# {'original': 'dishies', 'correction': 'dishes', 'type': 'Spelling', 'sentence': 18}
# {'original': 'breathe', 'correction': 'breath', 'type': 'Word Choice', 'sentence': 23}
# {'original': 'Your', 'correction': "You're", 'type': 'Grammatical', 'sentence': 27}
# {'original': 'cant', 'correction': "can't", 'type': 'Grammatical', 'sentence': 4}
# {'original': 'than', 'correction': 'then', 'type': 'Word Choice', 'sentence': 13}
#
# Sampled data for list 49:
# {'original': 'in a office', 'correction': 'in an office', 'type': 'Grammatical', 'sentence': 8}
# {'original': 'their', 'correction': 'its', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'throught', 'correction': 'through', 'type': 'Spelling', 'sentence': 2}
# {'original': 'menning', 'correction': 'meaning', 'type': 'Spelling', 'sentence': 3}
# {'original': 'happend', 'correction': 'happened', 'type': 'Spelling', 'sentence': 9}
#
# Sampled data for list 50:
# {'original': '@PERCENT1', 'correction': 'percent', 'type': 'Other', 'sentence': 5}
# {'original': 'that kids like playing games on them', 'correction': 'that kids like to play games on them', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'calculated', 'correction': 'calculator', 'type': 'Word Choice', 'sentence': 8}
# {'original': 'to do work', 'correction': 'doing work', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'easier they', 'correction': 'easier; they', 'type': 'Grammatical', 'sentence': 2}
#
# Sampled data for list 51:
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 2}
# {'original': 'This a letter', 'correction': 'This is a letter', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'Its', 'correction': "It's", 'type': 'Grammatical', 'sentence': 17}
# {'original': 'secreaterys', 'correction': 'secretaries', 'type': 'Spelling', 'sentence': 8}
# {'original': 'Im', 'correction': "I'm", 'type': 'Grammatical', 'sentence': 5}
#
# Sampled data for list 52:
# {'original': 'haveing', 'correction': 'having', 'type': 'Spelling', 'sentence': 1}
# {'original': 'depresion', 'correction': 'depression', 'type': 'Spelling', 'sentence': 13}
# {'original': 'enternet', 'correction': 'internet', 'type': 'Spelling', 'sentence': 1}
# {'original': 'humerous', 'correction': 'humorous', 'type': 'Spelling', 'sentence': 7}
# {'original': 'bought', 'correction': 'brought', 'type': 'Word Choice', 'sentence': 2}
#
# Sampled data for list 53:
# {'original': 'noreveting', 'correction': 'not investing', 'type': 'Spelling', 'sentence': 4}
# {'original': 'affenders', 'correction': 'offenders', 'type': 'Spelling', 'sentence': 12}
# {'original': 'leanring', 'correction': 'learning', 'type': 'Spelling', 'sentence': 16}
# {'original': 'chating', 'correction': 'chatting', 'type': 'Spelling', 'sentence': 11}
# {'original': 'controll', 'correction': 'control', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 54:
# {'original': 'wait', 'correction': 'weight', 'type': 'Spelling', 'sentence': 11}
# {'original': 'there', 'correction': 'their', 'type': 'Word Choice', 'sentence': 19}
# {'original': 'talking', 'correction': 'taking', 'type': 'Spelling', 'sentence': 14}
# {'original': 'leeds', 'correction': 'leads', 'type': 'Spelling', 'sentence': 8}
# {'original': 'feelings', 'correction': 'feeling', 'type': 'Grammatical', 'sentence': 8}
#
# Sampled data for list 55:
# {'original': 'sized', 'correction': 'sizes', 'type': 'Spelling', 'sentence': 34}
# {'original': 'These day', 'correction': 'These days', 'type': 'Grammatical', 'sentence': 17}
# {'original': 'with a soccerball', 'correction': 'with a soccer ball', 'type': 'Spelling', 'sentence': 21}
# {'original': 'dont', 'correction': "don't", 'type': 'Spelling', 'sentence': 25}
# {'original': 'Lets', 'correction': "Let's", 'type': 'Grammatical', 'sentence': 13}
#
# Sampled data for list 56:
# {'original': 'spent', 'correction': 'spend', 'type': 'Grammatical', 'sentence': 2}
# {'original': "they don't get they don't walk", 'correction': "they don't get to walk", 'type': 'Grammatical', 'sentence': 2}
# {'original': 'm', 'correction': 'My', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'A on their heart', 'correction': 'a strain on their heart', 'type': 'Word Choice', 'sentence': 4}
# {'original': "could you can't do", 'correction': "that you can't do", 'type': 'Grammatical', 'sentence': 5}
#
# Sampled data for list 57:
# {'original': 'reconected', 'correction': 'reconnected', 'type': 'Spelling', 'sentence': 24}
# {'original': 'deffidently', 'correction': 'definitely', 'type': 'Spelling', 'sentence': 4}
# {'original': 'personal', 'correction': 'personally', 'type': 'Spelling', 'sentence': 17}
# {'original': 'elses lifes', 'correction': "else's lives", 'type': 'Grammatical', 'sentence': 4}
# {'original': 'you', 'correction': 'your', 'type': 'Grammatical', 'sentence': 27}
#
# Sampled data for list 58:
# {'original': 'evebady', 'correction': 'everybody', 'type': 'Spelling', 'sentence': 3}
# {'original': 'far a long time', 'correction': 'for a long time', 'type': 'Spelling', 'sentence': 6}
# {'original': 'takeing', 'correction': 'talking', 'type': 'Spelling', 'sentence': 6}
# {'original': 'Now what will you why you that side', 'correction': 'Now what will you do with that knowledge?', 'type': 'Word Choice', 'sentence': 9}
# {'original': 'becau', 'correction': 'because', 'type': 'Spelling', 'sentence': 1}
#
# Sampled data for list 59:
# {'original': 'france', 'correction': 'France', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'africa', 'correction': 'Africa', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'jest', 'correction': 'just', 'type': 'Spelling', 'sentence': 9}
# {'original': 'affect', 'correction': 'effect', 'type': 'Word Choice', 'sentence': 2}
# {'original': 'benifit', 'correction': 'benefit from', 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 60:
# {'original': 'cause', 'correction': 'causes', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'Its', 'correction': "It's", 'type': 'Grammatical', 'sentence': 11}
# {'original': 'slopy', 'correction': 'sloppy', 'type': 'Spelling', 'sentence': 8}
# {'original': 'friend', 'correction': 'friends', 'type': 'Grammatical', 'sentence': 11}
# {'original': "of cell's", 'correction': 'of cells', 'type': 'Grammatical', 'sentence': 8}
#
# Sampled data for list 61:
# {'original': 'a great of knowledge', 'correction': 'a great source of knowledge', 'type': 'Word Choice', 'sentence': 7}
# {'original': 'there', 'correction': 'their', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'So you eyes are beter their seeing nothing.', 'correction': "So your eyes are better; they're seeing nothing.", 'type': 'Grammatical', 'sentence': 5}
# {'original': 'fastes', 'correction': 'fastest', 'type': 'Spelling', 'sentence': 8}
# {'original': 'Dear, Local @ORGANIZATION1 paper', 'correction': 'Dear Local @ORGANIZATION1 paper', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 62:
# {'original': 'word', 'correction': 'Word', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'shourt', 'correction': 'short', 'type': 'Spelling', 'sentence': 13}
# {'original': 'Lets', 'correction': "Let's", 'type': 'Grammatical', 'sentence': 17}
# {'original': 'skype', 'correction': 'Skype', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'Antoher', 'correction': 'Another', 'type': 'Spelling', 'sentence': 20}
#
# Sampled data for list 63:
# {'original': 'Latly', 'correction': 'Lately', 'type': 'Spelling', 'sentence': 25}
# {'original': 'When he not on during they day', 'correction': "When he's not on during the day", 'type': 'Grammatical', 'sentence': 34}
# {'original': 'a at home mother', 'correction': 'an at-home mother', 'type': 'Grammatical', 'sentence': 33}
# {'original': 'bannas', 'correction': 'bananas', 'type': 'Spelling', 'sentence': 24}
# {'original': 'Te', 'correction': 'The', 'type': 'Spelling', 'sentence': 22}
#
# Sampled data for list 64:
# {'original': 'jus', 'correction': 'just', 'type': 'Spelling', 'sentence': 19}
# {'original': 'intellegent', 'correction': 'intelligent', 'type': 'Spelling', 'sentence': 9}
# {'original': "aren'@CAPS2", 'correction': "aren't", 'type': 'Spelling', 'sentence': 25}
# {'original': 'person', 'correction': 'people', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'Which how', 'correction': 'This is how', 'type': 'Grammatical', 'sentence': 8}
#
# Sampled data for list 65:
# {'original': 'vidieo', 'correction': 'video', 'type': 'Spelling', 'sentence': 16}
# {'original': 'thay', 'correction': 'they', 'type': 'Spelling', 'sentence': 7}
# {'original': 'scientist', 'correction': 'scientists', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'tramendisly', 'correction': 'tremendously', 'type': 'Spelling', 'sentence': 1}
# {'original': 'on a button,, Who', 'correction': 'on a button. Who', 'type': 'Grammatical', 'sentence': 21}
#
# Sampled data for list 66:
# {'original': 'does benifit', 'correction': 'do benefit', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 7}
# {'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 6}
# {'original': 'they are', 'correction': 'and they are', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 8}
#
# Sampled data for list 67:
# {'original': 'facebook', 'correction': 'Facebook', 'type': 'Grammatical', 'sentence': 23}
# {'original': 'boredom', 'correction': 'boredom', 'type': 'Spelling', 'sentence': 20}
# {'original': 'everyday', 'correction': 'every day', 'type': 'Word Choice', 'sentence': 3}
# {'original': 'affects', 'correction': 'effects', 'type': 'Word Choice', 'sentence': 3}
# {'original': 'Everyday', 'correction': 'Every day', 'type': 'Word Choice', 'sentence': 11}
#
# Sampled data for list 68:
# {'original': "Sure people don't get to enjoy the campus,", 'correction': "Sure, people don't get to enjoy the campus,", 'type': 'Grammatical', 'sentence': 18}
# {'original': 'myspace', 'correction': 'MySpace', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'Remember computers are easy to use,', 'correction': 'Remember, computers are easy to use,', 'type': 'Grammatical', 'sentence': 20}
# {'original': "that is only if you start talking to people you don't know.", 'correction': "but that is only if you start talking to people you don't know.", 'type': 'Grammatical', 'sentence': 12}
# {'original': 'Computers are amazing advancement', 'correction': 'Computers are an amazing advancement', 'type': 'Grammatical', 'sentence': 3}
#
# Sampled data for list 69:
# {'original': 'far which', 'correction': 'for a walk', 'type': 'Word Choice', 'sentence': 19}
# {'original': 'some thing', 'correction': 'something', 'type': 'Spelling', 'sentence': 11}
# {'original': 'talk', 'correction': 'talking', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'you.', 'correction': 'you.', 'type': 'Other', 'sentence': 13}
# {'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 3}
#
# Sampled data for list 70:
# {'original': 'Agains', 'correction': 'Against', 'type': 'Spelling', 'sentence': 23}
# {'original': "wasn't going to sell more computer", 'correction': "weren't going to sell more computers", 'type': 'Grammatical', 'sentence': 4}
# {'original': 'grate', 'correction': 'great', 'type': 'Spelling', 'sentence': 10}
# {'original': 'how much often', 'correction': 'how often', 'type': 'Grammatical', 'sentence': 16}
# {'original': 'them', 'correction': 'him', 'type': 'Word Choice', 'sentence': 15}
#
# Sampled data for list 71:
# {'original': 'is used', 'correction': 'are used', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'intead', 'correction': 'instead', 'type': 'Spelling', 'sentence': 13}
# {'original': 'and effect', 'correction': 'an effect', 'type': 'Grammatical', 'sentence': 15}
# {'original': 'negitive', 'correction': 'negative', 'type': 'Spelling', 'sentence': 21}
# {'original': 'a play', 'correction': 'and play', 'type': 'Grammatical', 'sentence': 19}
#
# Sampled data for list 72:
# {'original': 'excersize', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 20}
# {'original': 'excersize', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 18}
# {'original': 'reutine', 'correction': 'routine', 'type': 'Spelling', 'sentence': 9}
# {'original': 'instratford', 'correction': 'in Stratford', 'type': 'Grammatical', 'sentence': 21}
# {'original': 'laye', 'correction': 'late', 'type': 'Spelling', 'sentence': 13}
#
# Sampled data for list 73:
# {'original': 'infact', 'correction': 'in fact', 'type': 'Spelling', 'sentence': 15}
# {'original': 'beliver', 'correction': 'believer', 'type': 'Spelling', 'sentence': 4}
# {'original': 'relitives', 'correction': 'relatives', 'type': 'Spelling', 'sentence': 18}
# {'original': 'globaly', 'correction': 'globally', 'type': 'Spelling', 'sentence': 17}
# {'original': 'ourlives', 'correction': 'our lives', 'type': 'Spelling', 'sentence': 16}
#
# Sampled data for list 74:
# {'original': 'pletvera', 'correction': 'plethora', 'type': 'Spelling', 'sentence': 24}
# {'original': 'cerrect', 'correction': 'correct', 'type': 'Spelling', 'sentence': 39}
# {'original': 'their', 'correction': 'his or her', 'type': 'Grammatical', 'sentence': 15}
# {'original': 'Futhermore', 'correction': 'Furthermore', 'type': 'Spelling', 'sentence': 8}
# {'original': 'on average', 'correction': 'On average', 'type': 'Grammatical', 'sentence': 38}
#
# Sampled data for list 75:
# {'original': 'yu', 'correction': 'you', 'type': 'Spelling', 'sentence': 27}
# {'original': 'imprdove', 'correction': 'improve', 'type': 'Spelling', 'sentence': 38}
# {'original': 'the society', 'correction': 'society', 'type': 'Grammatical', 'sentence': 39}
# {'original': 'suggest', 'correction': 'suggests', 'type': 'Grammatical', 'sentence': 28}
# {'original': 'more of people', 'correction': 'more aware of people', 'type': 'Word Choice', 'sentence': 16}
#
# Sampled data for list 76:
# {'original': 'all there, could', 'correction': 'all this could', 'type': 'Grammatical', 'sentence': 18}
# {'original': 'the', 'correction': 'them', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'can bad', 'correction': 'can be bad', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'at a the eyes', 'correction': 'for the eyes', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'became', 'correction': 'becomes', 'type': 'Grammatical', 'sentence': 3}
#
# Sampled data for list 77:
# {'original': 'apetite', 'correction': 'appetite', 'type': 'Spelling', 'sentence': 19}
# {'original': 'The electricity that runs computers of this radiation.', 'correction': 'The electricity that runs computers emits radiation.', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'excersise', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 23}
# {'original': 'The computers are children from a better education.', 'correction': 'The computers are preventing children from a better education.', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'moved and of were more succesful in school.', 'correction': 'moved and were more successful in school.', 'type': 'Grammatical', 'sentence': 10}
#
# Sampled data for list 78:
# {'original': 'use', 'correction': 'used', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'lets', 'correction': 'let', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'Its', 'correction': "It's", 'type': 'Grammatical', 'sentence': 10}
# {'original': 'Has', 'correction': 'It has', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'useing', 'correction': 'using', 'type': 'Spelling', 'sentence': 12}
#
# Sampled data for list 79:
# {'original': 'maintaing', 'correction': 'maintaining', 'type': 'Spelling', 'sentence': 16}
# {'original': 'goto', 'correction': 'go to', 'type': 'Spelling', 'sentence': 20}
# {'original': 'their', 'correction': 'there', 'type': 'Grammatical', 'sentence': 19}
# {'original': 'leaguges', 'correction': 'leagues', 'type': 'Spelling', 'sentence': 25}
# {'original': 'your', 'correction': "you're", 'type': 'Grammatical', 'sentence': 10}
#
# Sampled data for list 80:
# {'original': 'it less your hand', 'correction': 'it lessens the strain on your hand', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'find everyone', 'correction': 'find everything', 'type': 'Word Choice', 'sentence': 15}
# {'original': 'heerd', 'correction': 'heard', 'type': 'Spelling', 'sentence': 1}
# {'original': 'benef it', 'correction': 'benefit', 'type': 'Spelling', 'sentence': 2}
# {'original': 'dispute', 'correction': 'despite', 'type': 'Word Choice', 'sentence': 1}
#
# Sampled data for list 81:
# {'original': 'probley', 'correction': 'probably', 'type': 'Spelling', 'sentence': 5}
# {'original': "opinion's", 'correction': 'opinions', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'wont', 'correction': "won't", 'type': 'Grammatical', 'sentence': 12}
# {'original': 'looking on', 'correction': 'looking at', 'type': 'Word Choice', 'sentence': 1}
# {'original': 'rather then', 'correction': 'rather than', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 82:
# {'original': '@CAPS1', 'correction': 'Twitter', 'type': 'Word Choice', 'sentence': 6}
# {'original': 'facebook', 'correction': 'Facebook', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'a positive effects of', 'correction': 'positive effects on', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'great you can,', 'correction': 'great because you can', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'peoples', 'correction': "people's", 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 83:
# {'original': 'so that he can be prepared', 'correction': 'so that he could be prepared', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'is that is helps', 'correction': 'is that it helps', 'type': 'Grammatical', 'sentence': 22}
# {'original': 'it helps them with', 'correction': 'they help them with', 'type': 'Grammatical', 'sentence': 1}
# {'original': 'helps us learn', 'correction': 'help us learn', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'it helps them learn', 'correction': 'they help them learn', 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 84:
# {'original': 'Now that are new technology', 'correction': 'Now that there is new technology', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'exerce', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 28}
# {'original': 'tecnology', 'correction': 'technology', 'type': 'Spelling', 'sentence': 2}
# {'original': 'effecting', 'correction': 'affecting', 'type': 'Word Choice', 'sentence': 4}
# {'original': 'relie', 'correction': 'rely', 'type': 'Spelling', 'sentence': 18}
#
# Sampled data for list 85:
# {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'thats', 'correction': "that's", 'type': 'Grammatical', 'sentence': 8}
# {'original': 'dont', 'correction': "don't", 'type': 'Grammatical', 'sentence': 5}
# {'original': 'exsesise', 'correction': 'exercise', 'type': 'Spelling', 'sentence': 2}
# {'original': 'could', 'correction': 'can', 'type': 'Word Choice', 'sentence': 4}
#
# Sampled data for list 86:
# {'original': 'mose', 'correction': 'mouse', 'type': 'Spelling', 'sentence': 3}
# {'original': 'reson', 'correction': 'reason', 'type': 'Spelling', 'sentence': 3}
# {'original': 'jod', 'correction': 'job', 'type': 'Spelling', 'sentence': 3}
# {'original': 'resifes', 'correction': 'recipes', 'type': 'Spelling', 'sentence': 3}
# {'original': 'grand mom', 'correction': 'grandmom', 'type': 'Spelling', 'sentence': 2}
#
# Sampled data for list 87:
# {'original': "it's different", 'correction': "they're different", 'type': 'Grammatical', 'sentence': 9}
# {'original': 'their alike', 'correction': "they're alike", 'type': 'Grammatical', 'sentence': 9}
# {'original': 'typer', 'correction': 'typist', 'type': 'Word Choice', 'sentence': 7}
# {'original': 'you typeing', 'correction': 'your typing', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'their doing', 'correction': "they're doing", 'type': 'Grammatical', 'sentence': 13}
#
# Sampled data for list 88:
# {'original': 'the in jobs, and in to days @CAPS1 the for that gets In the quarter mile must be able to find his and on in an office you have to watch as typing', 'correction': "them in jobs, and in today's world, the person that gets the job must be able to find his way around an office and watch as they type", 'type': 'Grammatical', 'sentence': 6}
# {'original': 'were', 'correction': 'since', 'type': 'Word Choice', 'sentence': 12}
# {'original': 'a positive reason', 'correction': 'positive reasons', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'allows', 'correction': 'allow', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'what better to start than now', 'correction': 'what better time to start than now', 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 89:
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 8}
# {'original': 'plant', 'correction': 'plants', 'type': 'Grammatical', 'sentence': 7}
# {'original': 'arent', 'correction': "aren't", 'type': 'Grammatical', 'sentence': 17}
# {'original': 'and', 'correction': 'history', 'type': 'Word Choice', 'sentence': 15}
# {'original': 'Think about!', 'correction': 'Think about it!', 'type': 'Grammatical', 'sentence': 18}
#
# Sampled data for list 90:
# {'original': 'get to out location', 'correction': 'get to our location', 'type': 'Spelling', 'sentence': 8}
# {'original': 'diffrent', 'correction': 'different', 'type': 'Spelling', 'sentence': 13}
# {'original': 'location were', 'correction': 'location where', 'type': 'Grammatical', 'sentence': 5}
# {'original': 'the years computers', 'correction': 'the years, computers have', 'type': 'Grammatical', 'sentence': 17}
# {'original': 'cant', 'correction': "can't", 'type': 'Grammatical', 'sentence': 10}
#
# Sampled data for list 91:
# {'original': 'helps', 'correction': 'help', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'doing lazy then go', 'correction': 'being lazy, then go', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'Getting more active @MONTH1 even bring', 'correction': 'Getting more active can even bring', 'type': 'Grammatical', 'sentence': 7}
# {'original': "your'e", 'correction': "you're", 'type': 'Spelling', 'sentence': 2}
# {'original': 'bad effects on peoples lives', 'correction': "bad effects on people's lives", 'type': 'Grammatical', 'sentence': 1}
#
# Sampled data for list 92:
# {'original': 'what if something happened that you needed to know about you could just go on the internet and look it up', 'correction': 'what if something happened that you needed to know about? You could just go on the internet and look it up', 'type': 'Grammatical', 'sentence': 14}
# {'original': 'your phones not', 'correction': "your phone's not", 'type': 'Grammatical', 'sentence': 3}
# {'original': 'pixecl', 'correction': 'pixelated', 'type': 'Spelling', 'sentence': 4}
# {'original': 'alot', 'correction': 'a lot', 'type': 'Spelling', 'sentence': 5}
# {'original': 'went to talk', 'correction': 'want to talk', 'type': 'Word Choice', 'sentence': 10}
#
# Sampled data for list 93:
# {'original': 'excersizing', 'correction': 'exercising', 'type': 'Spelling', 'sentence': 37}
# {'original': 'Every intelligent citizen would @CAPS1 that computer @MONTH1 have wrong information.', 'correction': 'Every intelligent citizen would agree that computers sometimes have wrong information.', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'In addition just going outside can do more.', 'correction': 'In addition, just going outside can do more.', 'type': 'Grammatical', 'sentence': 38}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 28}
# {'original': 'fashion', 'correction': 'fashioned', 'type': 'Word Choice', 'sentence': 42}
#
# Sampled data for list 94:
# {'original': 'shone', 'correction': 'shown', 'type': 'Spelling', 'sentence': 19}
# {'original': 'dont', 'correction': "don't", 'type': 'Grammatical', 'sentence': 5}
# {'original': 'Its', 'correction': 'It', 'type': 'Grammatical', 'sentence': 10}
# {'original': "give's", 'correction': 'gives', 'type': 'Grammatical', 'sentence': 6}
# {'original': 'their', 'correction': "they're", 'type': 'Grammatical', 'sentence': 22}
#
# Sampled data for list 95:
# {'original': 'relized', 'correction': 'realized', 'type': 'Spelling', 'sentence': 5}
# {'original': 'reaserch', 'correction': 'research', 'type': 'Spelling', 'sentence': 17}
# {'original': 'knowhere', 'correction': 'nowhere', 'type': 'Spelling', 'sentence': 14}
# {'original': 'repertative', 'correction': 'repetitive', 'type': 'Spelling', 'sentence': 21}
# {'original': 'availble', 'correction': 'available', 'type': 'Spelling', 'sentence': 18}
#
# Sampled data for list 96:
# {'original': 'have good time', 'correction': 'have a good time', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'you friends', 'correction': 'your friends', 'type': 'Grammatical', 'sentence': 20}
# {'original': 'with', 'correction': 'will', 'type': 'Grammatical', 'sentence': 11}
# {'original': 'with', 'correction': 'will', 'type': 'Grammatical', 'sentence': 10}
# {'original': 'me and her', 'correction': 'she and I', 'type': 'Grammatical', 'sentence': 18}
#
# Sampled data for list 97:
# {'original': 'never seen', 'correction': 'never have seen', 'type': 'Grammatical', 'sentence': 25}
# {'original': 'ever', 'correction': 'over', 'type': 'Spelling', 'sentence': 22}
# {'original': 'relie', 'correction': 'rely', 'type': 'Spelling', 'sentence': 2}
# {'original': '@CAPS3', 'correction': 'know', 'type': 'Word Choice', 'sentence': 9}
# {'original': "Let's not forget about what lawyers do?", 'correction': "Let's not forget about what lawyers do.", 'type': 'Grammatical', 'sentence': 19}
#
# Sampled data for list 98:
# {'original': 'there', 'correction': 'their', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'everyone', 'correction': 'Everyone', 'type': 'Grammatical', 'sentence': 2}
# {'original': 'its', 'correction': "it's", 'type': 'Grammatical', 'sentence': 4}
# {'original': 'making', 'correction': 'make', 'type': 'Grammatical', 'sentence': 4}
# {'original': 'but', 'correction': 'But', 'type': 'Grammatical', 'sentence': 4}
#
# Sampled data for list 99:
# {'original': 'faraway', 'correction': 'far away', 'type': 'Word Choice', 'sentence': 9}
# {'original': 'powerpoint', 'correction': 'PowerPoint', 'type': 'Grammatical', 'sentence': 13}
# {'original': 'videochat', 'correction': 'video chat', 'type': 'Word Choice', 'sentence': 10}
# {'original': 'learning of catching', 'correction': 'learning or catching', 'type': 'Grammatical', 'sentence': 3}
# {'original': 'microsoft word', 'correction': 'Microsoft Word', 'type': 'Grammatical', 'sentence': 12}
#
# Sampled data for list 100:
# {'original': 'use', 'correction': 'use,', 'type': 'Grammatical', 'sentence': 1}
# {'original': "aunt's lisa", 'correction': 'aunt Lisa', 'type': 'Grammatical', 'sentence': 9}
# {'original': 'alot', 'correction': 'a lot', 'type': 'Spelling', 'sentence': 32}
# {'original': 'is', 'correction': 'there is', 'type': 'Grammatical', 'sentence': 23}
# {'original': 'dads', 'correction': "dad's", 'type': 'Grammatical', 'sentence': 15}

# %%
sampled_corrections
# Out:
# [[{'original': 'it take',
#    'correction': 'it takes',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'affect',
#    'correction': 'effect',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'affect',
#    'correction': 'effect',
#    'type': 'Word Choice',
#    'sentence': 9},
#   {'original': 'postitive',
#    'correction': 'positive',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'Computer',
#    'correction': 'Computers',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'every on',
#    'correction': 'everyone',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'thinkin',
#    'correction': 'thinking',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'you @MONTH1 lose',
#    'correction': 'you might lose',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'act side',
#    'correction': 'activities outside',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'there',
#    'correction': 'their',
#    'type': 'Word Choice',
#    'sentence': 1}],
#  [{'original': 'You',
#    'correction': 'you',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'Whether it',
#    'correction': "Whether it's",
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'into about',
#    'correction': 'into',
#    'type': 'Word Choice',
#    'sentence': 17},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 26},
#   {'original': 'your',
#    'correction': 'their',
#    'type': 'Word Choice',
#    'sentence': 3}],
#  [{'original': 'erson',
#    'correction': 'person',
#    'type': 'Spelling',
#    'sentence': 27},
#   {'original': 'lisen',
#    'correction': 'listen',
#    'type': 'Spelling',
#    'sentence': 42},
#   {'original': 'andd',
#    'correction': 'and',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'art',
#    'correction': 'out',
#    'type': 'Word Choice',
#    'sentence': 13},
#   {'original': 'callories',
#    'correction': 'calories',
#    'type': 'Spelling',
#    'sentence': 35}],
#  [{'original': 'that week of from the rest',
#    'correction': 'that he was off from the rest',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'at the end of he school',
#    'correction': 'at the end of the school year',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'the we got back the',
#    'correction': 'then we got back on',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'excersising',
#    'correction': 'exercising',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'excersise',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 5}],
#  [{'original': 'for exsample',
#    'correction': 'For example',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'exsample',
#    'correction': 'example',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'lette',
#    'correction': 'letter',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'say you been',
#    'correction': "say you've been",
#    'type': 'Grammatical',
#    'sentence': 12}],
#  [{'original': 'all these days',
#    'correction': 'all these things',
#    'type': 'Word Choice',
#    'sentence': 19},
#   {'original': 'Its',
#    'correction': "It's",
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'when ever',
#    'correction': 'whenever',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'learn new places',
#    'correction': 'learn about new places',
#    'type': 'Word Choice',
#    'sentence': 18},
#   {'original': 'I gives',
#    'correction': 'It gives',
#    'type': 'Grammatical',
#    'sentence': 12}],
#  [{'original': 'reason',
#    'correction': 'reasons',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'hace',
#    'correction': 'have',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'Teachers immediately you have to talk',
#    'correction': 'Teachers immediately know you have to talk',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'van', 'correction': 'can', 'type': 'Spelling', 'sentence': 10},
#   {'original': 'or', 'correction': 'of', 'type': 'Spelling', 'sentence': 16}],
#  [{'original': 'ask',
#    'correction': 'Ask',
#    'type': 'Word Choice',
#    'sentence': 8},
#   {'original': 'comunicate',
#    'correction': 'communicate',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'their',
#    'correction': "they're",
#    'type': 'Grammatical',
#    'sentence': 22},
#   {'original': 'decition',
#    'correction': 'decision',
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 13}],
#  [{'original': 'tred mill',
#    'correction': 'treadmill',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'peoples',
#    'correction': "people's",
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'attack',
#    'correction': 'attach',
#    'type': 'Word Choice',
#    'sentence': 6},
#   {'original': 'too', 'correction': 'to', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'attrack',
#    'correction': 'attract',
#    'type': 'Spelling',
#    'sentence': 24}],
#  [{'original': 'This being you can from wikipedia all the way to the infamous google in just .',
#    'correction': 'This means you can go from Wikipedia all the way to the infamous Google in just seconds.',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': '@CAPS4 thats one job exemple, another would be real state.',
#    'correction': "@CAPS4 that's one job example, another would be real estate.",
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'i think',
#    'correction': 'I think',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'you will get a the .',
#    'correction': 'you will get the information you need.',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'computers I believe',
#    'correction': 'computers. I believe',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'benefitted',
#    'correction': 'benefited',
#    'type': 'Spelling',
#    'sentence': 29},
#   {'original': 'garenteed',
#    'correction': 'guaranteed',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'commerical',
#    'correction': 'commercial',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'espically',
#    'correction': 'especially',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'coud',
#    'correction': 'could',
#    'type': 'Spelling',
#    'sentence': 7}],
#  [{'original': 'mind browning',
#    'correction': 'mind-blowing',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'world of war craft',
#    'correction': 'World of Warcraft',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'hoped you readers',
#    'correction': 'hope you readers enjoyed',
#    'type': 'Grammatical',
#    'sentence': 24},
#   {'original': 'recer antal acitivitys',
#    'correction': 'recreational activities',
#    'type': 'Spelling',
#    'sentence': 4}],
#  [{'original': 'parket',
#    'correction': 'packet',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'tribute',
#    'correction': 'contribute',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'gateway communication',
#    'correction': 'gateway for communication',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'a cheetah',
#    'correction': 'a cheetah runs',
#    'type': 'Word Choice',
#    'sentence': 12}],
#  [{'original': 'charater',
#    'correction': 'character',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'saild',
#    'correction': 'solid',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'truely',
#    'correction': 'truly',
#    'type': 'Spelling',
#    'sentence': 26},
#   {'original': 'design',
#    'correction': 'designed',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'This websites',
#    'correction': 'These websites',
#    'type': 'Grammatical',
#    'sentence': 18}],
#  [{'original': 'enviorment',
#    'correction': 'environment',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'sudject',
#    'correction': 'subject',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'phenominon',
#    'correction': 'phenomenon',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'iload',
#    'correction': 'load',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'cheif',
#    'correction': 'chief',
#    'type': 'Spelling',
#    'sentence': 10}],
#  [{'original': 'you',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'The goverment',
#    'correction': 'The government',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'Scheduleing',
#    'correction': 'Scheduling',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'you',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 19}],
#  [{'original': 'wikipedia',
#    'correction': 'Wikipedia',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'what',
#    'correction': 'whom',
#    'type': 'Word Choice',
#    'sentence': 10},
#   {'original': 'any one',
#    'correction': 'anyone',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'ture',
#    'correction': 'true',
#    'type': 'Spelling',
#    'sentence': 14}],
#  [{'original': 'enternet',
#    'correction': 'internet',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'eascier',
#    'correction': 'easier',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'coumputr',
#    'correction': 'computer',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'adulds',
#    'correction': 'adults',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'somthig',
#    'correction': 'something',
#    'type': 'Spelling',
#    'sentence': 6}],
#  [{'original': 'the reasons I feel this why are',
#    'correction': 'the reasons I feel this way are',
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'read in detail, as to why',
#    'correction': 'read in detail why',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'gey away from it',
#    'correction': 'get away from it',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'get off of computer.',
#    'correction': 'get off the computer.',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'that those people that think',
#    'correction': 'that those people who think',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'Consiquently',
#    'correction': 'Consequently',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'resonsibly',
#    'correction': 'responsibly',
#    'type': 'Spelling',
#    'sentence': 27},
#   {'original': 'pay chedes',
#    'correction': 'paychecks',
#    'type': 'Spelling',
#    'sentence': 33},
#   {'original': 'english',
#    'correction': 'English',
#    'type': 'Grammatical',
#    'sentence': 28},
#   {'original': 'unuseful',
#    'correction': 'useless',
#    'type': 'Word Choice',
#    'sentence': 44}],
#  [{'original': 'go gives',
#    'correction': 'get',
#    'type': 'Word Choice',
#    'sentence': 7},
#   {'original': 'the the',
#    'correction': 'the',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'inform',
#    'correction': 'informs',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'beleive',
#    'correction': 'believe',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'because, I',
#    'correction': 'because I',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'eisier',
#    'correction': 'easier',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'game while not only are fun improve',
#    'correction': 'games, while not only fun, improve',
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'redundunt',
#    'correction': 'redundant',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'benifits',
#    'correction': 'benefits',
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'exiting',
#    'correction': 'exciting',
#    'type': 'Spelling',
#    'sentence': 26}],
#  [{'original': 'computer are',
#    'correction': 'computers are',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'Peple',
#    'correction': 'People',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'compter',
#    'correction': 'computer',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'daster',
#    'correction': 'faster',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'computer are',
#    'correction': 'computers are',
#    'type': 'Grammatical',
#    'sentence': 13}],
#  [{'original': 'there',
#    'correction': 'their',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'whats',
#    'correction': "what's",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'to',
#    'correction': 'too',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'there',
#    'correction': "they're",
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'moveing',
#    'correction': 'moving',
#    'type': 'Spelling',
#    'sentence': 3}],
#  [{'original': 'other',
#    'correction': 'others',
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'most definately',
#    'correction': 'most definitely',
#    'type': 'Spelling',
#    'sentence': 32},
#   {'original': 'extremely faster',
#    'correction': 'much faster',
#    'type': 'Word Choice',
#    'sentence': 19},
#   {'original': "@CAPS3't",
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'a computers',
#    'correction': 'a computer',
#    'type': 'Grammatical',
#    'sentence': 15}],
#  [{'original': 'think',
#    'correction': 'thinking',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'whats',
#    'correction': "what's",
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'then',
#    'correction': 'than',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'gone',
#    'correction': 'game',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': "are't",
#    'correction': "aren't",
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': 'unnecissary',
#    'correction': 'unnecessary',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'infront',
#    'correction': 'in front',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'arnt',
#    'correction': "aren't",
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'perfessionals',
#    'correction': 'professionals',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'Whats',
#    'correction': "What's",
#    'type': 'Spelling',
#    'sentence': 15}],
#  [{'original': 'Useing',
#    'correction': 'Using',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'you self',
#    'correction': 'yourself',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 're eyes',
#    'correction': 'their eyes',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'excersize',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'affect',
#    'correction': 'effect',
#    'type': 'Word Choice',
#    'sentence': 19},
#   {'original': 'ar', 'correction': 'are', 'type': 'Spelling', 'sentence': 16},
#   {'original': 'technicly',
#    'correction': 'technically',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 6},
#   {'original': 'posative',
#    'correction': 'positive',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'the has',
#    'correction': 'the internet has',
#    'type': 'Word Choice',
#    'sentence': 24},
#   {'original': 'foreigh',
#    'correction': 'foreign',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'those',
#    'correction': 'there',
#    'type': 'Word Choice',
#    'sentence': 14},
#   {'original': 'wil',
#    'correction': 'will',
#    'type': 'Spelling',
#    'sentence': 16}],
#  [{'original': 'abut',
#    'correction': 'about',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'saved',
#    'correction': 'save',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'A home computer',
#    'correction': 'Home computers',
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'price',
#    'correction': 'piece',
#    'type': 'Word Choice',
#    'sentence': 23},
#   {'original': 'is',
#    'correction': 'are',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'tha', 'correction': 'the', 'type': 'Spelling', 'sentence': 5},
#   {'original': 'was',
#    'correction': 'were',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'rareley',
#    'correction': 'rarely',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'what your doing',
#    'correction': "what you're doing",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'america',
#    'correction': 'America',
#    'type': 'Grammatical',
#    'sentence': 23}],
#  [{'original': 'the baseball bats the pencils you we are all made by',
#    'correction': 'the baseball bats, the pencils we use are all made by',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'everday',
#    'correction': 'everyday',
#    'type': 'Spelling',
#    'sentence': 24},
#   {'original': 'one move step',
#    'correction': 'one more step',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'give people to learn',
#    'correction': 'give people the opportunity to learn',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'biult',
#    'correction': 'built',
#    'type': 'Spelling',
#    'sentence': 11}],
#  [{'original': 'magazeens',
#    'correction': 'magazines',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'trulthfully',
#    'correction': 'truthfully',
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'Insead',
#    'correction': 'Instead',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'imediatly',
#    'correction': 'immediately',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'increadable',
#    'correction': 'incredible',
#    'type': 'Spelling',
#    'sentence': 26}],
#  [{'original': 'electrisity',
#    'correction': 'electricity',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'paly',
#    'correction': 'play',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'when you the computer',
#    'correction': 'when you use the computer',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'is',
#    'correction': 'spends',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'thier',
#    'correction': 'their',
#    'type': 'Spelling',
#    'sentence': 8}],
#  [{'original': 'world wide web',
#    'correction': 'World Wide Web',
#    'type': 'Capitalization',
#    'sentence': 11},
#   {'original': 'threw',
#    'correction': 'through',
#    'type': 'Spelling',
#    'sentence': 19},
#   {'original': 'threw',
#    'correction': 'through',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'beacuse',
#    'correction': 'because',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'threw',
#    'correction': 'through',
#    'type': 'Spelling',
#    'sentence': 11}],
#  [{'original': 'their, it',
#    'correction': 'them, and it',
#    'type': 'Grammatical',
#    'sentence': 20},
#   {'original': 'it is using',
#    'correction': 'if using',
#    'type': 'Grammatical',
#    'sentence': 25},
#   {'original': 'langages',
#    'correction': 'languages',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'dictionary',
#    'correction': 'dictionaries',
#    'type': 'Grammatical',
#    'sentence': 23},
#   {'original': 'prounociation',
#    'correction': 'pronunciation',
#    'type': 'Spelling',
#    'sentence': 23}],
#  [{'original': 'than',
#    'correction': 'then',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'learne any thing',
#    'correction': 'learn anything',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'now', 'correction': 'new', 'type': 'Spelling', 'sentence': 31},
#   {'original': 'freen',
#    'correction': 'free',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'tele phones',
#    'correction': 'telephones',
#    'type': 'Spelling',
#    'sentence': 23}],
#  [{'original': 'other student',
#    'correction': 'other students',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'but all the time',
#    'correction': 'but not all the time',
#    'type': 'Grammatical',
#    'sentence': 20},
#   {'original': 'Student',
#    'correction': 'Students',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'much more places',
#    'correction': 'many more places',
#    'type': 'Word Choice',
#    'sentence': 17},
#   {'original': 'than',
#    'correction': 'while',
#    'type': 'Word Choice',
#    'sentence': 14}],
#  [{'original': 'thing',
#    'correction': 'think',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'we to problem',
#    'correction': 'we come to the problem',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'making bad .',
#    'correction': 'making bad decisions.',
#    'type': 'Grammatical',
#    'sentence': 20},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'Plus while so much you will be prone to using in , thus you with, nothing but a bad grade.',
#    'correction': 'Plus, while using it so much, you will be prone to distractions, thus leaving you with nothing but a bad grade.',
#    'type': 'Grammatical',
#    'sentence': 13}],
#  [{'original': 'your',
#    'correction': 'their',
#    'type': 'Word Choice',
#    'sentence': 13},
#   {'original': 'reasonings',
#    'correction': 'reasons',
#    'type': 'Word Choice',
#    'sentence': 26},
#   {'original': 'became',
#    'correction': 'become',
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'ruins',
#    'correction': 'ruin',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 14}],
#  [{'original': "computer's",
#    'correction': 'computers',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': "Computer's",
#    'correction': 'Computers',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'excercize',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'effect',
#    'correction': 'affect',
#    'type': 'Word Choice',
#    'sentence': 5},
#   {'original': 'to',
#    'correction': 'too',
#    'type': 'Grammatical',
#    'sentence': 7}],
#  [{'original': 'a bad acession',
#    'correction': 'a bad recession',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'out dated',
#    'correction': 'outdated',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'their',
#    'correction': "they're",
#    'type': 'Grammatical',
#    'sentence': 29},
#   {'original': 'definetly',
#    'correction': 'definitely',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'their',
#    'correction': "they're",
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'convienience',
#    'correction': 'convenience',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'helps',
#    'correction': 'help',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'reason',
#    'correction': 'reasons',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'beleive',
#    'correction': 'believe',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'convienience',
#    'correction': 'convenience',
#    'type': 'Spelling',
#    'sentence': 3}],
#  [{'original': 'health',
#    'correction': 'healthy',
#    'type': 'Word Choice',
#    'sentence': 14},
#   {'original': 'the thev',
#    'correction': 'the',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'uses',
#    'correction': 'use',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'suceed',
#    'correction': 'succeed',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'leperdy',
#    'correction': 'Jeopardy',
#    'type': 'Spelling',
#    'sentence': 7}],
#  [{'original': 'okey',
#    'correction': 'day',
#    'type': 'Word Choice',
#    'sentence': 24},
#   {'original': 'any thing',
#    'correction': 'anything',
#    'type': 'Spelling',
#    'sentence': 26},
#   {'original': 'word',
#    'correction': 'worn',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'saftey',
#    'correction': 'safety',
#    'type': 'Spelling',
#    'sentence': 24},
#   {'original': 'over weight',
#    'correction': 'overweight',
#    'type': 'Spelling',
#    'sentence': 11}],
#  [{'original': 'dishies',
#    'correction': 'dishes',
#    'type': 'Spelling',
#    'sentence': 18},
#   {'original': 'breathe',
#    'correction': 'breath',
#    'type': 'Word Choice',
#    'sentence': 23},
#   {'original': 'Your',
#    'correction': "You're",
#    'type': 'Grammatical',
#    'sentence': 27},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'than',
#    'correction': 'then',
#    'type': 'Word Choice',
#    'sentence': 13}],
#  [{'original': 'in a office',
#    'correction': 'in an office',
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'their',
#    'correction': 'its',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'throught',
#    'correction': 'through',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'menning',
#    'correction': 'meaning',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'happend',
#    'correction': 'happened',
#    'type': 'Spelling',
#    'sentence': 9}],
#  [{'original': '@PERCENT1',
#    'correction': 'percent',
#    'type': 'Other',
#    'sentence': 5},
#   {'original': 'that kids like playing games on them',
#    'correction': 'that kids like to play games on them',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'calculated',
#    'correction': 'calculator',
#    'type': 'Word Choice',
#    'sentence': 8},
#   {'original': 'to do work',
#    'correction': 'doing work',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'easier they',
#    'correction': 'easier; they',
#    'type': 'Grammatical',
#    'sentence': 2}],
#  [{'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'This a letter',
#    'correction': 'This is a letter',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'Its',
#    'correction': "It's",
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'secreaterys',
#    'correction': 'secretaries',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'Im',
#    'correction': "I'm",
#    'type': 'Grammatical',
#    'sentence': 5}],
#  [{'original': 'haveing',
#    'correction': 'having',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'depresion',
#    'correction': 'depression',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'enternet',
#    'correction': 'internet',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'humerous',
#    'correction': 'humorous',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'bought',
#    'correction': 'brought',
#    'type': 'Word Choice',
#    'sentence': 2}],
#  [{'original': 'noreveting',
#    'correction': 'not investing',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'affenders',
#    'correction': 'offenders',
#    'type': 'Spelling',
#    'sentence': 12},
#   {'original': 'leanring',
#    'correction': 'learning',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'chating',
#    'correction': 'chatting',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'controll',
#    'correction': 'control',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'wait',
#    'correction': 'weight',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'there',
#    'correction': 'their',
#    'type': 'Word Choice',
#    'sentence': 19},
#   {'original': 'talking',
#    'correction': 'taking',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'leeds',
#    'correction': 'leads',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'feelings',
#    'correction': 'feeling',
#    'type': 'Grammatical',
#    'sentence': 8}],
#  [{'original': 'sized',
#    'correction': 'sizes',
#    'type': 'Spelling',
#    'sentence': 34},
#   {'original': 'These day',
#    'correction': 'These days',
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'with a soccerball',
#    'correction': 'with a soccer ball',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'Lets',
#    'correction': "Let's",
#    'type': 'Grammatical',
#    'sentence': 13}],
#  [{'original': 'spent',
#    'correction': 'spend',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': "they don't get they don't walk",
#    'correction': "they don't get to walk",
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'm', 'correction': 'My', 'type': 'Grammatical', 'sentence': 6},
#   {'original': 'A on their heart',
#    'correction': 'a strain on their heart',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': "could you can't do",
#    'correction': "that you can't do",
#    'type': 'Grammatical',
#    'sentence': 5}],
#  [{'original': 'reconected',
#    'correction': 'reconnected',
#    'type': 'Spelling',
#    'sentence': 24},
#   {'original': 'deffidently',
#    'correction': 'definitely',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'personal',
#    'correction': 'personally',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'elses lifes',
#    'correction': "else's lives",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'you',
#    'correction': 'your',
#    'type': 'Grammatical',
#    'sentence': 27}],
#  [{'original': 'evebady',
#    'correction': 'everybody',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'far a long time',
#    'correction': 'for a long time',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'takeing',
#    'correction': 'talking',
#    'type': 'Spelling',
#    'sentence': 6},
#   {'original': 'Now what will you why you that side',
#    'correction': 'Now what will you do with that knowledge?',
#    'type': 'Word Choice',
#    'sentence': 9},
#   {'original': 'becau',
#    'correction': 'because',
#    'type': 'Spelling',
#    'sentence': 1}],
#  [{'original': 'france',
#    'correction': 'France',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'africa',
#    'correction': 'Africa',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'jest',
#    'correction': 'just',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'affect',
#    'correction': 'effect',
#    'type': 'Word Choice',
#    'sentence': 2},
#   {'original': 'benifit',
#    'correction': 'benefit from',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'cause',
#    'correction': 'causes',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'Its',
#    'correction': "It's",
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'slopy',
#    'correction': 'sloppy',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'friend',
#    'correction': 'friends',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': "of cell's",
#    'correction': 'of cells',
#    'type': 'Grammatical',
#    'sentence': 8}],
#  [{'original': 'a great of knowledge',
#    'correction': 'a great source of knowledge',
#    'type': 'Word Choice',
#    'sentence': 7},
#   {'original': 'there',
#    'correction': 'their',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'So you eyes are beter their seeing nothing.',
#    'correction': "So your eyes are better; they're seeing nothing.",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'fastes',
#    'correction': 'fastest',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'Dear, Local @ORGANIZATION1 paper',
#    'correction': 'Dear Local @ORGANIZATION1 paper',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'word',
#    'correction': 'Word',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'shourt',
#    'correction': 'short',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'Lets',
#    'correction': "Let's",
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'skype',
#    'correction': 'Skype',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'Antoher',
#    'correction': 'Another',
#    'type': 'Spelling',
#    'sentence': 20}],
#  [{'original': 'Latly',
#    'correction': 'Lately',
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'When he not on during they day',
#    'correction': "When he's not on during the day",
#    'type': 'Grammatical',
#    'sentence': 34},
#   {'original': 'a at home mother',
#    'correction': 'an at-home mother',
#    'type': 'Grammatical',
#    'sentence': 33},
#   {'original': 'bannas',
#    'correction': 'bananas',
#    'type': 'Spelling',
#    'sentence': 24},
#   {'original': 'Te', 'correction': 'The', 'type': 'Spelling', 'sentence': 22}],
#  [{'original': 'jus',
#    'correction': 'just',
#    'type': 'Spelling',
#    'sentence': 19},
#   {'original': 'intellegent',
#    'correction': 'intelligent',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': "aren'@CAPS2",
#    'correction': "aren't",
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'person',
#    'correction': 'people',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'Which how',
#    'correction': 'This is how',
#    'type': 'Grammatical',
#    'sentence': 8}],
#  [{'original': 'vidieo',
#    'correction': 'video',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'thay',
#    'correction': 'they',
#    'type': 'Spelling',
#    'sentence': 7},
#   {'original': 'scientist',
#    'correction': 'scientists',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'tramendisly',
#    'correction': 'tremendously',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'on a button,, Who',
#    'correction': 'on a button. Who',
#    'type': 'Grammatical',
#    'sentence': 21}],
#  [{'original': 'does benifit',
#    'correction': 'do benefit',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 6},
#   {'original': 'they are',
#    'correction': 'and they are',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 8}],
#  [{'original': 'facebook',
#    'correction': 'Facebook',
#    'type': 'Grammatical',
#    'sentence': 23},
#   {'original': 'boredom',
#    'correction': 'boredom',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'everyday',
#    'correction': 'every day',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'affects',
#    'correction': 'effects',
#    'type': 'Word Choice',
#    'sentence': 3},
#   {'original': 'Everyday',
#    'correction': 'Every day',
#    'type': 'Word Choice',
#    'sentence': 11}],
#  [{'original': "Sure people don't get to enjoy the campus,",
#    'correction': "Sure, people don't get to enjoy the campus,",
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'myspace',
#    'correction': 'MySpace',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'Remember computers are easy to use,',
#    'correction': 'Remember, computers are easy to use,',
#    'type': 'Grammatical',
#    'sentence': 20},
#   {'original': "that is only if you start talking to people you don't know.",
#    'correction': "but that is only if you start talking to people you don't know.",
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'Computers are amazing advancement',
#    'correction': 'Computers are an amazing advancement',
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'far which',
#    'correction': 'for a walk',
#    'type': 'Word Choice',
#    'sentence': 19},
#   {'original': 'some thing',
#    'correction': 'something',
#    'type': 'Spelling',
#    'sentence': 11},
#   {'original': 'talk',
#    'correction': 'talking',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'you.', 'correction': 'you.', 'type': 'Other', 'sentence': 13},
#   {'original': 'to', 'correction': 'too', 'type': 'Spelling', 'sentence': 3}],
#  [{'original': 'Agains',
#    'correction': 'Against',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': "wasn't going to sell more computer",
#    'correction': "weren't going to sell more computers",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'grate',
#    'correction': 'great',
#    'type': 'Spelling',
#    'sentence': 10},
#   {'original': 'how much often',
#    'correction': 'how often',
#    'type': 'Grammatical',
#    'sentence': 16},
#   {'original': 'them',
#    'correction': 'him',
#    'type': 'Word Choice',
#    'sentence': 15}],
#  [{'original': 'is used',
#    'correction': 'are used',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'intead',
#    'correction': 'instead',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'and effect',
#    'correction': 'an effect',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'negitive',
#    'correction': 'negative',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'a play',
#    'correction': 'and play',
#    'type': 'Grammatical',
#    'sentence': 19}],
#  [{'original': 'excersize',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'excersize',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 18},
#   {'original': 'reutine',
#    'correction': 'routine',
#    'type': 'Spelling',
#    'sentence': 9},
#   {'original': 'instratford',
#    'correction': 'in Stratford',
#    'type': 'Grammatical',
#    'sentence': 21},
#   {'original': 'laye',
#    'correction': 'late',
#    'type': 'Spelling',
#    'sentence': 13}],
#  [{'original': 'infact',
#    'correction': 'in fact',
#    'type': 'Spelling',
#    'sentence': 15},
#   {'original': 'beliver',
#    'correction': 'believer',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'relitives',
#    'correction': 'relatives',
#    'type': 'Spelling',
#    'sentence': 18},
#   {'original': 'globaly',
#    'correction': 'globally',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'ourlives',
#    'correction': 'our lives',
#    'type': 'Spelling',
#    'sentence': 16}],
#  [{'original': 'pletvera',
#    'correction': 'plethora',
#    'type': 'Spelling',
#    'sentence': 24},
#   {'original': 'cerrect',
#    'correction': 'correct',
#    'type': 'Spelling',
#    'sentence': 39},
#   {'original': 'their',
#    'correction': 'his or her',
#    'type': 'Grammatical',
#    'sentence': 15},
#   {'original': 'Futhermore',
#    'correction': 'Furthermore',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'on average',
#    'correction': 'On average',
#    'type': 'Grammatical',
#    'sentence': 38}],
#  [{'original': 'yu', 'correction': 'you', 'type': 'Spelling', 'sentence': 27},
#   {'original': 'imprdove',
#    'correction': 'improve',
#    'type': 'Spelling',
#    'sentence': 38},
#   {'original': 'the society',
#    'correction': 'society',
#    'type': 'Grammatical',
#    'sentence': 39},
#   {'original': 'suggest',
#    'correction': 'suggests',
#    'type': 'Grammatical',
#    'sentence': 28},
#   {'original': 'more of people',
#    'correction': 'more aware of people',
#    'type': 'Word Choice',
#    'sentence': 16}],
#  [{'original': 'all there, could',
#    'correction': 'all this could',
#    'type': 'Grammatical',
#    'sentence': 18},
#   {'original': 'the',
#    'correction': 'them',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'can bad',
#    'correction': 'can be bad',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'at a the eyes',
#    'correction': 'for the eyes',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'became',
#    'correction': 'becomes',
#    'type': 'Grammatical',
#    'sentence': 3}],
#  [{'original': 'apetite',
#    'correction': 'appetite',
#    'type': 'Spelling',
#    'sentence': 19},
#   {'original': 'The electricity that runs computers of this radiation.',
#    'correction': 'The electricity that runs computers emits radiation.',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'excersise',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 23},
#   {'original': 'The computers are children from a better education.',
#    'correction': 'The computers are preventing children from a better education.',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'moved and of were more succesful in school.',
#    'correction': 'moved and were more successful in school.',
#    'type': 'Grammatical',
#    'sentence': 10}],
#  [{'original': 'use',
#    'correction': 'used',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'lets',
#    'correction': 'let',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'Its',
#    'correction': "It's",
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'Has',
#    'correction': 'It has',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'useing',
#    'correction': 'using',
#    'type': 'Spelling',
#    'sentence': 12}],
#  [{'original': 'maintaing',
#    'correction': 'maintaining',
#    'type': 'Spelling',
#    'sentence': 16},
#   {'original': 'goto',
#    'correction': 'go to',
#    'type': 'Spelling',
#    'sentence': 20},
#   {'original': 'their',
#    'correction': 'there',
#    'type': 'Grammatical',
#    'sentence': 19},
#   {'original': 'leaguges',
#    'correction': 'leagues',
#    'type': 'Spelling',
#    'sentence': 25},
#   {'original': 'your',
#    'correction': "you're",
#    'type': 'Grammatical',
#    'sentence': 10}],
#  [{'original': 'it less your hand',
#    'correction': 'it lessens the strain on your hand',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'find everyone',
#    'correction': 'find everything',
#    'type': 'Word Choice',
#    'sentence': 15},
#   {'original': 'heerd',
#    'correction': 'heard',
#    'type': 'Spelling',
#    'sentence': 1},
#   {'original': 'benef it',
#    'correction': 'benefit',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'dispute',
#    'correction': 'despite',
#    'type': 'Word Choice',
#    'sentence': 1}],
#  [{'original': 'probley',
#    'correction': 'probably',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': "opinion's",
#    'correction': 'opinions',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'wont',
#    'correction': "won't",
#    'type': 'Grammatical',
#    'sentence': 12},
#   {'original': 'looking on',
#    'correction': 'looking at',
#    'type': 'Word Choice',
#    'sentence': 1},
#   {'original': 'rather then',
#    'correction': 'rather than',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': '@CAPS1',
#    'correction': 'Twitter',
#    'type': 'Word Choice',
#    'sentence': 6},
#   {'original': 'facebook',
#    'correction': 'Facebook',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'a positive effects of',
#    'correction': 'positive effects on',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'great you can,',
#    'correction': 'great because you can',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'peoples',
#    'correction': "people's",
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'so that he can be prepared',
#    'correction': 'so that he could be prepared',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'is that is helps',
#    'correction': 'is that it helps',
#    'type': 'Grammatical',
#    'sentence': 22},
#   {'original': 'it helps them with',
#    'correction': 'they help them with',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': 'helps us learn',
#    'correction': 'help us learn',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'it helps them learn',
#    'correction': 'they help them learn',
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'Now that are new technology',
#    'correction': 'Now that there is new technology',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'exerce',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 28},
#   {'original': 'tecnology',
#    'correction': 'technology',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'effecting',
#    'correction': 'affecting',
#    'type': 'Word Choice',
#    'sentence': 4},
#   {'original': 'relie',
#    'correction': 'rely',
#    'type': 'Spelling',
#    'sentence': 18}],
#  [{'original': 'i', 'correction': 'I', 'type': 'Grammatical', 'sentence': 5},
#   {'original': 'thats',
#    'correction': "that's",
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'exsesise',
#    'correction': 'exercise',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'could',
#    'correction': 'can',
#    'type': 'Word Choice',
#    'sentence': 4}],
#  [{'original': 'mose',
#    'correction': 'mouse',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'reson',
#    'correction': 'reason',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'jod', 'correction': 'job', 'type': 'Spelling', 'sentence': 3},
#   {'original': 'resifes',
#    'correction': 'recipes',
#    'type': 'Spelling',
#    'sentence': 3},
#   {'original': 'grand mom',
#    'correction': 'grandmom',
#    'type': 'Spelling',
#    'sentence': 2}],
#  [{'original': "it's different",
#    'correction': "they're different",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'their alike',
#    'correction': "they're alike",
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'typer',
#    'correction': 'typist',
#    'type': 'Word Choice',
#    'sentence': 7},
#   {'original': 'you typeing',
#    'correction': 'your typing',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'their doing',
#    'correction': "they're doing",
#    'type': 'Grammatical',
#    'sentence': 13}],
#  [{'original': 'the in jobs, and in to days @CAPS1 the for that gets In the quarter mile must be able to find his and on in an office you have to watch as typing',
#    'correction': "them in jobs, and in today's world, the person that gets the job must be able to find his way around an office and watch as they type",
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'were',
#    'correction': 'since',
#    'type': 'Word Choice',
#    'sentence': 12},
#   {'original': 'a positive reason',
#    'correction': 'positive reasons',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'allows',
#    'correction': 'allow',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'what better to start than now',
#    'correction': 'what better time to start than now',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 8},
#   {'original': 'plant',
#    'correction': 'plants',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': 'arent',
#    'correction': "aren't",
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'and',
#    'correction': 'history',
#    'type': 'Word Choice',
#    'sentence': 15},
#   {'original': 'Think about!',
#    'correction': 'Think about it!',
#    'type': 'Grammatical',
#    'sentence': 18}],
#  [{'original': 'get to out location',
#    'correction': 'get to our location',
#    'type': 'Spelling',
#    'sentence': 8},
#   {'original': 'diffrent',
#    'correction': 'different',
#    'type': 'Spelling',
#    'sentence': 13},
#   {'original': 'location were',
#    'correction': 'location where',
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'the years computers',
#    'correction': 'the years, computers have',
#    'type': 'Grammatical',
#    'sentence': 17},
#   {'original': 'cant',
#    'correction': "can't",
#    'type': 'Grammatical',
#    'sentence': 10}],
#  [{'original': 'helps',
#    'correction': 'help',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'doing lazy then go',
#    'correction': 'being lazy, then go',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'Getting more active @MONTH1 even bring',
#    'correction': 'Getting more active can even bring',
#    'type': 'Grammatical',
#    'sentence': 7},
#   {'original': "your'e",
#    'correction': "you're",
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': 'bad effects on peoples lives',
#    'correction': "bad effects on people's lives",
#    'type': 'Grammatical',
#    'sentence': 1}],
#  [{'original': 'what if something happened that you needed to know about you could just go on the internet and look it up',
#    'correction': 'what if something happened that you needed to know about? You could just go on the internet and look it up',
#    'type': 'Grammatical',
#    'sentence': 14},
#   {'original': 'your phones not',
#    'correction': "your phone's not",
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'pixecl',
#    'correction': 'pixelated',
#    'type': 'Spelling',
#    'sentence': 4},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'went to talk',
#    'correction': 'want to talk',
#    'type': 'Word Choice',
#    'sentence': 10}],
#  [{'original': 'excersizing',
#    'correction': 'exercising',
#    'type': 'Spelling',
#    'sentence': 37},
#   {'original': 'Every intelligent citizen would @CAPS1 that computer @MONTH1 have wrong information.',
#    'correction': 'Every intelligent citizen would agree that computers sometimes have wrong information.',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'In addition just going outside can do more.',
#    'correction': 'In addition, just going outside can do more.',
#    'type': 'Grammatical',
#    'sentence': 38},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 28},
#   {'original': 'fashion',
#    'correction': 'fashioned',
#    'type': 'Word Choice',
#    'sentence': 42}],
#  [{'original': 'shone',
#    'correction': 'shown',
#    'type': 'Spelling',
#    'sentence': 19},
#   {'original': 'dont',
#    'correction': "don't",
#    'type': 'Grammatical',
#    'sentence': 5},
#   {'original': 'Its',
#    'correction': 'It',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': "give's",
#    'correction': 'gives',
#    'type': 'Grammatical',
#    'sentence': 6},
#   {'original': 'their',
#    'correction': "they're",
#    'type': 'Grammatical',
#    'sentence': 22}],
#  [{'original': 'relized',
#    'correction': 'realized',
#    'type': 'Spelling',
#    'sentence': 5},
#   {'original': 'reaserch',
#    'correction': 'research',
#    'type': 'Spelling',
#    'sentence': 17},
#   {'original': 'knowhere',
#    'correction': 'nowhere',
#    'type': 'Spelling',
#    'sentence': 14},
#   {'original': 'repertative',
#    'correction': 'repetitive',
#    'type': 'Spelling',
#    'sentence': 21},
#   {'original': 'availble',
#    'correction': 'available',
#    'type': 'Spelling',
#    'sentence': 18}],
#  [{'original': 'have good time',
#    'correction': 'have a good time',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'you friends',
#    'correction': 'your friends',
#    'type': 'Grammatical',
#    'sentence': 20},
#   {'original': 'with',
#    'correction': 'will',
#    'type': 'Grammatical',
#    'sentence': 11},
#   {'original': 'with',
#    'correction': 'will',
#    'type': 'Grammatical',
#    'sentence': 10},
#   {'original': 'me and her',
#    'correction': 'she and I',
#    'type': 'Grammatical',
#    'sentence': 18}],
#  [{'original': 'never seen',
#    'correction': 'never have seen',
#    'type': 'Grammatical',
#    'sentence': 25},
#   {'original': 'ever',
#    'correction': 'over',
#    'type': 'Spelling',
#    'sentence': 22},
#   {'original': 'relie',
#    'correction': 'rely',
#    'type': 'Spelling',
#    'sentence': 2},
#   {'original': '@CAPS3',
#    'correction': 'know',
#    'type': 'Word Choice',
#    'sentence': 9},
#   {'original': "Let's not forget about what lawyers do?",
#    'correction': "Let's not forget about what lawyers do.",
#    'type': 'Grammatical',
#    'sentence': 19}],
#  [{'original': 'there',
#    'correction': 'their',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'everyone',
#    'correction': 'Everyone',
#    'type': 'Grammatical',
#    'sentence': 2},
#   {'original': 'its',
#    'correction': "it's",
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'making',
#    'correction': 'make',
#    'type': 'Grammatical',
#    'sentence': 4},
#   {'original': 'but',
#    'correction': 'But',
#    'type': 'Grammatical',
#    'sentence': 4}],
#  [{'original': 'faraway',
#    'correction': 'far away',
#    'type': 'Word Choice',
#    'sentence': 9},
#   {'original': 'powerpoint',
#    'correction': 'PowerPoint',
#    'type': 'Grammatical',
#    'sentence': 13},
#   {'original': 'videochat',
#    'correction': 'video chat',
#    'type': 'Word Choice',
#    'sentence': 10},
#   {'original': 'learning of catching',
#    'correction': 'learning or catching',
#    'type': 'Grammatical',
#    'sentence': 3},
#   {'original': 'microsoft word',
#    'correction': 'Microsoft Word',
#    'type': 'Grammatical',
#    'sentence': 12}],
#  [{'original': 'use',
#    'correction': 'use,',
#    'type': 'Grammatical',
#    'sentence': 1},
#   {'original': "aunt's lisa",
#    'correction': 'aunt Lisa',
#    'type': 'Grammatical',
#    'sentence': 9},
#   {'original': 'alot',
#    'correction': 'a lot',
#    'type': 'Spelling',
#    'sentence': 32},
#   {'original': 'is',
#    'correction': 'there is',
#    'type': 'Grammatical',
#    'sentence': 23},
#   {'original': 'dads',
#    'correction': "dad's",
#    'type': 'Grammatical',
#    'sentence': 15}]]

# %%
joblib.dump(sampled_corrections, 'files/correction_test_100essay_5corr')
# Out:
# ['files/correction_test_100essay_5corr']

# %%
# Function to apply corrections to the essay
def apply_corrections_grammar(essay, corrections):
    # Tokenize the essay into sentences using NLTK
    sentences = nltk.sent_tokenize(essay)

    # Create a list to store corrected sentences
    corrected_sentences = []

    # Iterate through sentences
    for i, sentence in enumerate(sentences):
        # Apply corrections to the current sentence
        for correction in corrections:
            # Adjust the index by subtracting 1 to match the enumeration starting from 0
            if correction['sentence'] == i + 1:
                # Replace all occurrences of the incorrect text with the correction
                #sentence = sentence.replace(correction['original'], correction['correction'])
                 # Use regular expression with word boundaries to replace only whole words
                sentence = re.sub(r'\b' + re.escape(correction['original']) + r'\b', correction['correction'], sentence)
        # Add the corrected sentence to the list
        corrected_sentences.append(sentence)

    # Join the corrected sentences to form the final essay
    corrected_essay = ' '.join(corrected_sentences)
    return corrected_essay

# Function to generate all combinations of corrections and apply them
def generate_corrected_versions(essay, corrections):
    corrected_versions = []
    max_corrections = len(corrections)

    # Iterate over different numbers of corrections to apply
    for num_corrections in range(1, max_corrections + 1):
        for combination in itertools.combinations(corrections, num_corrections):
            corrected_essay = apply_corrections_grammar(essay, combination)
            corrected_versions.append(corrected_essay)
  
    return corrected_versions

# # Example usage
# essay = "This is a tess essay. The break through was amazing. The possitive effects were clear."
# corrections = [
#     {'original': 'tess', 'correction': 'test', 'type': 'Spelling', 'sentence': 1},
#     {'original': 'break through', 'correction': 'breakthrough', 'type': 'Spelling', 'sentence': 2},
#     {'original': 'possitive', 'correction': 'positive', 'type': 'Spelling', 'sentence': 3},
# ]

# # Generate corrected versions with combinations of 1, 2, and 3 corrections
# corrected_versions = generate_corrected_versions(essay, corrections)
# corrected_versions

# %%
correction_test_100essay_5corr = joblib.load('files/correction_test_100essay_5corr')

corrected_test_100data_5corr = []

for index, row in data_100.iterrows():
    try:
        corrected_essays = generate_corrected_versions(row['essay'], correction_test_100essay_5corr[index]) 
        # Append the result to the list
        corrected_test_100data_5corr.append(corrected_essays)
    except Exception as e:
        print(f"Error processing row {index}: {e}")
        corrected_test_100data_5corr.append(None)  # Append None or an empty dict if an error occurs

# %%
np.array(corrected_test_100data_5corr).shape
# Out:
# (100, 31)

# %%
joblib.dump(corrected_test_100data_5corr, 'files/corrected_test_100data_5corr')
# Out:
# ['files/corrected_test_100data_5corr']
