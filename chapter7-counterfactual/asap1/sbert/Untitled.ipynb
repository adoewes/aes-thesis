# %%
import joblib
import xgboost

# %%
model = joblib.load("model_asap1_counterfactual")

# %%
model

# %%
booster = xgboost.Booster()

# %%
model.save_model('new_model.json')

# %%
booster.load_model('new_model.json')

# %%
booster
