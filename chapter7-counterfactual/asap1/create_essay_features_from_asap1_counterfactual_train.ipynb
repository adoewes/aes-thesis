# %%
from features.essay_features import extract_essay_features, get_length_features
import pandas as pd
import numpy as np
import joblib
# Out:
# C:\Users\VICTUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
#data_train_counter = joblib.load('files/errored_train_100data_5err')
data_train_counter = joblib.load('files/corrected_train_100data_5corr')

# %%
np.array(data_train_counter).shape
# Out:
# (100, 31)

# %%
prompt = """More and more people use computers, but not everyone agrees that this benefits society. Those who support advances in technology believe that computers have a positive effect on people. They teach hand-eye coordination, give people the ability to learn about faraway places and people, and even allow people to talk online with other people. Others have different ideas. Some experts are concerned that people are spending too much time on their computers and less time exercising, enjoying nature, and interacting with family and friends. 

Write a letter to your local newspaper in which you state your opinion on the effects computers have on people. Persuade the readers to agree with you.
"""

# %%
feats_counter = []

row_ctr = 0

for row in data_train_counter:
    row_feats = []
    ctr = 0
    for essay in row:
        feats = extract_essay_features(essay, prompt)
        row_feats.append(feats)
        ctr += 1
        print("current: ", ctr)
    feats_counter.append(row_feats)
    row_ctr = row_ctr + 1
    print("Finished row number : ", row_ctr)

print("row number: ", row_ctr)
# Out:
# current:  1
# current:  2
# current:  3
# current:  4
# current:  5
# current:  6
# current:  7
# current:  8
# current:  9
# current:  10
# current:  11
# current:  12
# current:  13
# current:  14
# current:  15
# current:  16
# current:  17
# current:  18
# current:  19
# current:  20
# current:  21
# current:  22
# current:  23
# current:  24
# current:  25
# current:  26
# current:  27
# current:  28
# current:  29
# current:  30
# current:  31
# Finished row number :  1
# current:  1
# current:  2
# current:  3
# current:  4
# current:  5
# current:  6
# current:  7
# current:  8
# current:  9
# current:  10
# current:  11
# current:  12
# current:  13
# current:  14
# current:  15
# current:  16
# current:  17
# current:  18
# current:  19
# current:  20
# current:  21
# current:  22
# current:  23
# current:  24
# current:  25
# current:  26
# current:  27
# current:  28
# current:  29
# current:  30
# current:  31
# Finished row number :  2
# current:  1
# current:  2
# ...

# %%
np.array(feats_counter).shape
# Out:
# (100, 31, 1, 778)

# %%
joblib.dump(np.array(feats_counter), 'files/feats_counter_train_correct_778')
# Out:
# ['files/feats_counter_train_correct_778']
